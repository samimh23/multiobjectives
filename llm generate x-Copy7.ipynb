# %%
# %load_ext cython

# %%
import requests
import json

def get_strategy_from_llm(iteration):
    """
    Queries the local Ollama Llama3:8b model to suggest an optimization strategy.
    
    Args:
        iteration (int): The current iteration number of the algorithm.
        
    Returns:
        int: The chosen strategy number (1-5).
    """
    prompt = f"""Select strategy for knapsack optimization iteration {iteration}/100.

Phase: {"Early" if iteration < 20 else "Mid" if iteration < 60 else "Late" if iteration < 90 else "Final"}

Strategies:
1 = Balanced exploration (early phase, need diversity)
2 = Objective specialization (mid phase, extreme solutions)
3 = Gap filling (always good, improve weak objective)
4 = Aggressive exploitation (late phase, high quality only)
5 = Random perturbation (if stuck)

Reply with ONE number (1-5):"""

    url = "http://localhost:11434/api/generate"
    payload = {
        "model": "llama3:8b",
        "prompt": prompt,
        "stream": False,
        "options": {
            "temperature": 0.7,  # Some creativity but not too random
            "max_tokens": 10     # We only need a single digit
        }
    }
    
    try:
        response = requests.post(url, json=payload, timeout=40) # Added timeout
        if response.status_code == 200:
            result = response.json()
            # Extract the first digit found in the response
            response_text = result.get('response', '')
            for char in response_text:
                if char.isdigit():
                    strategy = int(char)
                    # Ensure it's a valid strategy number
                    return min(max(strategy, 1), 5)
            # Fallback if no number found
            print(f"Warning: LLM response '{response_text}' did not contain a number. Defaulting to strategy 1.")
            return 1
        else:
            print(f"Error connecting to Ollama: {response.status_code} - {response.text}")
            return 1  # Default to balanced exploration
    except requests.exceptions.RequestException as e:
        print(f"Error getting strategy from LLM: {e}. Is Ollama running?")
        return 1  # Default to balanced exploration

# --- Test the function ---
# Make sure Ollama is running before testing!
print("Testing LLM connection...")
strategy = get_strategy_from_llm(50)
print(f"LLM suggested strategy: {strategy}")
# Out:
# Testing LLM connection...
# LLM suggested strategy: 2

# %%
# %%cython
# # ============================================================================
# # HYBRID LLM-MOACP - STABLE VERSION
# # ============================================================================
#
# from libc.stdlib cimport malloc, free, srand, rand
# from libc.string cimport memset
# from libc.math cimport exp
# import time
#
# cdef struct ind:
#     int nombr_nonpris
#     int nombr
#     int rank
#     float fitnessbest
#     float fitness
#     int explored
#     double *f
#     double *capa
#     double *v
#     int *d
#     int *Items
#
# cdef struct pop:
#     int size
#     int maxsize
#     ind **ind_array
#
# # ============================================================================
# # GLOBAL VARIABLES
# # ============================================================================
#
# cdef int NBITEMS = 250
# cdef int ni = 250
# cdef int L = 5
# cdef double LARGE = 10e50
# cdef float smallValue = 0.0000001
# cdef double kappa = 0.05
# cdef int alpha = 10
# cdef int paretoIni = 28000
#
# cdef int nf = 2
# cdef double *capacities = NULL
# cdef int **weights = NULL
# cdef int **profits = NULL
# cdef double *vector_weight = NULL
# cdef double max_bound = 0.0
# cdef double **OBJ_Weights = NULL
# cdef int nombreLIGNE = 0
# cdef int nextLn = 0
# cdef int inv = 0
# cdef int OBJ_Weights_lines = 0
#
# # Statistics
# cdef long long llm_strategy_calls = 0
# cdef int current_iteration = 0
#
# # ============================================================================
# # UTILITY FUNCTIONS
# # ============================================================================
#
# def seed(int x):
#     srand(x)
#
# cdef int irand(int range_val):
#     return rand() % range_val
#
# cdef void *chk_malloc(size_t size):
#     cdef void *return_value = malloc(size)
#     if return_value == NULL:
#         raise MemoryError("Out of memory.")
#     memset(return_value, 0, size)
#     return return_value
#
# # ============================================================================
# # POPULATION MANAGEMENT
# # ============================================================================
#
# cdef pop *create_pop(int maxsize, int nf):
#     cdef int i
#     cdef pop *pp = <pop *>chk_malloc(sizeof(pop))
#     pp.size = 0
#     pp.maxsize = maxsize
#     pp.ind_array = <ind **>chk_malloc(maxsize * sizeof(void*))
#     for i in range(maxsize):
#         pp.ind_array[i] = NULL
#     return pp
#
# cdef ind *create_ind(int nf):
#     cdef int i
#     cdef ind *p_ind = <ind *>chk_malloc(sizeof(ind))
#     p_ind.nombr_nonpris = 0
#     p_ind.nombr = 0
#     p_ind.rank = 0
#     p_ind.fitnessbest = -1.0
#     p_ind.fitness = -1.0
#     p_ind.explored = 0
#     p_ind.f = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.capa = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.v = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.d = <int *>chk_malloc(ni * sizeof(int))
#     p_ind.Items = <int *>chk_malloc(ni * sizeof(int))
#     for i in range(ni):
#         p_ind.Items[i] = 0
#         p_ind.d[i] = 0
#     for i in range(nf):
#         p_ind.f[i] = 0.0
#         p_ind.capa[i] = 0.0
#         p_ind.v[i] = 0.0
#     return p_ind
#
# cdef ind *ind_copy(ind *i):
#     cdef ind *p_ind = create_ind(nf)
#     cdef int k
#     p_ind.nombr_nonpris = i.nombr_nonpris
#     p_ind.nombr = i.nombr
#     p_ind.rank = i.rank
#     p_ind.fitnessbest = i.fitnessbest
#     p_ind.fitness = i.fitness
#     p_ind.explored = i.explored
#     for k in range(nf):
#         p_ind.f[k] = i.f[k]
#         p_ind.v[k] = i.v[k]
#         p_ind.capa[k] = i.capa[k]
#     for k in range(ni):
#         p_ind.d[k] = i.d[k]
#         p_ind.Items[k] = i.Items[k]
#     return p_ind
#
# cdef void free_ind(ind *p_ind):
#     if p_ind != NULL:
#         free(p_ind.d)
#         free(p_ind.f)
#         free(p_ind.capa)
#         free(p_ind.v)
#         free(p_ind.Items)
#         free(p_ind)
#
# cdef void complete_free_pop(pop *pp):
#     cdef int i
#     if pp != NULL:
#         if pp.ind_array != NULL:
#             for i in range(pp.size):
#                 if pp.ind_array[i] != NULL:
#                     free_ind(pp.ind_array[i])
#                     pp.ind_array[i] = NULL
#             free(pp.ind_array)
#         free(pp)
#
# cdef void cleanup_globals():
#     global capacities, weights, profits, vector_weight, OBJ_Weights, OBJ_Weights_lines, nf, ni
#     cdef int i
#     if capacities != NULL:
#         free(capacities)
#         capacities = NULL
#     if weights != NULL:
#         for i in range(nf):
#             if weights[i] != NULL:
#                 free(weights[i])
#         free(weights)
#         weights = NULL
#     if profits != NULL:
#         for i in range(nf):
#             if profits[i] != NULL:
#                 free(profits[i])
#         free(profits)
#         profits = NULL
#     if vector_weight != NULL:
#         free(vector_weight)
#         vector_weight = NULL
#     if OBJ_Weights != NULL:
#         for i in range(nf):
#             if OBJ_Weights[i] != NULL:
#                 free(OBJ_Weights[i])
#         free(OBJ_Weights)
#         OBJ_Weights = NULL
#     OBJ_Weights_lines = 0
#     nf = 0
#     ni = 0
#
# # ============================================================================
# # PARETO DOMINANCE
# # ============================================================================
#
# cdef int non_dominated(ind *p_ind_a, ind *p_ind_b):
#     cdef int i
#     cdef int a_is_good = -1
#     cdef int equal = 1
#     for i in range(nf):
#         if p_ind_a.f[i] > p_ind_b.f[i]:
#             a_is_good = 1
#         if p_ind_a.f[i] != p_ind_b.f[i]:
#             equal = 0
#     if equal:
#         return 0
#     return a_is_good
#
# # ============================================================================
# # EPSILON INDICATOR & FITNESS
# # ============================================================================
#
# cdef double calcAddEpsIndicator(ind *p_ind_a, ind *p_ind_b):
#     global max_bound
#     cdef int i
#     cdef double eps
#     cdef double temp_eps
#     if max_bound == 0.0:
#         max_bound = 1e-8
#     eps = (p_ind_a.v[0]/max_bound)-(p_ind_b.v[0]/max_bound)
#     for i in range(1, nf):
#         temp_eps = (p_ind_a.v[i]/max_bound)-(p_ind_b.v[i]/max_bound)
#         if temp_eps > eps:
#             eps = temp_eps
#     return eps
#
# cdef void init_fitness(ind *x):
#     x.fitness = 0.0
#
# cdef void update_fitness(ind *x, double I):
#     x.fitness -= exp(-I / kappa)
#
# cdef double update_fitness_return(double f, double I):
#     return f - exp(-I / kappa)
#
# cdef int delete_fitness(ind *x, double I):
#     x.fitness += exp(-I / kappa)
#     return 0
#
# cdef void compute_ind_fitness(ind *x, pop *SP):
#     cdef int j
#     init_fitness(x)
#     for j in range(SP.size):
#         if SP.ind_array[j] != x:
#             update_fitness(x, calcAddEpsIndicator(SP.ind_array[j], x))
#
# cdef void compute_all_fitness(pop *SP):
#     cdef int i
#     for i in range(SP.size):
#         compute_ind_fitness(SP.ind_array[i], SP)
#
# # ============================================================================
# # FILE I/O
# # ============================================================================
#
# cdef void loadMOKP(char *filename):
#     global nf, ni, capacities, weights, profits
#     cdef int i, f
#     with open(filename.decode(), "r") as source:
#         _nf, _ni = [int(x) for x in source.readline().split()]
#         nf = _nf
#         ni = _ni
#         capacities = <double *>chk_malloc(nf * sizeof(double))
#         weights = <int **>chk_malloc(nf * sizeof(void*))
#         profits = <int **>chk_malloc(nf * sizeof(void*))
#         for f in range(nf):
#             capacities[f] = float(source.readline().strip())
#             weights[f] = <int *>chk_malloc(ni * sizeof(int))
#             profits[f] = <int *>chk_malloc(ni * sizeof(int))
#             for i in range(ni):
#                 source.readline()
#                 weights[f][i] = int(source.readline().strip())
#                 profits[f][i] = int(source.readline().strip())
#
# cdef void read_weights_file(char *filename):
#     global OBJ_Weights, nombreLIGNE, nf, OBJ_Weights_lines
#     cdef int i, j, nlines
#     with open(filename.decode(), "r") as f:
#         lines = [line for line in f if line.strip()]
#     nlines = len(lines)
#     OBJ_Weights = <double **>chk_malloc(nf * sizeof(void*))
#     for i in range(nf):
#         OBJ_Weights[i] = <double *>chk_malloc(nlines * sizeof(double))
#     for i, line in enumerate(lines):
#         vals = line.strip().split()
#         for j in range(nf):
#             OBJ_Weights[j][i] = float(vals[j])
#     nombreLIGNE = nlines - 1
#     OBJ_Weights_lines = nlines
#
# cdef void dynamic_weight_allpop():
#     global vector_weight, OBJ_Weights, nombreLIGNE, nf, nextLn
#     cdef int i
#     if vector_weight == NULL:
#         vector_weight = <double *>chk_malloc(nf * sizeof(double))
#     for i in range(nf):
#         vector_weight[i] = OBJ_Weights[i][nextLn]
#     if nextLn == nombreLIGNE:
#         nextLn = 0
#     else:
#         nextLn += 1
#
# cdef void choose_weight():
#     dynamic_weight_allpop()
#
# # ============================================================================
# # INITIALIZATION & EVALUATION
# # ============================================================================
#
# cdef void random_init_ind(ind *x):
#     cdef int j, r, tmp
#     for j in range(ni):
#         x.d[j] = j
#     for j in range(ni):
#         r = irand(ni)
#         tmp = x.d[r]
#         x.d[r] = x.d[j]
#         x.d[j] = tmp
#
# cdef void evaluate(ind *x):
#     cdef int j, l, k, faisable
#     x.nombr = 0
#     x.nombr_nonpris = 0
#     for j in range(nf):
#         x.capa[j] = 0.0
#         x.f[j] = 0.0
#     for j in range(ni):
#         l = 0
#         faisable = 1
#         while l < nf and faisable == 1:
#             if x.capa[l] + weights[l][x.d[j]] > capacities[l]:
#                 faisable = 0
#             l += 1
#         if faisable == 1:
#             for k in range(nf):
#                 x.capa[k] += weights[k][x.d[j]]
#                 x.f[k] += profits[k][x.d[j]]
#             x.Items[x.d[j]] = 1
#             x.nombr += 1
#         else:
#             x.Items[x.d[j]] = 0
#             x.nombr_nonpris += 1
#
# cdef void P_init_pop(pop *SP, pop *Sarchive, int alpha):
#     cdef int i, x, tmp, t
#     t = max(alpha, Sarchive.size)
#     cdef int* shuffle = <int *>chk_malloc(t * sizeof(int))
#     for i in range(t):
#         shuffle[i] = i
#     for i in range(t):
#         x = irand(alpha)
#         tmp = shuffle[i]
#         shuffle[i] = shuffle[x]
#         shuffle[x] = tmp
#     SP.size = alpha
#     if Sarchive.size > alpha:
#         for i in range(alpha):
#             SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#     else:
#         for i in range(alpha):
#             if shuffle[i] < Sarchive.size:
#                 SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#             else:
#                 SP.ind_array[i] = create_ind(nf)
#                 random_init_ind(SP.ind_array[i])
#                 evaluate(SP.ind_array[i])
#     free(shuffle)
#
# # ============================================================================
# # ARCHIVE MANAGEMENT
# # ============================================================================
#
# cdef int extractPtoArchive(pop *P, pop *archive):
#     cdef int i, j, dom, t, convergence_rate
#     t = archive.size + P.size
#     archiveAndP = create_pop(t, nf)
#     convergence_rate = 0
#     for i in range(archive.size):
#         archiveAndP.ind_array[i] = archive.ind_array[i]
#     for i in range(P.size):
#         archiveAndP.ind_array[i + archive.size] = ind_copy(P.ind_array[i])
#     archiveAndP.size = t
#     archive.size = 0
#     for i in range(t):
#         for j in range(t):
#             if i != j:
#                 dom = non_dominated(archiveAndP.ind_array[i], archiveAndP.ind_array[j])
#                 if dom == -1 or (dom == 0 and i > j):
#                     break
#         else:
#             archive.ind_array[archive.size] = ind_copy(archiveAndP.ind_array[i])
#             archive.size += 1
#             if i >= t - P.size:
#                 convergence_rate += 1
#     complete_free_pop(archiveAndP)
#     return convergence_rate
#
# cdef double calcMaxbound(pop *SP, int size):
#     global max_bound
#     cdef int i, j
#     SP.size = size
#     cdef double max_b = SP.ind_array[0].v[0]
#     for i in range(SP.size):
#         for j in range(nf):
#             if max_b < SP.ind_array[i].v[j]:
#                 max_b = SP.ind_array[i].v[j]
#     if max_b == 0.0:
#         max_b = 1e-8
#     max_bound = max_b
#     return max_bound
#
# cdef void calcul_weight(pop *SP, int size):
#     cdef int i, j
#     for i in range(SP.size):
#         for j in range(nf):
#             SP.ind_array[i].v[j] = SP.ind_array[i].f[j] * vector_weight[j]
#
# # ============================================================================
# # SELECTION
# # ============================================================================
#
# cdef int compute_fitness_and_select(pop *SP, ind *x, int size):
#     cdef int i, worst
#     cdef double worst_fit, fit_tmp
#     SP.size = size
#     x.fitness = 0
#     compute_ind_fitness(x, SP)
#     worst_fit = x.fitness
#     worst = -1
#     for i in range(SP.size):
#         fit_tmp = update_fitness_return(SP.ind_array[i].fitness, calcAddEpsIndicator(x, SP.ind_array[i]))
#         if fit_tmp > worst_fit:
#             worst = i
#             worst_fit = fit_tmp
#     fit_tmp = x.fitness
#     if worst == -1:
#         return -1
#     else:
#         for i in range(SP.size):
#             delete_fitness(SP.ind_array[i], calcAddEpsIndicator(SP.ind_array[worst], SP.ind_array[i]))
#             update_fitness(SP.ind_array[i], calcAddEpsIndicator(x, SP.ind_array[i]))
#         delete_fitness(x, calcAddEpsIndicator(SP.ind_array[worst], x))
#         free_ind(SP.ind_array[worst])
#         SP.ind_array[worst] = ind_copy(x)
#         if fit_tmp - worst_fit > smallValue:
#             return worst
#         else:
#             return -1
#
# # ============================================================================
# # STRATEGY EXECUTION FUNCTIONS
# # ============================================================================
#
# # ============================================================================
# # ULTRA-FAST, SAMPLING-BASED STRATEGY EXECUTION FUNCTIONS
# # ============================================================================
#
# cdef list balanced_exploration(ind *x, list available_items, int L_val):
#     cdef list scores = []
#     cdef int item, k, sample_size
#     cdef double eff1, eff2, mean_eff, balance, score
#     cdef int feasible
#
#     sample_size = 50 # Only check 50 random items instead of all 250
#
#     for _ in range(sample_size):
#         item = irand(ni)
#         if x.Items[item] == 0:
#             feasible = 1
#             for k in range(nf):
#                 if x.capa[k] + weights[k][item] > capacities[k]:
#                     feasible = 0
#                     break
#             if feasible:
#                 eff1 = profits[0][item] / (weights[0][item] + 1.0)
#                 eff2 = profits[1][item] / (weights[1][item] + 1.0)
#                 mean_eff = (eff1 + eff2) / 2.0
#                 balance = min(eff1, eff2) / (max(eff1, eff2) + 1e-8)
#                 score = mean_eff * (0.7 + 0.3 * balance)
#                 scores.append((score, item))
#
#     scores.sort(reverse=True)
#     return [item for score, item in scores[:min(L_val, len(scores))]]
#
# cdef list objective_specialization(ind *x, list available_items, int L_val, int target_obj):
#     cdef list scores = []
#     cdef int item, other_obj, sample_size
#     cdef double target_eff, other_eff, score
#     cdef int feasible
#
#     other_obj = 1 - target_obj
#     sample_size = 50
#
#     for _ in range(sample_size):
#         item = irand(ni)
#         if x.Items[item] == 0:
#             feasible = 1
#             for k in range(nf):
#                 if x.capa[k] + weights[k][item] > capacities[k]:
#                     feasible = 0
#                     break
#             if feasible:
#                 target_eff = profits[target_obj][item] / (weights[target_obj][item] + 1.0)
#                 other_eff = profits[other_obj][item] / (weights[other_obj][item] + 1.0)
#                 score = 0.9 * target_eff + 0.1 * other_eff
#                 scores.append((score, item))
#
#     scores.sort(reverse=True)
#     return [item for score, item in scores[:L_val]]
#
# cdef list gap_filling(ind *x, list available_items, int L_val):
#     cdef list scores = []
#     cdef int item, weakest_idx, sample_size
#     cdef double weak_eff, total_profit, score
#     cdef int feasible
#
#     weakest_idx = 0 if x.f[0] < x.f[1] else 1
#     sample_size = 50
#
#     for _ in range(sample_size):
#         item = irand(ni)
#         if x.Items[item] == 0:
#             feasible = 1
#             for k in range(nf):
#                 if x.capa[k] + weights[k][item] > capacities[k]:
#                     feasible = 0
#                     break
#             if feasible:
#                 weak_eff = profits[weakest_idx][item] / (weights[weakest_idx][item] + 1.0)
#                 total_profit = profits[0][item] + profits[1][item]
#                 score = 0.7 * weak_eff + 0.3 * total_profit / 1000.0
#                 scores.append((score, item))
#
#     scores.sort(reverse=True)
#     return [item for score, item in scores[:L_val]]
#
# cdef list aggressive_exploitation(ind *x, list available_items, int L_val, double threshold):
#     cdef list scores = []
#     cdef int item, sample_size
#     cdef double total_profit, total_weight, efficiency, current_avg
#     cdef int feasible
#
#     current_avg = (x.f[0] + x.f[1]) / (x.nombr + 1.0)
#     sample_size = 50
#
#     for _ in range(sample_size):
#         item = irand(ni)
#         if x.Items[item] == 0:
#             feasible = 1
#             for k in range(nf):
#                 if x.capa[k] + weights[k][item] > capacities[k]:
#                     feasible = 0
#                     break
#             if feasible:
#                 total_profit = profits[0][item] + profits[1][item]
#                 total_weight = weights[0][item] + weights[1][item]
#                 efficiency = total_profit / (total_weight + 1.0)
#                 if efficiency > threshold * current_avg:
#                     scores.append((efficiency, item))
#
#     scores.sort(reverse=True)
#     if scores:
#         return [item for score, item in scores[:L_val]]
#     else:
#         return balanced_exploration(x, [], L_val)
#
#
# cdef list random_perturbation(ind *x, int L_val):
#     """
#     A fast, sampling-based random strategy, consistent with other strategies.
#     Selects up to L_val random, feasible items to add.
#     """
#     cdef list selected = []
#     cdef int item, k, attempts
#     cdef int feasible
#     cdef int max_attempts = L_val * 10 # Try a few more times than needed
#
#     attempts = 0
#     while len(selected) < L_val and attempts < max_attempts:
#         item = irand(ni)
#         attempts += 1
#
#         # Check if item is already in the solution or already selected
#         if x.Items[item] == 1:
#             continue
#         if item in selected:
#             continue
#
#         # Check if the item is feasible to add
#         feasible = 1
#         for k in range(nf):
#             if x.capa[k] + weights[k][item] > capacities[k]:
#                 feasible = 0
#                 break
#
#         if feasible:
#             selected.append(item)
#
#     return selected
# # ============================================================================
# # HYBRID LOCAL SEARCH - OPTIMIZED AND STABLE VERSION (FIXED)
# # ============================================================================
#
# cdef void Indicator_local_search1_hybrid(pop *SP, int size, object python_strategy_provider):
#     """
#     A FAST and focused local search with DEBUG PRINTS
#     """
#     cdef ind *x
#     cdef int i, j, r, sol, mino, consistant, taille, feasible, tv, l, t
#     cdef int* remplace = <int *>chk_malloc(L * sizeof(int))
#     cdef list selected_items
#     cdef dict strategy_dict
#     cdef int strategy_code
#     cdef int target_obj
#     cdef double threshold
#     cdef int max_attempts_per_solution
#     cdef int attempt
#     cdef int item
#     cdef int accepted
#
#     print(f"  [DEBUG 1] Entering local search, PopSize={size}")
#
#     SP.size = size
#
#     print(f"  [DEBUG 2] Getting strategy from provider...")
#     strategy_dict = python_strategy_provider.get_strategy_dict(current_iteration)
#     strategy_code = strategy_dict.get('code', 1)
#     target_obj = strategy_dict.get('target_obj', 0)
#     threshold = strategy_dict.get('threshold', 0.9)
#
#     print(f"  [DEBUG 3] Strategy={strategy_code}, target={target_obj}, threshold={threshold:.2f}")
#
#     if current_iteration % 20 == 0:
#         print(f"[ITER {current_iteration}] Strategy={strategy_code}, PopSize={SP.size}")
#
#     print(f"  [DEBUG 4] Starting loop over {SP.size} solutions")
#
#     for i in range(SP.size):
#         print(f"  [DEBUG 5] Processing solution {i+1}/{SP.size}")
#
#         x = ind_copy(SP.ind_array[i])
#         print(f"  [DEBUG 6] Copied solution, nombr={x.nombr}")
#
#         max_attempts_per_solution = x.nombr
#         accepted = 0
#
#         print(f"  [DEBUG 7] Will try {max_attempts_per_solution} attempts")
#
#         for attempt in range(max_attempts_per_solution):
#             if attempt % 10 == 0:
#                 print(f"    [DEBUG 8] Attempt {attempt}/{max_attempts_per_solution}")
#
#             for l in range(L):
#                 remplace[l] = 0
#
#             # 1. REMOVE one item
#             print(f"    [DEBUG 9] Removing one item...")
#             while True:
#                 mino = irand(ni)
#                 if x.Items[mino] == 1:
#                     break
#
#             print(f"    [DEBUG 10] Removed item {mino}")
#
#             x.Items[mino] = 0
#             x.nombr -= 1
#             x.nombr_nonpris += 1
#             for r in range(nf):
#                 x.capa[r] -= weights[r][mino]
#                 x.f[r] -= profits[r][mino]
#
#             # 2. SELECT items to ADD
#             print(f"    [DEBUG 11] Selecting items with strategy {strategy_code}...")
#
#             if strategy_code == 1:
#                 selected_items = balanced_exploration(x, [], L)
#             elif strategy_code == 2:
#                 selected_items = objective_specialization(x, [], L, target_obj)
#             elif strategy_code == 3:
#                 selected_items = gap_filling(x, [], L)
#             elif strategy_code == 4:
#                 selected_items = aggressive_exploitation(x, [], L, threshold)
#             else:
#                 selected_items = random_perturbation(x, L)
#
#             print(f"    [DEBUG 12] Selected {len(selected_items)} items")
#
#             # 3. ADD selected items
#             print(f"    [DEBUG 13] Adding selected items...")
#             taille = 0
#             for item in selected_items:
#                 if x.Items[item] == 0:
#                     consistant = 1
#                     for r in range(nf):
#                         if x.capa[r] + weights[r][item] > capacities[r]:
#                             consistant = 0
#                             break
#                     if consistant == 1:
#                         feasible = 1
#                         for r in range(taille):
#                             if item == remplace[r]:
#                                 feasible = 0
#                                 break
#                         if feasible == 1:
#                             remplace[taille] = item
#                             taille += 1
#                             x.Items[item] = 1
#                             x.nombr_nonpris -= 1
#                             x.nombr += 1
#                             for r in range(nf):
#                                 x.capa[r] += weights[r][item]
#                                 x.f[r] += profits[r][item]
#
#             print(f"    [DEBUG 14] Added {taille} items")
#
#             # 4. EVALUATE
#             print(f"    [DEBUG 15] Evaluating...")
#             for tv in range(nf):
#                 x.v[tv] = x.f[tv] * vector_weight[tv]
#
#             print(f"    [DEBUG 16] Calculating maxbound...")
#             max_bound = calcMaxbound(SP, SP.size)
#
#             print(f"    [DEBUG 17] Computing fitness and selecting...")
#             sol = compute_fitness_and_select(SP, x, SP.size)
#
#             print(f"    [DEBUG 18] Selection result: sol={sol}")
#
#             # 5. ACCEPT or REJECT
#             if sol != -1:
#                 print(f"    [DEBUG 19] ACCEPTED! Breaking...")
#                 accepted = 1
#                 break
#             else:
#                 print(f"    [DEBUG 20] REJECTED, restoring...")
#                 # RESTORE
#                 x.Items[mino] = 1
#                 x.nombr_nonpris -= 1
#                 x.nombr += 1
#                 for r in range(nf):
#                     x.capa[r] += weights[r][mino]
#                     x.f[r] += profits[r][mino]
#
#                 if taille >= 1:
#                     for r in range(taille):
#                         x.Items[remplace[r]] = 0
#                         x.nombr -= 1
#                         x.nombr_nonpris += 1
#                         for t in range(nf):
#                             x.capa[t] -= weights[t][remplace[r]]
#                             x.f[t] -= profits[t][remplace[r]]
#                             x.v[t] = x.f[t] * vector_weight[t]
#                 print(f"    [DEBUG 21] Restored solution")
#
#         print(f"  [DEBUG 22] Finished attempts for solution {i+1}, accepted={accepted}")
#
#         # Free x only if NOT accepted
#         if not accepted:
#             print(f"  [DEBUG 23] Freeing rejected solution")
#             free_ind(x)
#         else:
#             print(f"  [DEBUG 24] Keeping accepted solution")
#
#     print(f"  [DEBUG 25] Freeing remplace array")
#     free(remplace)
#
#     print(f"  [DEBUG 26] Local search completed")
#
# # ============================================================================
# # MAIN RUNNER
# # ============================================================================
#
# # In Cell 1, replace the old run_hybrid_moacp with this:
#
# def run_hybrid_moacp(instance_file, weights_file, nbitems, num_objectives, output_file, strategy_provider):
#     """
#     Main runner for the hybrid LLM-MOACP with a fast, decoupled local search.
#     """
#     global nf, ni, NBITEMS, alpha, paretoIni, L, nombreLIGNE, nextLn, inv, vector_weight
#     global capacities, weights, profits, OBJ_Weights
#     global current_iteration
#
#     alpha = 10
#     paretoIni = 28000
#     NBL = 100
#     NRUNS = 10
#
#     for run in range(1, NRUNS+1):
#         NBITEMS = nbitems
#         ni = nbitems
#         nf = num_objectives
#
#         print(f"RUN {run}/{NRUNS} -- {instance_file.decode()} nbitems={ni} nf={nf} => {output_file}")
#
#         nombreLIGNE = 0
#         nextLn = 0
#         inv = 0
#
#         seed(run)
#         loadMOKP(instance_file)
#         read_weights_file(weights_file)
#
#         vector_weight = <double *>chk_malloc(nf * sizeof(double))
#         P = create_pop(paretoIni, nf) # This is the MAIN archive
#
#         strategy_provider.reset_for_run(run)
#
#         it = 0
#         while it < NBL:
#             current_iteration = it
#             solutions = create_pop(alpha, nf) # This is the working population SP
#
#             choose_weight()
#             P_init_pop(solutions, P, alpha) # Initialize population from main archive
#             calcul_weight(solutions, alpha)
#             calcMaxbound(solutions, alpha)
#             compute_all_fitness(solutions)
#
#             # --- KEY CHANGE: Call the fast, decoupled local search ---
#             Indicator_local_search1_hybrid(solutions, alpha, strategy_provider)
#
#             # --- KEY CHANGE: Update the main archive AFTER the local search is finished ---
#             extractPtoArchive(solutions, P)
#
#             it += 1
#             complete_free_pop(solutions)
#
#         with open(output_file, "a") as fpareto:
#             fpareto.write("\n")
#             for i in range(P.size):
#                 for j in range(nf):
#                     fpareto.write(f"{P.ind_array[i].f[j]:.6f} ")
#                 fpareto.write("\n")
#
#         complete_free_pop(P)
#         cleanup_globals()
# Out:
# Content of stdout:
# _cython_magic_0865dc48aa3bff331facfe05fca4310defec7f80bb9644db4b30214520ead711.c
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_0865dc48aa3bff331facfe05fca4310defec7f80bb9644db4b30214520ead711.c(4843): warning C4244: '='ÿ: conversion de 'double' en 'float', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_0865dc48aa3bff331facfe05fca4310defec7f80bb9644db4b30214520ead711.c(4933): warning C4244: '='ÿ: conversion de 'double' en 'float', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_0865dc48aa3bff331facfe05fca4310defec7f80bb9644db4b30214520ead711.c(5943): warning C4244: '='ÿ: conversion de 'Py_ssize_t' en 'int', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_0865dc48aa3bff331facfe05fca4310defec7f80bb9644db4b30214520ead711.c(12938): warning C4305: '='ÿ: troncation de 'double' … 'float'
#    Cr‚ation de la bibliothŠque C:\Users\Aziz il patal\.ipython\cython\Users\Aziz il patal\.ipython\cython\_cython_magic_0865dc48aa3bff331facfe05fca4310defec7f80bb9644db4b30214520ead711.cp39-win_amd64.lib et de l'objet C:\Users\Aziz il patal\.ipython\cython\Users\Aziz il patal\.ipython\cython\_cython_magic_0865dc48aa3bff331facfe05fca4310defec7f80bb9644db4b30214520ead711.cp39-win_amd64.exp
# G‚n‚ration de code en cours
# Fin de la g‚n‚ration du code

# %%
# Cell 2: Python Strategy Provider and Execution (FIXED)

import requests
import json
import matplotlib.pyplot as plt

# --- The Strategy Provider Class ---
class LLMStrategyProvider:
    """
    Provides optimization strategies by querying a local LLM.
    This class is designed to be passed to the Cython runner.
    """
    def __init__(self, model_name="llama3:8b"):
        self.model_name = model_name
        # FIX: The template now expects a 'phase' to be provided.
        self.prompt_template = """
Select strategy for knapsack optimization iteration {iteration}/100.

Phase: {phase}

Strategies:
1 = Balanced exploration (early phase, need diversity)
2 = Objective specialization (mid phase, extreme solutions)
3 = Gap filling (always good, improve weak objective)
4 = Aggressive exploitation (late phase, high quality only)
5 = Random perturbation (if stuck)

Reply with ONE number (1-5):"""
        self.url = "http://localhost:11434/api/generate"

    def reset_for_run(self, run_id):
        """Can be used to reset state for a new run if needed."""
        print(f"[PYTHON] Strategy provider reset for run {run_id}")

    def _query_llm(self, prompt):
        """Helper function to query the LLM."""
        payload = {
            "model": self.model_name,
            "prompt": prompt,
            "stream": False,
            "options": {"temperature": 0.7, "max_tokens": 10}
        }
        try:
            response = requests.post(self.url, json=payload, timeout=40)
            if response.status_code == 200:
                result = response.json()
                response_text = result.get('response', '')
                for char in response_text:
                    if char.isdigit():
                        return int(char)
                print(f"[PYTHON] Warning: LLM response '{response_text}' did not contain a number. Defaulting to 1.")
                return 1
            else:
                print(f"[PYTHON] Error connecting to Ollama: {response.status_code}. Defaulting to 1.")
                return 1
        except requests.exceptions.RequestException as e:
            print(f"[PYTHON] Error getting strategy from LLM: {e}. Is Ollama running? Defaulting to 1.")
            return 1

    def get_strategy_dict(self, iteration):
        """
        Queries the LLM and returns a dictionary with strategy details.
        This is the main method called by the Cython code.
        """
        # FIX: Calculate the phase string here in Python
        if iteration < 20:
            phase = "Early"
        elif iteration < 60:
            phase = "Mid"
        elif iteration < 90:
            phase = "Late"
        else:
            phase = "Final"

        # Now, format the prompt with both the iteration and the calculated phase
        prompt = self.prompt_template.format(iteration=iteration, phase=phase)
        strategy_code = self._query_llm(prompt)
        
        # You can add more complex logic here to determine other parameters
        # based on the strategy code or iteration.
        target_obj = 0 if strategy_code == 2 else 0 # Example: focus on objective 0 for specialization
        threshold = 0.9 if strategy_code == 4 else 0.9 # Example: threshold for exploitation

        return {
            'code': strategy_code,
            'target_obj': target_obj,
            'threshold': threshold
        }

# --- Execution ---
# 1. Create an instance of the strategy provider
llm_provider = LLMStrategyProvider()

# 2. Call the main Cython runner function, passing the provider instance
print("--- Starting LLM-guided MOACP execution (Stable Version) ---")
run_hybrid_moacp(
    instance_file=b"250.2.txt",
    weights_file=b"Weights_2obj_FQ200.txt",
    nbitems=250,
    num_objectives=2,
    output_file="2502_ResultsStable.txt",
    strategy_provider=llm_provider
)
print("--- Execution finished ---")


# --- Plotting ---
def dominates(a, b):
    return all(x >= y for x, y in zip(a, b)) and any(x > y for x, y in zip(a, b))

def get_true_pareto_front(points):
    pareto = []
    for i, p in enumerate(points):
        dominated = False
        for j, q in enumerate(points):
            if i != j and dominates(q, p):
                dominated = True; break
        if not dominated: pareto.append(p)
    return pareto

def plot_pareto_front(filename, title_suffix=""):
    points = []
    with open(filename, "r") as f:
        for line in f:
            line = line.strip()
            if line: points.append([float(x) for x in line.split()])
    if not points:
        print(f"No data to plot in {filename}"); return
    pareto = get_true_pareto_front(points)
    xs, ys = zip(*pareto)
    plt.figure(figsize=(8,6))
    plt.scatter(xs, ys, color='purple', label=f"Pareto front {title_suffix}")
    plt.xlabel("Objective 1"); plt.ylabel("Objective 2")
    plt.title(f"Pareto Front from {filename}")
    plt.legend(); plt.grid(True); plt.tight_layout()
    plt.show()

print("\n--- Plotting results ---")
plot_pareto_front("2502_ResultsStable.txt", title_suffix="(Stable LLM-Guided)")
# Out:
# --- Starting LLM-guided MOACP execution (Stable Version) ---
# RUN 1/10 -- 250.2.txt nbitems=250 nf=2 => 2502_ResultsStable.txt
# [PYTHON] Strategy provider reset for run 1
#   [DEBUG 1] Entering local search, PopSize=10
#   [DEBUG 2] Getting strategy from provider...
#   [DEBUG 3] Strategy=1, target=0, threshold=0.90
# [ITER 0] Strategy=1, PopSize=10
#   [DEBUG 4] Starting loop over 10 solutions
#   [DEBUG 5] Processing solution 1/10
#   [DEBUG 6] Copied solution, nombr=127
#   [DEBUG 7] Will try 127 attempts
#     [DEBUG 8] Attempt 0/127
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 128
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 47
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 3 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 243
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 1 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 17
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 3 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 56
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 4 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 28
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 3 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 106
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 111
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 230
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 99
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 4 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 8] Attempt 10/127
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 187
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 112
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 248
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 243
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 1 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 30
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 146
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 175
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 219
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 2 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 49
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 3 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 205
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 3 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 8] Attempt 20/127
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 44
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 4
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 24
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 37
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 41
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 26
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 4 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 79
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 224
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 4 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 96
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 83
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 4 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 8] Attempt 30/127
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 200
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 26
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 197
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 20
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 3 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 96
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 42
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 72
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 96
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 202
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 110
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 2 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 8] Attempt 40/127
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 129
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 3 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 90
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 224
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 3 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 190
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 4
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 80
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 3 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 189
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 18
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 44
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 49
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 8] Attempt 50/127
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 106
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 129
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 143
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 202
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 139
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 9
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 3 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 202
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 59
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 216
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 83
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 3 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 8] Attempt 60/127
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 205
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 3 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 192
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 3 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 242
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 187
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 246
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 93
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 243
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 1 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 204
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 3 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 162
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 204
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 8] Attempt 70/127
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 236
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 3 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 184
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 81
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 187
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 205
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 3 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 9
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 205
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 1 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 46
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 165
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 108
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 1 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 8] Attempt 80/127
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 216
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 4 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 138
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 2 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 164
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 0 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 0 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 114
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 1 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 41
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 244
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 4 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 20
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 2 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 47
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 82
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 77
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 8] Attempt 90/127
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 138
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 4 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 83
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 4 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 20
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 0 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 0 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 205
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 1 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 48
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 146
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 156
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 3 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 118
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 1 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 96
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 3 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 109
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 2 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 8] Attempt 100/127
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 173
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 4 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 242
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 132
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 24
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 3 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 218
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 3 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 110
#     [DEBUG 11] Selecting items with strategy 1...
#     [DEBUG 12] Selected 0 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 0 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
# ...
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 22
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 4 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 96
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 219
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 119
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 91
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 113
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 0 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 0 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 162
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 9
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 192
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 8] Attempt 180/206
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 192
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 48
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 246
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 218
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 35
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 66
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 44
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 9
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 54
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 91
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 8] Attempt 190/206
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 66
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 98
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 44
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 9
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 98
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 14
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 246
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 98
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 99
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 2 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 73
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 8] Attempt 200/206
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 74
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 1 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 119
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 164
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 1 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 164
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 0 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 0 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 51
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#     [DEBUG 9] Removing one item...
#     [DEBUG 10] Removed item 22
#     [DEBUG 11] Selecting items with strategy 7...
#     [DEBUG 12] Selected 5 items
#     [DEBUG 13] Adding selected items...
#     [DEBUG 14] Added 1 items
#     [DEBUG 15] Evaluating...
#     [DEBUG 16] Calculating maxbound...
#     [DEBUG 17] Computing fitness and selecting...
#     [DEBUG 18] Selection result: sol=-1
#     [DEBUG 20] REJECTED, restoring...
#     [DEBUG 21] Restored solution
#   [DEBUG 22] Finished attempts for solution 10, accepted=0
#   [DEBUG 23] Freeing rejected solution
#   [DEBUG 25] Freeing remplace array
#   [DEBUG 26] Local search completed
#   [DEBUG 1] Entering local search, PopSize=10
#   [DEBUG 2] Getting strategy from provider...

# %%
# %load_ext cython
# Out:
# The cython extension is already loaded. To reload it, use:
#   %reload_ext cython

# %%
# %%cython
# # --- Original Cython code starts here (with modifications) ---
# import re
# from libc.stdlib cimport malloc, free, srand, rand
# from libc.string cimport memset
# from libc.math cimport exp
#
# cdef struct ind:
#     int nombr_nonpris
#     int nombr
#     int rank
#     float fitnessbest
#     float fitness
#     int explored
#     double *f
#     double *capa
#     double *v
#     int *d
#     int *Items
#
# cdef struct pop:
#     int size
#     int maxsize
#     ind **ind_array
#
# # Globals that reset per run
# cdef int NBITEMS = 250
# cdef int ni = 250
# cdef int L = 5
# cdef double LARGE = 10e50
# cdef float smallValue = 0.0000001
# cdef double kappa = 0.05
# cdef int alpha = 10
# cdef int paretoIni = 28000
#
# cdef int nf = 2
# cdef double *capacities = NULL
# cdef int **weights = NULL
# cdef int **profits = NULL
# cdef double *vector_weight = NULL
# cdef double max_bound = 0.0
# cdef double **OBJ_Weights = NULL
# cdef int nombreLIGNE = 0
# cdef int nextLn = 0
# cdef int inv = 0
# cdef int OBJ_Weights_lines = 0
#
# # HYBRID: Add a global counter to track iterations
# cdef long long iteration_counter = 0
# # HYBRID: Add global counters to track LLM performance
# cdef long long llm_calls_made = 0
# cdef long long llm_suggestions_accepted = 0
# cdef long long llm_suggestions_rejected = 0
#
# def seed(int x):
#     srand(x)
#
# cdef int irand(int range_val):
#     return rand() % range_val
#
# cdef void *chk_malloc(size_t size):
#     cdef void *return_value = malloc(size)
#     if return_value == NULL:
#         raise MemoryError("Out of memory.")
#     memset(return_value, 0, size)
#     return return_value
#
# cdef pop *create_pop(int maxsize, int nf):
#     cdef int i
#     cdef pop *pp = <pop *>chk_malloc(sizeof(pop))
#     pp.size = 0
#     pp.maxsize = maxsize
#     pp.ind_array = <ind **>chk_malloc(maxsize * sizeof(void*))
#     for i in range(maxsize):
#         pp.ind_array[i] = NULL
#     return pp
#
# cdef ind *create_ind(int nf):
#     cdef int i
#     cdef ind *p_ind = <ind *>chk_malloc(sizeof(ind))
#     p_ind.nombr_nonpris = 0
#     p_ind.nombr = 0
#     p_ind.rank = 0
#     p_ind.fitnessbest = -1.0
#     p_ind.fitness = -1.0
#     p_ind.explored = 0
#     p_ind.f = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.capa = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.v = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.d = <int *>chk_malloc(ni * sizeof(int))
#     p_ind.Items = <int *>chk_malloc(ni * sizeof(int))
#     for i in range(ni):
#         p_ind.Items[i] = 0
#         p_ind.d[i] = 0
#     for i in range(nf):
#         p_ind.f[i] = 0.0
#         p_ind.capa[i] = 0.0
#         p_ind.v[i] = 0.0
#     return p_ind
#
# cdef ind *ind_copy(ind *i):
#     cdef ind *p_ind = create_ind(nf)
#     cdef int k
#     p_ind.nombr_nonpris = i.nombr_nonpris
#     p_ind.nombr = i.nombr
#     p_ind.rank = i.rank
#     p_ind.fitnessbest = i.fitnessbest
#     p_ind.fitness = i.fitness
#     p_ind.explored = i.explored
#     for k in range(nf):
#         p_ind.f[k] = i.f[k]
#         p_ind.v[k] = i.v[k]
#         p_ind.capa[k] = i.capa[k]
#     for k in range(ni):
#         p_ind.d[k] = i.d[k]
#         p_ind.Items[k] = i.Items[k]
#     return p_ind
#
# cdef void free_ind(ind *p_ind):
#     if p_ind != NULL:
#         free(p_ind.d)
#         free(p_ind.f)
#         free(p_ind.capa)
#         free(p_ind.v)
#         free(p_ind.Items)
#         free(p_ind)
#
# cdef void complete_free_pop(pop *pp):
#     cdef int i
#     if pp != NULL:
#         if pp.ind_array != NULL:
#             for i in range(pp.size):
#                 if pp.ind_array[i] != NULL:
#                     free_ind(pp.ind_array[i])
#                     pp.ind_array[i] = NULL
#             free(pp.ind_array)
#         free(pp)
#
# cdef void cleanup_globals():
#     global capacities, weights, profits, vector_weight, OBJ_Weights, OBJ_Weights_lines, nf, ni
#     if capacities != NULL:
#         free(capacities)
#         capacities = NULL
#     if weights != NULL:
#         for i in range(nf):
#             if weights[i] != NULL:
#                 free(weights[i])
#         free(weights)
#         weights = NULL
#     if profits != NULL:
#         for i in range(nf):
#             if profits[i] != NULL:
#                 free(profits[i])
#         free(profits)
#         profits = NULL
#     if vector_weight != NULL:
#         free(vector_weight)
#         vector_weight = NULL
#     if OBJ_Weights != NULL:
#         for i in range(nf):
#             if OBJ_Weights[i] != NULL:
#                 free(OBJ_Weights[i])
#         free(OBJ_Weights)
#         OBJ_Weights = NULL
#     OBJ_Weights_lines = 0
#     nf = 0
#     ni = 0
#
# cdef int non_dominated(ind *p_ind_a, ind *p_ind_b):
#     cdef int i
#     cdef int a_is_good = -1
#     cdef int equal = 1
#     for i in range(nf):
#         if p_ind_a.f[i] > p_ind_b.f[i]:
#             a_is_good = 1
#         if p_ind_a.f[i] != p_ind_b.f[i]:
#             equal = 0
#     if equal:
#         return 0
#     return a_is_good
#
# cdef double calcAddEpsIndicator(ind *p_ind_a, ind *p_ind_b):
#     global max_bound
#     cdef int i
#     cdef double eps
#     cdef double temp_eps
#     if max_bound == 0.0:
#         max_bound = 1e-8
#     eps = (p_ind_a.v[0]/max_bound)-(p_ind_b.v[0]/max_bound)
#     for i in range(1, nf):
#         temp_eps = (p_ind_a.v[i]/max_bound)-(p_ind_b.v[i]/max_bound)
#         if temp_eps > eps:
#             eps = temp_eps
#     return eps
#
# cdef void init_fitness(ind *x):
#     x.fitness = 0.0
#
# cdef void update_fitness(ind *x, double I):
#     x.fitness -= exp(-I / kappa)
#
# cdef double update_fitness_return(double f, double I):
#     return f - exp(-I / kappa)
#
# cdef int delete_fitness(ind *x, double I):
#     x.fitness += exp(-I / kappa)
#     return 0
#
# cdef void compute_ind_fitness(ind *x, pop *SP):
#     cdef int j
#     init_fitness(x)
#     for j in range(SP.size):
#         if SP.ind_array[j] != x:
#             update_fitness(x, calcAddEpsIndicator(SP.ind_array[j], x))
#
# cdef void compute_all_fitness(pop *SP):
#     cdef int i
#     for i in range(SP.size):
#         compute_ind_fitness(SP.ind_array[i], SP)
#
# cdef void loadMOKP(char *filename):
#     global nf, ni, capacities, weights, profits
#     cdef int i, f
#     with open(filename.decode(), "r") as source:
#         _nf, _ni = [int(x) for x in source.readline().split()]
#         nf = _nf
#         ni = _ni
#         capacities = <double *>chk_malloc(nf * sizeof(double))
#         weights = <int **>chk_malloc(nf * sizeof(void*))
#         profits = <int **>chk_malloc(nf * sizeof(void*))
#         for f in range(nf):
#             capacities[f] = float(source.readline().strip())
#             weights[f] = <int *>chk_malloc(ni * sizeof(int))
#             profits[f] = <int *>chk_malloc(ni * sizeof(int))
#             for i in range(ni):
#                 source.readline()  # item index (ignore)
#                 weights[f][i] = int(source.readline().strip())
#                 profits[f][i] = int(source.readline().strip())
#
# cdef void read_weights_file(char *filename):
#     global OBJ_Weights, nombreLIGNE, nf, OBJ_Weights_lines
#     cdef int i, j, nlines
#     with open(filename.decode(), "r") as f:
#         lines = [line for line in f if line.strip()]
#     nlines = len(lines)
#     OBJ_Weights = <double **>chk_malloc(nf * sizeof(void*))
#     for i in range(nf):
#         OBJ_Weights[i] = <double *>chk_malloc(nlines * sizeof(double))
#     for i, line in enumerate(lines):
#         vals = line.strip().split()
#         for j in range(nf):
#             OBJ_Weights[j][i] = float(vals[j])
#     nombreLIGNE = nlines - 1
#     OBJ_Weights_lines = nlines
#
# cdef void dynamic_weight_allpop():
#     global vector_weight, OBJ_Weights, nombreLIGNE, nf, nextLn
#     cdef int i
#     if vector_weight == NULL:
#         vector_weight = <double *>chk_malloc(nf * sizeof(double))
#     for i in range(nf):
#         vector_weight[i] = OBJ_Weights[i][nextLn]
#     if nextLn == nombreLIGNE:
#         nextLn = 0
#     else:
#         nextLn += 1
#
# cdef void choose_weight():
#     dynamic_weight_allpop()
#
# cdef void random_init_ind(ind *x):
#     cdef int j, r, tmp
#     for j in range(ni):
#         x.d[j] = j
#     for j in range(ni):
#         r = irand(ni)
#         tmp = x.d[r]
#         x.d[r] = x.d[j]
#         x.d[j] = tmp
#
# cdef void evaluate(ind *x):
#     cdef int j, l, k, faisable
#     x.nombr = 0
#     x.nombr_nonpris = 0
#     for j in range(nf):
#         x.capa[j] = 0.0
#         x.f[j] = 0.0
#     for j in range(ni):
#         l = 0
#         faisable = 1
#         while l < nf and faisable == 1:
#             if x.capa[l] + weights[l][x.d[j]] > capacities[l]:
#                 faisable = 0
#             l += 1
#         if faisable == 1:
#             for k in range(nf):
#                 x.capa[k] += weights[k][x.d[j]]
#                 x.f[k] += profits[k][x.d[j]]
#             x.Items[x.d[j]] = 1
#             x.nombr += 1
#         else:
#             x.Items[x.d[j]] = 0
#             x.nombr_nonpris += 1
#
# cdef void P_init_pop(pop *SP, pop *Sarchive, int alpha):
#     cdef int i, x, tmp, t
#     t = max(alpha, Sarchive.size)
#     cdef int* shuffle = <int *>chk_malloc(t * sizeof(int))
#     for i in range(t):
#         shuffle[i] = i
#     for i in range(t):
#         x = irand(alpha)
#         tmp = shuffle[i]
#         shuffle[i] = shuffle[x]
#         shuffle[x] = tmp
#     SP.size = alpha
#     if Sarchive.size > alpha:
#         for i in range(alpha):
#             SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#     else:
#         for i in range(alpha):
#             if shuffle[i] < Sarchive.size:
#                 SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#             else:
#                 SP.ind_array[i] = create_ind(nf)
#                 random_init_ind(SP.ind_array[i])
#                 evaluate(SP.ind_array[i])
#     free(shuffle)
#
# cdef int extractPtoArchive(pop *P, pop *archive):
#     cdef int i, j, dom, t, convergence_rate
#     t = archive.size + P.size
#     archiveAndP = create_pop(t, nf)
#     convergence_rate = 0
#     for i in range(archive.size):
#         archiveAndP.ind_array[i] = archive.ind_array[i]
#     for i in range(P.size):
#         archiveAndP.ind_array[i + archive.size] = ind_copy(P.ind_array[i])
#     archiveAndP.size = t
#     archive.size = 0
#     for i in range(t):
#         for j in range(t):
#             if i != j:
#                 dom = non_dominated(archiveAndP.ind_array[i], archiveAndP.ind_array[j])
#                 if dom == -1 or (dom == 0 and i > j):
#                     break
#         else:
#             archive.ind_array[archive.size] = ind_copy(archiveAndP.ind_array[i])
#             archive.size += 1
#             if i >= t - P.size:
#                 convergence_rate += 1
#     complete_free_pop(archiveAndP)
#     return convergence_rate
#
# cdef double calcMaxbound(pop *SP, int size):
#     global max_bound
#     cdef int i, j
#     SP.size = size
#     cdef double max_b = SP.ind_array[0].v[0]
#     for i in range(SP.size):
#         for j in range(nf):
#             if max_b < SP.ind_array[i].v[j]:
#                 max_b = SP.ind_array[i].v[j]
#     if max_b == 0.0:
#         max_b = 1e-8
#     max_bound = max_b
#     return max_b
#
# cdef void calcul_weight(pop *SP, int size):
#     cdef int i, j
#     for i in range(SP.size):
#         for j in range(nf):
#             SP.ind_array[i].v[j] = SP.ind_array[i].f[j] * vector_weight[j]
#
# cdef int compute_fitness_and_select(pop *SP, ind *x, int size):
#     cdef int i, worst
#     cdef double worst_fit, fit_tmp
#     SP.size = size
#     x.fitness = 0
#     compute_ind_fitness(x, SP)
#     worst_fit = x.fitness
#     worst = -1
#     for i in range(SP.size):
#         fit_tmp = update_fitness_return(SP.ind_array[i].fitness, calcAddEpsIndicator(x, SP.ind_array[i]))
#         if fit_tmp > worst_fit:
#             worst = i
#             worst_fit = fit_tmp
#     fit_tmp = x.fitness
#     if worst == -1:
#         return -1
#     else:
#         for i in range(SP.size):
#             delete_fitness(SP.ind_array[i], calcAddEpsIndicator(SP.ind_array[worst], SP.ind_array[i]))
#             update_fitness(SP.ind_array[i], calcAddEpsIndicator(x, SP.ind_array[i]))
#         delete_fitness(x, calcAddEpsIndicator(SP.ind_array[worst], x))
#         free_ind(SP.ind_array[worst])
#         SP.ind_array[worst] = ind_copy(x)
#         if fit_tmp - worst_fit > smallValue:
#             return worst
#         else:
#             return -1
#
# # HYBRID: The new LLM-based neighbor generation function
# # HYBRID: The new LLM-based neighbor generation function (with DEBUG output)
# cdef int generate_neighbor_with_llm(ind *x, object llm_callable, long long iteration_num):
#     global llm_calls_made
#
#     cdef int i, k, r, item_to_remove, item_to_add
#     cdef int* items_to_add_list = <int *>chk_malloc(L * sizeof(int))
#     cdef int num_items_to_add = 0
#     cdef int success = 0
#
#     # 1. Serialize the current state into a prompt
#     cdef list selected_items = [str(idx) for idx in range(ni) if x.Items[idx] == 1]
#     cdef list objective_values = [x.f[i] for i in range(nf)]
#     cdef list remaining_capacity = [capacities[i] - x.capa[i] for i in range(nf)]
#
#     # Find weakest objective
#     cdef int weakest_obj_index = 0
#     if nf > 1 and x.f[1] < x.f[0]:
#         weakest_obj_index = 1
#
#     # Get top K candidate items to add
#     cdef list candidate_items = []
#     cdef double efficiency
#     for i in range(ni):
#         if x.Items[i] == 0:
#             efficiency = profits[weakest_obj_index][i] / (weights[weakest_obj_index][i] + 1e-8)  # Avoid division by zero
#             candidate_items.append((efficiency, i))
#
#     candidate_items.sort(reverse=True, key=lambda item: item[0])
#     cdef list top_k_items = candidate_items[:15]
#
#     cdef str formatted_candidates = "\n".join([f"Item {idx}: profit={profits[weakest_obj_index][idx]}, weight={weights[weakest_obj_index][idx]}, efficiency={eff:.2f}" for eff, idx in top_k_items])
#
#     # ⬇️⬇️⬇️ NEW IMPROVED PROMPT STARTS HERE ⬇️⬇️⬇️
#     # Show item contributions for items currently in knapsack
#     cdef list item_contributions = []
#     for i in range(ni):
#         if x.Items[i] == 1:
#             contribution = f"Item {i}: profits={[profits[k][i] for k in range(nf)]}, weights={[weights[k][i] for k in range(nf)]}"
#             item_contributions.append(contribution)
#
#     cdef str items_in_knapsack_detail = "\n".join(item_contributions[:10])  # Show first 10 to save tokens
#
#     cdef str prompt = f"""You are optimizing a {nf}-objective knapsack problem.
#
# PROBLEM CONSTRAINTS:
# - Capacities: {[capacities[i] for i in range(nf)]}
#
# CURRENT SOLUTION:
# - Items in knapsack ({x.nombr} items): {selected_items}
# - Objective values: {objective_values}
# - Capacity used: {[x.capa[i] for i in range(nf)]}
# - Remaining capacity: {remaining_capacity}
#
# DETAILED ITEM CONTRIBUTIONS (items currently in knapsack):
# {items_in_knapsack_detail}
#
# ANALYSIS:
# - Weakest objective: Objective {weakest_obj_index} (value={x.f[weakest_obj_index]:.0f})
# - Focus on improving this objective!
#
# TOP CANDIDATE ITEMS TO ADD (sorted by profit/weight ratio for weakest objective):
# {formatted_candidates}
#
# YOUR TASK:
# 1. Choose ONE item to REMOVE from the knapsack (must be in the current knapsack list above)
# 2. Choose 1-5 items to ADD from the candidate list (must respect capacity constraints)
# 3. GOAL: Improve objective {weakest_obj_index} without violating capacity constraints
#
# CRITICAL RULES:
# - Item to REMOVE must be in: {selected_items}
# - Items to ADD must be from the candidate list above
# - Total weight added ≤ total weight removed (for each objective)
#
# OUTPUT FORMAT (no other text):
# REMOVE: <item_id>
# ADD: <item_id_1>, <item_id_2>, ...
#
# Example:
# REMOVE: 42
# ADD: 73, 91, 102
# """
#
#
#     # DEBUG: Print the prompt being sent to the LLM
#     print(f"\n===== LLM CALL AT ITERATION {iteration_num} =====")
#     print("--- PROMPT SENT TO LLM ---")
#     print(prompt)
#     print("----------------------------")
#
#     # 2. Call the LLM via the Python callable
#     cdef str response = llm_callable(prompt)
#     llm_calls_made += 1
#
#     # DEBUG: Print the response received from the LLM
#     print("--- RESPONSE FROM LLM ---")
#     if response:
#         print(response)
#     else:
#         print("ERROR: No response received from LLM.")
#     print("-----------------------------")
#
#     # 3. Parse the response (ROBUST VERSION)
#     if not response:
#         free(items_to_add_list)
#         return 0 # Fallback
#
#     item_to_remove = -1
#     cdef list add_ids_str = []
#
#     try:
#         # Find the item to remove (more flexible search)
#         # Look for "REMOVE:" followed by any characters and then a number
#         import re
#         remove_match = re.search(r'REMOVE:\s*\'?(\d+)\'?', response)
#         if remove_match:
#             item_to_remove = int(remove_match.group(1))
#         else:
#             raise ValueError("Could not find REMOVE line.")
#
#         # Find the items to add (more flexible search)
#         # Look for "ADD:" followed by any characters and then numbers
#         add_match = re.search(r'ADD:\s*\'?([\d\s,]+)\'?', response)
#         if add_match:
#             add_ids_str = [s.strip() for s in add_match.group(1).split(',') if s.strip()]
#             num_items_to_add = min(len(add_ids_str), L)
#             for i in range(num_items_to_add):
#                 items_to_add_list[i] = int(add_ids_str[i])
#         else:
#             raise ValueError("Could not find ADD line.")
#
#     except Exception as e:
#         print(f"ERROR: Failed to parse LLM response. Reason: {e}. Falling back to heuristic.")
#         free(items_to_add_list)
#         return 0 # Fallback on parsing error
#
#     # 4. VALIDATE the LLM's suggestion BEFORE applying
#     # Check if item to remove is actually in the knapsack
#     if x.Items[item_to_remove] != 1:
#         print(f"⚠️  VALIDATION ERROR: LLM suggested removing item {item_to_remove}, but it's NOT in knapsack!")
#         print(f"   Items in knapsack: {selected_items}")
#         free(items_to_add_list)
#         return 0  # Fallback to heuristic
#
#     # Validate ALL items to add BEFORE making any changes
#     for i in range(num_items_to_add):
#         item_to_add = items_to_add_list[i]
#         if x.Items[item_to_add] == 1:
#             print(f"⚠️  VALIDATION ERROR: LLM suggested adding item {item_to_add}, but it's ALREADY in knapsack!")
#             free(items_to_add_list)
#             return 0  # Fallback to heuristic
#
#     # 5. Apply the suggested move to a temporary copy
#     cdef ind *temp_x = ind_copy(x)
#
#     # Remove item (we already validated it exists)
#     temp_x.Items[item_to_remove] = 0
#     temp_x.nombr -= 1
#     temp_x.nombr_nonpris += 1
#     for k in range(nf):
#         temp_x.capa[k] -= weights[k][item_to_remove]
#         temp_x.f[k] -= profits[k][item_to_remove]
#
#     # Add items with feasibility checking
#     cdef int items_actually_added = 0
#     cdef int faisable  # ADD THIS LINE - was missing!
#
#     for i in range(num_items_to_add):
#         item_to_add = items_to_add_list[i]
#
#         # Check capacity constraints for this item
#         faisable = 1
#         for k in range(nf):
#             if temp_x.capa[k] + weights[k][item_to_add] > capacities[k]:
#                 faisable = 0
#                 print(f"⚠️  Item {item_to_add} would exceed capacity on objective {k}, skipping...")
#                 break
#
#         # Only add if feasible
#         if faisable:
#             temp_x.Items[item_to_add] = 1
#             temp_x.nombr += 1
#             temp_x.nombr_nonpris -= 1
#             items_actually_added += 1
#             for k in range(nf):
#                 temp_x.capa[k] += weights[k][item_to_add]
#                 temp_x.f[k] += profits[k][item_to_add]
#
#     # Log what actually happened
#     print(f"✓ LLM suggestion applied: Removed item {item_to_remove}, added {items_actually_added}/{num_items_to_add} items")
#
#     # 6. Copy the successful change back to x
#     for k in range(ni):
#         x.Items[k] = temp_x.Items[k]
#     for k in range(nf):
#         x.f[k] = temp_x.f[k]
#         x.capa[k] = temp_x.capa[k]
#     x.nombr = temp_x.nombr
#     x.nombr_nonpris = temp_x.nombr_nonpris
#
#     free_ind(temp_x)
#     free(items_to_add_list)
#     return 1  # Success
#
# # HYBRID: The original heuristic-based neighbor generation, refactored
# cdef int generate_neighbor_with_heuristic(ind *x):
#     cdef int r, l, k, mino, maxp, consistant, IM, taille, feasible
#     cdef int* remplace = <int *>chk_malloc(L * sizeof(int))
#
#     # Initialize remplace array
#     for l in range(L):
#         remplace[l] = 0
#
#     # STEP 1: Remove ONE random item from knapsack
#     while True:
#         mino = irand(ni)
#         if x.Items[mino] == 1:
#             break
#
#     x.Items[mino] = 0
#     x.nombr -= 1
#     x.nombr_nonpris += 1
#     for r in range(nf):
#         x.capa[r] -= weights[r][mino]
#         x.f[r] -= profits[r][mino]
#
#     # STEP 2: Try to add up to L random items
#     IM = 0
#     taille = 0
#     while IM < L:
#         # Pick a random item not in knapsack
#         while True:
#             maxp = irand(ni)
#             if x.Items[maxp] == 0:
#                 break
#
#         if maxp != mino:
#             # Check if adding this item respects capacity constraints
#             consistant = 1
#             r = 0
#             while r < nf and consistant == 1:
#                 if x.capa[r] + weights[r][maxp] > capacities[r]:
#                     consistant = 0
#                 r += 1
#
#             if consistant == 1:
#                 # Check if we haven't already selected this item
#                 feasible = 1
#                 r = 0
#                 while r < taille and feasible:
#                     if maxp == remplace[r]:
#                         feasible = 0
#                     r += 1
#
#                 if feasible == 1:
#                     remplace[taille] = maxp
#                     taille += 1
#                     x.Items[maxp] = 1
#                     x.nombr_nonpris -= 1
#                     x.nombr += 1
#                     for r in range(nf):
#                         x.capa[r] += weights[r][maxp]
#                         x.f[r] += profits[r][maxp]
#         IM += 1
#
#     free(remplace)
#     return 1
#
# # HYBRID: The main local search function, now with hybrid logic
# cdef void Indicator_local_search1(pop *SP, pop *Sarchive, int size, object llm_callable):
#     global iteration_counter
#     cdef ind *x
#     cdef ind *y
#     cdef int llm_success
#     cdef int i, j, r, t, k, l, v, sol, mino, mp, maxp, consistant, pos, stop, convergence, ii, tmp_pris, tmp_nonpris, taille, feasible, tv, IM
#     cdef int* remplace = <int *>chk_malloc(L * sizeof(int))
#     SP.size = size
#     extractPtoArchive(SP, Sarchive)
#     while True:
#         convergence = 0
#         for i in range(SP.size):
#             if not SP.ind_array[i].explored:
#                 x = ind_copy(SP.ind_array[i])
#
#                 # HYBRID: Increment counter and decide which strategy to use
#                 iteration_counter += 1
#                 llm_success = 0
#
#                 # Adaptive LLM calling strategy
#                 cdef int use_llm = 0
#
#                 # Strategy 1: Regular interval (every 20 iterations)
#                 if iteration_counter % 20 == 0:
#                     use_llm = 1
#
#                 # Strategy 2: Use LLM for high-quality solutions (top 30% of population)
#                 cdef int solution_rank = i + 1
#                 if solution_rank <= (SP.size * 0.3):
#                     use_llm = 1
#
#                 if use_llm:
#                     llm_success = generate_neighbor_with_llm(x, llm_callable, iteration_counter)
#
#                 if not llm_success: # Fallback to heuristic if LLM fails or is not called
#                     generate_neighbor_with_heuristic(x)
#
#                 for tv in range(nf):
#                     x.v[tv] = x.f[tv] * vector_weight[tv]
#                 max_bound = calcMaxbound(SP, SP.size)
#                 sol = compute_fitness_and_select(SP, x, SP.size)
#
#                 # MODIFICATION 2: Add a check to see if the LLM's suggestion was accepted
#                 if llm_success:  # This was an LLM call
#                     global llm_suggestions_accepted, llm_suggestions_rejected
#                     if sol != -1:
#                         llm_suggestions_accepted += 1
#                         print(f"✅ LLM SUGGESTION ACCEPTED! (Replaced solution at index {sol})")
#                     else:
#                         llm_suggestions_rejected += 1
#                         print("❌ LLM SUGGESTION REJECTED by fitness evaluation.")
#
#                 if sol != -1:
#                     if sol > i and i + 1 < SP.size:
#                         y = SP.ind_array[i + 1]
#                         SP.ind_array[i + 1] = SP.ind_array[sol]
#                         SP.ind_array[sol] = y
#                         i += 1
#                 free_ind(x)
#
#                 if sol == -1:
#                     SP.ind_array[i].explored = 1
#         convergence = extractPtoArchive(SP, Sarchive)
#         if not convergence:
#             break
#     free(remplace)
#
# def run_hybrid_moacp(instance_file, weights_file, nbitems, num_objectives, output_file, object llm_callable):
#     """
#     Run the HYBRID MOACP for a given instance.
#     """
#     global nf, ni, NBITEMS, alpha, paretoIni, L, nombreLIGNE, nextLn, inv, vector_weight, iteration_counter
#     global capacities, weights, profits, OBJ_Weights
#     global llm_calls_made, llm_suggestions_accepted, llm_suggestions_rejected  # ADD THIS LINE!
#
#     alpha = 10
#     paretoIni = 28000
#     NBL = 100  # Number of iterations per run
#     NRUNS = 10 # Number of runs
#
#     for run in range(1, NRUNS+1):
#         print(f"--- HYBRID RUN {run}/{NRUNS} ---")
#         NBITEMS = nbitems
#         ni = nbitems
#         nf = num_objectives
#         iteration_counter = 0 # Reset counter for each run
#         llm_calls_made = 0  # ADD THIS
#         llm_suggestions_accepted = 0  # ADD THIS
#         llm_suggestions_rejected = 0  # ADD THIS
#
#         seed(run)
#         loadMOKP(instance_file)
#         read_weights_file(weights_file)
#
#         vector_weight = <double *>chk_malloc(nf * sizeof(double))
#         P = create_pop(paretoIni, nf)
#
#         it = 0
#         while it < NBL:
#             solutions = create_pop(alpha, nf)
#             archive = create_pop(paretoIni, nf)
#             choose_weight()
#             P_init_pop(solutions, P, alpha)
#             extractPtoArchive(solutions, P)
#             calcul_weight(solutions, alpha)
#             calcMaxbound(solutions, alpha)
#             compute_all_fitness(solutions)
#             Indicator_local_search1(solutions, archive, alpha, llm_callable)
#             extractPtoArchive(archive, P)
#             it += 1
#             complete_free_pop(solutions)
#             complete_free_pop(archive)
#
#         with open(output_file, "a") as fpareto:
#             fpareto.write("\n")
#             for i in range(P.size):
#                 for j in range(nf):
#                     fpareto.write(f"{P.ind_array[i].f[j]:.6f} ")
#                 fpareto.write("\n")
#
#         # Print LLM statistics for this run
#         if llm_calls_made > 0:
#             acceptance_rate = 100.0 * llm_suggestions_accepted / llm_calls_made
#             print(f"\n{'='*60}")
#             print(f"RUN {run} - LLM PERFORMANCE STATISTICS")
#             print(f"{'='*60}")
#             print(f"Total LLM Calls:        {llm_calls_made}")
#             print(f"Suggestions Accepted:   {llm_suggestions_accepted} ({acceptance_rate:.1f}%)")
#             print(f"Suggestions Rejected:   {llm_suggestions_rejected} ({100-acceptance_rate:.1f}%)")
#             print(f"{'='*60}\n")
#
#             # Export metrics to Python for logging
#             with open("llm_stats_temp.txt", "a") as stats_file:
#                 stats_file.write(f"{run},{llm_calls_made},{llm_suggestions_accepted},{llm_suggestions_rejected}\n")
#
#         complete_free_pop(P)
#         cleanup_globals()
# Out:
# Content of stdout:
# _cython_magic_92a2afba5bec4269ecedc802b1bfc8a9b4b913db29f81322b291a85462ceb4c3.c
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_92a2afba5bec4269ecedc802b1bfc8a9b4b913db29f81322b291a85462ceb4c3.c(4813): warning C4244: '='ÿ: conversion de 'double' en 'float', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_92a2afba5bec4269ecedc802b1bfc8a9b4b913db29f81322b291a85462ceb4c3.c(4903): warning C4244: '='ÿ: conversion de 'double' en 'float', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_92a2afba5bec4269ecedc802b1bfc8a9b4b913db29f81322b291a85462ceb4c3.c(5913): warning C4244: '='ÿ: conversion de 'Py_ssize_t' en 'int', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_92a2afba5bec4269ecedc802b1bfc8a9b4b913db29f81322b291a85462ceb4c3.c(8955): warning C4244: '='ÿ: conversion de 'Py_ssize_t' en 'int', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_92a2afba5bec4269ecedc802b1bfc8a9b4b913db29f81322b291a85462ceb4c3.c(12050): warning C4305: '='ÿ: troncation de 'double' … 'float'
#    Cr‚ation de la bibliothŠque C:\Users\Aziz il patal\.ipython\cython\Users\Aziz il patal\.ipython\cython\_cython_magic_92a2afba5bec4269ecedc802b1bfc8a9b4b913db29f81322b291a85462ceb4c3.cp39-win_amd64.lib et de l'objet C:\Users\Aziz il patal\.ipython\cython\Users\Aziz il patal\.ipython\cython\_cython_magic_92a2afba5bec4269ecedc802b1bfc8a9b4b913db29f81322b291a85462ceb4c3.cp39-win_amd64.exp
# G‚n‚ration de code en cours
# Fin de la g‚n‚ration du code

# %%
import time
import os
import ollama
import matplotlib.pyplot as plt
import csv


# --- Python Helper Function ---
def python_llm_call(prompt: str) -> str:
    """Communicates with the local Ollama server."""
    try:
        response = ollama.chat(
            model='llama3:8b',
            messages=[{'role': 'user', 'content': prompt}]
        )
        return response['message']['content']
    except Exception as e:
        print(f"Error communicating with Ollama: {e}")
        return None


def save_llm_metrics(run_num, llm_calls, accepted, rejected, output_file="llm_metrics.csv"):
    """Save LLM performance metrics to CSV"""
    file_exists = os.path.exists(output_file)
    
    with open(output_file, 'a', newline='') as f:
        writer = csv.writer(f)
        if not file_exists:
            writer.writerow(['Run', 'LLM_Calls', 'Accepted', 'Rejected', 'Acceptance_Rate'])
        
        acceptance_rate = 100.0 * accepted / llm_calls if llm_calls > 0 else 0
        writer.writerow([run_num, llm_calls, accepted, rejected, f"{acceptance_rate:.2f}"])
        

# --- Configuration ---
INSTANCE_FILE = b"250.2.txt"
WEIGHTS_FILE = b"Weights_2obj_FQ200.txt"
NB_ITEMS = 250
NUM_OBJECTIVES = 2
HYBRID_OUTPUT_FILE = "2502_Results_HYBRID.txt"

# --- Clean up previous results ---
if os.path.exists(HYBRID_OUTPUT_FILE):
    os.remove(HYBRID_OUTPUT_FILE)

# --- Run the experiment ---
start_time = time.time()
print(f"Starting Hybrid MOACP experiment...")
print(f"Instance: {INSTANCE_FILE.decode()}")
print(f"Output will be saved to: {HYBRID_OUTPUT_FILE}")
print("-" * 20)

run_hybrid_moacp(
    instance_file=INSTANCE_FILE,
    weights_file=WEIGHTS_FILE,
    nbitems=NB_ITEMS,
    num_objectives=NUM_OBJECTIVES,
    output_file=HYBRID_OUTPUT_FILE,
    llm_callable=python_llm_call  # Pass the function here
)
# Read and process LLM statistics
if os.path.exists("llm_stats_temp.txt"):
    with open("llm_stats_temp.txt", "r") as f:
        for line in f:
            run, calls, accepted, rejected = line.strip().split(',')
            save_llm_metrics(int(run), int(calls), int(accepted), int(rejected))
    os.remove("llm_stats_temp.txt")  # Clean up temp file
    
    # Display summary
    print("\n" + "="*60)
    print("LLM METRICS SAVED TO: llm_metrics.csv")
    print("="*60)
end_time = time.time()
print("-" * 20)
print(f"Experiment finished in {end_time - start_time:.2f} seconds.")

# --- Analysis (same as before) ---
def dominates(a, b):
    return all(x >= y for x, y in zip(a, b)) and any(x > y for x, y in zip(a, b))

def get_true_pareto_front(points):
    pareto = []
    for i, p in enumerate(points):
        dominated = False
        for j, q in enumerate(points):
            if i != j and dominates(q, p):
                dominated = True
                break
        if not dominated:
            pareto.append(p)
    return pareto

def report_pareto_stats(filename, label):
    points = []
    with open(filename, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                try:
                    points.append([float(x) for x in line.split()])
                except Exception:
                    pass
    total_points = len(points)
    pareto_front = get_true_pareto_front(points)
    num_pareto = len(pareto_front)
    print(f"--- {label} ---")
    print(f"  Total points: {total_points}")
    print(f"  Pareto-optimal points: {num_pareto}")
    return pareto_front

def plot_pareto_fronts(fronts, labels, title):
    plt.figure(figsize=(10, 7))
    for front, label in zip(fronts, labels):
        if not front: continue
        xs, ys = zip(*front)
        plt.scatter(xs, ys, label=label, alpha=0.7)
    plt.xlabel("Objective 1 (Profit)")
    plt.ylabel("Objective 2 (Profit)")
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

# --- Comparison ---
BASELINE_FILE = "2502_ResultsMD.txt"
HYBRID_FILE = "2502_Results_HYBRID.txt"

print("\nComparing Baseline vs. Hybrid Algorithm Results:\n")

baseline_front = report_pareto_stats(BASELINE_FILE, "Baseline (Original MOACP)")
hybrid_front = report_pareto_stats(HYBRID_FILE, "Hybrid (MOACP + LLM)")

plot_pareto_fronts(
    fronts=[baseline_front, hybrid_front],
    labels=["Baseline", "Hybrid"],
    title="Pareto Front Comparison: Baseline vs. Hybrid Algorithm"
)
# Out:
# Starting Hybrid MOACP experiment...
# Instance: 250.2.txt
# Output will be saved to: 2502_Results_HYBRID.txt
# --------------------
# --- HYBRID RUN 1/10 ---
# --- Iteration 20: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 20 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['3', '5', '10', '11', '12', '14', '17', '18', '19', '23', '27', '30', '31', '32', '33', '35', '38', '39', '40', '42', '43', '46', '51', '52', '57', '58', '59', '61', '63', '65', '66', '68', '69', '70', '72', '74', '75', '76', '77', '79', '80', '84', '85', '88', '89', '90', '91', '93', '94', '95', '97', '103', '104', '107', '108', '111', '112', '113', '114', '118', '121', '123', '125', '129', '130', '131', '132', '134', '138', '139', '142', '143', '144', '145', '146', '147', '149', '151', '152', '154', '156', '158', '162', '165', '168', '170', '171', '172', '175', '176', '178', '179', '182', '184', '186', '187', '193', '194', '195', '196', '197', '199', '202', '203', '206', '209', '211', '212', '214', '216', '217', '218', '219', '223', '225', '226', '227', '228', '229', '232', '235', '237', '239', '240', '241', '243', '244']
# - Objective values: [6922.0, 6929.0]
# - Remaining capacity: [5.0, 41.0]
#
# ANALYSIS:
# - The weakest objective is Objective #0.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 83: profit=89, weight=10
# Item 116: profit=91, weight=19
# Item 157: profit=46, weight=10
# Item 34: profit=100, weight=22
# Item 169: profit=93, weight=24
# Item 78: profit=84, weight=22
# Item 127: profit=77, weight=21
# Item 163: profit=52, weight=15
# Item 122: profit=81, weight=24
# Item 234: profit=53, weight=16
# Item 50: profit=68, weight=21
# Item 82: profit=92, weight=32
# Item 140: profit=56, weight=20
# Item 109: profit=97, weight=36
# Item 64: profit=79, weight=30
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis and the provided data, I suggest one move to improve the knapsack solution:
#
# **REMOVE:** 18 (profit=78, weight=26)
#
# The removed item is the one with the highest weight-to-profit ratio among all items in the current knapsack. This will free up some capacity and allow for more efficient use of resources.
#
# **ADD:** 83, 140
#
# The added items are the ones with the highest efficiency values (profit/weight) for Objective #0, which is the weakest objective. The total weight of these added items (89 + 56 = 145) does not exceed the total weight of the removed item (26).
# -----------------------------
# ERROR: Failed to parse LLM response. Reason: Could not find REMOVE line.. Falling back to heuristic.
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 40: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 40 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['3', '5', '6', '9', '13', '17', '18', '19', '20', '21', '22', '24', '27', '28', '29', '32', '35', '38', '42', '43', '45', '51', '52', '53', '54', '55', '57', '59', '61', '62', '63', '64', '66', '67', '68', '71', '73', '74', '75', '76', '78', '80', '83', '84', '85', '88', '89', '90', '91', '92', '93', '98', '103', '105', '106', '107', '108', '110', '112', '113', '114', '115', '116', '117', '118', '120', '121', '124', '125', '127', '128', '131', '132', '133', '136', '137', '138', '139', '140', '143', '144', '145', '147', '150', '152', '153', '154', '155', '159', '161', '163', '164', '165', '167', '169', '171', '175', '177', '179', '181', '185', '188', '189', '190', '191', '193', '194', '195', '196', '198', '199', '200', '202', '203', '205', '206', '207', '208', '210', '211', '213', '214', '216', '217', '219', '222', '223', '224', '225', '228', '229', '232', '234', '237', '240', '241', '242', '243', '244', '245', '246']
# - Objective values: [7377.0, 7887.0]
# - Remaining capacity: [42.0, 48.0]
#
# ANALYSIS:
# - The weakest objective is Objective #0.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 157: profit=46, weight=10
# Item 34: profit=100, weight=22
# Item 162: profit=82, weight=19
# Item 142: profit=42, weight=11
# Item 122: profit=81, weight=24
# Item 50: profit=68, weight=21
# Item 40: profit=86, weight=28
# Item 184: profit=79, weight=27
# Item 82: profit=92, weight=32
# Item 109: profit=97, weight=36
# Item 168: profit=64, weight=25
# Item 96: profit=85, weight=34
# Item 146: profit=33, weight=14
# Item 111: profit=42, weight=18
# Item 170: profit=78, weight=37
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis and the critical constraints, I suggest:
#
# REMOVE: 111
# ADD: 157, 146
#
# Explanation:
# I choose to remove item 111 because it has a moderate profit of 42 and a relatively high weight of 18. This decision aims to improve the weakest objective (#0) by freeing up some capacity.
#
# To supplement the removed item's contribution, I add items 157 and 146 to the knapsack. Item 157 is highly efficient for improving Objective #0, with a profit-to-weight ratio of 4.6. Item 146 has a low weight and moderate profit, which can help without exceeding the total weight constraint.
#
# These suggestions aim to improve the weakest objective (#0) while respecting the critical constraints.
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 60: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 60 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['3', '4', '5', '8', '11', '13', '14', '16', '18', '19', '21', '26', '27', '28', '29', '32', '35', '37', '38', '39', '40', '42', '43', '44', '45', '46', '48', '49', '50', '51', '52', '55', '58', '61', '65', '66', '67', '71', '75', '76', '77', '78', '80', '83', '85', '89', '90', '91', '92', '93', '95', '96', '98', '99', '100', '103', '105', '107', '108', '109', '110', '113', '114', '116', '117', '118', '119', '125', '126', '127', '128', '130', '131', '133', '134', '135', '136', '138', '140', '142', '143', '145', '146', '147', '150', '152', '153', '154', '156', '157', '160', '161', '163', '164', '167', '168', '169', '173', '175', '179', '180', '181', '182', '184', '187', '189', '190', '191', '193', '202', '203', '204', '205', '206', '207', '208', '209', '210', '211', '213', '214', '216', '219', '222', '223', '224', '225', '227', '229', '231', '236', '237', '239', '240', '241', '242', '243', '245', '246', '249']
# - Objective values: [7302.0, 7904.0]
# - Remaining capacity: [100.0, 36.0]
#
# ANALYSIS:
# - The weakest objective is Objective #0.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 196: profit=66, weight=12
# Item 34: profit=100, weight=22
# Item 162: profit=82, weight=19
# Item 122: profit=81, weight=24
# Item 234: profit=53, weight=16
# Item 82: profit=92, weight=32
# Item 63: profit=90, weight=33
# Item 64: profit=79, weight=30
# Item 22: profit=84, weight=33
# Item 232: profit=30, weight=12
# Item 111: profit=42, weight=18
# Item 137: profit=67, weight=30
# Item 170: profit=78, weight=37
# Item 124: profit=48, weight=23
# Item 9: profit=99, weight=50
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis, I recommend:
#
# REMOVE: 119
#
# This is because Item #119 has a relatively low profit-to-weight ratio compared to other items in the knapsack. Removing it will free up some capacity and allow for more efficient use of resources.
#
# ADD: 196, 234
#
# These two items are ranked high in terms of efficiency for improving Objective #0. They have good profit-to-weight ratios and can be added without exceeding the weight constraint for either objective.
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 80: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 80 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['1', '2', '3', '5', '7', '8', '9', '11', '15', '18', '19', '22', '26', '27', '28', '29', '32', '34', '35', '38', '39', '40', '41', '44', '45', '46', '48', '49', '51', '52', '53', '54', '57', '59', '60', '62', '64', '65', '66', '68', '69', '72', '73', '74', '75', '76', '78', '80', '82', '84', '85', '87', '88', '91', '92', '96', '99', '100', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '117', '118', '120', '121', '122', '124', '126', '130', '131', '132', '134', '137', '140', '143', '144', '145', '146', '151', '152', '156', '157', '160', '161', '162', '163', '164', '165', '166', '169', '171', '175', '177', '179', '180', '182', '183', '185', '186', '188', '190', '192', '196', '197', '198', '199', '204', '205', '206', '207', '208', '209', '211', '212', '213', '215', '216', '219', '222', '223', '227', '231', '234', '235', '237', '242', '243', '245', '247']
# - Objective values: [7617.0, 7593.0]
# - Remaining capacity: [8.0, 21.0]
#
# ANALYSIS:
# - The weakest objective is Objective #1.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 31: profit=61, weight=10
# Item 244: profit=90, weight=17
# Item 13: profit=96, weight=19
# Item 71: profit=61, weight=16
# Item 226: profit=60, weight=16
# Item 203: profit=78, weight=22
# Item 123: profit=72, weight=21
# Item 56: profit=47, weight=14
# Item 67: profit=68, weight=21
# Item 167: profit=93, weight=33
# Item 58: profit=96, weight=36
# Item 154: profit=76, weight=30
# Item 20: profit=43, weight=17
# Item 136: profit=96, weight=39
# Item 128: profit=97, weight=41
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis and available data, I recommend the following move to improve the knapsack solution:
#
# REMOVE: 19
#
# This item has a weight of 22 and is currently in the knapsack. Replacing it with one or more items from the candidate list will not exceed its weight for either objective.
#
# ADD: 31, 226
#
# Item 31 has a high efficiency (61/10 = 6.1) for the weakest objective (#1), while item 226 has a moderate efficiency (60/16 = 3.75). Adding these two items to the knapsack will not exceed the removed item's weight and may improve the overall performance of the solution.
#
# Note that I have chosen to remove an item with a relatively high weight, which should give us more flexibility to add new items without exceeding the total weight constraint.
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 100: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 100 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['3', '7', '9', '10', '13', '15', '18', '19', '20', '24', '26', '29', '30', '31', '33', '34', '36', '37', '39', '40', '43', '44', '45', '47', '48', '50', '52', '53', '54', '55', '57', '58', '59', '60', '61', '64', '65', '67', '68', '69', '70', '72', '73', '74', '76', '82', '83', '84', '85', '87', '89', '90', '91', '94', '95', '96', '97', '98', '99', '100', '102', '103', '104', '105', '109', '114', '116', '117', '118', '119', '121', '123', '124', '125', '126', '127', '128', '132', '133', '135', '136', '137', '138', '139', '140', '142', '147', '150', '151', '152', '153', '157', '160', '161', '162', '163', '166', '168', '169', '175', '176', '177', '182', '183', '184', '185', '188', '190', '191', '192', '193', '194', '195', '196', '198', '203', '204', '205', '208', '209', '210', '211', '212', '213', '215', '223', '225', '229', '237', '238', '239', '242', '243', '244', '247', '248']
# - Objective values: [7555.0, 7652.0]
# - Remaining capacity: [72.0, 16.0]
#
# ANALYSIS:
# - The weakest objective is Objective #0.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 38: profit=91, weight=15
# Item 78: profit=84, weight=22
# Item 122: profit=81, weight=24
# Item 234: profit=53, weight=16
# Item 63: profit=90, weight=33
# Item 216: profit=42, weight=16
# Item 22: profit=84, weight=33
# Item 5: profit=75, weight=30
# Item 232: profit=30, weight=12
# Item 222: profit=61, weight=25
# Item 146: profit=33, weight=14
# Item 111: profit=42, weight=18
# Item 107: profit=99, weight=43
# Item 143: profit=55, weight=24
# Item 170: profit=78, weight=37
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis provided, I recommend the following move:
#
# REMOVE: 20
#
# ADD: 38, 146
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 120: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 120 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['5', '7', '8', '11', '13', '15', '17', '20', '22', '23', '25', '26', '27', '29', '34', '35', '38', '39', '40', '41', '42', '44', '45', '48', '49', '50', '51', '52', '55', '56', '58', '61', '62', '64', '66', '69', '72', '73', '74', '75', '78', '79', '80', '82', '83', '87', '89', '90', '91', '92', '95', '96', '97', '98', '99', '100', '103', '105', '108', '109', '110', '112', '115', '117', '119', '120', '121', '123', '124', '126', '127', '128', '131', '132', '135', '137', '138', '139', '140', '141', '143', '144', '146', '149', '151', '153', '154', '157', '160', '162', '164', '168', '170', '173', '175', '177', '180', '181', '182', '184', '185', '187', '188', '190', '191', '193', '195', '196', '198', '199', '200', '203', '205', '207', '208', '209', '210', '211', '212', '213', '214', '216', '217', '218', '219', '222', '223', '225', '227', '228', '230', '232', '234', '236', '237', '240', '243', '244', '245', '246', '249']
# - Objective values: [7819.0, 7935.0]
# - Remaining capacity: [41.0, 6.0]
#
# ANALYSIS:
# - The weakest objective is Objective #0.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 114: profit=99, weight=12
# Item 76: profit=92, weight=12
# Item 229: profit=59, weight=11
# Item 116: profit=91, weight=19
# Item 18: profit=75, weight=17
# Item 169: profit=93, weight=24
# Item 142: profit=42, weight=11
# Item 163: profit=52, weight=15
# Item 3: profit=41, weight=12
# Item 122: profit=81, weight=24
# Item 43: profit=45, weight=14
# Item 19: profit=70, weight=24
# Item 63: profit=90, weight=33
# Item 111: profit=42, weight=18
# Item 107: profit=99, weight=43
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis, I recommend the following move:
#
# REMOVE: 20
# ADD: 114, 142
#
# Justification:
# I removed Item 20 (profit=59, weight=11) from the knapsack because it has a relatively low profit-to-weight ratio compared to other items. This removal will not significantly affect the remaining capacity.
#
# I added Items 114 (profit=99, weight=12) and 142 (profit=42, weight=11) because they are highly efficient for improving Objective #0. The total weight of these two items (23) does not exceed the weight of Item 20 (11), satisfying the critical constraint.
#
# Note that I did not add more items to balance the objectives, as per the problem statement, you must focus on improving the weakest objective (Objective #0).
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 140: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 140 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['2', '3', '5', '6', '7', '8', '13', '15', '17', '18', '19', '22', '23', '24', '26', '27', '28', '30', '31', '33', '34', '36', '39', '40', '43', '44', '45', '46', '48', '49', '52', '54', '55', '56', '57', '60', '64', '65', '66', '68', '70', '72', '75', '76', '78', '80', '85', '88', '89', '90', '91', '95', '98', '99', '101', '103', '104', '105', '107', '108', '109', '110', '111', '112', '113', '116', '117', '121', '122', '124', '126', '127', '128', '129', '135', '137', '138', '139', '140', '142', '143', '144', '146', '148', '151', '152', '153', '154', '157', '159', '161', '162', '165', '168', '169', '171', '175', '176', '178', '179', '180', '182', '184', '185', '188', '191', '192', '195', '196', '197', '198', '201', '205', '206', '207', '208', '209', '210', '212', '214', '219', '222', '223', '224', '225', '226', '228', '229', '230', '231', '234', '236', '237', '240', '243', '244', '245', '247']
# - Objective values: [7285.0, 7519.0]
# - Remaining capacity: [64.0, 31.0]
#
# ANALYSIS:
# - The weakest objective is Objective #0.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 83: profit=89, weight=10
# Item 114: profit=99, weight=12
# Item 38: profit=91, weight=15
# Item 61: profit=57, weight=12
# Item 211: profit=49, weight=13
# Item 163: profit=52, weight=15
# Item 50: profit=68, weight=21
# Item 82: profit=92, weight=32
# Item 63: profit=90, weight=33
# Item 216: profit=42, weight=16
# Item 96: profit=85, weight=34
# Item 232: profit=30, weight=12
# Item 213: profit=44, weight=20
# Item 170: profit=78, weight=37
# Item 32: profit=99, weight=49
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# After analyzing the current solution and candidate items to add, I recommend the following move:
#
# REMOVE: 109
#
# The item with ID 109 has a total weight of 12. This will free up capacity in both objectives.
#
# ADD: 83, 211
#
# Item 83 is ranked high for improving the weakest objective (Objective #0) and has a moderate weight of 10. Item 211 also improves Objective #0 and has a weight of 13. The total weight of these two items (23) does not exceed the weight of the removed item (12), satisfying the critical constraints.
#
# Note: I did not add any other items to balance the objectives, as removing an item with moderate weight can already have a significant impact on improving the weakest objective.
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 160: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 160 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['3', '5', '6', '7', '9', '12', '13', '15', '16', '17', '18', '20', '21', '22', '23', '24', '25', '26', '27', '29', '32', '34', '36', '38', '39', '41', '42', '44', '46', '48', '52', '54', '57', '58', '60', '61', '62', '64', '65', '66', '67', '68', '69', '70', '72', '74', '75', '80', '82', '83', '85', '87', '90', '91', '92', '94', '96', '98', '99', '100', '101', '103', '106', '107', '108', '110', '111', '113', '114', '115', '117', '118', '119', '120', '121', '124', '126', '128', '132', '134', '137', '138', '139', '140', '142', '144', '145', '146', '147', '148', '151', '152', '153', '154', '156', '157', '158', '161', '162', '164', '166', '167', '169', '171', '173', '175', '177', '178', '179', '181', '182', '186', '189', '190', '191', '192', '203', '204', '207', '208', '209', '210', '211', '212', '213', '216', '217', '219', '222', '226', '229', '232', '234', '239', '241', '242', '243', '245', '246', '247']
# - Objective values: [7354.0, 7769.0]
# - Remaining capacity: [12.0, 98.0]
#
# ANALYSIS:
# - The weakest objective is Objective #0.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 76: profit=92, weight=12
# Item 196: profit=66, weight=12
# Item 116: profit=91, weight=19
# Item 78: profit=84, weight=22
# Item 127: profit=77, weight=21
# Item 163: profit=52, weight=15
# Item 122: profit=81, weight=24
# Item 50: profit=68, weight=21
# Item 43: profit=45, weight=14
# Item 40: profit=86, weight=28
# Item 184: profit=79, weight=27
# Item 19: profit=70, weight=24
# Item 63: profit=90, weight=33
# Item 109: profit=97, weight=36
# Item 168: profit=64, weight=25
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis and candidate items to add, I recommend the following move:
#
# REMOVE: 67
# ADD: 76, 163
#
# Explanation:
# - Removing item 67 (profit=70, weight=24) will free up capacity in both objectives.
# - Item 76 has a high profit-to-weight ratio for Objective #0, which is the weakest objective. Adding this item will improve the performance of Objective #0.
# - Item 163 has a moderate profit-to-weight ratio and can be added without violating any constraints.
#
# Note: The total weight of added items (12+15=27) does not exceed the total weight of removed item (24), ensuring that constraint 3 is satisfied.
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 180: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 180 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['0', '1', '2', '3', '5', '8', '10', '13', '14', '15', '17', '20', '21', '23', '26', '27', '29', '30', '32', '33', '34', '35', '36', '38', '39', '40', '41', '42', '44', '45', '46', '48', '49', '50', '51', '52', '54', '55', '58', '59', '62', '65', '71', '72', '73', '74', '76', '78', '79', '80', '82', '83', '84', '85', '89', '90', '91', '92', '95', '96', '97', '99', '100', '101', '105', '107', '108', '109', '111', '113', '114', '115', '116', '117', '118', '119', '122', '123', '124', '126', '128', '135', '137', '138', '140', '141', '143', '146', '148', '149', '150', '151', '152', '153', '154', '155', '156', '162', '163', '167', '170', '171', '175', '176', '177', '179', '182', '189', '190', '191', '193', '196', '198', '199', '200', '203', '205', '209', '210', '211', '212', '213', '216', '219', '221', '225', '227', '229', '234', '236', '239', '241', '242', '243', '244', '245', '246', '248', '249']
# - Objective values: [7786.0, 7731.0]
# - Remaining capacity: [33.0, 183.0]
#
# ANALYSIS:
# - The weakest objective is Objective #1.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 66: profit=99, weight=12
# Item 110: profit=69, weight=11
# Item 31: profit=61, weight=10
# Item 87: profit=86, weight=15
# Item 68: profit=84, weight=17
# Item 164: profit=75, weight=16
# Item 226: profit=60, weight=16
# Item 208: profit=41, weight=11
# Item 169: profit=82, weight=23
# Item 56: profit=47, weight=14
# Item 67: profit=68, weight=21
# Item 75: profit=27, weight=10
# Item 247: profit=90, weight=36
# Item 136: profit=96, weight=39
# Item 103: profit=59, weight=24
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis and critical constraints, I recommend the following move:
#
# REMOVE: 100
#
# This item has a weight of 36, which is higher than any of the candidate items to add. Removing it will free up capacity in both objectives.
#
# ADD: 66, 31
#
# These two items are ranked high in terms of efficiency for improving Objective #1, and their total weight (23) does not exceed the weight of the removed item (36).
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 200: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 200 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['1', '3', '4', '5', '6', '7', '9', '10', '12', '17', '19', '20', '21', '23', '28', '29', '30', '31', '35', '36', '38', '39', '41', '42', '45', '46', '47', '48', '49', '50', '51', '52', '54', '56', '58', '60', '61', '62', '64', '65', '66', '67', '68', '69', '72', '74', '76', '78', '82', '83', '84', '85', '87', '88', '91', '92', '94', '95', '96', '97', '98', '100', '101', '103', '105', '108', '109', '110', '112', '113', '114', '115', '116', '120', '124', '126', '127', '128', '131', '135', '136', '137', '138', '141', '143', '144', '145', '146', '148', '151', '153', '154', '155', '157', '158', '159', '164', '169', '170', '171', '174', '175', '176', '178', '181', '182', '183', '188', '190', '191', '192', '195', '196', '198', '199', '202', '204', '206', '207', '208', '209', '210', '213', '215', '216', '217', '218', '219', '223', '225', '226', '229', '231', '232', '234', '236', '239', '242', '243', '244', '247']
# - Objective values: [7188.0, 7815.0]
# - Remaining capacity: [11.0, 54.0]
#
# ANALYSIS:
# - The weakest objective is Objective #0.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 34: profit=100, weight=22
# Item 18: profit=75, weight=17
# Item 162: profit=82, weight=19
# Item 142: profit=42, weight=11
# Item 211: profit=49, weight=13
# Item 163: profit=52, weight=15
# Item 122: profit=81, weight=24
# Item 43: profit=45, weight=14
# Item 40: profit=86, weight=28
# Item 184: profit=79, weight=27
# Item 140: profit=56, weight=20
# Item 63: profit=90, weight=33
# Item 168: profit=64, weight=25
# Item 22: profit=84, weight=33
# Item 222: profit=61, weight=25
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis, I recommend:
#
# REMOVE: 29
#
# ADD: 34, 142
#
# Explanation:
# The weakest objective is Objective #0. Item 29 has the highest weight-to-profit ratio among the items in the knapsack for this objective. Removing it will free up capacity to add more profitable items.
#
# Item 34 and Item 142 are the top-ranked candidates for adding new items. They have high efficiency for the weakest objective (Objective #0) and their combined weight does not exceed the weight of the removed item (29).
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 220: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 220 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['5', '7', '8', '11', '13', '15', '17', '20', '22', '23', '25', '26', '27', '29', '34', '35', '38', '39', '40', '41', '42', '44', '45', '48', '49', '50', '51', '52', '55', '56', '58', '61', '62', '64', '66', '69', '72', '73', '74', '75', '78', '79', '80', '82', '83', '87', '89', '90', '91', '92', '95', '96', '97', '98', '99', '100', '103', '105', '108', '109', '110', '112', '115', '117', '119', '120', '121', '123', '124', '126', '127', '128', '131', '132', '135', '137', '138', '139', '140', '141', '143', '144', '146', '149', '151', '153', '154', '157', '160', '162', '164', '168', '170', '173', '175', '177', '180', '181', '182', '184', '185', '187', '188', '190', '191', '193', '195', '196', '198', '199', '200', '203', '205', '207', '208', '209', '210', '211', '212', '213', '214', '216', '217', '218', '219', '222', '223', '225', '227', '228', '230', '232', '234', '236', '237', '240', '243', '244', '245', '246', '249']
# - Objective values: [7819.0, 7935.0]
# - Remaining capacity: [41.0, 6.0]
#
# ANALYSIS:
# - The weakest objective is Objective #0.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 114: profit=99, weight=12
# Item 76: profit=92, weight=12
# Item 229: profit=59, weight=11
# Item 116: profit=91, weight=19
# Item 18: profit=75, weight=17
# Item 169: profit=93, weight=24
# Item 142: profit=42, weight=11
# Item 163: profit=52, weight=15
# Item 3: profit=41, weight=12
# Item 122: profit=81, weight=24
# Item 43: profit=45, weight=14
# Item 19: profit=70, weight=24
# Item 63: profit=90, weight=33
# Item 111: profit=42, weight=18
# Item 107: profit=99, weight=43
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis and candidate items to add, I recommend:
#
# REMOVE: 23
#
# ADD: 114, 142
#
# These suggestions are based on improving the weakest objective (#0) by removing an item that does not have a high profit-to-weight ratio (item 23 has a profit of 52 and weight of 17), and adding two items with a higher profit-to-weight ratio that do not exceed the total weight of the removed item for either objective.
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 240: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 240 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['1', '5', '6', '9', '10', '12', '13', '14', '15', '18', '19', '20', '22', '26', '28', '29', '31', '32', '34', '38', '39', '42', '43', '44', '45', '47', '49', '50', '51', '52', '53', '55', '57', '61', '65', '66', '68', '69', '71', '73', '75', '76', '78', '83', '84', '87', '88', '89', '90', '91', '92', '93', '95', '96', '97', '98', '99', '100', '105', '106', '109', '110', '111', '112', '113', '114', '115', '117', '118', '121', '124', '125', '126', '129', '132', '135', '136', '137', '138', '140', '142', '146', '147', '148', '149', '151', '152', '153', '155', '157', '159', '161', '162', '163', '164', '167', '168', '169', '171', '175', '178', '179', '181', '184', '185', '188', '189', '190', '191', '192', '193', '196', '198', '199', '200', '201', '202', '203', '205', '206', '207', '208', '209', '211', '214', '216', '221', '222', '223', '224', '225', '227', '231', '238', '242', '243', '245', '246', '247', '248']
# - Objective values: [7060.0, 7663.0]
# - Remaining capacity: [23.0, 120.0]
#
# ANALYSIS:
# - The weakest objective is Objective #0.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 229: profit=59, weight=11
# Item 116: profit=91, weight=19
# Item 127: profit=77, weight=21
# Item 3: profit=41, weight=12
# Item 122: profit=81, weight=24
# Item 234: profit=53, weight=16
# Item 40: profit=86, weight=28
# Item 82: profit=92, weight=32
# Item 63: profit=90, weight=33
# Item 64: profit=79, weight=30
# Item 232: profit=30, weight=12
# Item 107: profit=99, weight=43
# Item 143: profit=55, weight=24
# Item 213: profit=44, weight=20
# Item 170: profit=78, weight=37
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis and constraints, I recommend:
#
# REMOVE: '151'
#
# This is because removing item 151 will free up a significant amount of capacity in both objectives, allowing for more efficient additions to improve the weakest objective.
#
# ADD: '229', '122'
#
# These two items have high efficiency values for improving the weakest objective (Objective #0) and can be added without exceeding the weight constraint.
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 260: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 260 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['5', '7', '8', '11', '13', '15', '17', '20', '22', '25', '26', '27', '29', '34', '35', '38', '39', '40', '41', '42', '44', '45', '48', '49', '50', '51', '52', '55', '56', '58', '61', '62', '64', '66', '69', '72', '73', '74', '75', '78', '79', '80', '82', '83', '87', '89', '90', '91', '92', '95', '96', '97', '98', '99', '100', '103', '105', '108', '109', '110', '112', '114', '115', '117', '119', '120', '121', '123', '124', '126', '127', '128', '131', '132', '135', '137', '138', '139', '140', '141', '142', '143', '144', '146', '149', '151', '153', '154', '157', '160', '162', '164', '168', '170', '173', '175', '177', '180', '181', '182', '184', '185', '187', '188', '190', '191', '193', '195', '196', '198', '199', '200', '203', '205', '207', '208', '209', '210', '211', '212', '213', '214', '216', '217', '218', '219', '222', '223', '225', '227', '228', '230', '232', '234', '236', '237', '240', '243', '244', '245', '246', '249']
# - Objective values: [7944.0, 7952.0]
# - Remaining capacity: [57.0, 19.0]
#
# ANALYSIS:
# - The weakest objective is Objective #0.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 76: profit=92, weight=12
# Item 229: profit=59, weight=11
# Item 116: profit=91, weight=19
# Item 18: profit=75, weight=17
# Item 169: profit=93, weight=24
# Item 163: profit=52, weight=15
# Item 3: profit=41, weight=12
# Item 122: profit=81, weight=24
# Item 43: profit=45, weight=14
# Item 19: profit=70, weight=24
# Item 63: profit=90, weight=33
# Item 111: profit=42, weight=18
# Item 107: profit=99, weight=43
# Item 32: profit=99, weight=49
# Item 9: profit=99, weight=50
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis, I recommend:
#
# REMOVE: 27
#
# This is because Item 27 has a weight of 29 and an objective #0 value that can be improved by adding other items. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# ADD: 76, 163
#
# These two items have high efficiency values for Objective #0 (92 and 52, respectively) and their weights are relatively low (12 and 15, respectively). This will help improve the weakest objective without exceeding the remaining capacity.
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 280: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 280 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['5', '7', '8', '11', '13', '15', '17', '20', '22', '25', '26', '27', '29', '34', '35', '38', '39', '40', '41', '42', '44', '45', '48', '49', '50', '51', '52', '55', '56', '58', '61', '62', '64', '66', '69', '72', '73', '74', '75', '78', '79', '80', '82', '83', '87', '89', '90', '91', '92', '95', '96', '97', '98', '99', '100', '103', '105', '108', '109', '110', '112', '114', '115', '117', '119', '120', '121', '123', '124', '126', '127', '128', '131', '132', '135', '137', '138', '139', '140', '141', '142', '143', '144', '146', '149', '151', '153', '154', '157', '160', '162', '164', '168', '170', '173', '175', '177', '180', '181', '182', '184', '185', '187', '188', '190', '191', '193', '195', '196', '198', '199', '200', '203', '205', '207', '208', '209', '210', '211', '212', '213', '214', '216', '217', '218', '219', '222', '223', '225', '227', '228', '230', '232', '234', '236', '237', '240', '243', '244', '245', '246', '249']
# - Objective values: [7944.0, 7952.0]
# - Remaining capacity: [57.0, 19.0]
#
# ANALYSIS:
# - The weakest objective is Objective #0.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 76: profit=92, weight=12
# Item 229: profit=59, weight=11
# Item 116: profit=91, weight=19
# Item 18: profit=75, weight=17
# Item 169: profit=93, weight=24
# Item 163: profit=52, weight=15
# Item 3: profit=41, weight=12
# Item 122: profit=81, weight=24
# Item 43: profit=45, weight=14
# Item 19: profit=70, weight=24
# Item 63: profit=90, weight=33
# Item 111: profit=42, weight=18
# Item 107: profit=99, weight=43
# Item 32: profit=99, weight=49
# Item 9: profit=99, weight=50
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis and constraints, I recommend:
#
# REMOVE: 75
# ADD: 76, 43
#
# The removed item is Item 75 with a weight of 24. The added items are Item 76 with a profit of 92 and a weight of 12, and Item 43 with a profit of 45 and a weight of 14.
#
# These choices satisfy the constraints:
#
# 1. Removed item (75) is present in the 'Items in knapsack' list.
# 2. Added items (76 and 43) are present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items (12 + 14 = 26) does not exceed the total weight of the removed item (24) for either objective.
#
# These moves aim to improve the weakest objective (#0), as per the analysis.
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 300: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 300 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# ...
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis, I recommend:
#
# REMOVE: 31
#
# This is because Item 31 has a high weight of 35 and a moderate profit of 47. Replacing it with a more efficient item can potentially improve Objective #0.
#
# ADD: 38, 211
#
# These two items have high efficiency for improving Objective #0, with profits of 91 and 49, respectively, and weights of 15 and 13, which are relatively low.
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 200: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 200 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['2', '5', '7', '8', '10', '11', '12', '16', '18', '19', '20', '22', '23', '24', '25', '27', '29', '30', '31', '33', '36', '38', '39', '41', '42', '43', '46', '47', '49', '51', '52', '53', '54', '55', '56', '61', '64', '66', '69', '71', '72', '75', '78', '79', '80', '82', '83', '84', '87', '88', '89', '90', '91', '92', '93', '94', '96', '97', '98', '99', '104', '106', '109', '111', '113', '118', '119', '120', '122', '127', '128', '129', '131', '133', '134', '135', '137', '140', '142', '144', '146', '148', '149', '150', '151', '152', '153', '156', '158', '161', '162', '163', '167', '168', '170', '174', '177', '182', '186', '189', '192', '194', '197', '200', '201', '203', '204', '206', '208', '209', '210', '213', '215', '218', '221', '226', '227', '228', '233', '237', '238', '240', '242', '243', '244']
# - Objective values: [6922.0, 7126.0]
# - Remaining capacity: [26.0, 0.0]
#
# ANALYSIS:
# - The weakest objective is Objective #0.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 114: profit=99, weight=12
# Item 76: profit=92, weight=12
# Item 196: profit=66, weight=12
# Item 229: profit=59, weight=11
# Item 116: profit=91, weight=19
# Item 157: profit=46, weight=10
# Item 34: profit=100, weight=22
# Item 138: profit=96, weight=24
# Item 169: profit=93, weight=24
# Item 211: profit=49, weight=13
# Item 3: profit=41, weight=12
# Item 234: profit=53, weight=16
# Item 50: profit=68, weight=21
# Item 40: profit=86, weight=28
# Item 184: profit=79, weight=27
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis, I recommend:
#
# REMOVE: 34
#
# This item has a weight of 22, which is the highest among all items in the knapsack. Removing it will free up capacity for adding other items.
#
# ADD: 114, 157
#
# These two items are highly efficient for improving Objective #0 (the weakest objective). Item 114 has a profit-to-weight ratio of 99/12 = 8.25, and item 157 has a profit-to-weight ratio of 46/10 = 4.6. Both items have a relatively low weight compared to their profit values, making them good candidates for addition.
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 220: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 220 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['0', '2', '3', '7', '8', '9', '11', '12', '13', '14', '15', '17', '19', '23', '24', '25', '27', '28', '29', '31', '32', '35', '38', '40', '45', '47', '48', '51', '52', '53', '54', '58', '59', '61', '64', '65', '66', '67', '69', '70', '74', '75', '78', '79', '81', '83', '89', '92', '93', '94', '96', '98', '101', '102', '103', '106', '107', '108', '110', '112', '114', '117', '118', '119', '120', '123', '124', '127', '129', '130', '131', '134', '135', '139', '143', '145', '146', '149', '152', '153', '156', '159', '161', '163', '164', '165', '166', '167', '168', '169', '174', '175', '176', '180', '182', '183', '186', '187', '189', '190', '193', '194', '195', '196', '199', '200', '201', '202', '210', '212', '215', '217', '220', '227', '228', '229', '232', '233', '238', '245', '246', '247']
# - Objective values: [6912.0, 6256.0]
# - Remaining capacity: [3.0, 177.0]
#
# ANALYSIS:
# - The weakest objective is Objective #1.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 105: profit=88, weight=11
# Item 100: profit=99, weight=15
# Item 84: profit=65, weight=11
# Item 87: profit=86, weight=15
# Item 151: profit=66, weight=12
# Item 244: profit=90, weight=17
# Item 85: profit=83, weight=16
# Item 68: profit=84, weight=17
# Item 113: profit=83, weight=18
# Item 211: profit=67, weight=17
# Item 39: profit=74, weight=19
# Item 219: profit=65, weight=17
# Item 71: profit=61, weight=16
# Item 226: profit=60, weight=16
# Item 208: profit=41, weight=11
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis and constraints provided, I suggest:
#
# REMOVE: 164
# ADD: 105, 68
#
# Explanation:
# I focused on improving Objective #1, which is the weakest objective. Item 164 has a weight of 12, which will be removed to make room for new items.
#
# Item 105 (88/11) and Item 68 (84/17) are added to improve Objective #1. The total weight of these two items (28) does not exceed the total weight of item 164 (12), satisfying constraint 3.
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 240: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 240 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['4', '6', '9', '10', '11', '12', '17', '18', '19', '20', '21', '22', '23', '24', '26', '29', '31', '32', '33', '36', '38', '39', '40', '41', '42', '44', '51', '53', '55', '60', '61', '63', '65', '66', '68', '70', '71', '73', '77', '78', '79', '81', '84', '87', '95', '96', '98', '100', '102', '103', '105', '107', '108', '109', '110', '111', '116', '117', '118', '119', '120', '123', '124', '125', '127', '130', '132', '133', '134', '135', '136', '137', '138', '139', '142', '147', '149', '151', '152', '155', '156', '161', '162', '163', '164', '165', '168', '170', '177', '180', '181', '183', '184', '185', '187', '191', '192', '194', '195', '196', '197', '199', '200', '201', '205', '208', '209', '212', '214', '217', '218', '220', '222', '225', '227', '228', '229', '232', '237', '242', '244', '245', '246', '248']
# - Objective values: [7131.0, 6732.0]
# - Remaining capacity: [5.0, 124.0]
#
# ANALYSIS:
# - The weakest objective is Objective #1.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 74: profit=95, weight=10
# Item 85: profit=83, weight=16
# Item 13: profit=96, weight=19
# Item 113: profit=83, weight=18
# Item 211: profit=67, weight=17
# Item 219: profit=65, weight=17
# Item 226: profit=60, weight=16
# Item 182: profit=56, weight=15
# Item 169: profit=82, weight=23
# Item 203: profit=78, weight=22
# Item 56: profit=47, weight=14
# Item 8: profit=97, weight=29
# Item 115: profit=62, weight=19
# Item 67: profit=68, weight=21
# Item 167: profit=93, weight=33
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis provided, I suggest the following moves:
#
# REMOVE: 169
#
# ADD: 74, 226
#
# Explanation:
# The weakest objective is Objective #1. The candidate items to add are ranked by efficiency for this objective. Item 169 has a high weight and low profit compared to other candidates. Removing it will improve the current solution.
#
# Item 74 has a high profit-to-weight ratio and adding it will further improve Objective #1. Item 226 also has a good profit-to-weight ratio and can be added without exceeding the total weight of the removed item (169).
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 260: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 260 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['0', '1', '3', '4', '5', '6', '8', '9', '10', '12', '13', '17', '18', '19', '20', '21', '22', '24', '27', '29', '33', '34', '35', '37', '38', '41', '43', '44', '45', '47', '50', '51', '52', '56', '57', '58', '61', '63', '65', '66', '67', '72', '74', '76', '78', '81', '83', '84', '85', '87', '89', '92', '94', '95', '96', '97', '98', '99', '100', '103', '105', '108', '109', '112', '113', '114', '115', '116', '117', '118', '119', '120', '122', '124', '127', '128', '131', '132', '134', '135', '137', '139', '140', '141', '142', '143', '146', '147', '148', '149', '150', '151', '152', '153', '154', '157', '158', '159', '160', '161', '164', '167', '169', '170', '172', '181', '182', '184', '185', '189', '190', '191', '194', '196', '197', '198', '201', '203', '206', '207', '208', '209', '210', '211', '212', '213', '216', '217', '218', '219', '222', '223', '225', '230', '231', '232', '237', '238', '239', '243', '244', '245', '246', '247']
# - Objective values: [7876.0, 7973.0]
# - Remaining capacity: [81.0, 10.0]
#
# ANALYSIS:
# - The weakest objective is Objective #0.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 229: profit=59, weight=11
# Item 162: profit=82, weight=19
# Item 138: profit=96, weight=24
# Item 163: profit=52, weight=15
# Item 234: profit=53, weight=16
# Item 40: profit=86, weight=28
# Item 82: profit=92, weight=32
# Item 91: profit=82, weight=30
# Item 64: profit=79, weight=30
# Item 168: profit=64, weight=25
# Item 111: profit=42, weight=18
# Item 107: profit=99, weight=43
# Item 205: profit=70, weight=33
# Item 32: profit=99, weight=49
# Item 7: profit=59, weight=31
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------
# --- RESPONSE FROM LLM ---
# Based on the analysis, I recommend removing item 27 from the knapsack and adding items 229, 163, and 234.
#
# REMOVE: 27
#
# ADD: 229, 163, 234
# -----------------------------
# RESULT: LLM SUGGESTION WAS REJECTED by fitness evaluation. Falling back to heuristic.
# --- Iteration 280: Calling LLM for guidance ---
#
# ===== LLM CALL AT ITERATION 280 =====
# --- PROMPT SENT TO LLM ---
#
# You are an expert analyst for a multi-objective optimization algorithm. Your task is to suggest one move to improve a knapsack solution. You must be precise and only use the data provided.
#
# PROBLEM DETAILS:
# - Number of objectives: 2
# - Knapsack capacities: [6536.0, 6489.0]
#
# CURRENT SOLUTION:
# - Items in knapsack: ['0', '1', '4', '8', '9', '10', '11', '12', '13', '14', '17', '18', '24', '25', '26', '28', '32', '34', '36', '38', '39', '40', '41', '47', '51', '52', '53', '54', '57', '59', '62', '64', '67', '69', '71', '73', '74', '76', '80', '81', '83', '84', '86', '87', '88', '94', '96', '97', '102', '104', '108', '109', '110', '112', '113', '114', '115', '117', '118', '119', '120', '121', '122', '124', '125', '126', '127', '129', '130', '134', '135', '136', '137', '140', '141', '142', '143', '144', '147', '149', '151', '157', '160', '161', '163', '164', '165', '167', '169', '170', '174', '176', '179', '180', '181', '182', '183', '184', '187', '190', '191', '192', '193', '194', '196', '197', '200', '201', '207', '208', '209', '210', '212', '213', '218', '219', '220', '222', '223', '225', '231', '236', '238', '240', '248']
# - Objective values: [6834.0, 6457.0]
# - Remaining capacity: [109.0, 9.0]
#
# ANALYSIS:
# - The weakest objective is Objective #1.
# - You must focus on improving this objective.
#
# CANDIDATE ITEMS TO ADD (not in knapsack, ranked by efficiency for the weakest objective):
# Item 66: profit=99, weight=12
# Item 105: profit=88, weight=11
# Item 100: profit=99, weight=15
# Item 31: profit=61, weight=10
# Item 244: profit=90, weight=17
# Item 85: profit=83, weight=16
# Item 68: profit=84, weight=17
# Item 65: profit=95, weight=22
# Item 152: profit=43, weight=10
# Item 211: profit=67, weight=17
# Item 29: profit=98, weight=25
# Item 226: profit=60, weight=16
# Item 205: profit=73, weight=20
# Item 203: profit=78, weight=22
# Item 123: profit=72, weight=21
#
# TASK:
# Your task is to find one valid item to REMOVE from the 'Items in knapsack' list and one or more items to ADD from the 'CANDIDATE ITEMS TO ADD' list.
#
# CRITICAL CONSTRAINTS:
# 1. The item you REMOVE must be present in the 'Items in knapsack' list.
# 2. The items you ADD must be present in the 'CANDIDATE ITEMS TO ADD' list.
# 3. The total weight of added items must not exceed the total weight of the removed item for ANY objective.
#
# OUTPUT FORMAT (strictly follow, no other text):
# REMOVE: <item_id_to_remove>
# ADD: <item_id_to_add_1>, <item_id_to_add_2>, ...
#
# ----------------------------

# %%
import matplotlib.pyplot as plt

# --- Functions for analysis (same as before) ---
def dominates(a, b):
    return all(x >= y for x, y in zip(a, b)) and any(x > y for x, y in zip(a, b))

def get_true_pareto_front(points):
    pareto = []
    for i, p in enumerate(points):
        dominated = False
        for j, q in enumerate(points):
            if i != j and dominates(q, p):
                dominated = True
                break
        if not dominated:
            pareto.append(p)
    return pareto

def report_pareto_stats(filename, label):
    points = []
    with open(filename, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                try:
                    points.append([float(x) for x in line.split()])
                except Exception:
                    pass
    total_points = len(points)
    pareto_front = get_true_pareto_front(points)
    num_pareto = len(pareto_front)
    print(f"--- {label} ---")
    print(f"  Total points: {total_points}")
    print(f"  Pareto-optimal points: {num_pareto}")
    return pareto_front

def plot_pareto_fronts(fronts, labels, title):
    plt.figure(figsize=(10, 7))
    for front, label in zip(fronts, labels):
        if not front: continue
        xs, ys = zip(*front)
        plt.scatter(xs, ys, label=label, alpha=0.7)
    plt.xlabel("Objective 1 (Profit)")
    plt.ylabel("Objective 2 (Profit)")
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

# --- Comparison ---
BASELINE_FILE = "2502_ResultsMD.txt"
HYBRID_FILE = "2502_Results_HYBRID.txt"

print("Comparing Baseline vs. Hybrid Algorithm Results:\n")

baseline_front = report_pareto_stats(BASELINE_FILE, "Baseline (Original MOACP)")
hybrid_front = report_pareto_stats(HYBRID_FILE, "Hybrid (MOACP + LLM)")

# --- Visual Comparison ---
plot_pareto_fronts(
    fronts=[baseline_front, hybrid_front],
    labels=["Baseline", "Hybrid"],
    title="Pareto Front Comparison: Baseline vs. Hybrid Algorithm"
)
# Out:
# Comparing Baseline vs. Hybrid Algorithm Results:
#
# --- Baseline (Original MOACP) ---
#   Total points: 1413
#   Pareto-optimal points: 212
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 57
#      54 print("Comparing Baseline vs. Hybrid Algorithm Results:\n")
#      56 baseline_front = report_pareto_stats(BASELINE_FILE, "Baseline (Original MOACP)")
# ---> 57 hybrid_front = report_pareto_stats(HYBRID_FILE, "Hybrid (MOACP + LLM)")
#      59 # --- Visual Comparison ---
#      60 plot_pareto_fronts(
#      61     fronts=[baseline_front, hybrid_front],
#      62     labels=["Baseline", "Hybrid"],
#      63     title="Pareto Front Comparison: Baseline vs. Hybrid Algorithm"
#      64 )
#
# Cell In[6], line 21, in report_pareto_stats(filename, label)
#      19 def report_pareto_stats(filename, label):
#      20     points = []
# ---> 21     with open(filename, "r") as f:
#      22         for line in f:
#      23             line = line.strip()
#
# File A:\conda\envs\ibmols\lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '2502_Results_HYBRID.txt'

# %%
# Cell: Visualization - Pareto Front Comparison

import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

def load_points_from_file(filename):
    """Load all points from results file"""
    points = []
    try:
        with open(filename, "r") as f:
            for line in f:
                line = line.strip()
                if line:
                    try:
                        points.append([float(x) for x in line.split()])
                    except:
                        pass
    except FileNotFoundError:
        print(f"❌ File not found: {filename}")
        return []
    return points

def dominates(a, b):
    """Check if solution a dominates b (maximization)"""
    return all(x >= y for x, y in zip(a, b)) and any(x > y for x, y in zip(a, b))

def get_pareto_front(points):
    """Extract Pareto-optimal solutions"""
    pareto = []
    for i, p in enumerate(points):
        dominated = False
        for j, q in enumerate(points):
            if i != j and dominates(q, p):
                dominated = True
                break
        if not dominated:
            pareto.append(p)
    return pareto

def calculate_hypervolume_2d(pareto_front, reference_point):
    """Calculate hypervolume for 2D (approximation)"""
    if len(pareto_front) == 0:
        return 0.0
    
    # Sort by first objective (descending)
    sorted_front = sorted(pareto_front, key=lambda x: x[0], reverse=True)
    
    hypervolume = 0.0
    prev_f1 = reference_point[0]
    
    for solution in sorted_front:
        f1, f2 = solution[0], solution[1]
        width = prev_f1 - f1
        height = f2 - reference_point[1]
        hypervolume += width * height
        prev_f1 = f1
    
    return hypervolume

def plot_pareto_comparison_2d(baseline_file, hybrid_file, title="Pareto Front Comparison"):
    """Plot 2D Pareto front comparison"""
    
    # Load data
    baseline_points = load_points_from_file(baseline_file)
    hybrid_points = load_points_from_file(hybrid_file)
    
    if not baseline_points or not hybrid_points:
        print("❌ Cannot load data files")
        return
    
    # Extract Pareto fronts
    baseline_pareto = get_pareto_front(baseline_points)
    hybrid_pareto = get_pareto_front(hybrid_points)
    
    # Convert to numpy arrays
    baseline_pareto = np.array(baseline_pareto)
    hybrid_pareto = np.array(hybrid_pareto)
    baseline_all = np.array(baseline_points)
    hybrid_all = np.array(hybrid_points)
    
    # Create figure with subplots
    fig = plt.figure(figsize=(18, 6))
    
    # ========== SUBPLOT 1: Pareto Fronts Only ==========
    ax1 = fig.add_subplot(1, 3, 1)
    
    # Sort for line plotting
    baseline_sorted = baseline_pareto[baseline_pareto[:, 0].argsort()]
    hybrid_sorted = hybrid_pareto[hybrid_pareto[:, 0].argsort()]
    
    ax1.plot(baseline_sorted[:, 0], baseline_sorted[:, 1], 
             'o-', color='#FF6B6B', linewidth=2, markersize=6, 
             label=f'Baseline ({len(baseline_pareto)} solutions)', alpha=0.8)
    ax1.plot(hybrid_sorted[:, 0], hybrid_sorted[:, 1], 
             's-', color='#4ECDC4', linewidth=2, markersize=6, 
             label=f'Hybrid LLM ({len(hybrid_pareto)} solutions)', alpha=0.8)
    
    ax1.set_xlabel('Objective 1 (Profit)', fontsize=12, fontweight='bold')
    ax1.set_ylabel('Objective 2 (Profit)', fontsize=12, fontweight='bold')
    ax1.set_title('Pareto Fronts Comparison', fontsize=14, fontweight='bold')
    ax1.legend(loc='best', fontsize=10)
    ax1.grid(True, alpha=0.3)
    
    # ========== SUBPLOT 2: All Solutions ==========
    ax2 = fig.add_subplot(1, 3, 2)
    
    ax2.scatter(baseline_all[:, 0], baseline_all[:, 1], 
                c='#FFB6C1', s=20, alpha=0.3, label='Baseline (all)')
    ax2.scatter(baseline_pareto[:, 0], baseline_pareto[:, 1], 
                c='#FF6B6B', s=80, marker='o', edgecolors='darkred', 
                linewidths=2, label='Baseline (Pareto)', zorder=5)
    
    ax2.scatter(hybrid_all[:, 0], hybrid_all[:, 1], 
                c='#B4E7E3', s=20, alpha=0.3, label='Hybrid (all)')
    ax2.scatter(hybrid_pareto[:, 0], hybrid_pareto[:, 1], 
                c='#4ECDC4', s=80, marker='s', edgecolors='darkblue', 
                linewidths=2, label='Hybrid (Pareto)', zorder=5)
    
    ax2.set_xlabel('Objective 1 (Profit)', fontsize=12, fontweight='bold')
    ax2.set_ylabel('Objective 2 (Profit)', fontsize=12, fontweight='bold')
    ax2.set_title('All Solutions + Pareto Fronts', fontsize=14, fontweight='bold')
    ax2.legend(loc='best', fontsize=9)
    ax2.grid(True, alpha=0.3)
    
    # ========== SUBPLOT 3: Statistics ==========
    ax3 = fig.add_subplot(1, 3, 3)
    ax3.axis('off')
    
    # Calculate metrics
    ref_point = [0, 0]  # For hypervolume (nadir point)
    hv_baseline = calculate_hypervolume_2d(baseline_pareto.tolist(), ref_point)
    hv_hybrid = calculate_hypervolume_2d(hybrid_pareto.tolist(), ref_point)
    hv_improvement = ((hv_hybrid - hv_baseline) / hv_baseline * 100) if hv_baseline > 0 else 0
    
    pareto_improvement = ((len(hybrid_pareto) - len(baseline_pareto)) / len(baseline_pareto) * 100)
    
    # Average objectives
    baseline_avg = baseline_pareto.mean(axis=0)
    hybrid_avg = hybrid_pareto.mean(axis=0)
    
    stats_text = f"""
    📊 COMPARISON STATISTICS
    {'='*40}
    
    🔴 BASELINE:
      • Total solutions: {len(baseline_points)}
      • Pareto solutions: {len(baseline_pareto)}
      • Pareto ratio: {len(baseline_pareto)/len(baseline_points)*100:.2f}%
      • Avg Obj1: {baseline_avg[0]:.2f}
      • Avg Obj2: {baseline_avg[1]:.2f}
      • Hypervolume: {hv_baseline:.2f}
    
    🔵 HYBRID (LLM):
      • Total solutions: {len(hybrid_points)}
      • Pareto solutions: {len(hybrid_pareto)}
      • Pareto ratio: {len(hybrid_pareto)/len(hybrid_points)*100:.2f}%
      • Avg Obj1: {hybrid_avg[0]:.2f}
      • Avg Obj2: {hybrid_avg[1]:.2f}
      • Hypervolume: {hv_hybrid:.2f}
    
    📈 IMPROVEMENT:
      • Pareto solutions: {pareto_improvement:+.2f}%
      • Hypervolume: {hv_improvement:+.2f}%
      • Avg Obj1: {(hybrid_avg[0]-baseline_avg[0])/baseline_avg[0]*100:+.2f}%
      • Avg Obj2: {(hybrid_avg[1]-baseline_avg[1])/baseline_avg[1]*100:+.2f}%
    
    {'='*40}
    """
    
    ax3.text(0.1, 0.5, stats_text, fontsize=10, family='monospace',
             verticalalignment='center', bbox=dict(boxstyle='round', 
             facecolor='wheat', alpha=0.3))
    
    plt.tight_layout()
    plt.savefig('pareto_comparison.png', dpi=300, bbox_inches='tight')
    print("✅ Plot saved as 'pareto_comparison.png'")
    plt.show()
    
    # Return metrics for further analysis
    return {
        'baseline': {
            'total': len(baseline_points),
            'pareto': len(baseline_pareto),
            'hypervolume': hv_baseline,
            'avg': baseline_avg
        },
        'hybrid': {
            'total': len(hybrid_points),
            'pareto': len(hybrid_pareto),
            'hypervolume': hv_hybrid,
            'avg': hybrid_avg
        },
        'improvement': {
            'pareto_pct': pareto_improvement,
            'hypervolume_pct': hv_improvement
        }
    }


def plot_pareto_comparison_3d(baseline_file, hybrid_file):
    """Plot 3D Pareto front comparison (for 3-objective problems)"""
    
    baseline_points = load_points_from_file(baseline_file)
    hybrid_points = load_points_from_file(hybrid_file)
    
    if not baseline_points or not hybrid_points:
        print("❌ Cannot load data files")
        return
    
    if len(baseline_points[0]) != 3:
        print("⚠️  This function is for 3-objective problems only")
        return
    
    baseline_pareto = np.array(get_pareto_front(baseline_points))
    hybrid_pareto = np.array(get_pareto_front(hybrid_points))
    
    fig = plt.figure(figsize=(14, 6))
    
    # Subplot 1: Baseline
    ax1 = fig.add_subplot(1, 2, 1, projection='3d')
    ax1.scatter(baseline_pareto[:, 0], baseline_pareto[:, 1], baseline_pareto[:, 2],
                c='#FF6B6B', s=50, alpha=0.6, edgecolors='darkred', linewidths=1.5)
    ax1.set_xlabel('Objective 1', fontweight='bold')
    ax1.set_ylabel('Objective 2', fontweight='bold')
    ax1.set_zlabel('Objective 3', fontweight='bold')
    ax1.set_title(f'Baseline Pareto Front\n({len(baseline_pareto)} solutions)', fontweight='bold')
    
    # Subplot 2: Hybrid
    ax2 = fig.add_subplot(1, 2, 2, projection='3d')
    ax2.scatter(hybrid_pareto[:, 0], hybrid_pareto[:, 1], hybrid_pareto[:, 2],
                c='#4ECDC4', s=50, alpha=0.6, edgecolors='darkblue', linewidths=1.5)
    ax2.set_xlabel('Objective 1', fontweight='bold')
    ax2.set_ylabel('Objective 2', fontweight='bold')
    ax2.set_zlabel('Objective 3', fontweight='bold')
    ax2.set_title(f'Hybrid LLM Pareto Front\n({len(hybrid_pareto)} solutions)', fontweight='bold')
    
    plt.tight_layout()
    plt.savefig('pareto_comparison_3d.png', dpi=300, bbox_inches='tight')
    print("✅ 3D plot saved as 'pareto_comparison_3d.png'")
    plt.show()


# ========== USAGE EXAMPLES ==========

if __name__ == "__main__":
    print("VISUALIZING PARETO FRONTS")
    
    # For 2-objective problems
    metrics = plot_pareto_comparison_2d(
        OUTPUT_BASELINE, 
        OUTPUT_HYBRID,
        title="Baseline vs Hybrid LLM"
    )
    
    # Print summary
    if metrics:
        print(f"\n{'='*50}")
        print(f"📊 QUICK SUMMARY:")
        print(f"{'='*50}")
        print(f"Baseline Pareto: {metrics['baseline']['pareto']} solutions")
        print(f"Hybrid Pareto:   {metrics['hybrid']['pareto']} solutions")
        print(f"Improvement:     {metrics['improvement']['pareto_pct']:+.2f}%")
        print(f"Hypervolume imp: {metrics['improvement']['hypervolume_pct']:+.2f}%")
        print(f"{'='*50}\n")
    
    # Uncomment for 3-objective problems:
    # plot_pareto_comparison_3d(OUTPUT_BASELINE, OUTPUT_HYBRID)
# Out:
# VISUALIZING PARETO FRONTS
# C:\Users\Aziz il patal\AppData\Local\Temp\ipykernel_5860\2811596463.py:175: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans Mono.
#   plt.tight_layout()
# C:\Users\Aziz il patal\AppData\Local\Temp\ipykernel_5860\2811596463.py:175: UserWarning: Glyph 128308 (\N{LARGE RED CIRCLE}) missing from font(s) DejaVu Sans Mono.
#   plt.tight_layout()
# C:\Users\Aziz il patal\AppData\Local\Temp\ipykernel_5860\2811596463.py:175: UserWarning: Glyph 128309 (\N{LARGE BLUE CIRCLE}) missing from font(s) DejaVu Sans Mono.
#   plt.tight_layout()
# C:\Users\Aziz il patal\AppData\Local\Temp\ipykernel_5860\2811596463.py:175: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans Mono.
#   plt.tight_layout()
# C:\Users\Aziz il patal\AppData\Local\Temp\ipykernel_5860\2811596463.py:176: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig('pareto_comparison.png', dpi=300, bbox_inches='tight')
# C:\Users\Aziz il patal\AppData\Local\Temp\ipykernel_5860\2811596463.py:176: UserWarning: Glyph 128308 (\N{LARGE RED CIRCLE}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig('pareto_comparison.png', dpi=300, bbox_inches='tight')
# C:\Users\Aziz il patal\AppData\Local\Temp\ipykernel_5860\2811596463.py:176: UserWarning: Glyph 128309 (\N{LARGE BLUE CIRCLE}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig('pareto_comparison.png', dpi=300, bbox_inches='tight')
# C:\Users\Aziz il patal\AppData\Local\Temp\ipykernel_5860\2811596463.py:176: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig('pareto_comparison.png', dpi=300, bbox_inches='tight')
# ✅ Plot saved as 'pareto_comparison.png'
# A:\conda\envs\ibmols\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# A:\conda\envs\ibmols\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128308 (\N{LARGE RED CIRCLE}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# A:\conda\envs\ibmols\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128309 (\N{LARGE BLUE CIRCLE}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# A:\conda\envs\ibmols\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# ==================================================
# 📊 QUICK SUMMARY:
# ==================================================
# Baseline Pareto: 227 solutions
# Hybrid Pareto:   210 solutions
# Improvement:     -7.49%
# Hypervolume imp: +0.00%
# ==================================================

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Helper Functions (same as before) ---
def dominates(a, b):
    """Returns True if a dominates b (maximization for both objectives)."""
    return all(x >= y for x, y in zip(a, b)) and any(x > y for x, y in zip(a, b))

def get_true_pareto_front(points):
    """Extracts the non-dominated points from a list of points."""
    pareto = []
    for i, p in enumerate(points):
        dominated = False
        for j, q in enumerate(points):
            if i != j and dominates(q, p):
                dominated = True
                break
        if not dominated:
            pareto.append(p)
    return pareto

def load_and_parse_results(filename):
    """Loads a results file and parses it into a list of points."""
    points = []
    try:
        with open(filename, "r") as f:
            for line in f:
                line = line.strip()
                if line:  # Skip empty lines
                    try:
                        # Split the line by whitespace and convert to float
                        point = [float(x) for x in line.split()]
                        if len(point) == 2: # Ensure it's a 2-objective point
                            points.append(point)
                    except ValueError:
                        print(f"Warning: Could not parse line: '{line}' in {filename}")
    except FileNotFoundError:
        print(f"Error: File not found at {filename}")
        return None
    return points

def plot_pareto_comparison(baseline_file, hybrid_file, instance_name="250.2"):
    """
    Generates a comparison plot of the Pareto fronts from two result files.
    """
    print(f"📊 Generating visualization for {instance_name}...")

    # 1. Load the raw data from both files
    baseline_points = load_and_parse_results(baseline_file)
    hybrid_points = load_and_parse_results(hybrid_file)

    if baseline_points is None or hybrid_points is None:
        print("❌ Cannot generate plot due to missing or corrupt files.")
        return

    # 2. Extract the true Pareto-optimal points from each dataset
    baseline_pareto = get_true_pareto_front(baseline_points)
    hybrid_pareto = get_true_pareto_front(hybrid_points)

    # 3. Prepare data for plotting
    if not baseline_pareto or not hybrid_pareto:
        print("❌ One of the result files is empty. Cannot plot.")
        return
        
    baseline_x, baseline_y = zip(*baseline_pareto)
    hybrid_x, hybrid_y = zip(*hybrid_pareto)

    # 4. Create the plot
    plt.style.use('seaborn-v0_8-whitegrid') # Use a clean, professional style
    plt.figure(figsize=(12, 9))

    # Plot the baseline Pareto front
    plt.scatter(baseline_x, baseline_y, 
                color='blue', 
                label=f'Baseline ({len(baseline_pareto)} points)', 
                alpha=0.7, 
                s=50, # Marker size
                edgecolors='w', # White edge for markers
                linewidth=0.5)

    # Plot the hybrid Pareto front
    plt.scatter(hybrid_x, hybrid_y, 
                color='red', 
                label=f'Hybrid (LLM) ({len(hybrid_pareto)} points)', 
                alpha=0.7, 
                s=50,
                marker='^', # Use a different marker shape
                edgecolors='w',
                linewidth=0.5)

    # 5. Add labels, title, and legend
    plt.xlabel("Objective 1 (Profit)", fontsize=14)
    plt.ylabel("Objective 2 (Profit)", fontsize=14)
    plt.title(f"Pareto Front Comparison for {instance_name}", fontsize=18, fontweight='bold')
    plt.legend(fontsize=12)
    plt.grid(True) # Ensure grid is on
    plt.tight_layout() # Adjust plot to ensure everything fits without overlapping

    # 6. Save and show the plot
    output_filename = f"{instance_name}_pareto_comparison.png"
    plt.savefig(output_filename, dpi=300) # Save as a high-resolution image
    print(f"✅ Plot saved as {output_filename}")
    plt.show()

# --- MAIN EXECUTION ---
if __name__ == "__main__":
    # --- Configuration ---
    # Make sure these filenames match the ones from your experiment controller
    BASELINE_FILE = "250_2obj_BASELINE.txt"
    HYBRID_FILE = "250_2obj_HYBRID_strategic.txt"
    INSTANCE_NAME = "250 items, 2 objectives"

    # Run the visualization
    plot_pareto_comparison(BASELINE_FILE, HYBRID_FILE, INSTANCE_NAME)
# Out:
# 📊 Generating visualization for 250 items, 2 objectives...
# ✅ Plot saved as 250 items, 2 objectives_pareto_comparison.png

# %%
# %load_ext cython
# Out:
# The cython extension is already loaded. To reload it, use:
#   %reload_ext cython

# %%
# %%cython
#
# # =========================================================================
# # PART 1: C LIBRARY IMPORTS AND GLOBAL DEFINITIONS
# # =========================================================================
#
# from libc.stdlib cimport malloc, free, srand, rand
# from libc.string cimport memset
# from libc.math cimport exp
#
# # Import Python libraries needed for the LLM part
# import time
# import json
# import ollama
# import numpy as np
# import hashlib
# from collections import defaultdict
#
# # Constants for the enhanced algorithm
# cdef int NBITEMS = 250
# cdef int ni = 250
# cdef int L = 5  # This will be adjusted by the LLM
# cdef double LARGE = 10e50
# cdef float smallValue = 0.0000001
# cdef double kappa = 0.05  # This will be adjusted by the LLM
# cdef int alpha = 10
# cdef int paretoIni = 28000
#
# # Data structures (MODIFIED to track more info)
# cdef struct ind:
#     int nombr_nonpris
#     int nombr
#     int rank
#     float fitnessbest
#     float fitness
#     int explored
#     double *f
#     double *capa
#     double *v
#     int *d
#     int *Items
#     int age
#     int improvement_count
#     int llm_enhanced
#     int last_improvement_iteration # NEW: Track when it was last improved
#
# cdef struct pop:
#     int size
#     int maxsize
#     ind **ind_array
#
# # Global variables for the problem instance (unchanged)
# cdef int nf = 2
# cdef double *capacities = NULL
# cdef int **weights = NULL
# cdef int **profits = NULL
# cdef double *vector_weight = NULL
# cdef double max_bound = 0.0
# cdef double **OBJ_Weights = NULL
# cdef int nombreLIGNE = 0
# cdef int nextLn = 0
# cdef int inv = 0
# cdef int OBJ_Weights_lines = 0
#
# # =========================================================================
# # PART 2: CORE CYTHON HELPER FUNCTIONS
# # =========================================================================
#
# def seed(int x):
#     srand(x)
#
# cdef int irand(int range_val):
#     return rand() % range_val
#
# cdef void *chk_malloc(size_t size):
#     cdef void *return_value = malloc(size)
#     if return_value == NULL:
#         raise MemoryError("Out of memory.")
#     memset(return_value, 0, size)
#     return return_value
#
# cdef pop *create_pop(int maxsize, int nf):
#     cdef int i
#     cdef pop *pp = <pop *>chk_malloc(sizeof(pop))
#     pp.size = 0
#     pp.maxsize = maxsize
#     pp.ind_array = <ind **>chk_malloc(maxsize * sizeof(void*))
#     for i in range(maxsize):
#         pp.ind_array[i] = NULL
#     return pp
#
# cdef ind *create_ind(int nf):
#     cdef int i
#     cdef ind *p_ind = <ind *>chk_malloc(sizeof(ind))
#     p_ind.nombr_nonpris = 0
#     p_ind.nombr = 0
#     p_ind.rank = 0
#     p_ind.fitnessbest = -1.0
#     p_ind.fitness = -1.0
#     p_ind.explored = 0
#     p_ind.age = 0
#     p_ind.improvement_count = 0
#     p_ind.llm_enhanced = 0
#     p_ind.last_improvement_iteration = 0 # NEW
#     p_ind.f = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.capa = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.v = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.d = <int *>chk_malloc(ni * sizeof(int))
#     p_ind.Items = <int *>chk_malloc(ni * sizeof(int))
#     for i in range(ni):
#         p_ind.Items[i] = 0
#         p_ind.d[i] = 0
#     for i in range(nf):
#         p_ind.f[i] = 0.0
#         p_ind.capa[i] = 0.0
#         p_ind.v[i] = 0.0
#     return p_ind
#
# cdef ind *ind_copy(ind *i):
#     cdef ind *p_ind = create_ind(nf)
#     cdef int k
#     p_ind.nombr_nonpris = i.nombr_nonpris
#     p_ind.nombr = i.nombr
#     p_ind.rank = i.rank
#     p_ind.fitnessbest = i.fitnessbest
#     p_ind.fitness = i.fitness
#     p_ind.explored = i.explored
#     p_ind.age = i.age
#     p_ind.improvement_count = i.improvement_count
#     p_ind.llm_enhanced = i.llm_enhanced
#     p_ind.last_improvement_iteration = i.last_improvement_iteration # NEW
#     for k in range(nf):
#         p_ind.f[k] = i.f[k]
#         p_ind.v[k] = i.v[k]
#         p_ind.capa[k] = i.capa[k]
#     for k in range(ni):
#         p_ind.d[k] = i.d[k]
#         p_ind.Items[k] = i.Items[k]
#     return p_ind
#
# cdef void free_ind(ind *p_ind):
#     if p_ind != NULL:
#         free(p_ind.d)
#         free(p_ind.f)
#         free(p_ind.capa)
#         free(p_ind.v)
#         free(p_ind.Items)
#         free(p_ind)
#
# cdef void complete_free_pop(pop *pp):
#     cdef int i
#     if pp != NULL:
#         if pp.ind_array != NULL:
#             for i in range(pp.size):
#                 if pp.ind_array[i] != NULL:
#                     free_ind(pp.ind_array[i])
#                     pp.ind_array[i] = NULL
#             free(pp.ind_array)
#         free(pp)
#
# cdef void cleanup_globals():
#     global capacities, weights, profits, vector_weight, OBJ_Weights, OBJ_Weights_lines, nf, ni
#     if capacities != NULL:
#         free(capacities)
#         capacities = NULL
#     if weights != NULL:
#         for i in range(nf):
#             if weights[i] != NULL:
#                 free(weights[i])
#         free(weights)
#         weights = NULL
#     if profits != NULL:
#         for i in range(nf):
#             if profits[i] != NULL:
#                 free(profits[i])
#         free(profits)
#         profits = NULL
#     if vector_weight != NULL:
#         free(vector_weight)
#         vector_weight = NULL
#     if OBJ_Weights != NULL:
#         for i in range(nf):
#             if OBJ_Weights[i] != NULL:
#                 free(OBJ_Weights[i])
#         free(OBJ_Weights)
#         OBJ_Weights = NULL
#     OBJ_Weights_lines = 0
#     nf = 0
#     ni = 0
#
# cdef int non_dominated(ind *p_ind_a, ind *p_ind_b):
#     cdef int i
#     cdef int a_is_good = -1
#     cdef int equal = 1
#     for i in range(nf):
#         if p_ind_a.f[i] > p_ind_b.f[i]:
#             a_is_good = 1
#         if p_ind_a.f[i] != p_ind_b.f[i]:
#             equal = 0
#     if equal:
#         return 0
#     return a_is_good
#
# cdef double calcAddEpsIndicator(ind *p_ind_a, ind *p_ind_b):
#     global max_bound
#     cdef int i
#     cdef double eps
#     cdef double temp_eps
#     if max_bound == 0.0:
#         max_bound = 1e-8
#     eps = (p_ind_a.v[0]/max_bound)-(p_ind_b.v[0]/max_bound)
#     for i in range(1, nf):
#         temp_eps = (p_ind_a.v[i]/max_bound)-(p_ind_b.v[i]/max_bound)
#         if temp_eps > eps:
#             eps = temp_eps
#     return eps
#
# cdef void init_fitness(ind *x):
#     x.fitness = 0.0
#
# cdef void update_fitness(ind *x, double I):
#     x.fitness -= exp(-I / kappa)
#
# cdef double update_fitness_return(double f, double I):
#     return f - exp(-I / kappa)
#
# cdef int delete_fitness(ind *x, double I):
#     x.fitness += exp(-I / kappa)
#     return 0
#
# cdef void compute_ind_fitness(ind *x, pop *SP):
#     cdef int j
#     init_fitness(x)
#     for j in range(SP.size):
#         if SP.ind_array[j] != x:
#             update_fitness(x, calcAddEpsIndicator(SP.ind_array[j], x))
#
# cdef void compute_all_fitness(pop *SP):
#     cdef int i
#     for i in range(SP.size):
#         compute_ind_fitness(SP.ind_array[i], SP)
#
# # =========================================================================
# # PART 3: PROBLEM LOADING AND EVALUATION FUNCTIONS
# # =========================================================================
#
# def loadMOKP(char *filename):
#     global nf, ni, capacities, weights, profits
#     cdef int i, f
#     with open(filename.decode(), "r") as source:
#         _nf, _ni = [int(x) for x in source.readline().split()]
#         nf = _nf
#         ni = _ni
#         capacities = <double *>chk_malloc(nf * sizeof(double))
#         weights = <int **>chk_malloc(nf * sizeof(void*))
#         profits = <int **>chk_malloc(nf * sizeof(void*))
#         for f in range(nf):
#             capacities[f] = float(source.readline().strip())
#             weights[f] = <int *>chk_malloc(ni * sizeof(int))
#             profits[f] = <int *>chk_malloc(ni * sizeof(int))
#             for i in range(ni):
#                 source.readline()  # item index (ignore)
#                 weights[f][i] = int(source.readline().strip())
#                 profits[f][i] = int(source.readline().strip())
#
# def read_weights_file(char *filename):
#     global OBJ_Weights, nombreLIGNE, nf, OBJ_Weights_lines
#     cdef int i, j, nlines
#     with open(filename.decode(), "r") as f:
#         lines = [line for line in f if line.strip()]
#     nlines = len(lines)
#     OBJ_Weights = <double **>chk_malloc(nf * sizeof(void*))
#     for i in range(nf):
#         OBJ_Weights[i] = <double *>chk_malloc(nlines * sizeof(double))
#     for i, line in enumerate(lines):
#         vals = line.strip().split()
#         for j in range(nf):
#             OBJ_Weights[j][i] = float(vals[j])
#     nombreLIGNE = nlines - 1
#     OBJ_Weights_lines = nlines
#
# cdef void dynamic_weight_allpop():
#     global vector_weight, OBJ_Weights, nombreLIGNE, nf, nextLn
#     cdef int i
#     if vector_weight == NULL:
#         vector_weight = <double *>chk_malloc(nf * sizeof(double))
#     for i in range(nf):
#         vector_weight[i] = OBJ_Weights[i][nextLn]
#     if nextLn == nombreLIGNE:
#         nextLn = 0
#     else:
#         nextLn += 1
#
# cdef void choose_weight():
#     dynamic_weight_allpop()
#
# cdef void random_init_ind(ind *x):
#     cdef int j, r, tmp
#     for j in range(ni):
#         x.d[j] = j
#     for j in range(ni):
#         r = irand(ni)
#         tmp = x.d[r]
#         x.d[r] = x.d[j]
#         x.d[j] = tmp
#
# cdef void evaluate(ind *x):
#     cdef int j, l, k, faisable
#     x.nombr = 0
#     x.nombr_nonpris = 0
#     for j in range(nf):
#         x.capa[j] = 0.0
#         x.f[j] = 0.0
#     for j in range(ni):
#         l = 0
#         faisable = 1
#         while l < nf and faisable == 1:
#             if x.capa[l] + weights[l][x.d[j]] > capacities[l]:
#                 faisable = 0
#             l += 1
#         if faisable == 1:
#             for k in range(nf):
#                 x.capa[k] += weights[k][x.d[j]]
#                 x.f[k] += profits[k][x.d[j]]
#             x.Items[x.d[j]] = 1
#             x.nombr += 1
#         else:
#             x.Items[x.d[j]] = 0
#             x.nombr_nonpris += 1
#
# cdef void P_init_pop(pop *SP, pop *Sarchive, int alpha):
#     cdef int i, x, tmp, t
#     t = max(alpha, Sarchive.size)
#     cdef int* shuffle = <int *>chk_malloc(t * sizeof(int))
#     for i in range(t):
#         shuffle[i] = i
#     for i in range(t):
#         x = irand(alpha)
#         tmp = shuffle[i]
#         shuffle[i] = shuffle[x]
#         shuffle[x] = tmp
#     SP.size = alpha
#     if Sarchive.size > alpha:
#         for i in range(alpha):
#             SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#     else:
#         for i in range(alpha):
#             if shuffle[i] < Sarchive.size:
#                 SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#             else:
#                 SP.ind_array[i] = create_ind(nf)
#                 random_init_ind(SP.ind_array[i])
#                 evaluate(SP.ind_array[i])
#     free(shuffle)
#
# cdef int extractPtoArchive(pop *P, pop *archive):
#     cdef int i, j, dom, t, convergence_rate
#     t = archive.size + P.size
#     archiveAndP = create_pop(t, nf)
#     convergence_rate = 0
#     for i in range(archive.size):
#         archiveAndP.ind_array[i] = archive.ind_array[i]
#     for i in range(P.size):
#         archiveAndP.ind_array[i + archive.size] = ind_copy(P.ind_array[i])
#     archiveAndP.size = t
#     archive.size = 0
#     for i in range(t):
#         for j in range(t):
#             if i != j:
#                 dom = non_dominated(archiveAndP.ind_array[i], archiveAndP.ind_array[j])
#                 if dom == -1 or (dom == 0 and i > j):
#                     break
#         else:
#             archive.ind_array[archive.size] = ind_copy(archiveAndP.ind_array[i])
#             archive.size += 1
#             if i >= t - P.size:
#                 convergence_rate += 1
#     complete_free_pop(archiveAndP)
#     return convergence_rate
#
# cdef double calcMaxbound(pop *SP, int size):
#     global max_bound
#     cdef int i, j
#     SP.size = size
#     cdef double max_b = SP.ind_array[0].v[0]
#     for i in range(SP.size):
#         for j in range(nf):
#             if max_b < SP.ind_array[i].v[j]:
#                 max_b = SP.ind_array[i].v[j]
#     if max_b == 0.0:
#         max_b = 1e-8
#     max_bound = max_b
#     return max_b
#
# cdef void calcul_weight(pop *SP, int size):
#     cdef int i, j
#     for i in range(SP.size):
#         for j in range(nf):
#             SP.ind_array[i].v[j] = SP.ind_array[i].f[j] * vector_weight[j]
#
# cdef int compute_fitness_and_select(pop *SP, ind *x, int size):
#     cdef int i, worst
#     cdef double worst_fit, fit_tmp
#     SP.size = size
#     x.fitness = 0
#     compute_ind_fitness(x, SP)
#     worst_fit = x.fitness
#     worst = -1
#     for i in range(SP.size):
#         fit_tmp = update_fitness_return(SP.ind_array[i].fitness, calcAddEpsIndicator(x, SP.ind_array[i]))
#         if fit_tmp > worst_fit:
#             worst = i
#             worst_fit = fit_tmp
#     fit_tmp = x.fitness
#     if worst == -1:
#         return -1
#     else:
#         for i in range(SP.size):
#             delete_fitness(SP.ind_array[i], calcAddEpsIndicator(SP.ind_array[worst], SP.ind_array[i]))
#             update_fitness(SP.ind_array[i], calcAddEpsIndicator(x, SP.ind_array[i]))
#         delete_fitness(x, calcAddEpsIndicator(SP.ind_array[worst], x))
#         free_ind(SP.ind_array[worst])
#         SP.ind_array[worst] = ind_copy(x)
#         if fit_tmp - worst_fit > smallValue:
#             return worst
#         else:
#             return -1
#
# # =========================================================================
# # PART 4: ENHANCED LOCAL SEARCH
# # =========================================================================
#
# cdef void Indicator_local_search1(pop *SP, pop *Sarchive, int size):
#     cdef ind *x
#     cdef ind *y
#     cdef int i, j, r, t, k, l, v, sol, mino, mp, maxp, consistant, pos, stop, convergence, ii, tmp_pris, tmp_nonpris, taille, feasible, tv, IM
#     cdef int* remplace = <int *>chk_malloc(L * sizeof(int))
#     SP.size = size
#     extractPtoArchive(SP, Sarchive)
#     while True:
#         convergence = 0
#         for i in range(SP.size):
#             if not SP.ind_array[i].explored:
#                 x = ind_copy(SP.ind_array[i])
#                 j = 0
#                 while j < x.nombr:
#                     for l in range(L):
#                         remplace[l] = 0
#                     while True:
#                         mino = irand(ni)
#                         if x.Items[mino] == 1:
#                             break
#                     x.Items[mino] = 0
#                     x.nombr -= 1
#                     x.nombr_nonpris += 1
#                     for r in range(nf):
#                         x.capa[r] -= weights[r][mino]
#                         x.f[r] -= profits[r][mino]
#                     IM = 0
#                     taille = 0
#                     while IM < L:
#                         while True:
#                             maxp = irand(ni)
#                             if x.Items[maxp] == 0:
#                                 break
#                         if maxp != mino:
#                             consistant = 1
#                             r = 0
#                             while r < nf and consistant == 1:
#                                 if x.capa[r] + weights[r][maxp] > capacities[r]:
#                                     consistant = 0
#                                 r += 1
#                             if consistant == 1:
#                                 feasible = 1
#                                 r = 0
#                                 while r < taille and feasible:
#                                     if maxp == remplace[r]:
#                                         feasible = 0
#                                     r += 1
#                                 if feasible == 1:
#                                     remplace[taille] = maxp
#                                     taille += 1
#                                     x.Items[maxp] = 1
#                                     x.nombr_nonpris -= 1
#                                     x.nombr += 1
#                                     for r in range(nf):
#                                         x.capa[r] += weights[r][maxp]
#                                         x.f[r] += profits[r][maxp]
#                         IM += 1
#                     for tv in range(nf):
#                         x.v[tv] = x.f[tv] * vector_weight[tv]
#                     max_bound = calcMaxbound(SP, SP.size)
#                     sol = compute_fitness_and_select(SP, x, SP.size)
#                     if sol != -1:
#                         j = x.nombr + 1
#                         if sol > i and i + 1 < SP.size:
#                             y = SP.ind_array[i + 1]
#                             SP.ind_array[i + 1] = SP.ind_array[sol]
#                             SP.ind_array[sol] = y
#                             i += 1
#                         break
#                     elif sol == -1:
#                         x.Items[mino] = 1
#                         x.nombr_nonpris -= 1
#                         x.nombr += 1
#                         for r in range(nf):
#                             x.capa[r] += weights[r][mino]
#                             x.f[r] += profits[r][mino]
#                         if taille >= 1:
#                             for r in range(taille):
#                                 x.Items[remplace[r]] = 0
#                                 x.nombr -= 1
#                                 x.nombr_nonpris += 1
#                                 for t in range(nf):
#                                     x.capa[t] -= weights[t][remplace[r]]
#                                     x.f[t] -= profits[t][remplace[r]]
#                                     x.v[t] = x.f[t] * vector_weight[t]
#                     j += 1
#                 tmp_pris = x.nombr
#                 tmp_nonpris = x.nombr_nonpris
#                 free_ind(x)
#                 if j == tmp_pris:
#                     SP.ind_array[i].explored = 1
#         convergence = extractPtoArchive(SP, Sarchive)
#         if not convergence:
#             break
#     free(remplace)
#
# # =========================================================================
# # PART 4.5: HELPER FUNCTIONS FOR V10 (INTELLIGENT EXPLORER)
# # =========================================================================
#
# cdef double calculate_archive_diversity(pop *archive):
#     if archive == NULL or archive.size <= 1:
#         return 0.0
#     cdef int i, j, n = archive.size
#     cdef double total_distance = 0.0, x1, y1, x2, y2, dist
#     for i in range(n):
#         x1 = archive.ind_array[i].f[0]
#         y1 = archive.ind_array[i].f[1]
#         for j in range(i + 1, n):
#             x2 = archive.ind_array[j].f[0]
#             y2 = archive.ind_array[j].f[1]
#             dist = ((x1 - x2)**2 + (y1 - y2)**2)**0.5
#             total_distance += dist
#     return total_distance / (n * (n - 1) / 2) if n > 1 else 0.0
#
# cdef double calculate_archive_hypervolume(pop *archive):
#     if archive == NULL or archive.size == 0:
#         return 0.0
#     points = []
#     cdef int i
#     for i in range(archive.size):
#         points.append((archive.ind_array[i].f[0], archive.ind_array[i].f[1]))
#     if not points:
#         return 0.0
#     ref_x = max(p[0] for p in points) * 1.1
#     ref_y = max(p[1] for p in points) * 1.1
#     points.sort(key=lambda p: p[0])
#     cdef double hv = 0.0
#     cdef int j
#     for j in range(len(points) - 1):
#         x1, y1 = points[j]
#         x2, y2 = points[j + 1]
#         hv += (x2 - x1) * (ref_y - y1)
#     if points:
#         x_last, y_last = points[-1]
#         hv += (ref_x - x_last) * (ref_y - y_last)
#     return hv
#
# cdef void biased_random_init_ind(ind *x, list important_items):
#     cdef int j, r, tmp, item_id, idx, i
#     for j in range(ni):
#         x.d[j] = j
#     for item_id in important_items:
#         if item_id < ni:
#             idx = -1
#             for i in range(ni):
#                 if x.d[i] == item_id:
#                     idx = i
#                     break
#             if idx != -1:
#                 r = irand(min(20, ni))
#                 tmp = x.d[r]
#                 x.d[r] = x.d[idx]
#                 x.d[idx] = tmp
#     for j in range(ni):
#         r = irand(ni)
#         tmp = x.d[r]
#         x.d[r] = x.d[j]
#         x.d[j] = tmp
#
# cdef dict extract_solution_data_for_python(ind *solution_ind):
#     cdef int i
#     data = {
#         'f': [solution_ind.f[i] for i in range(nf)],
#         'capa': [solution_ind.capa[i] for i in range(nf)],
#         'nombr': solution_ind.nombr,
#         'Items': [solution_ind.Items[i] for i in range(ni)]
#     }
#     return data
#
# def extract_problem_features_for_llm():
#     if capacities == NULL or weights == NULL or profits == NULL:
#         return None
#     total_capacity = sum(capacities[i] for i in range(nf))
#     total_avg_weight = sum(sum(weights[obj][i] for i in range(ni)) for obj in range(nf)) / nf
#     capacity_tightness = total_avg_weight / total_capacity if total_capacity > 0 else 0
#     profit_variances = []
#     weight_variances = []
#     for obj in range(nf):
#         profits_list = [profits[obj][i] for i in range(ni)]
#         weights_list = [weights[obj][i] for i in range(ni)]
#         profit_variances.append(np.var(profits_list))
#         weight_variances.append(np.var(weights_list))
#     features = {
#         "num_items": ni, "num_objectives": nf, "capacity_tightness": round(capacity_tightness, 4),
#         "avg_profit_variance": round(np.mean(profit_variances), 2),
#         "avg_weight_variance": round(np.mean(weight_variances), 2),
#     }
#     return features
#
# cdef void write_results_to_file(pop *P, output_file, str log_message=""):
#     cdef int i, j
#     with open(output_file if isinstance(output_file, str) else output_file.decode(), "a") as fpareto:
#         if log_message:
#             fpareto.write(f"# LOG: {log_message}\n")
#         fpareto.write("\n")
#         for i in range(P.size):
#             for j in range(nf):
#                 fpareto.write(f"{P.ind_array[i].f[j]:.6f} ")
#             fpareto.write("\n")
#
# # =========================================================================
# # PART 5: MAIN EXECUTION FUNCTION (V10 - INTELLIGENT EXPLORER)
# # =========================================================================
#
# def run_efficient_llm_moacp_v10(instance_file, weights_file, nbitems, num_objectives, output_file):
#     """
#     V10: The "Intelligent Explorer". Combines adaptive parameter tuning (V6.1)
#     with creative crossover for directed exploration (V7).
#     """
#     # All cdef variables must be declared at the top of the function
#     cdef pop *P
#     cdef pop *solutions
#     cdef pop *archive
#     cdef int it
#     cdef double last_hv = 0.0
#     cdef double current_hv
#     cdef double last_diversity = 0.0
#     cdef double current_diversity
#     cdef bint use_biased_init = False
#     cdef list important_items = []
#
#     global nf, ni, NBITEMS, alpha, paretoIni, L, kappa, nombreLIGNE, nextLn, inv, vector_weight
#     global capacities, weights, profits, OBJ_Weights
#
#     # --- V10 LLM Agent Definition ---
#     class LLMStrategistV10:
#         def __init__(self, model_name="llama3:latest"):
#             self.model_name = model_name
#             self.cache = {}
#
#         def _call_llm_with_json(self, prompt, cache_key):
#             if cache_key in self.cache:
#                 print(f"  [LLM Cache Hit] Using cached response.")
#                 return self.cache[cache_key]
#             print(f"  [LLM Call] Sending prompt to {self.model_name}...")
#             try:
#                 response = ollama.generate(model=self.model_name, prompt=prompt, format='json')
#                 response_text = response.get('response', '').strip()
#                 if not response_text:
#                     print("  [LLM Error] Empty response. Using default strategy.")
#                     return None
#                 result = json.loads(response_text)
#                 self.cache[cache_key] = result
#                 print(f"  [LLM Success] Received valid JSON.")
#                 return result
#             except (json.JSONDecodeError, Exception) as e:
#                 print(f"  [LLM Error] {e}. Using default strategy.")
#                 return None
#
#         def get_initial_strategy(self, problem_features):
#             cache_key = f"init_{hash(str(problem_features))}"
#             prompt = f"""
# You are an expert strategist for the Multi-Objective Knapsack Problem. Analyze the features and recommend the best initial search strategy.
# You control two parameters:
# 1. 'L': local search intensity (higher=more exploration).
# 2. 'kappa': selection pressure (lower=more diversity, higher=better solutions).
#
# Problem Features:
# {json.dumps(problem_features, indent=2)}
#
# Respond with a JSON object containing 'L_value', 'kappa_value', and 'reasoning'.
# Example: {{"L_value": 8, "kappa_value": 0.08, "reasoning": "High tightness requires broad exploration and strong selection."}}
# """
#             result = self._call_llm_with_json(prompt, cache_key)
#             if result and 'L_value' in result and 'kappa_value' in result:
#                 print(f"  [LLM Initial] L={result['L_value']}, kappa={result['kappa_value']}")
#                 return result['L_value'], result['kappa_value']
#             return 5, 0.05
#
#         def get_adaptive_strategy(self, current_iteration, last_hv, current_hv, last_diversity, current_diversity, current_L):
#             hv_change = current_hv - last_hv
#             diversity_change = current_diversity - last_diversity
#             cache_key = f"adaptive_v10_{current_iteration}_{current_hv:.2f}_{current_diversity:.2f}_{current_L}"
#             prompt = f"""
# You are an expert strategist monitoring a multi-objective search.
# Iteration: {current_iteration}. Current parameters: L={current_L}.
# HYPERVOLUME: Was {last_hv:.2f}, now {current_hv:.2f}. Change: {hv_change:.2f}.
# DIVERSITY: Was {last_diversity:.2f}, now {current_diversity:.2f}. Change: {diversity_change:.2f}.
#
# Adjust 'L' to increase hypervolume and maintain diversity.
# - If hypervolume stagnates, increase 'L'.
# - If diversity drops, decrease 'L'.
# - If both improve, keep 'L' or increase slightly.
#
# Respond with a JSON object containing 'new_L_value' and 'reasoning'.
# """
#             result = self._call_llm_with_json(prompt, cache_key)
#             if result and 'new_L_value' in result:
#                 print(f"  [LLM Adaptive] Iteration {current_iteration}: New L={result['new_L_value']}")
#                 return result['new_L_value']
#             return current_L
#
#         def creative_crossover_with_llm(self, parent1_data, parent2_data):
#             cache_key = f"crossover_v10_{hash(str(parent1_data['Items']) + str(parent2_data['Items']))}"
#             prompt = f"""
# You are an expert solver for the Multi-Objective Knapsack Problem. I will provide you with two good parent solutions. Your task is to reason about a NEW, high-quality child solution that combines their strengths.
#
# Parent 1: Items={parent1_data['Items']}, Objectives={parent1_data['f']}
# Parent 2: Items={parent2_data['Items']}, Objectives={parent2_data['f']}
#
# The problem has {ni} items, indexed from 0 to {ni-1}.
# Analyze the parents. Identify 3-5 key items that a child solution should contain to bridge the gap between the parents or to explore a new trade-off.
# The child solution MUST be a list of integers.
#
# Respond with a JSON object containing 'key_items' (a list of integers) and 'reasoning'.
# Example: {{"key_items": [5, 12, 23, 58], "reasoning": "This combination takes high-profit items from parent 1..."}}
# """
#             result = self._call_llm_with_json(prompt, cache_key)
#             return result
#
#     # --- Main Execution Loop ---
#     alpha = 10
#     paretoIni = 28000
#     NBL = 100
#     NRUNS = 10
#     INTERVENTION_INTERVAL = 25  # For adaptive strategy (V6.1)
#     CROSSOVER_INTERVAL = 50     # For creative crossover (V7)
#
#     total_time = 0
#     start_time = time.time()
#
#     for run in range(1, NRUNS + 1):
#         NBITEMS = nbitems
#         ni = nbitems
#         nf = num_objectives
#         print(f"\n--- RUN {run}/{NRUNS} --- V10 Intelligent Explorer")
#         print(f"Instance: {instance_file.decode()}, Items: {ni}, Objectives: {nf}")
#
#         nombreLIGNE = 0
#         nextLn = 0
#         inv = 0
#         use_biased_init = False
#
#         seed(run)
#         loadMOKP(instance_file)
#         read_weights_file(weights_file)
#
#         llm_strategist = LLMStrategistV10()
#         problem_features = extract_problem_features_for_llm()
#         print(f"  [Problem Features] {json.dumps(problem_features, indent=4)}")
#
#         # --- LLM Call 1: Initial Strategy ---
#         L, kappa = llm_strategist.get_initial_strategy(problem_features)
#         print(f"  [Final Parameters] L={L}, kappa={kappa}")
#
#         vector_weight = <double *>chk_malloc(nf * sizeof(double))
#         P = create_pop(paretoIni, nf)
#         current_log = f"Run {run}: V10 LLM strategy."
#
#         it = 0
#         while it < NBL:
#             # --- V6.1 Intervention: Adaptive Strategy ---
#             if it > 0 and it % INTERVENTION_INTERVAL == 0:
#                 print(f"  [Intervention] Pausing at iteration {it} for adaptive strategy...")
#                 current_hv = calculate_archive_hypervolume(P)
#                 current_diversity = calculate_archive_diversity(P)
#                 L = llm_strategist.get_adaptive_strategy(it, last_hv, current_hv, last_diversity, current_diversity, L)
#                 last_hv = current_hv
#                 last_diversity = current_diversity
#
#             # --- V7 Intervention: Creative Crossover ---
#             elif it > 0 and it % CROSSOVER_INTERVAL == 0:
#                 print(f"  [Creative Crossover] Pausing at iteration {it} for directed exploration...")
#                 if P.size > 10:
#                     parent1_data = extract_solution_data_for_python(P.ind_array[0])
#                     parent2_data = extract_solution_data_for_python(P.ind_array[P.size // 2])
#                     crossover_result = llm_strategist.creative_crossover_with_llm(parent1_data, parent2_data)
#                     if crossover_result and 'key_items' in crossover_result:
#                         print(f"  [LLM Creative] Reasoning: {crossover_result.get('reasoning')}")
#                         important_items = crossover_result['key_items']
#                         if important_items:
#                             print(f"  [LLM Creative] Identified key items: {important_items}. Applying bias to next population.")
#                             use_biased_init = True
#                         else:
#                             print("  [LLM Creative] No key items found. Continuing normally.")
#                     else:
#                         print("  [LLM Creative] Failed to generate a valid child summary. Continuing normally.")
#
#             # --- Core Cython Search ---
#             solutions = create_pop(alpha, nf)
#             archive = create_pop(paretoIni, nf)
#
#             choose_weight()
#             P_init_pop(solutions, P, alpha)
#
#             # Apply biased initialization if the flag is set
#             if use_biased_init:
#                 print("  [Creative Crossover] Using biased initialization for new population.")
#                 for i in range(alpha):
#                     biased_random_init_ind(solutions.ind_array[i], important_items)
#                 use_biased_init = False
#
#             extractPtoArchive(solutions, P)
#             calcul_weight(solutions, alpha)
#             calcMaxbound(solutions, alpha)
#             compute_all_fitness(solutions)
#
#             Indicator_local_search1(solutions, archive, alpha)
#
#             extractPtoArchive(archive, P)
#             it += 1
#             complete_free_pop(solutions)
#             complete_free_pop(archive)
#
#         write_results_to_file(P, output_file, current_log)
#         complete_free_pop(P)
#         cleanup_globals()
#
#     total_time = time.time() - start_time
#     print(f"\nTotal execution time: {total_time:.2f} seconds")
#     print(f"Average time per run: {total_time/NRUNS:.2f} seconds")
#     with open(output_file, "a") as f:
#         f.write(f"# RUNTIME: {total_time:.2f}\n")
# Out:
# Content of stdout:
# _cython_magic_4d90c77975b6fa92bfdfdb67b44aa80998b7f57140a8fed318fe34f92c6c736e.c
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_4d90c77975b6fa92bfdfdb67b44aa80998b7f57140a8fed318fe34f92c6c736e.c(5641): warning C4244: '='ÿ: conversion de 'double' en 'float', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_4d90c77975b6fa92bfdfdb67b44aa80998b7f57140a8fed318fe34f92c6c736e.c(5731): warning C4244: '='ÿ: conversion de 'double' en 'float', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_4d90c77975b6fa92bfdfdb67b44aa80998b7f57140a8fed318fe34f92c6c736e.c(6917): warning C4244: '='ÿ: conversion de 'Py_ssize_t' en 'int', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_4d90c77975b6fa92bfdfdb67b44aa80998b7f57140a8fed318fe34f92c6c736e.c(17946): warning C4305: '='ÿ: troncation de 'double' … 'float'
#    Cr‚ation de la bibliothŠque C:\Users\Aziz il patal\.ipython\cython\Users\Aziz il patal\.ipython\cython\_cython_magic_4d90c77975b6fa92bfdfdb67b44aa80998b7f57140a8fed318fe34f92c6c736e.cp39-win_amd64.lib et de l'objet C:\Users\Aziz il patal\.ipython\cython\Users\Aziz il patal\.ipython\cython\_cython_magic_4d90c77975b6fa92bfdfdb67b44aa80998b7f57140a8fed318fe34f92c6c736e.cp39-win_amd64.exp
# G‚n‚ration de code en cours
# Fin de la g‚n‚ration du code

# %%
# =========================================================================
# PART 6: RUN THE V10 EXPERIMENTS
# =========================================================================

print("Running V10 'Intelligent Explorer' experiments...")
print("This version combines adaptive parameter tuning with creative crossover.")

# Test with 250 items, 2 objectives
print("\n======================================================")
print("Starting experiment for 250 items...")
run_efficient_llm_moacp_v10(b"250.2.txt", b"Weights_2obj_FQ200.txt", 250, 2, "2502_Results_Strategist_v10.txt")
print("Finished experiment for 250 items.")
print("======================================================")


# Test with 500 items, 2 objectives
print("\n======================================================")
print("Starting experiment for 500 items...")
run_efficient_llm_moacp_v10(b"500.2.txt", b"Weights_2obj_FQ200.txt", 500, 2, "5002_Results_Strategist_v10.txt")
print("Finished experiment for 500 items.")
print("======================================================")


# Test with 750 items, 2 objectives
print("\n======================================================")
print("Starting experiment for 750 items...")
run_efficient_llm_moacp_v10(b"750.2.txt", b"Weights_2obj_FQ200.txt", 750, 2, "7502_Results_Strategist_v10.txt")
print("Finished experiment for 750 items.")
print("======================================================")


print("\n\nAll V10 experiments finished.")
print("The following result files have been created:")
print("- 2502_Results_Strategist_v10.txt")
print("- 5002_Results_Strategist_v10.txt")
print("- 7502_Results_Strategist_v10.txt")
print("\nYou can now run the final analysis cell to compare the new results.")
# Out:
# Running V10 'Intelligent Explorer' experiments...
# This version combines adaptive parameter tuning with creative crossover.
#
# ======================================================
# Starting experiment for 250 items...
#
# --- RUN 1/10 --- V10 Intelligent Explorer
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.05
#   [Final Parameters] L=12, kappa=0.05
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=15
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=17
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=18
#
# --- RUN 2/10 --- V10 Intelligent Explorer
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.05
#   [Final Parameters] L=12, kappa=0.05
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=15
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=17
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=19
#
# --- RUN 3/10 --- V10 Intelligent Explorer
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=10, kappa=0.04
#   [Final Parameters] L=10, kappa=0.04
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=12
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=15
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=16
#
# --- RUN 4/10 --- V10 Intelligent Explorer
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.1
#   [Final Parameters] L=12, kappa=0.1
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=15
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=20
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=22
#
# --- RUN 5/10 --- V10 Intelligent Explorer
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.02
#   [Final Parameters] L=12, kappa=0.02
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=15
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=18
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=20
#
# --- RUN 6/10 --- V10 Intelligent Explorer
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.04
#   [Final Parameters] L=12, kappa=0.04
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=15
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=18
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=20
#
# --- RUN 7/10 --- V10 Intelligent Explorer
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.05
#   [Final Parameters] L=12, kappa=0.05
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=15
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=17
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=18
#
# --- RUN 8/10 --- V10 Intelligent Explorer
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.04
#   [Final Parameters] L=12, kappa=0.04
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=15
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=20
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=22
#
# --- RUN 9/10 --- V10 Intelligent Explorer
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.04
#   [Final Parameters] L=12, kappa=0.04
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=16
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=20
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=25
#
# --- RUN 10/10 --- V10 Intelligent Explorer
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=10, kappa=0.12
#   [Final Parameters] L=10, kappa=0.12
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=12
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=16
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=18
#
# Total execution time: 944.92 seconds
# Average time per run: 94.49 seconds
# Finished experiment for 250 items.
# ======================================================
#
# ======================================================
# Starting experiment for 500 items...
#
# --- RUN 1/10 --- V10 Intelligent Explorer
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=10, kappa=0.1
#   [Final Parameters] L=10, kappa=0.1
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=12
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=14
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=15
#
# --- RUN 2/10 --- V10 Intelligent Explorer
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.1
#   [Final Parameters] L=12, kappa=0.1
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=16
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=18
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=20
#
# --- RUN 3/10 --- V10 Intelligent Explorer
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.06
#   [Final Parameters] L=12, kappa=0.06
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=15
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=17
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=18
#
# --- RUN 4/10 --- V10 Intelligent Explorer
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.1
#   [Final Parameters] L=12, kappa=0.1
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=15
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=17
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=18
#
# --- RUN 5/10 --- V10 Intelligent Explorer
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=10, kappa=0.05
#   [Final Parameters] L=10, kappa=0.05
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=12
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=14
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=16
#
# --- RUN 6/10 --- V10 Intelligent Explorer
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.06
#   [Final Parameters] L=12, kappa=0.06
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=14
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=16
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=17
#
# --- RUN 7/10 --- V10 Intelligent Explorer
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.1
#   [Final Parameters] L=12, kappa=0.1
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=15
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=16
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=17
#
# --- RUN 8/10 --- V10 Intelligent Explorer
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.06
#   [Final Parameters] L=12, kappa=0.06
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=14
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=16
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=18
#
# --- RUN 9/10 --- V10 Intelligent Explorer
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.06
#   [Final Parameters] L=12, kappa=0.06
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=15
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=20
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=22
#
# --- RUN 10/10 --- V10 Intelligent Explorer
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.05
#   [Final Parameters] L=12, kappa=0.05
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=14
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=16
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=20
#
# Total execution time: 888.23 seconds
# Average time per run: 88.82 seconds
# Finished experiment for 500 items.
# ======================================================
#
# ======================================================
# Starting experiment for 750 items...
#
# --- RUN 1/10 --- V10 Intelligent Explorer
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.1
#   [Final Parameters] L=12, kappa=0.1
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=15
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=20
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=25
#
# --- RUN 2/10 --- V10 Intelligent Explorer
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=10, kappa=0.05
#   [Final Parameters] L=10, kappa=0.05
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=12
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=15
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=17
#
# --- RUN 3/10 --- V10 Intelligent Explorer
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.05
#   [Final Parameters] L=12, kappa=0.05
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=14
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=15
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=16
#
# --- RUN 4/10 --- V10 Intelligent Explorer
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=10, kappa=0.1
#   [Final Parameters] L=10, kappa=0.1
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=11
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=12
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=13
#
# --- RUN 5/10 --- V10 Intelligent Explorer
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.15
#   [Final Parameters] L=12, kappa=0.15
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=16
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=20
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=22
#
# --- RUN 6/10 --- V10 Intelligent Explorer
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.05
#   [Final Parameters] L=12, kappa=0.05
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=15
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=17
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=18
#
# --- RUN 7/10 --- V10 Intelligent Explorer
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.1
#   [Final Parameters] L=12, kappa=0.1
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=16
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=20
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=22
#
# --- RUN 8/10 --- V10 Intelligent Explorer
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=12, kappa=0.15
#   [Final Parameters] L=12, kappa=0.15
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=15
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=17
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=18
#
# --- RUN 9/10 --- V10 Intelligent Explorer
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=10, kappa=0.05
#   [Final Parameters] L=10, kappa=0.05
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=15
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=17
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=18
#
# --- RUN 10/10 --- V10 Intelligent Explorer
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Initial] L=10, kappa=0.1
#   [Final Parameters] L=10, kappa=0.1
#   [Intervention] Pausing at iteration 25 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 25: New L=12
#   [Intervention] Pausing at iteration 50 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 50: New L=15
#   [Intervention] Pausing at iteration 75 for adaptive strategy...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive] Iteration 75: New L=16
#
# Total execution time: 925.25 seconds
# Average time per run: 92.52 seconds
# Finished experiment for 750 items.
# ======================================================
#
#
# All V10 experiments finished.
# The following result files have been created:
# - 2502_Results_Strategist_v10.txt
# - 5002_Results_Strategist_v10.txt
# - 7502_Results_Strategist_v10.txt
#
# You can now run the final analysis cell to compare the new results.

# %%
# =========================================================================
# PART 7: COMPREHENSIVE RESULTS ANALYSIS (V10 vs. Baseline)
# =========================================================================

import matplotlib.pyplot as plt
import numpy as np

def dominates(a, b):
    """Returns True if a dominates b (maximization for both objectives)."""
    return all(x >= y for x, y in zip(a, b)) and any(x > y for x, y in zip(a, b))

def get_true_pareto_front(points):
    """Extract the true Pareto front from a set of points."""
    pareto = []
    for i, p in enumerate(points):
        dominated = False
        for j, q in enumerate(points):
            if i != j and dominates(q, p):
                dominated = True
                break
        if not dominated:
            pareto.append(p)
    return pareto

def calculate_hypervolume(points):
    """Calculate a simplified hypervolume metric for comparison."""
    if not points:
        return 0.0
    ref_x = max(p[0] for p in points) * 1.1
    ref_y = max(p[1] for p in points) * 1.1
    sorted_points = sorted(points, key=lambda p: p[0])
    hv = 0.0
    for i in range(len(sorted_points) - 1):
        x1, y1 = sorted_points[i]
        x2, y2 = sorted_points[i + 1]
        hv += (x2 - x1) * (ref_y - y1)
    if sorted_points:
        x_last, y_last = sorted_points[-1]
        hv += (ref_x - x_last) * (ref_y - y_last)
    return hv

def analyze_dominance(baseline_pareto, v10_pareto):
    """Calculate dominance metrics between two Pareto fronts."""
    dominated_baseline_count = 0
    dominated_v10_count = 0
    
    for b_point in baseline_pareto:
        for v_point in v10_pareto:
            if dominates(v_point, b_point):
                dominated_baseline_count += 1
                break
                
    for v_point in v10_pareto:
        for b_point in baseline_pareto:
            if dominates(b_point, v_point):
                dominated_v10_count += 1
                break

    percent_baseline_dominated = (dominated_baseline_count / len(baseline_pareto)) * 100 if baseline_pareto else 0
    percent_v10_dominated = (dominated_v10_count / len(v10_pareto)) * 100 if v10_pareto else 0
    
    return {
        "dominated_baseline_count": dominated_baseline_count,
        "percent_baseline_dominated": percent_baseline_dominated,
        "dominated_v10_count": dominated_v10_count,
        "percent_v10_dominated": percent_v10_dominated
    }

def load_results_and_runtime(filename):
    """Load points and parse runtime from a results file."""
    points = []
    runtime = -1.0
    with open(filename, "r") as f:
        for line in f:
            line = line.strip()
            if line.startswith("# RUNTIME:"):
                try:
                    runtime = float(line.split(":")[1].strip())
                except (IndexError, ValueError):
                    pass
            elif line and not line.startswith("#"):
                try:
                    points.append([float(x) for x in line.split()])
                except ValueError:
                    pass
    return points, runtime

def compare_baseline_vs_v10(original_file, v10_file, title):
    """
    Compare the original baseline results with the new LLM-Strategist V10 results.
    """
    print(f"\n--- Analyzing {title} ---")
    
    # --- Load and Process Results ---
    original_points, _ = load_results_and_runtime(original_file)
    v10_points, v10_runtime = load_results_and_runtime(v10_file)

    if not original_points:
        print(f"  [ERROR] Original file not found or empty: {original_file}")
        return None
    if not v10_points:
        print(f"  [ERROR] V10 file not found or empty: {v10_file}")
        return None

    # --- Calculate Pareto Fronts and Metrics ---
    original_pareto = get_true_pareto_front(original_points)
    v10_pareto = get_true_pareto_front(v10_points)
    
    original_size = len(original_pareto)
    v10_size = len(v10_pareto)
    
    original_hv = calculate_hypervolume(original_pareto)
    v10_hv = calculate_hypervolume(v10_pareto)
    
    # --- Calculate Percentage Improvements ---
    size_improvement = (v10_size - original_size) / original_size * 100 if original_size > 0 else 0
    hv_improvement = (v10_hv - original_hv) / original_hv * 100 if original_hv > 0 else 0
    
    # --- Calculate Dominance ---
    dominance_stats = analyze_dominance(original_pareto, v10_pareto)

    # --- Print Results ---
    print(f"  Original Algorithm:")
    print(f"    Pareto Front Size: {original_size}")
    print(f"    Hypervolume: {original_hv:.2f}")
    print(f"  LLM-Strategist V10 (Intelligent Explorer):")
    print(f"    Pareto Front Size: {v10_size} ({size_improvement:+.2f}%)")
    print(f"    Hypervolume: {v10_hv:.2f} ({hv_improvement:+.2f}%)")
    if v10_runtime > 0:
        print(f"    Total Runtime: {v10_runtime:.2f} seconds")
    print(f"  -------------------------------------------------")
    print(f"  Dominance Analysis:")
    print(f"    Baseline points dominated by V10: {dominance_stats['dominated_baseline_count']} / {original_size} ({dominance_stats['percent_baseline_dominated']:.2f}%)")
    print(f"    V10 points dominated by Baseline: {dominance_stats['dominated_v10_count']} / {v10_size} ({dominance_stats['percent_v10_dominated']:.2f}%)")
    print(f"  -------------------------------------------------")

    # --- Plotting ---
    plt.figure(figsize=(12, 10))
    
    if original_pareto:
        ox, oy = zip(*original_pareto)
        plt.scatter(ox, oy, color='blue', alpha=0.6, s=50, label="Original Baseline")
    if v10_pareto:
        sx, sy = zip(*v10_pareto)
        plt.scatter(sx, sy, color='red', marker='x', s=50, alpha=0.8, label="LLM-Strategist V10")

    plt.xlabel("Objective 1 (Profit 1)", fontsize=12)
    plt.ylabel("Objective 2 (Profit 2)", fontsize=12)
    plt.title(f"{title} - Pareto Front Comparison (V10)", fontsize=16)
    plt.legend(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()
    
    return {
        "title": title,
        "original_size": original_size,
        "v10_size": v10_size,
        "size_improvement": size_improvement,
        "original_hv": original_hv,
        "v10_hv": v10_hv,
        "hv_improvement": hv_improvement,
        "v10_runtime": v10_runtime,
        "dominance_stats": dominance_stats
    }

# --- MAIN EXECUTION ---
print("Starting comprehensive results analysis: Original Baseline vs. LLM-Strategist V10...")

# Define the file names for comparison
files_to_compare = [
    {
        "original": "2502_ResultsMD.txt",
        "v10": "2502_Results_Strategist_v10.txt",
        "title": "250-Item Problem"
    },
    {
        "original": "5002_ResultsMD.txt",
        "v10": "5002_Results_Strategist_v10.txt",
        "title": "500-Item Problem"
    },
    {
        "original": "7502_ResultsMD.txt",
        "v10": "7502_Results_Strategist_v10.txt",
        "title": "750-Item Problem"
    }
]

all_results = []
for files in files_to_compare:
    result = compare_baseline_vs_v10(
        files["original"], 
        files["v10"], 
        files["title"]
    )
    if result:
        all_results.append(result)

# --- Summary of Improvements ---
print("\n" + "="*60)
print("              SUMMARY OF IMPROVEMENTS (V10)")
print("="*60)

if all_results:
    total_hv_improvement = 0
    total_domination_advantage = 0
    for res in all_results:
        print(f"\n{res['title']}:")
        print(f"  Hypervolume Improvement: {res['hv_improvement']:+.2f}%")
        print(f"  Dominance Advantage: {res['dominance_stats']['percent_baseline_dominated'] - res['dominance_stats']['percent_v10_dominated']:+.2f}%")
        if res['v10_runtime'] > 0:
            print(f"  V10 Runtime: {res['v10_runtime']:.2f}s")
        total_hv_improvement += res['hv_improvement']
        total_domination_advantage += (res['dominance_stats']['percent_baseline_dominated'] - res['dominance_stats']['percent_v10_dominated'])

    avg_hv_improvement = total_hv_improvement / len(all_results)
    avg_domination_advantage = total_domination_advantage / len(all_results)
    
    print("\n" + "-"*60)
    print(f"  AVERAGE HV IMPROVEMENT: {avg_hv_improvement:+.2f}%")
    print(f"  AVERAGE DOMINANCE ADVANTAGE: {avg_domination_advantage:+.2f}%")
    print("-"*60)
else:
    print("\nCould not generate a summary as no results were successfully analyzed.")

print("\nAnalysis complete.")
# Out:
# Starting comprehensive results analysis: Original Baseline vs. LLM-Strategist V10...
#
# --- Analyzing 250-Item Problem ---
#   Original Algorithm:
#     Pareto Front Size: 212
#     Hypervolume: 6614986.88
#   LLM-Strategist V10 (Intelligent Explorer):
#     Pareto Front Size: 216 (+1.89%)
#     Hypervolume: 6383996.75 (-3.49%)
#     Total Runtime: 944.92 seconds
#   -------------------------------------------------
#   Dominance Analysis:
#     Baseline points dominated by V10: 160 / 212 (75.47%)
#     V10 points dominated by Baseline: 43 / 216 (19.91%)
#   -------------------------------------------------
# --- Analyzing 500-Item Problem ---
#   Original Algorithm:
#     Pareto Front Size: 369
#     Hypervolume: 23044962.94
#   LLM-Strategist V10 (Intelligent Explorer):
#     Pareto Front Size: 334 (-9.49%)
#     Hypervolume: 22392900.94 (-2.83%)
#     Total Runtime: 888.23 seconds
#   -------------------------------------------------
#   Dominance Analysis:
#     Baseline points dominated by V10: 191 / 369 (51.76%)
#     V10 points dominated by Baseline: 141 / 334 (42.22%)
#   -------------------------------------------------
# --- Analyzing 750-Item Problem ---
#   Original Algorithm:
#     Pareto Front Size: 552
#     Hypervolume: 56877706.67
#   LLM-Strategist V10 (Intelligent Explorer):
#     Pareto Front Size: 561 (+1.63%)
#     Hypervolume: 55318411.65 (-2.74%)
#     Total Runtime: 925.25 seconds
#   -------------------------------------------------
#   Dominance Analysis:
#     Baseline points dominated by V10: 222 / 552 (40.22%)
#     V10 points dominated by Baseline: 294 / 561 (52.41%)
#   -------------------------------------------------
# ============================================================
#               SUMMARY OF IMPROVEMENTS (V10)
# ============================================================
#
# 250-Item Problem:
#   Hypervolume Improvement: -3.49%
#   Dominance Advantage: +55.56%
#   V10 Runtime: 944.92s
#
# 500-Item Problem:
#   Hypervolume Improvement: -2.83%
#   Dominance Advantage: +9.55%
#   V10 Runtime: 888.23s
#
# 750-Item Problem:
#   Hypervolume Improvement: -2.74%
#   Dominance Advantage: -12.19%
#   V10 Runtime: 925.25s
#
# ------------------------------------------------------------
#   AVERAGE HV IMPROVEMENT: -3.02%
#   AVERAGE DOMINANCE ADVANTAGE: +17.64%
# ------------------------------------------------------------
#
# Analysis complete.

# %%
# =========================================================================
# ADVANCED ANALYSIS: DOMINANCE BETWEEN V7 AND BASELINE
# =========================================================================

import matplotlib.pyplot as plt
import numpy as np

def dominates(a, b):
    """Returns True if a dominates b (maximization for both objectives)."""
    return all(x >= y for x, y in zip(a, b)) and any(x > y for x, y in zip(a, b))

def get_true_pareto_front(points):
    pareto = []
    for i, p in enumerate(points):
        dominated = False
        for j, q in enumerate(points):
            if i != j and dominates(q, p):
                dominated = True
                break
        if not dominated:
            pareto.append(p)
    return pareto

def analyze_dominance(baseline_file, v7_file, title):
    """
    Analyze the dominance relationship between two Pareto fronts.
    """
    print(f"\n--- Advanced Analysis: {title} ---")
    
    # Load data
    baseline_points = []
    with open(baseline_file, "r") as f:
        for line in f:
            line = line.strip()
            if line and not line.startswith("#"):
                try:
                    baseline_points.append([float(x) for x in line.split()])
                except ValueError: pass

    v7_points = []
    with open(v7_file, "r") as f:
        for line in f:
            line = line.strip()
            if line and not line.startswith("#"):
                try:
                    v7_points.append([float(x) for x in line.split()])
                except ValueError: pass
    
    baseline_pareto = get_true_pareto_front(baseline_points)
    v7_pareto = get_true_pareto_front(v7_points)

    # Calculate dominance
    dominated_baseline_count = 0
    dominated_v7_count = 0
    
    for b_point in baseline_pareto:
        for v_point in v7_pareto:
            if dominates(v_point, b_point):
                dominated_baseline_count += 1
                break # This baseline point is dominated, move to the next
                
    for v_point in v7_pareto:
        for b_point in baseline_pareto:
            if dominates(b_point, v_point):
                dominated_v7_count += 1
                break # This v7 point is dominated, move to the next

    # Calculate percentages
    percent_baseline_dominated = (dominated_baseline_count / len(baseline_pareto)) * 100 if baseline_pareto else 0
    percent_v7_dominated = (dominated_v7_count / len(v7_pareto)) * 100 if v7_pareto else 0
    
    print(f"  Baseline Pareto Front Size: {len(baseline_pareto)}")
    print(f"  V7 Pareto Front Size: {len(v7_pareto)}")
    print(f"  -------------------------------------------------")
    print(f"  Baseline points dominated by V7: {dominated_baseline_count} / {len(baseline_pareto)} ({percent_baseline_dominated:.2f}%)")
    print(f"  V7 points dominated by Baseline: {dominated_v7_count} / {len(v7_pareto)} ({percent_v7_dominated:.2f}%)")
    print(f"  -------------------------------------------------")

    # Plotting
    plt.figure(figsize=(12, 10))
    
    # Plot all points
    bx, by = zip(*baseline_points)
    vx, vy = zip(*v7_points)
    plt.scatter(bx, by, color='blue', alpha=0.2, s=20, label="All Baseline Solutions")
    plt.scatter(vx, vy, color='red', alpha=0.2, s=20, label="All V7 Solutions")

    # Plot Pareto fronts
    bx_p, by_p = zip(*baseline_pareto)
    vx_p, vy_p = zip(*v7_pareto)
    plt.scatter(bx_p, by_p, color='blue', alpha=0.8, s=50, label="Baseline Pareto Front")
    plt.scatter(vx_p, vy_p, color='red', marker='x', s=50, label="V7 Pareto Front")

    # Highlight dominated points
    dominated_b_points = []
    for b_point in baseline_pareto:
        for v_point in v7_pareto:
            if dominates(v_point, b_point):
                dominated_b_points.append(b_point)
                break
    if dominated_b_points:
        dbx, dby = zip(*dominated_b_points)
        plt.scatter(dbx, dby, color='orange', s=80, marker='o', facecolors='none', label="Baseline Points Dominated by V7")

    plt.xlabel("Objective 1 (Profit 1)", fontsize=12)
    plt.ylabel("Objective 2 (Profit 2)", fontsize=12)
    plt.title(f"{title} - Dominance Analysis", fontsize=16)
    plt.legend(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# --- MAIN EXECUTION ---
print("Starting advanced dominance analysis: Baseline vs. V7...")

# Make sure you use the correct V7 filename
analyze_dominance(
    "5002_ResultsMD.txt", 
    "5002_Results_Strategist_v7.txt", # <-- USE YOUR V7 FILENAME
    "500-Item Problem (V7 vs. Baseline)"
)
# Out:
# Starting advanced dominance analysis: Baseline vs. V7...
#
# --- Advanced Analysis: 500-Item Problem (V7 vs. Baseline) ---
#   Baseline Pareto Front Size: 369
#   V7 Pareto Front Size: 371
#   -------------------------------------------------
#   Baseline points dominated by V7: 170 / 369 (46.07%)
#   V7 points dominated by Baseline: 156 / 371 (42.05%)
#   -------------------------------------------------

# %%
# Test with 750 items, 2 objectives
print("\n======================================================")
print("Starting experiment for 750 items...")
run_efficient_llm_moacp_v5(b"750.2.txt", b"Weights_2obj_FQ200.txt", 750, 2, "7502_Results_Strategist_v7.txt")
print("Finished experiment for 750 items.")
print("======================================================")
print("- 7502_Results_Strategist_v7.txt")
# Out:
# ======================================================
# Starting experiment for 750 items...
#
# --- RUN 1/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MODERATE, L: 5
#   [LLM Reasoning] The problem has a moderate number of items (750) and multiple objectives (2). The high average profit variance (703.64) suggests that the problem is complex and may require some exploration to find good solutions. However, the relatively low capacity tightness (1.0) means that there are still many feasible solutions to consider. Therefore, a moderate L value of 5 should provide a good balance between exploration and exploitation.
#   [Final Parameters] L=5, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 25: New L=7
#   [LLM Reasoning] The hypervolume has increased significantly from 0.00 to 33124484.00, which aligns with the primary goal of increasing the hypervolume. The diversity has also improved from 0.00 to 1631.20, which is satisfactory considering the secondary goal of maintaining or improving diversity. Since the hypervolume is not stagnating and the diversity is decent, I will increase 'L' to 7 to further encourage exploration and potentially lead to even more significant improvements in the hypervolume.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 50: New L=9
#   [LLM Reasoning] Since the hypervolume has increased by a significant amount (21645247.20), it's likely that we're still exploring new solutions effectively. The diversity metric has also improved, which suggests that increasing 'L' hasn't led to a significant loss of diversity yet. Given our primary goal is to increase hypervolume and secondary goal is to maintain or improve diversity, I recommend keeping the upward trend going by increasing 'L' to 9. This will provide more exploration opportunities while still allowing us to leverage the diversity gained so far.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 75: New L=10
#   [LLM Reasoning] Although the hypervolume has decreased slightly, it's still relatively high. To further increase the hypervolume, I'll try increasing L to see if it can help find better solutions. Since diversity is also decreasing, but not significantly, I'm willing to take this risk to potentially achieve higher hypervolume values.
#
# --- RUN 2/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: STEEP, L: 4
#   [LLM Reasoning] The large number of items (750) and moderate variance in both profit and weight suggest that the search space is relatively complex. The high capacity tightness indicates that the optimal solution is likely to be close to the boundaries, but not necessarily at the extreme edges. A moderate value for L (4) allows for some local exploration while still maintaining the possibility of discovering better solutions by swapping a few items.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 25: New L=6
#   [LLM Reasoning] The hypervolume has been declining for several iterations, indicating stagnation. Since the primary goal is to increase hypervolume, I will increase L to potentially escape local optima. However, I will not increase it too much as diversity is also important. The current value of L (4) is relatively low, so a moderate increase to 6 seems reasonable.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 50: New L=8
#   [LLM Reasoning] The primary goal of increasing hypervolume is being achieved, as the hypervolume metric has increased by a significant amount. The diversity metric is also improving, albeit slightly. Considering the stagnation threshold for hypervolume has not been reached yet, I decide to increase 'L' further to potentially continue driving up the hypervolume while maintaining diversity.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 75: New L=9
#   [LLM Reasoning] Since the primary goal of increasing hypervolume is being achieved (hypervolume has increased by 366694.25), I will consider increasing L to further explore the solution space. However, I will also monitor diversity as it has decreased slightly. Since the decrease in diversity (-27.30) is not significant, I believe that a small increase in L will still allow for improvement in hypervolume while maintaining diversity.
#
# --- RUN 3/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: AGGRESSIVE, L: 12
#   [LLM Reasoning] The high number of items (750) and moderate variance in both profit (703.64) and weight (687.3) suggest that the search space is large and complex. The capacity tightness being very high (1.0) indicates that the knapsack is highly constrained, which also favors a more aggressive approach to explore the solution space. Therefore, I recommend starting with an AGGRESSIVE strategy and setting L=12 to allow for a decent breadth of exploration.
#   [Final Parameters] L=12, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 25: New L=15
#   [LLM Reasoning] The hypervolume has decreased significantly, which is not desirable. However, the diversity has also dropped sharply, indicating that the search might be getting stuck in a local optimum. To balance these two competing goals, I will increase 'L' to 15 to introduce more exploration and potentially escape the current local optimum. This decision is motivated by the primary goal of increasing hypervolume and the secondary goal of maintaining diversity.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 50: New L=20
#   [LLM Reasoning] Since the hypervolume has plateaued at 7188352.80 for two consecutive iterations, I decide to increase 'L' to stimulate further exploration. Although diversity is still stable at 8.60, a slight increase in 'L' might help maintain or even improve it while allowing the search to move towards new regions of high-quality solutions.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 75: New L=25
#   [LLM Reasoning] Given that the hypervolume has not changed, I'm inclined to increase L to explore more of the search space. Since diversity is still maintained at 8.60, there's no significant concern on this front. As the primary goal is to increase hypervolume, and stagnation is present, I recommend increasing L to 25.
#
# --- RUN 4/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: BALANCED, L: 4
#   [LLM Reasoning] Moderate number of items (750) and reasonable variance in both profit and weight suggest a balanced approach to explore the search space effectively. A value of L=4 will provide sufficient diversity in the local search while avoiding excessive exploration.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 25: New L=5
#   [LLM Reasoning] The primary goal of increasing hypervolume has not been achieved yet, as the current change in hypervolume is significant (23978605.30). Additionally, diversity has improved by a substantial amount (1616.02), which suggests that increasing 'L' might be beneficial for further exploring the solution space. Therefore, I recommend increasing 'L' to 5.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 50: New L=7
#   [LLM Reasoning] Based on the current metrics, I've decided to increase 'L' from 5 to 7. The hypervolume has increased by 18686186.65, which suggests that the search is making progress and more exploration is needed. Although diversity has also increased, it's still relatively low (2570.49), so increasing 'L' should allow for more diverse solutions to be explored. Given the primary goal of increasing hypervolume, I believe a moderate increase in 'L' will continue to drive progress without sacrificing too much diversity.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 75: New L=9
#   [LLM Reasoning] Based on the current values of hypervolume (52299275.10) and diversity (2668.54), I recommend increasing 'L' to 9. The primary goal is to increase hypervolume, which has shown significant improvement since the last iteration. Although the diversity metric has also increased, it's still below its initial value. Considering the stagnation in hypervolume growth may be alleviated by a larger value of 'L'. As the diversity change is relatively small (98.05), it's not a significant concern at this point.
#
# --- RUN 5/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: BROAD Exploration, L: 15
#   [LLM Reasoning] Given the large number of items (750), moderate average profit variance (703.64) and weight variance (687.3), and high capacity tightness (1.0), a broad exploration strategy is recommended to ensure that the search covers most of the solution space effectively.
#   [Final Parameters] L=15, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 25: New L=20
#   [LLM Reasoning] Since the hypervolume has decreased by a significant amount (-22.5 million), it's likely that the search is stuck in a local optimum. To encourage exploration, I'll increase L to 20, hoping to reach better areas of the solution space. Although diversity has also dropped, the decrease is not as severe as the loss in hypervolume, so increasing L seems like a reasonable trade-off.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 50: New L=30
#   [LLM Reasoning] Given the significant increase in hypervolume (19277268.70) and the moderate improvement in diversity (977.75), I recommend increasing L to 30. This decision is based on the primary goal of increasing hypervolume, which has been successful so far. Additionally, the moderate gain in diversity suggests that the increased L value has not negatively impacted diversity significantly. As the search continues to make progress in terms of hypervolume, it's reasonable to expect further exploration and potential improvements in diversity as well.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 75: New L=40
#   [LLM Reasoning] Hypervolume has been stagnant for some time, and since the change in hypervolume was relatively small (-8495.00), I will increase 'L' to potentially further improve the search. The current diversity is still acceptable (2420.39), so increasing 'L' should not significantly harm it.
#
# --- RUN 6/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: BREADTH_FIRST, L: 15
#   [LLM Reasoning] The high number of items (750) and moderate variance in both profit (703.64) and weight (687.3) suggest that the problem has a complex structure. A larger value of L will help to explore this space more effectively. The relatively low capacity tightness (1.0) indicates that there is still some flexibility in packing items, which supports the use of breadth-first strategies.
#   [Final Parameters] L=15, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 25: New L=20
#   [LLM Reasoning] Based on the current hypervolume metric, which has decreased by a significant amount (-19,075,477.21), I recommend increasing 'L' to 20. This will allow for more exploration and potentially lead to a larger hypervolume. Although diversity is also decreasing, the primary goal of increasing hypervolume takes precedence. A moderate increase in 'L' should balance the need to explore new areas with maintaining some level of diversity.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 50: New L=25
#   [LLM Reasoning] The hypervolume has increased significantly since the last iteration, which aligns with our primary goal. The diversity metric also shows an increase, indicating that we're exploring a more diverse solution space. Considering these metrics, I recommend increasing 'L' to 25 to continue the momentum and further explore the solution space while maintaining or improving diversity.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 75: New L=30
#   [LLM Reasoning] Based on the current parameters, I suggest increasing L to 30. The hypervolume has shown significant improvement (602823.46) and is still growing, which aligns with our primary goal. Although diversity has decreased slightly (-9.67), it's not a significant drop, and we can consider it an acceptable trade-off for the increased hypervolume. Since hypervolume is still improving, I don't see any reason to decrease L. Therefore, increasing L to 30 seems like a good choice to continue exploring new solutions.
#
# --- RUN 7/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MEDIUM, L: 5
#   [LLM Reasoning] The number of items is high (750), indicating a complex problem instance. The average profit variance and weight variance are also relatively high, suggesting that the objectives have some correlation. Given these characteristics, a medium-level local search (L=5) will provide a good balance between exploration and exploitation, allowing for effective exploration of the solution space while still taking into account the complexity of the problem.
#   [Final Parameters] L=5, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 25: New L=7
#   [LLM Reasoning] The hypervolume has been declining over the iterations, which is concerning. However, increasing 'L' can help to explore more of the solution space and potentially increase the hypervolume again. Meanwhile, the diversity metric is also decreasing, but not drastically so. Therefore, I will increase 'L' from 5 to 7 in an attempt to boost the hypervolume while still maintaining some level of diversity.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 50: New L=9
#   [LLM Reasoning] The primary goal of increasing the hypervolume is not being compromised as the change in hypervolume is significant. The diversity metric has also improved, which suggests that the current L value is still beneficial for maintaining or improving diversity. Given that the hypervolume is continuing to grow, I will increase L to 9 to further explore the search space and potentially discover better solutions.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 75: New L=11
#   [LLM Reasoning] Since the primary goal of increasing hypervolume is being met (hypervolume has increased by 520927.03), I will consider further increasing L to continue this trend. However, I will also keep an eye on diversity, which has decreased by -84.18. Although it's not dropping significantly, I'll increase L slightly to 11 to maintain the momentum and encourage a balance between hypervolume growth and diversity maintenance.
#
# --- RUN 8/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: CAUTIOUS, L: 3
#   [LLM Reasoning] The number of items (750) is relatively high, which suggests that the problem has many local optima. Additionally, both the average profit variance and weight variance are quite large, indicating that there may be a wide range of possible solutions. A cautious approach with L=3 will allow for some exploration while still being mindful of the computational cost.
#   [Final Parameters] L=3, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 25: New L=5
#   [LLM Reasoning] Based on the current metrics, I recommend increasing L to 5. The hypervolume has been declining significantly, which is our primary concern. Increasing L may help to explore more of the solution space and potentially improve the hypervolume. Although diversity has dropped dramatically, a small increase in L may not further exacerbate this issue. In fact, it's possible that increasing L could lead to a more diverse set of solutions overall.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 50: New L=10
#   [LLM Reasoning] Since the hypervolume has not changed in the past iteration and we are currently at a moderate value of L (5), I decide to increase L to 10. This is because our primary goal is to increase hypervolume, and increasing L can potentially lead to more diverse solutions being explored. Although diversity has also remained stagnant, I believe that the benefits of increased exploration outweigh the potential risks of decreased diversity. As we are not yet seeing a significant drop in diversity, I am willing to take this calculated risk to further improve the hypervolume.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 75: New L=15
#   [LLM Reasoning] Since the hypervolume has not changed since iteration 75, it seems like the current value of L (10) might be stagnating. Increasing L to 15 could potentially lead to a higher hypervolume and more efficient search. The diversity metric remains unchanged, so it's reasonable to assume that increasing L will not significantly drop the diversity. Overall, the primary goal of increasing hypervolume is being prioritized.
#
# --- RUN 9/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MODERATE, L: 5
#   [LLM Reasoning] The problem instance has a moderate number of items (750) and two objectives. The capacity tightness is high (1.0), indicating that the knapsack is almost full. This suggests that the optimal solution may be near the boundary, but not necessarily extreme. A moderate value for L (5) will provide a good balance between exploration and exploitation, allowing the algorithm to adapt to the problem's characteristics.
#   [Final Parameters] L=5, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 25: New L=7
#   [LLM Reasoning] Based on the current hypervolume metric, the value has increased by a significant amount. This suggests that increasing L might be beneficial to further improve the search space. However, we should also consider the diversity metric. The diversity has improved significantly as well, which indicates that the increased L is not causing a significant loss in exploration. Considering both goals, I recommend increasing L to 7, as it may lead to even more effective exploration and exploitation.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 50: New L=9
#   [LLM Reasoning] Based on the current state of the search, I recommend increasing 'L' to 9. The hypervolume has increased significantly (19428183.50), indicating that we are exploring a more diverse and promising region of the solution space. While diversity has also improved (1094.20), it's still relatively low compared to the gain in hypervolume. Given our primary goal is to increase hypervolume, I believe increasing 'L' will allow us to continue exploring this new region and potentially discover even better solutions. The potential trade-off with decreased diversity can be mitigated by monitoring and adjusting other parameters if necessary.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 75: New L=10
#   [LLM Reasoning] Since the hypervolume has decreased by -130597.00 compared to the previous iteration, it's stagnating. However, decreasing 'L' might harm diversity as the diversity metric has also decreased by -59.85. To balance these two objectives, I'll increase 'L' to 10, hoping that this will help improve hypervolume while keeping diversity in check.
#
# --- RUN 10/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: STRATEGIC_LOCAL_SEARCH, L: 5
#   [LLM Reasoning] The moderate number of items (750) and relatively high variance in profit and weight suggest a balance between exploration and exploitation. With the problem being well-constrained (capacity tightness is 1.0), we want to focus on exploring the solution space while still maintaining some level of local optimization. A swap size of 5 allows for decent exploration without getting stuck in local optima.
#   [Final Parameters] L=5, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 25: New L=7
#   [LLM Reasoning] The hypervolume has decreased by -19297714.36, indicating stagnation. Since the primary goal is to increase hypervolume, I will increase L to potentially discover new solutions that can improve the hypervolume. Additionally, the diversity metric has decreased, but only by a small amount (-918.86), which suggests that increasing L might not significantly worsen the diversity. Given the stagnation in hypervolume and the relatively minor decrease in diversity, I believe increasing L to 7 is a suitable choice.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 50: New L=9
#   [LLM Reasoning] The primary goal of increasing the hypervolume is being met, as the hypervolume has increased by a significant amount. The secondary goal of maintaining or improving diversity is also being met, as the diversity metric has improved slightly. Given that the hypervolume is still trending upwards, I will increase 'L' to 9 to continue exploring new solutions and potentially further increasing the hypervolume.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V7] Iteration 75: New L=10
#   [LLM Reasoning] The hypervolume has increased by a significant margin (330535.90) since the last iteration, indicating that the current value of L (9) is still effective in exploring the search space. However, diversity has also improved slightly (43.10), suggesting that increasing L may not harm diversity excessively. Since the primary goal is to increase hypervolume, and there's no significant stagnation, I recommend increasing L to 10.
#
# Total execution time: 1192.76 seconds
# Average time per run: 119.28 seconds
# Finished experiment for 750 items.
# ======================================================
# - 7502_Results_Strategist_v7.txt

# %%
# --- MAIN EXECUTION ---
print("Starting results analysis: Original Baseline vs. LLM-Strategist V6 (Adaptive)...")

# Define the file names for comparison
files_to_compare = [
    {
        "original": "7502_ResultsMD.txt",
        "strategist": "7502_Results_Strategist_v7.txt",
        "title": "750-Item Problem"
    },
]

all_results = []
for files in files_to_compare:
    result = compare_baseline_vs_strategist(
        files["original"], 
        files["strategist"], 
        files["title"]
    )
    if result:
        all_results.append(result)

# --- Summary of Improvements ---
print("\n" + "="*50)
print("              SUMMARY OF IMPROVEMENTS (V7)")
print("="*50)

if all_results:
    total_hv_improvement = 0
    for res in all_results:
        print(f"\n{res['title']}:")
        print(f"  Hypervolume Improvement: {res['hv_improvement']:+.2f}%")
        total_hv_improvement += res['hv_improvement']

    avg_hv_improvement = total_hv_improvement / len(all_results)
    
    print("\n" + "-"*50)
    print(f"  AVERAGE HV IMPROVEMENT: {avg_hv_improvement:+.2f}%")
    print("-"*50)
else:
    print("\nCould not generate a summary as no results were successfully analyzed.")

print("\nAnalysis complete.")
# Out:
# Starting results analysis: Original Baseline vs. LLM-Strategist V6 (Adaptive)...
#
# --- Analyzing 750-Item Problem ---
#   Original Algorithm:
#     Pareto Front Size: 552
#     Hypervolume: 56877706.67
#   LLM-Strategist V6 (Adaptive):
#     Pareto Front Size: 480 (-13.04%)
#     Hypervolume: 56039786.25 (-1.47%)
# ==================================================
#               SUMMARY OF IMPROVEMENTS (V7)
# ==================================================
#
# 750-Item Problem:
#   Hypervolume Improvement: -1.47%
#
# --------------------------------------------------
#   AVERAGE HV IMPROVEMENT: -1.47%
# --------------------------------------------------
#
# Analysis complete.

# %%
# =========================================================================
# ADVANCED ANALYSIS: DOMINANCE BETWEEN V7 AND BASELINE
# =========================================================================

import matplotlib.pyplot as plt
import numpy as np

def dominates(a, b):
    """Returns True if a dominates b (maximization for both objectives)."""
    return all(x >= y for x, y in zip(a, b)) and any(x > y for x, y in zip(a, b))

def get_true_pareto_front(points):
    pareto = []
    for i, p in enumerate(points):
        dominated = False
        for j, q in enumerate(points):
            if i != j and dominates(q, p):
                dominated = True
                break
        if not dominated:
            pareto.append(p)
    return pareto

def analyze_dominance(baseline_file, v7_file, title):
    """
    Analyze the dominance relationship between two Pareto fronts.
    """
    print(f"\n--- Advanced Analysis: {title} ---")
    
    # Load data
    baseline_points = []
    with open(baseline_file, "r") as f:
        for line in f:
            line = line.strip()
            if line and not line.startswith("#"):
                try:
                    baseline_points.append([float(x) for x in line.split()])
                except ValueError: pass

    v7_points = []
    with open(v7_file, "r") as f:
        for line in f:
            line = line.strip()
            if line and not line.startswith("#"):
                try:
                    v7_points.append([float(x) for x in line.split()])
                except ValueError: pass
    
    baseline_pareto = get_true_pareto_front(baseline_points)
    v7_pareto = get_true_pareto_front(v7_points)

    # Calculate dominance
    dominated_baseline_count = 0
    dominated_v7_count = 0
    
    for b_point in baseline_pareto:
        for v_point in v7_pareto:
            if dominates(v_point, b_point):
                dominated_baseline_count += 1
                break # This baseline point is dominated, move to the next
                
    for v_point in v7_pareto:
        for b_point in baseline_pareto:
            if dominates(b_point, v_point):
                dominated_v7_count += 1
                break # This v7 point is dominated, move to the next

    # Calculate percentages
    percent_baseline_dominated = (dominated_baseline_count / len(baseline_pareto)) * 100 if baseline_pareto else 0
    percent_v7_dominated = (dominated_v7_count / len(v7_pareto)) * 100 if v7_pareto else 0
    
    print(f"  Baseline Pareto Front Size: {len(baseline_pareto)}")
    print(f"  V7 Pareto Front Size: {len(v7_pareto)}")
    print(f"  -------------------------------------------------")
    print(f"  Baseline points dominated by V7: {dominated_baseline_count} / {len(baseline_pareto)} ({percent_baseline_dominated:.2f}%)")
    print(f"  V7 points dominated by Baseline: {dominated_v7_count} / {len(v7_pareto)} ({percent_v7_dominated:.2f}%)")
    print(f"  -------------------------------------------------")

    # Plotting
    plt.figure(figsize=(12, 10))
    
    # Plot all points
    bx, by = zip(*baseline_points)
    vx, vy = zip(*v7_points)
    plt.scatter(bx, by, color='blue', alpha=0.2, s=20, label="All Baseline Solutions")
    plt.scatter(vx, vy, color='red', alpha=0.2, s=20, label="All V7 Solutions")

    # Plot Pareto fronts
    bx_p, by_p = zip(*baseline_pareto)
    vx_p, vy_p = zip(*v7_pareto)
    plt.scatter(bx_p, by_p, color='blue', alpha=0.8, s=50, label="Baseline Pareto Front")
    plt.scatter(vx_p, vy_p, color='red', marker='x', s=50, label="V7 Pareto Front")

    # Highlight dominated points
    dominated_b_points = []
    for b_point in baseline_pareto:
        for v_point in v7_pareto:
            if dominates(v_point, b_point):
                dominated_b_points.append(b_point)
                break
    if dominated_b_points:
        dbx, dby = zip(*dominated_b_points)
        plt.scatter(dbx, dby, color='orange', s=80, marker='o', facecolors='none', label="Baseline Points Dominated by V7")

    plt.xlabel("Objective 1 (Profit 1)", fontsize=12)
    plt.ylabel("Objective 2 (Profit 2)", fontsize=12)
    plt.title(f"{title} - Dominance Analysis", fontsize=16)
    plt.legend(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# --- MAIN EXECUTION ---
print("Starting advanced dominance analysis: Baseline vs. V7...")

# Make sure you use the correct V7 filename
analyze_dominance(
    "7502_ResultsMD.txt", 
    "7502_Results_Strategist_v7.txt", # <-- USE YOUR V7 FILENAME
    "750-Item Problem (V7 vs. Baseline)"
)
# Out:
# Starting advanced dominance analysis: Baseline vs. V7...
#
# --- Advanced Analysis: 750-Item Problem (V7 vs. Baseline) ---
#   Baseline Pareto Front Size: 552
#   V7 Pareto Front Size: 480
#   -------------------------------------------------
#   Baseline points dominated by V7: 271 / 552 (49.09%)
#   V7 points dominated by Baseline: 176 / 480 (36.67%)
#   -------------------------------------------------

# %%
# =========================================================================
# PART 6: RUN THE EFFICIENT EXPERIMENTS (V4)
# =========================================================================

print("Running Efficient LLM-MOACP V4 on test instances...")
print("This version is optimized for efficiency with minimal LLM calls.")

# Test with 250 items, 2 objectives
print("\n======================================================")
print("Starting experiment for 250 items...")
run_efficient_llm_moacp_v5(b"250.2.txt", b"Weights_2obj_FQ200.txt", 250, 2, "2502_Results_Strategist_v7.txt")
print("Finished experiment for 250 items.")
print("======================================================")


# Test with 500 items, 2 objectives
print("\n======================================================")
print("Starting experiment for 500 items...")
run_efficient_llm_moacp_v5(b"500.2.txt", b"Weights_2obj_FQ200.txt", 500, 2, "5002_Results_Strategist_v7.txt")
print("Finished experiment for 500 items.")
print("======================================================")


# Test with 750 items, 2 objectives
print("\n======================================================")
print("Starting experiment for 750 items...")
run_efficient_llm_moacp_v5(b"750.2.txt", b"Weights_2obj_FQ200.txt", 750, 2, "7502_Results_Strategist_v7.txt")
print("Finished experiment for 750 items.")
print("======================================================")


print("\n\nAll efficient experiments finished.")
print("The following result files have been created:")
print("- 2502_Results_Strategist_v7.txt")
print("- 5002_Results_Strategist_v7.txt")
print("- 7502_Results_Strategist_v7.txt")
print("\nYou can now run the analysis cells to compare the new results.")
# Out:
# Running Efficient LLM-MOACP V4 on test instances...
# This version is optimized for efficiency with minimal LLM calls.
#
# ======================================================
# Starting experiment for 250 items...
#
# --- RUN 1/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: FOCUSED, L: 2
#   [LLM Reasoning] Low capacity tightness and low variance in both profit and weight suggest a focused approach to avoid missing good local optima.
#   [Final Parameters] L=2, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=3
#   [LLM Reasoning] The hypervolume has increased significantly, which is great! However, the diversity has also dropped, which could be a concern if it continues. Given that both metrics have changed, I'm going to keep 'L' at the current value of 2 for now and see how the search evolves. If the diversity continues to drop or stagnates, I may consider decreasing 'L' in the next iteration.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=4
#   [LLM Reasoning] Hypervolume has increased significantly, indicating that the current value of 'L' is still effective in exploring the search space. Diversity has also improved, but at a slower rate than hypervolume. Considering these factors, I will keep 'L' at its current value to maintain momentum and further explore the promising directions discovered so far.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=5
#   [LLM Reasoning] Hypervolume is decreasing and the change is significant, so I want to encourage further exploration. Since diversity has improved slightly, I will keep 'L' smaller than before to balance between hypervolume growth and solution spread.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 2/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: EXPLOITATIVE, L: 4
#   [LLM Reasoning] While the problem has a high number of items (250) and high variances in profit and weight, the capacity tightness is relatively low (1.0). This suggests that there may be some flexibility in the solution, making it beneficial to focus on exploiting local optima rather than exploring widely.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=5
#   [LLM Reasoning] Both hypervolume and diversity are decreasing, which is concerning. However, since the diversity drop is significant (-446.11), I'll choose to decrease 'L' to encourage a broader search and potentially regain some of that lost diversity. The small decrease should help without significantly affecting the hypervolume progress.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=7
#   [LLM Reasoning] The hypervolume has significantly increased, which is great! However, the diversity has also decreased by a significant amount, which could be problematic in the long run. Since both metrics are improving, I can afford to increase 'L' slightly (from 5 to 7) to explore more without losing too much diversity. This should help maintain the momentum of hypervolume growth while still allowing for some exploration.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=8
#   [LLM Reasoning] Although hypervolume is still increasing, the change is small and negative. Diversity has also dropped slightly. Given that both metrics are not improving strongly, I believe increasing 'L' will help to explore more solutions without sacrificing too much diversity. A larger value of 'L' may lead to a more comprehensive search.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 3/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MIXED, L: 4
#   [LLM Reasoning] While the high average profit and weight variances suggest a more explorative approach, the relatively low number of items (250) suggests that a more focused search is still needed to avoid getting stuck in local optima. A balanced strategy with L=4 will provide a good trade-off between exploration and exploitation.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=5
#   [LLM Reasoning] Although hypervolume is still decreasing, the change in hypervolume (-2673821.01) is quite significant. Diversity is also dropping (-395.83), which could lead to a loss of useful solutions. Given that hypervolume stagnation and diversity drop are both occurring, I will increase L slightly (from 4 to 5) to explore more without losing too much diversity.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=7
#   [LLM Reasoning] The hypervolume has increased significantly, which is great! However, the diversity metric has dropped a bit, which is concerning. Since both metrics are trending upward but not explosively so, I will increase L slightly to explore more and potentially improve the hypervolume even further without sacrificing too much diversity.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=8
#   [LLM Reasoning] The hypervolume is decreasing and diversity is dropping significantly. Considering the primary goal of increasing hypervolume, I believe increasing 'L' might help to explore new areas of the solution space and potentially increase the hypervolume again. Additionally, a small increase in 'L' will not lead to a significant loss of diversity.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 4/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MODERATE, L: 4
#   [LLM Reasoning] The problem has an average number of items (250) and a moderate capacity tightness (1.0). The variance in profit and weight is also moderate, suggesting that the problem is neither extremely tight nor loose. A moderate L value of 4 allows for some exploration while still focusing on local improvements.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=5
#   [LLM Reasoning] Hypervolume is decreasing and diversity is dropping significantly. To avoid further loss of diversity, I will decrease L by one unit to encourage a broader search while still exploring the current space.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=7
#   [LLM Reasoning] Hypervolume is improving significantly (1858525.22), which suggests that the current value of L is effective in exploring new solutions. However, diversity has dropped by 43.38, which indicates that the search might be getting stuck in local optima. To balance these two goals, I will increase L slightly to encourage further exploration while still maintaining some diversity.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=8
#   [LLM Reasoning] Although hypervolume has increased significantly, it's still growing at a relatively steady rate (382531). However, the recent drop in diversity (427.80) is concerning. To maintain some balance and potentially uncover more promising areas of the search space, I will increase 'L' by 1 to encourage exploration while keeping an eye on the diversity.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 5/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: EXPLORE, L: 5
#   [LLM Reasoning] High variance in both profit and weight suggests that the problem is non-trivial and may require some exploration to find better solutions. A moderate value of L (5) allows for a good balance between exploration and exploitation.
#   [Final Parameters] L=5, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=6
#   [LLM Reasoning] Hypervolume decreased significantly and diversity dropped moderately. Given the small negative change in hypervolume, I will increase L to explore more, hoping to regain some lost progress while still maintaining a reasonable level of diversity.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=7
#   [LLM Reasoning] The hypervolume has increased significantly, and while the diversity is also improving, it's not dropping significantly. Hypervolume stagnation could be a sign that the search is getting stuck in local optima. Increasing L by 1 should help explore more without sacrificing too much diversity.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=8
#   [LLM Reasoning] Although hypervolume is still decreasing, the decrease is relatively small compared to the previous iteration. Additionally, diversity has not dropped significantly, which suggests that we haven't lost too much exploration potential. Given this context, I will increase 'L' slightly to encourage more exploration and potentially escape local optima.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 6/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: EXPLORE_AND_EXPLOIT, L: 5
#   [LLM Reasoning] The problem has a relatively high capacity tightness and moderate variance in both profit and weight. While it's not extremely tight or loose, the moderate variance suggests that there may be some promising areas to explore, but also some potential local optima to avoid. A middle-of-the-road approach with L=5 seems suitable, allowing for a good balance between exploration and exploitation.
#   [Final Parameters] L=5, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=7
#   [LLM Reasoning] Hypervolume is decreasing significantly, indicating that the search might be getting stuck in local optima. Diversity is also dropping, which suggests that the algorithm is not exploring the solution space efficiently. Increasing L slightly to 7 will allow the algorithm to explore more and potentially escape from the current stagnation point without sacrificing too much diversity.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=8
#   [LLM Reasoning] Both hypervolume and diversity are improving, which is excellent! With a significant change in hypervolume (1650011.98) and a moderate gain in diversity (202.68), I will keep 'L' the same for now to maintain this momentum. A small increase might be too much risk, so I'll stick with the current value.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=10
#   [LLM Reasoning] The hypervolume has increased significantly since the last check, indicating that we are exploring new regions of the search space effectively. The diversity has also improved, which is a good sign that we're not getting stuck in local optima. Given these positive trends, I will increase L to 10 to continue exploring this promising area of the search space.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 7/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: FOCUSED, L: 2
#   [LLM Reasoning] Low variance in both profit and weight suggests a more focused search is suitable to exploit the problem's structure.
#   [Final Parameters] L=2, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=3
#   [LLM Reasoning] Hypervolume is dropping significantly, which means the search might be getting stuck in local optima. Increasing L by a small amount can help the search escape these local optima and potentially discover better solutions. Diversity is also dropping, but not as drastically. A slight increase in L will allow for some exploration while still maintaining some degree of diversity.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=4
#   [LLM Reasoning] The hypervolume has increased significantly (1977891.74), which aligns with my primary goal. However, the diversity metric has also improved by a moderate amount (321.20). Considering both metrics, I will increase 'L' to 4, slightly exploring more to maintain momentum and potentially discover better solutions while still keeping an eye on diversity.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=5
#   [LLM Reasoning] Hypervolume is decreasing, indicating that the current search might be stuck in a local optimum. To encourage exploration and potentially escape this stagnation, I'll decrease 'L' slightly to give the algorithm more flexibility while still keeping an eye on diversity.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 8/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: EXPLORE, L: 5
#   [LLM Reasoning] The problem has high variance in both profit and weight, indicating that the solution space is complex. A moderate level of exploration (L=5) is recommended to effectively explore this space and find a good initial solution.
#   [Final Parameters] L=5, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=7
#   [LLM Reasoning] The hypervolume has decreased significantly, indicating that the current value of L may be too small to effectively explore the search space. Meanwhile, the diversity has also dropped, but not as severely. To strike a balance between exploration and exploitation, I will increase L slightly to 7. This should allow the search to move forward without sacrificing too much diversity.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=8
#   [LLM Reasoning] The hypervolume has increased significantly, which is great! However, the diversity metric has also improved, albeit modestly. Considering both goals, I think it's safe to increase L slightly to maintain momentum in exploring new solutions while still keeping an eye on maintaining a reasonable level of diversity.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=9
#   [LLM Reasoning] Although hypervolume is increasing, the change is not dramatic. Diversity is also dropping slightly, which may indicate that we are getting stuck in a local optimum. I will increase L to 9 to explore more and potentially escape this stagnation without sacrificing too much diversity.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 9/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: BALANCED, L: 4
#   [LLM Reasoning] The problem has a moderate capacity tightness and variances. A balanced approach with L=4 is recommended to strike a balance between exploration and exploitation.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=5
#   [LLM Reasoning] The hypervolume has decreased significantly, which suggests that the search is getting stuck and needs a bit more exploration. The diversity has also dropped, but not drastically. To balance both goals, I will decrease L slightly to give the search some more freedom without sacrificing too much diversity.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=7
#   [LLM Reasoning] Both hypervolume and diversity are improving. Since the change in hypervolume is substantial (1.9 million), I'll keep 'L' at its current value for now. A small increase might not yield significant additional gains. If hypervolume stagnates or diversity drops significantly in future iterations, I'll reassess.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=8
#   [LLM Reasoning] Hypervolume is decreasing, indicating that the search may be getting stuck in a local optimum. Diversity is also dropping, which could further exacerbate this issue. I will increase L to encourage more exploration and potentially find better solutions.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 10/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: EXPLORATIVE, L: 12
#   [LLM Reasoning] Both high num_items and variance in both profit and weight suggest that the problem is complex and requires a more explorative approach to effectively search for the optimal solution.
#   [Final Parameters] L=12, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=15
#   [LLM Reasoning] Although hypervolume has been decreasing, it was still a significant drop (-2235076.86). Additionally, diversity has decreased significantly (-319.85), which is concerning. To balance both objectives, I will increase L slightly to explore more without losing too much diversity.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=17
#   [LLM Reasoning] Hypervolume is increasing significantly and diversity has also improved. Since both metrics are on an upward trend, I can make a small adjustment to 'L' while still exploring the search space effectively. An increase of 2 will allow for further exploration without sacrificing too much diversity.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=19
#   [LLM Reasoning] Although the hypervolume decreased slightly, it's still relatively high compared to the previous values. The diversity is also improving slowly. Considering that the change in diversity is not significant, I will increase L by 2 to explore more and potentially find better solutions. This should give us a good balance between exploring new areas of the search space and maintaining some level of diversity.
#   [Run Summary] LLM calls this run: 1
#
# Total execution time: 840.62 seconds
# Average time per run: 84.06 seconds
# Finished experiment for 250 items.
# ======================================================
#
# ======================================================
# Starting experiment for 500 items...
#
# --- RUN 1/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MODERATE, L: 4
#   [LLM Reasoning] The problem has a moderate level of variance in both profit and weight (681.29 and 672.18 respectively), indicating a balanced trade-off between diversity and focus. A moderate value for L, 4, provides a suitable balance between exploration and exploitation.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=5
#   [LLM Reasoning] The hypervolume has increased significantly, which is a good sign. However, the diversity metric has also improved, indicating that we're not sacrificing exploration for exploitation. Since both metrics are improving, I will keep 'L' at its current value of 4 and make only a small adjustment to ensure we continue exploring the space efficiently.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=7
#   [LLM Reasoning] Hypervolume has not changed, indicating stagnation. Diversity is still the same as well, which suggests that we're not exploring new areas of the search space. Given this situation, I will increase L slightly to explore more and potentially find better solutions. A small increase should allow us to venture into unexplored regions without sacrificing too much diversity.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=8
#   [LLM Reasoning] Hypervolume is not changing and diversity is stable. Increasing 'L' by one may help to explore new regions in the solution space, potentially leading to a larger hypervolume while maintaining current diversity level.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 2/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: AGGRESSIVE, L: 4
#   [LLM Reasoning] The high average profit and weight variances (681.29 and 672.18 respectively) suggest that the problem has a complex structure and may benefit from an exploratory search strategy to avoid getting stuck in local optima.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=5
#   [LLM Reasoning] Both hypervolume and diversity are improving, so I will keep 'L' the same for now. The change in hypervolume is significant and diversity has also increased, indicating that we're exploring the search space effectively. A small adjustment might not be necessary at this point.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=6
#   [LLM Reasoning] The hypervolume has seen a significant increase (8673366.94), which is my primary goal. However, the diversity metric has also improved by a substantial amount (728.49). Although it's not ideal to decrease 'L' now, I'm cautious since both metrics are trending upwards. To maintain this momentum and continue exploring without sacrificing too much diversity, I will increase 'L' slightly from 5 to 6.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=7
#   [LLM Reasoning] Hypervolume is stagnant and decreasing, so it's time to increase the exploration space by increasing L. The diversity is still relatively high, so a small increase in L should not significantly harm the diversity. I'll keep a close eye on both metrics to ensure this decision doesn't backfire.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 3/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MIXED, L: 4
#   [LLM Reasoning] While the problem has a high capacity tightness, indicating a need for some exploration, the average profit and weight variances are relatively low. This suggests that there is still value in focusing on local improvements. A moderate L value of 4 strikes a balance between exploration and exploitation.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=5
#   [LLM Reasoning] Hypervolume is decreasing significantly and diversity has dropped substantially. To encourage a broader search while still exploring new solutions, I will decrease 'L' by one unit.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=7
#   [LLM Reasoning] Hypervolume is not changing significantly, and neither is diversity. Increasing L by 2 might help explore new areas of the solution space, potentially leading to improved hypervolume without sacrificing diversity too much.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=8
#   [LLM Reasoning] Hypervolume is stagnating with no change in the last iteration. Increasing L by 1 will give the search a boost to explore new solutions and potentially improve hypervolume. Since diversity is still high at 25.55, I'm not too concerned about losing it.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 4/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MODERATE, L: 4
#   [LLM Reasoning] Average capacity tightness and moderate variance suggest a balanced approach. The problem is not too tight or loose, and the variances are not extremely high, so a moderate level of exploration is suitable.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=5
#   [LLM Reasoning] The hypervolume has increased significantly, which is a strong indication that the search is exploring new and diverse solutions. The diversity metric has also improved, indicating that the search is not getting stuck in local optima. Since both metrics are improving, I will keep 'L' at its current value for now, but slightly decrease it to maintain some degree of exploration.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=7
#   [LLM Reasoning] Both hypervolume and diversity have increased significantly since the last check. Since both metrics are improving, I can afford to make a small adjustment by increasing 'L' to explore even further while maintaining or potentially improving diversity.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=8
#   [LLM Reasoning] Although hypervolume is still decreasing, the rate of decrease has slowed down and it's not a significant drop. Additionally, diversity hasn't taken a drastic hit either. Considering the primary goal to increase hypervolume, I will increase L slightly to explore more possibilities without sacrificing too much diversity.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 5/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MODERATE, L: 4
#   [LLM Reasoning] Average capacity tightness and variance suggest a balance between exploration and exploitation. A moderate L value allows for some exploration while still focusing on promising areas of the search space.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=5
#   [LLM Reasoning] Hypervolume is still decreasing, which suggests that the current value of L may be too low and causing the search to get stuck in local optima. However, diversity has also decreased significantly, so increasing L could potentially lead to a broader search that explores more of the solution space. Given these circumstances, I will increase L slightly to 5, hoping to strike a balance between exploration and exploitation.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=7
#   [LLM Reasoning] The hypervolume has increased significantly, which is great! However, the diversity has also dropped by a significant amount, which could be problematic in the long run. Considering both metrics, I will increase L to 7, which should allow us to explore more without losing too much diversity. This adjustment should keep the hypervolume growth momentum going while maintaining some level of diversity.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=8
#   [LLM Reasoning] Although hypervolume is still increasing, the change is relatively small and negative diversity change might indicate a loss of exploration. Increasing 'L' by one could bring new solutions that improve overall performance and maintain diversity levels.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 6/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: EXPLORE_MORE, L: 6
#   [LLM Reasoning] High variance in both profit and weight indicates a need for more explorative moves to effectively search the solution space. The moderate capacity tightness suggests that some exploration is necessary to avoid getting stuck in local optima.
#   [Final Parameters] L=6, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=8
#   [LLM Reasoning] Hypervolume is stagnating with a negative change of -9683905.14. While diversity is dropping significantly as well, the current value of 'L' at 6 seems to be causing some focus in the search, which is reflected in the hypervolume increase initially. I will increase 'L' slightly to 8 to explore more and potentially regain momentum in hypervolume, while still maintaining a reasonable level of diversity.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=10
#   [LLM Reasoning] The hypervolume has increased significantly, which is great. However, the diversity metric has also improved substantially. This suggests that the current value of 'L' (8) is still allowing for a good balance between exploration and exploitation. Therefore, I will keep increasing 'L' slightly to continue exploring new areas in solution space while maintaining the high level of diversity.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=12
#   [LLM Reasoning] Although hypervolume is still increasing, the change is relatively small (-8113.00). Diversity has also dropped significantly (-29.00), which could indicate that we are getting stuck in local optima. Given these metrics, I will increase L to 12 to explore more and potentially find better solutions without sacrificing too much diversity.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 7/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: FOCUSED, L: 2
#   [LLM Reasoning] Low average profit and weight variances indicate a relatively stable problem instance. With a high number of items (500), it's best to start with a focused search approach that builds upon the initial solution, gradually exploring neighboring solutions.
#   [Final Parameters] L=2, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=4
#   [LLM Reasoning] Hypervolume is decreasing significantly, which is a concern. However, the drop in diversity is not extreme, so I don't want to over-correct by decreasing L too much. Increasing L slightly will allow for more exploration and potentially jump out of this local optima, while still maintaining some diversity.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=5
#   [LLM Reasoning] The hypervolume has significantly increased while the diversity has also improved. However, there's still room for growth in both metrics. I'll keep the parameter 'L' at 4 and continue exploring this promising direction, as small adjustments will not compromise the current progress.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=6
#   [LLM Reasoning] The hypervolume is still increasing, albeit at a slower rate. The diversity has dropped slightly, which is concerning. Given the small drop in diversity and considering that the hypervolume was stagnating before, I will increase L to 6 to explore more without sacrificing too much diversity.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 8/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: AGGRESSIVE, L: 4
#   [LLM Reasoning] While the problem has a high number of items and objectives, the capacity tightness is relatively high. This suggests that there may be multiple optimal solutions, making it more likely that a more explorative approach will find the global optimum.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=5
#   [LLM Reasoning] Hypervolume is decreasing, which suggests that the search might be getting stuck in a local optimum. However, diversity is still dropping significantly, which could lead to a loss of good solutions. To strike a balance between exploration and exploitation, I will decrease L slightly to encourage a broader search while trying to maintain some focus.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=7
#   [LLM Reasoning] The hypervolume has increased significantly, which is great! However, the diversity has also decreased by a decent amount, which might lead to stagnation in future iterations. I will increase L slightly to explore more and potentially regain some of the lost diversity. The current L value of 5 seems to be working well for increasing the hypervolume, so I'll give it another small bump.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=8
#   [LLM Reasoning] The hypervolume is still increasing, albeit slowly, which suggests that we are not yet saturating the search space. However, diversity has dropped significantly, which is a cause for concern. To strike a balance between exploration and exploitation, I will increase L to 8 to encourage more exploration while trying to maintain some of the diversity.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 9/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: FOCUSED, L: 2
#   [LLM Reasoning] Low variance in both profit and weight suggests a stable problem that can be efficiently solved with a focused approach.
#   [Final Parameters] L=2, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=3
#   [LLM Reasoning] Both hypervolume and diversity have decreased significantly. Since the primary goal is to increase hypervolume, I will decrease 'L' slightly to encourage a broader search that may help revitalize the stagnated hypervolume without sacrificing too much diversity.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=4
#   [LLM Reasoning] The hypervolume is improving significantly (9379877.40) and the diversity has increased as well (674.30). However, since both metrics are still showing a decent change, I will keep 'L' at its current value of 3 for now to avoid making any drastic changes. A small increase might also help maintain this trend.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=5
#   [LLM Reasoning] Hypervolume is decreasing, indicating that the search might be getting stuck in a local optimum. Despite this, diversity has only dropped by a small amount, which suggests that increasing L might help to explore new regions of the solution space without sacrificing too much diversity.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 10/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: FOCUSED, L: 2
#   [LLM Reasoning] Low capacity tightness and low variance suggest a more focused approach is suitable for this problem instance.
#   [Final Parameters] L=2, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=3
#   [LLM Reasoning] Hypervolume is decreasing and diversity is also dropping significantly. Increasing L would help to explore the search space further, which might lead to a larger hypervolume. However, I will only increase L slightly to avoid losing too much diversity.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=4
#   [LLM Reasoning] The hypervolume has increased significantly, which is a good sign. However, the diversity metric has also improved, indicating that we are exploring new areas of the search space. Since both metrics are improving, I will keep L at its current value and make no changes for now.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=5
#   [LLM Reasoning] Hypervolume is decreasing and diversity is dropping as well. Although both metrics are not improving, the decrease in hypervolume might be due to a less diverse search space. Increasing L slightly to explore more could help revitalize the search without sacrificing too much diversity.
#   [Run Summary] LLM calls this run: 1
#
# Total execution time: 787.88 seconds
# Average time per run: 78.79 seconds
# Finished experiment for 500 items.
# ======================================================
#
# ======================================================
# Starting experiment for 750 items...
#
# --- RUN 1/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MODERATE, L: 4
#   [LLM Reasoning] Average capacity tightness and moderate variance suggest a balanced approach between exploration and exploitation.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=5
#   [LLM Reasoning] Hypervolume is increasing significantly, indicating a good direction in the search. Diversity is also improving, which suggests that the current parameter settings are allowing for a decent exploration of the solution space. Since both metrics are improving, I will keep L at its current value (4) and only slightly increase it to 5. This will allow us to continue exploring the promising directions without losing too much diversity.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=7
# ...
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: FOCUSED, L: 2
#   [LLM Reasoning] Low variance in both profit and weight suggests a more focused approach is suitable for this instance.
#   [Final Parameters] L=2, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=4
#   [LLM Reasoning] The hypervolume is significantly decreasing, which suggests that the search might be stuck in a local optimum. The diversity has also decreased, but it's still relatively high compared to its previous value. Considering the primary goal of increasing hypervolume and the secondary goal of maintaining diversity, I will decrease 'L' slightly to encourage a more focused search while still allowing for some exploration.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=5
#   [LLM Reasoning] Hypervolume has not changed and the search may be getting stuck in a local optimum. Increasing 'L' by one should help to explore more possibilities without sacrificing too much diversity, which is still relatively high at 63.88.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=7
#   [LLM Reasoning] Hypervolume is stagnant and there's no significant change in diversity either. To explore more, I'll increase L by 2, which should help find better solutions while still maintaining the existing diversity.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 5/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MODERATE, L: 4
#   [LLM Reasoning] The problem has a moderate level of capacity tightness (1.0) and variance in both profit (703.64) and weight (687.3), suggesting that neither extreme exploration nor exploitation is necessary.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=5
#   [LLM Reasoning] The hypervolume has increased significantly, indicating that we are exploring new and potentially better regions of the search space. However, the diversity metric has also improved, suggesting that we are still maintaining a good spread of solutions. Given this situation, I will keep 'L' at its current value of 4 for now, as increasing it to 5 might cause us to lose some of the diversity we have gained.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=7
#   [LLM Reasoning] The hypervolume is increasing significantly, indicating that the current value of 'L' is still beneficial. However, the diversity has also improved by a substantial margin. Considering these factors, I will increase 'L' slightly to 7, hoping to maintain the growth in both metrics without sacrificing too much diversity.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=8
#   [LLM Reasoning] The hypervolume has stagnated with a small negative change, indicating that the search is not exploring new solutions efficiently. The diversity metric has also dropped slightly, but it's not a significant drop. Considering this information, I will increase L to 8 to encourage the search to explore more and potentially find better solutions while maintaining a reasonable level of diversity.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 6/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: EXPLORE, L: 5
#   [LLM Reasoning] High variance in both profit and weight suggests a more explorative approach to balance the trade-off between objective values.
#   [Final Parameters] L=5, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=7
#   [LLM Reasoning] Hypervolume is decreasing and diversity is also dropping significantly. To maintain or improve diversity, I will increase 'L' by a small amount to encourage the search to explore more but not lose its focus entirely.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=8
#   [LLM Reasoning] Both hypervolume and diversity are increasing, which is great! Considering the significant change in hypervolume, I think it's safe to keep exploring with a larger 'L'. A small increase should not significantly impact diversity, but still allow for more exploration. Let's see how the search performs with this new value.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=9
#   [LLM Reasoning] Both hypervolume and diversity are improving, which is great! However, the change in hypervolume could be larger if 'L' were increased. I will increase L slightly to explore more while maintaining a good level of diversity.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 7/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MODERATE, L: 5
#   [LLM Reasoning] The problem has a moderate number of items and objectives, but high variance in both profit and weight. This suggests that the search should be moderately exploratory to balance the need for broad exploration with the need for focused exploitation.
#   [Final Parameters] L=5, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=6
#   [LLM Reasoning] Hypervolume is decreasing, which means the search is not exploring new regions efficiently enough. However, diversity has also decreased, which could be a sign of getting stuck in local optima. I will increase L slightly to explore more and potentially find better solutions without sacrificing too much diversity.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=8
#   [LLM Reasoning] The hypervolume has increased significantly, indicating that the search is still exploring new regions of the solution space. The diversity has also improved, suggesting that the increased value of 'L' is not causing a focused search at the expense of diversity. Given these positive trends, I will increase 'L' to 8 to continue exploring and potentially find even better solutions.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=9
#   [LLM Reasoning] The hypervolume is still decreasing, which suggests that the search may be getting stuck in a local optimum. Increasing L to 9 could help escape this stagnation by introducing more possible solutions. Although diversity has also decreased, the drop is not significant enough to warrant a decrease in L yet.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 8/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: FLEXIBLE, L: 4
#   [LLM Reasoning] Moderate capacity tightness and high variances in profit and weight suggest a balanced approach. The flexible strategy strikes a balance between exploration and exploitation, allowing for some flexibility in the search process.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=5
#   [LLM Reasoning] Hypervolume is dropping significantly, which suggests that the search may be getting stuck in local optima. Diversity is also decreasing, which could indicate a loss of exploration. To balance these two goals, I will decrease L slightly to allow for more focused exploration and potentially improve diversity while still maintaining some room for hypervolume growth.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=7
#   [LLM Reasoning] Both hypervolume and diversity are improving significantly. However, I notice that the change in diversity is substantial, which might indicate that the search is becoming less focused. To balance exploration and exploitation, I will increase L slightly to encourage a bit more diversification without sacrificing too much progress.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=8
#   [LLM Reasoning] Although hypervolume is still increasing, the change is relatively small. Meanwhile, diversity has taken a moderate hit. Given these trends, I think it's reasonable to slightly increase 'L' to encourage more exploration and potentially uncover new areas of the solution space that could lead to further hypervolume growth. A smaller step up in 'L' should help maintain some diversity while still allowing for a broader search.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 9/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: FOCUSED, L: 3
#   [LLM Reasoning] Low capacity tightness and moderate variance suggest a focused search is suitable to exploit the good solutions already found.
#   [Final Parameters] L=3, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=4
#   [LLM Reasoning] Hypervolume is decreasing and diversity is dropping significantly. Since hypervolume is not improving, I will decrease 'L' to encourage a broader search that can potentially find better solutions while still maintaining some diversity.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=5
#   [LLM Reasoning] The hypervolume has increased significantly, which is good for the primary goal. However, the diversity has also decreased by a significant amount, which could lead to stagnation in the search. Considering both goals, I will keep 'L' at its current value of 4 and not increase it further. This should allow the search to continue exploring new solutions while still maintaining some level of diversity.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=7
#   [LLM Reasoning] Hypervolume is still improving, albeit slowly. Diversity has also maintained a relatively steady pace, with only a small drop. Considering the stagnation in hypervolume and the lack of significant diversity loss, I will increase L slightly to explore more and potentially further improve the hypervolume.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 10/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: EXPLORE_AND_EXPLOIT, L: 4
#   [LLM Reasoning] Moderate L value is suitable for a problem with moderate variance in both profit and weight. The number of items to try swapping during local search is balanced between exploration and exploitation, allowing for a good trade-off between exploring the solution space and refining a promising region.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 25: New L=5
#   [LLM Reasoning] The hypervolume is decreasing, which suggests that the search may be getting stuck in a local optimum. The diversity is also dropping significantly, but not as drastically as the hypervolume. I will decrease L slightly to encourage a broader search and potentially explore new areas of the solution space.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 50: New L=6
#   [LLM Reasoning] Hypervolume increased significantly and diversity also improved moderately. Since both metrics are moving in the right direction, I'll keep 'L' at the same level for now, expecting further exploration to bring even more improvement.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision V6.1] Iteration 75: New L=7
#   [LLM Reasoning] Although hypervolume is improving, the change is not significant enough to suggest 'L' should be decreased or kept at its current value. Diversity has dropped slightly as well, which indicates that the search might be getting stuck in local optima. To explore more while minimizing the loss of diversity, I will increase 'L' to 7.
#   [Run Summary] LLM calls this run: 1
#
# Total execution time: 808.56 seconds
# Average time per run: 80.86 seconds
# Finished experiment for 750 items.
# ======================================================
#
#
# All efficient experiments finished.
# The following result files have been created:
# - 2502_Results_Strategist_v5.txt
# - 5002_Results_Strategist_v5.txt
# - 7502_Results_Strategist_v5.txt
#
# You can now run the analysis cells to compare the new results.

# %%
# Test with 750 items, 2 objectives
print("\n======================================================")
print("Starting experiment for 750 items...")
run_efficient_llm_moacp_v5(b"750.2.txt", b"Weights_2obj_FQ200.txt", 750, 2, "7502_Results_Strategist_v7.txt")
print("Finished experiment for 750 items.")
print("======================================================")

# %%
# =========================================================================
# PART 7: RESULTS COMPARISON AND ANALYSIS (Fixed for V6)
# =========================================================================

import matplotlib.pyplot as plt
import numpy as np

def dominates(a, b):
    """Returns True if a dominates b (maximization for both objectives)."""
    return all(x >= y for x, y in zip(a, b)) and any(x > y for x, y in zip(a, b))

def get_true_pareto_front(points):
    """Extract the true Pareto front from a set of points."""
    pareto = []
    for i, p in enumerate(points):
        dominated = False
        for j, q in enumerate(points):
            if i != j and dominates(q, p):
                dominated = True
                break
        if not dominated:
            pareto.append(p)
    return pareto

def calculate_hypervolume(points):
    """Calculate a simplified hypervolume metric for comparison."""
    if not points:
        return 0.0
    
    # Find a reference point that is slightly worse than the worst point in all objectives
    ref_x = max(p[0] for p in points) * 1.1
    ref_y = max(p[1] for p in points) * 1.1
    
    # Sort points by the first objective to calculate the area under the curve
    sorted_points = sorted(points, key=lambda p: p[0])
    
    hv = 0.0
    for i in range(len(sorted_points) - 1):
        x1, y1 = sorted_points[i]
        x2, y2 = sorted_points[i + 1]
        # Area of the rectangle between two points on the front
        hv += (x2 - x1) * (ref_y - y1)
    
    # Add the area of the last rectangle to the reference point
    if sorted_points:
        x_last, y_last = sorted_points[-1]
        hv += (ref_x - x_last) * (ref_y - y_last)
    
    return hv

def compare_baseline_vs_strategist(original_file, strategist_v6_file, title):
    """
    Compare the original baseline results with the new LLM-Strategist V6 results.
    """
    print(f"\n--- Analyzing {title} ---")
    
    # --- Load and Process Original Results ---
    original_points = []
    try:
        with open(original_file, "r") as f:
            for line in f:
                line = line.strip()
                if line and not line.startswith("#"):
                    try:
                        original_points.append([float(x) for x in line.split()])
                    except ValueError:
                        pass # Skip malformed lines
    except FileNotFoundError:
        print(f"  [ERROR] Original file not found: {original_file}")
        return None

    # --- Load and Process Strategist V6 Results ---
    strategist_v6_points = []
    try:
        with open(strategist_v6_file, "r") as f:
            for line in f:
                line = line.strip()
                if line and not line.startswith("#"):
                    try:
                        strategist_v6_points.append([float(x) for x in line.split()])
                    except ValueError:
                        pass # Skip malformed lines
    except FileNotFoundError:
        print(f"  [ERROR] Strategist V6 file not found: {strategist_v6_file}")
        return None

    # --- Calculate Pareto Fronts and Metrics ---
    original_pareto = get_true_pareto_front(original_points)
    strategist_v6_pareto = get_true_pareto_front(strategist_v6_points)
    
    original_size = len(original_pareto)
    strategist_v6_size = len(strategist_v6_pareto)
    
    original_hv = calculate_hypervolume(original_pareto)
    strategist_v6_hv = calculate_hypervolume(strategist_v6_pareto)
    
    # --- Calculate Percentage Improvements ---
    size_improvement = (strategist_v6_size - original_size) / original_size * 100 if original_size > 0 else 0
    hv_improvement = (strategist_v6_hv - original_hv) / original_hv * 100 if original_hv > 0 else 0
    
    # --- Print Results ---
    print(f"  Original Algorithm:")
    print(f"    Pareto Front Size: {original_size}")
    print(f"    Hypervolume: {original_hv:.2f}")
    print(f"  LLM-Strategist V6 (Adaptive):")
    print(f"    Pareto Front Size: {strategist_v6_size} ({size_improvement:+.2f}%)")
    print(f"    Hypervolume: {strategist_v6_hv:.2f} ({hv_improvement:+.2f}%)")
    
    # --- Plotting ---
    plt.figure(figsize=(10, 8))
    
    if original_pareto:
        ox, oy = zip(*original_pareto)
        plt.scatter(ox, oy, color='blue', alpha=0.6, s=50, label="Original Baseline")
    if strategist_v6_pareto:
        sx, sy = zip(*strategist_v6_pareto)
        plt.scatter(sx, sy, color='red', marker='x', s=50, alpha=0.8, label="LLM-Strategist V6 (Adaptive)")

    plt.xlabel("Objective 1 (Profit 1)", fontsize=12)
    plt.ylabel("Objective 2 (Profit 2)", fontsize=12)
    plt.title(f"{title} - Pareto Front Comparison", fontsize=16)
    plt.legend(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()
    
    return {
        "title": title,
        "original_size": original_size,
        "strategist_v6_size": strategist_v6_size,
        "size_improvement": size_improvement,
        "original_hv": original_hv,
        "strategist_v6_hv": strategist_v6_hv,
        "hv_improvement": hv_improvement
    }

# --- MAIN EXECUTION ---
print("Starting results analysis: Original Baseline vs. LLM-Strategist V6 (Adaptive)...")

# Define the file names for comparison
files_to_compare = [
    {
        "original": "2502_ResultsMD.txt",
        "strategist": "2502_Results_Strategist_v6.1.txt",
        "title": "250-Item Problem"
    },
    {
        "original": "5002_ResultsMD.txt",
        "strategist": "5002_Results_Strategist_v6.1.txt",
        "title": "500-Item Problem"
    },
    {
        "original": "7502_ResultsMD.txt",
        "strategist": "7502_Results_Strategist_v6.1.txt",
        "title": "750-Item Problem"
    }
]

all_results = []
for files in files_to_compare:
    result = compare_baseline_vs_strategist(
        files["original"], 
        files["strategist"], 
        files["title"]
    )
    if result:
        all_results.append(result)

# --- Summary of Improvements ---
print("\n" + "="*50)
print("              SUMMARY OF IMPROVEMENTS (V6)")
print("="*50)

if all_results:
    total_hv_improvement = 0
    for res in all_results:
        print(f"\n{res['title']}:")
        print(f"  Hypervolume Improvement: {res['hv_improvement']:+.2f}%")
        total_hv_improvement += res['hv_improvement']

    avg_hv_improvement = total_hv_improvement / len(all_results)
    
    print("\n" + "-"*50)
    print(f"  AVERAGE HV IMPROVEMENT: {avg_hv_improvement:+.2f}%")
    print("-"*50)
else:
    print("\nCould not generate a summary as no results were successfully analyzed.")

print("\nAnalysis complete.")
# Out:
# Starting results analysis: Original Baseline vs. LLM-Strategist V6 (Adaptive)...
#
# --- Analyzing 250-Item Problem ---
#   Original Algorithm:
#     Pareto Front Size: 212
#     Hypervolume: 6614986.88
#   LLM-Strategist V6 (Adaptive):
#     Pareto Front Size: 216 (+1.89%)
#     Hypervolume: 6754690.96 (+2.11%)
# --- Analyzing 500-Item Problem ---
#   Original Algorithm:
#     Pareto Front Size: 369
#     Hypervolume: 23044962.94
#   LLM-Strategist V6 (Adaptive):
#     Pareto Front Size: 361 (-2.17%)
#     Hypervolume: 23899551.64 (+3.71%)
# --- Analyzing 750-Item Problem ---
#   Original Algorithm:
#     Pareto Front Size: 552
#     Hypervolume: 56877706.67
#   LLM-Strategist V6 (Adaptive):
#     Pareto Front Size: 523 (-5.25%)
#     Hypervolume: 57161384.67 (+0.50%)
# ==================================================
#               SUMMARY OF IMPROVEMENTS (V6)
# ==================================================
#
# 250-Item Problem:
#   Hypervolume Improvement: +2.11%
#
# 500-Item Problem:
#   Hypervolume Improvement: +3.71%
#
# 750-Item Problem:
#   Hypervolume Improvement: +0.50%
#
# --------------------------------------------------
#   AVERAGE HV IMPROVEMENT: +2.11%
# --------------------------------------------------
#
# Analysis complete.

# %%
# Simple test to see if the module exists and can be imported
try:
    import optimized_moacp_cython
    print("✅ Module imported successfully.")
    print("Functions available:", dir(optimized_moacp_cython))
except ImportError as e:
    print(f"❌ ImportError: {e}")
except Exception as e:
    print(f"❌ Other error: {e}")
# Out:
# ✅ Module imported successfully.
# Functions available: ['__builtins__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '__test__', 'get_L', 'get_alpha', 'get_kappa', 'np', 'run_optimized_cython_moacp', 'seed', 'set_L', 'set_alpha', 'set_kappa', 'set_smallValue', 'time']

# %%
import optimized_moacp_cython as omc
print(dir(omc))
# Out:
# ['__builtins__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '__test__', 'get_L', 'get_alpha', 'get_kappa', 'np', 'run_optimized_cython_moacp', 'seed', 'set_L', 'set_alpha', 'set_kappa', 'set_smallValue', 'time']

# %%
import optimized_moacp_cython as omc

for fn in [
    "set_alpha", "set_kappa", "set_L", "set_smallValue",
    "set_mutation_rate", "set_local_search_intensity",
    "set_greedy_bias", "set_repair_aggressiveness"
]:
    print(fn, hasattr(omc, fn))
# Out:
# set_alpha True
# set_kappa True
# set_L True
# set_smallValue True
# set_mutation_rate False
# set_local_search_intensity False
# set_greedy_bias False
# set_repair_aggressiveness False

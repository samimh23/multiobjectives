# %%
# %load_ext cython
# Out:
# The cython extension is already loaded. To reload it, use:
#   %reload_ext cython

# %%
import numpy as np

def load_profits_from_file(filename, num_objectives, num_items):
    profits = np.zeros((num_objectives, num_items))
    with open(filename, 'r') as f:
        lines = [line.strip() for line in f if line.strip()]
    idx = 1  # skip header
    for obj in range(num_objectives):
        idx += 1  # skip capacity line
        for item in range(num_items):
            idx += 1  # skip "n:" line
            idx += 1  # skip weight
            profit = int(lines[idx])
            profits[obj, item] = profit
            idx += 1
    return profits

def load_weights_from_file(filename, num_objectives, num_items):
    weights = np.zeros((num_objectives, num_items), dtype=int)
    with open(filename, 'r') as f:
        lines = [line.strip() for line in f if line.strip()]
    idx = 1  # skip header
    for obj in range(num_objectives):
        idx += 1  # skip capacity line
        for item in range(num_items):
            idx += 1  # skip "n:" line
            weight = int(lines[idx])
            weights[obj, item] = weight
            idx += 2  # skip profit
    return weights

def load_capacities_from_file(filename, num_objectives, num_items):
    with open(filename, 'r') as f:
        lines = [line.strip() for line in f if line.strip()]
    idx = 1  # skip header
    capacities = []
    for obj in range(num_objectives):
        cap = float(lines[idx])
        capacities.append(cap)
        idx += 1 + 3 * num_items
    return np.array(capacities)

# %%
import numpy as np

class SmartAgent:
    def __init__(self, nbitems, num_objectives, profits, weights, capacities):
        self.nbitems = nbitems
        self.num_objectives = num_objectives
        self.profits = profits
        self.weights = weights
        self.capacities = capacities
        self.move_types = ["local_search", "global_search", "follow", "mutation", "diversity"]
        self.move_counts = {k: 1 for k in self.move_types}
        self.move_successes = {k: 1 for k in self.move_types}
        self.move_probs = np.array([0.25, 0.20, 0.15, 0.15, 0.25], dtype=np.float64)
        self.best_observation = None
        self.last_move_type = None

    def observe(self, state):
        return np.array(state["Items"], dtype=np.int32)

    def act(self, observation, context=None):
        archive_objs = None
        if context is not None and "archive_objs" in context:
            archive_objs = context["archive_objs"]
        move_idx = np.random.choice(len(self.move_types), p=self.move_probs)
        move_type = self.move_types[move_idx]
        self.last_move_type = move_type

        # Diversity move logic
        if move_type == "diversity" and archive_objs is not None and self.profits is not None:
            move = self.diversity_move(observation, archive_objs)
            if move is not None:
                return move

        # Try move heuristics
        for _ in range(30):
            if move_type == "local_search":
                move = self.local_search_move(observation)
            elif move_type == "global_search":
                move = self.global_search_move(observation)
            elif move_type == "follow":
                move = self.follow_move(observation)
            elif move_type == "mutation":
                move = self.mutation_move(observation)
            else:
                continue  # If "diversity" move failed, skip

            if self._is_feasible(observation, move):
                return move

        # Fallback to feasible random mutation
        for _ in range(60):
            move = self.mutation_move(observation)
            if self._is_feasible(observation, move):
                return move

        return (0, 0)

    def report_move_result(self, move_type, success):
        if move_type is None:
            move_type = self.last_move_type
        if move_type not in self.move_types:
            return
        self.move_counts[move_type] += 1
        if success:
            self.move_successes[move_type] += 1

        # Softmax update of move probabilities
        rates = np.array(
            [self.move_successes[k] / self.move_counts[k] for k in self.move_types],
            dtype=np.float64,
        )
        exp_rates = np.exp(rates / 0.1)
        new_probs = exp_rates / np.sum(exp_rates)
        self.move_probs = 0.5 * self.move_probs + 0.5 * new_probs
        self.move_probs = self.move_probs / np.sum(self.move_probs)

    def update_best(self, observation):
        self.best_observation = observation.copy()

    def meta_adapt(self, meta_info: dict):
        # Optional meta-adapt hook
        pass

    # --- Heuristic Moves ---

    def local_search_move(self, observation):
        items_selected = np.where(observation == 1)[0]
        items_unselected = np.where(observation == 0)[0]
        if len(items_selected) == 0 or len(items_unselected) == 0 or self.profits is None:
            return 0, 0
        profs_selected = np.sum(self.profits[:, items_selected], axis=0)
        profs_unselected = np.sum(self.profits[:, items_unselected], axis=0)
        remove_idx = items_selected[np.argmin(profs_selected)]
        add_idx = items_unselected[np.argmax(profs_unselected)]
        return int(remove_idx), int(add_idx)

    def global_search_move(self, observation):
        items_selected = np.where(observation == 1)[0]
        items_unselected = np.where(observation == 0)[0]
        if len(items_selected) == 0 or len(items_unselected) == 0 or self.profits is None:
            return 0, 0
        profs_selected = np.sum(self.profits[:, items_selected], axis=0)
        profs_unselected = np.sum(self.profits[:, items_unselected], axis=0)
        ps = profs_selected + 1e-9
        pu = profs_unselected + 1e-9
        remove_idx = np.random.choice(items_selected, p=ps / np.sum(ps))
        add_idx = np.random.choice(items_unselected, p=pu / np.sum(pu))
        return int(remove_idx), int(add_idx)

    def follow_move(self, observation):
        if self.best_observation is None:
            return self.mutation_move(observation)
        diff = self.best_observation - observation
        add_candidates = np.where((diff == 1) & (observation == 0))[0]
        remove_candidates = np.where((diff == -1) & (observation == 1))[0]
        if len(add_candidates) == 0 or len(remove_candidates) == 0:
            return self.mutation_move(observation)
        add_idx = np.random.choice(add_candidates)
        remove_idx = np.random.choice(remove_candidates)
        return int(remove_idx), int(add_idx)

    def mutation_move(self, observation):
        items_selected = np.where(observation == 1)[0]
        items_unselected = np.where(observation == 0)[0]
        if len(items_selected) == 0 or len(items_unselected) == 0:
            return 0, 0
        remove_idx = int(np.random.choice(items_selected))
        add_idx = int(np.random.choice(items_unselected))
        return remove_idx, add_idx

    def diversity_move(self, observation, archive_objs):
        best_move = None
        best_min_dist = -np.inf
        items_selected = np.where(observation == 1)[0]
        items_unselected = np.where(observation == 0)[0]
        if len(items_selected) == 0 or len(items_unselected) == 0:
            return None

        for _ in range(30):
            remove_idx = int(np.random.choice(items_selected))
            add_idx = int(np.random.choice(items_unselected))
            if not self._is_feasible(observation, (remove_idx, add_idx)):
                continue
            candidate = observation.copy()
            candidate[remove_idx] = 0
            candidate[add_idx] = 1
            candidate_objs = np.sum(self.profits * candidate, axis=1)
            dists = np.linalg.norm(archive_objs - candidate_objs, axis=1)
            min_dist = np.min(dists)
            if min_dist > best_min_dist:
                best_min_dist = min_dist
                best_move = (remove_idx, add_idx)
        return best_move

    # --- Feasibility Checking ---

    def _is_feasible(self, observation, move):
        if self.weights is None or self.capacities is None:
            return True
        remove_idx, add_idx = move
        if remove_idx == add_idx:
            return False
        items = observation.copy()
        if items[remove_idx] == 0 or items[add_idx] == 1:
            return False
        items[remove_idx] = 0
        items[add_idx] = 1
        total_weights = np.sum(self.weights * items, axis=1)
        feasible = np.all(total_weights <= self.capacities)
        return feasible

# %%
# %%cython
# # Cython MOACP with agent integration (see usage of py_agent in Indicator_local_search1)
#
# from libc.stdlib cimport malloc, free, srand, rand
# from libc.string cimport memset
# from libc.math cimport exp
#
# import numpy as np
# cimport numpy as np
#
# cdef struct ind:
#     int nombr_nonpris
#     int nombr
#     int rank
#     float fitnessbest
#     float fitness
#     int explored
#     double *f
#     double *capa
#     double *v
#     int *d
#     int *Items
#
# cdef struct pop:
#     int size
#     int maxsize
#     ind **ind_array
#
# cdef int NBITEMS = 250
# cdef int ni = 250
# cdef int L = 5
# cdef double LARGE = 10e50
# cdef float smallValue = 0.0000001
# cdef double kappa = 0.05
# cdef int alpha = 10
# cdef int paretoIni = 28000
#
# cdef int nf = 2
# cdef double *capacities = NULL
# cdef int **weights = NULL
# cdef int **profits = NULL
# cdef double *vector_weight = NULL
# cdef double max_bound = 0.0
# cdef double **OBJ_Weights = NULL
# cdef int nombreLIGNE = 0
# cdef int nextLn = 0
# cdef int inv = 0
# cdef int OBJ_Weights_lines = 0
# cdef public object py_agent = None
#
# def set_agent(agent):
#     global py_agent
#     py_agent = agent
#
# def seed(int x):
#     srand(x)
#
# cdef int irand(int range_val):
#     return rand() % range_val
#
# cdef void *chk_malloc(size_t size):
#     cdef void *return_value = malloc(size)
#     if return_value == NULL:
#         raise MemoryError("Out of memory.")
#     memset(return_value, 0, size)
#     return return_value
#
# cdef pop *create_pop(int maxsize, int nf):
#     cdef int i
#     cdef pop *pp = <pop *>chk_malloc(sizeof(pop))
#     pp.size = 0
#     pp.maxsize = maxsize
#     pp.ind_array = <ind **>chk_malloc(maxsize * sizeof(void*))
#     for i in range(maxsize):
#         pp.ind_array[i] = NULL
#     return pp
#
# cdef ind *create_ind(int nf):
#     cdef int i
#     cdef ind *p_ind = <ind *>chk_malloc(sizeof(ind))
#     p_ind.nombr_nonpris = 0
#     p_ind.nombr = 0
#     p_ind.rank = 0
#     p_ind.fitnessbest = -1.0
#     p_ind.fitness = -1.0
#     p_ind.explored = 0
#     p_ind.f = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.capa = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.v = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.d = <int *>chk_malloc(ni * sizeof(int))
#     p_ind.Items = <int *>chk_malloc(ni * sizeof(int))
#     for i in range(ni):
#         p_ind.Items[i] = 0
#         p_ind.d[i] = 0
#     for i in range(nf):
#         p_ind.f[i] = 0.0
#         p_ind.capa[i] = 0.0
#         p_ind.v[i] = 0.0
#     return p_ind
#
# cdef ind *ind_copy(ind *i):
#     cdef ind *p_ind = create_ind(nf)
#     cdef int k
#     p_ind.nombr_nonpris = i.nombr_nonpris
#     p_ind.nombr = i.nombr
#     p_ind.rank = i.rank
#     p_ind.fitnessbest = i.fitnessbest
#     p_ind.fitness = i.fitness
#     p_ind.explored = i.explored
#     for k in range(nf):
#         p_ind.f[k] = i.f[k]
#         p_ind.v[k] = i.v[k]
#         p_ind.capa[k] = i.capa[k]
#     for k in range(ni):
#         p_ind.d[k] = i.d[k]
#         p_ind.Items[k] = i.Items[k]
#     return p_ind
#
# cdef void free_ind(ind *p_ind):
#     if p_ind != NULL:
#         free(p_ind.d)
#         free(p_ind.f)
#         free(p_ind.capa)
#         free(p_ind.v)
#         free(p_ind.Items)
#         free(p_ind)
#
# cdef void complete_free_pop(pop *pp):
#     cdef int i
#     if pp != NULL:
#         if pp.ind_array != NULL:
#             for i in range(pp.size):
#                 if pp.ind_array[i] != NULL:
#                     free_ind(pp.ind_array[i])
#                     pp.ind_array[i] = NULL
#             free(pp.ind_array)
#         free(pp)
#
# cdef void cleanup_globals():
#     global capacities, weights, profits, vector_weight, OBJ_Weights, OBJ_Weights_lines, nf, ni
#     if capacities != NULL:
#         free(capacities)
#         capacities = NULL
#     if weights != NULL:
#         for i in range(nf):
#             if weights[i] != NULL:
#                 free(weights[i])
#         free(weights)
#         weights = NULL
#     if profits != NULL:
#         for i in range(nf):
#             if profits[i] != NULL:
#                 free(profits[i])
#         free(profits)
#         profits = NULL
#     if vector_weight != NULL:
#         free(vector_weight)
#         vector_weight = NULL
#     if OBJ_Weights != NULL:
#         for i in range(nf):
#             if OBJ_Weights[i] != NULL:
#                 free(OBJ_Weights[i])
#         free(OBJ_Weights)
#         OBJ_Weights = NULL
#     OBJ_Weights_lines = 0
#     nf = 0
#     ni = 0
#
# cdef int non_dominated(ind *p_ind_a, ind *p_ind_b):
#     cdef int i
#     cdef int a_is_good = -1
#     cdef int equal = 1
#     for i in range(nf):
#         if p_ind_a.f[i] > p_ind_b.f[i]:
#             a_is_good = 1
#         if p_ind_a.f[i] != p_ind_b.f[i]:
#             equal = 0
#     if equal:
#         return 0
#     return a_is_good
#
# cdef double calcAddEpsIndicator(ind *p_ind_a, ind *p_ind_b):
#     global max_bound
#     cdef int i
#     cdef double eps
#     cdef double temp_eps
#     if max_bound == 0.0:
#         max_bound = 1e-8
#     eps = (p_ind_a.v[0]/max_bound)-(p_ind_b.v[0]/max_bound)
#     for i in range(1, nf):
#         temp_eps = (p_ind_a.v[i]/max_bound)-(p_ind_b.v[i]/max_bound)
#         if temp_eps > eps:
#             eps = temp_eps
#     return eps
#
# cdef void init_fitness(ind *x):
#     x.fitness = 0.0
#
# cdef void update_fitness(ind *x, double I):
#     x.fitness -= exp(-I / kappa)
#
# cdef double update_fitness_return(double f, double I):
#     return f - exp(-I / kappa)
#
# cdef int delete_fitness(ind *x, double I):
#     x.fitness += exp(-I / kappa)
#     return 0
#
# cdef void compute_ind_fitness(ind *x, pop *SP):
#     cdef int j
#     init_fitness(x)
#     for j in range(SP.size):
#         if SP.ind_array[j] != x:
#             update_fitness(x, calcAddEpsIndicator(SP.ind_array[j], x))
#
# cdef void compute_all_fitness(pop *SP):
#     cdef int i
#     for i in range(SP.size):
#         compute_ind_fitness(SP.ind_array[i], SP)
#
# cdef void loadMOKP(char *filename):
#     global nf, ni, capacities, weights, profits
#     cdef int i, f
#     with open(filename.decode(), "r") as source:
#         _nf, _ni = [int(x) for x in source.readline().split()]
#         nf = _nf
#         ni = _ni
#         capacities = <double *>chk_malloc(nf * sizeof(double))
#         weights = <int **>chk_malloc(nf * sizeof(void*))
#         profits = <int **>chk_malloc(nf * sizeof(void*))
#         for f in range(nf):
#             capacities[f] = float(source.readline().strip())
#             weights[f] = <int *>chk_malloc(ni * sizeof(int))
#             profits[f] = <int *>chk_malloc(ni * sizeof(int))
#             for i in range(ni):
#                 source.readline()
#                 weights[f][i] = int(source.readline().strip())
#                 profits[f][i] = int(source.readline().strip())
#
# cdef void read_weights_file(char *filename):
#     global OBJ_Weights, nombreLIGNE, nf, OBJ_Weights_lines
#     cdef int i, j, nlines
#     with open(filename.decode(), "r") as f:
#         lines = [line for line in f if line.strip()]
#     nlines = len(lines)
#     OBJ_Weights = <double **>chk_malloc(nf * sizeof(void*))
#     for i in range(nf):
#         OBJ_Weights[i] = <double *>chk_malloc(nlines * sizeof(double))
#     for i, line in enumerate(lines):
#         vals = line.strip().split()
#         for j in range(nf):
#             OBJ_Weights[j][i] = float(vals[j])
#     nombreLIGNE = nlines - 1
#     OBJ_Weights_lines = nlines
#
# cdef void dynamic_weight_allpop():
#     global vector_weight, OBJ_Weights, nombreLIGNE, nf, nextLn
#     cdef int i
#     if vector_weight == NULL:
#         vector_weight = <double *>chk_malloc(nf * sizeof(double))
#     for i in range(nf):
#         vector_weight[i] = OBJ_Weights[i][nextLn]
#     if nextLn == nombreLIGNE:
#         nextLn = 0
#     else:
#         nextLn += 1
#
# cdef void choose_weight():
#     dynamic_weight_allpop()
#
# cdef void random_init_ind(ind *x):
#     cdef int j, r, tmp
#     for j in range(ni):
#         x.d[j] = j
#     for j in range(ni):
#         r = irand(ni)
#         tmp = x.d[r]
#         x.d[r] = x.d[j]
#         x.d[j] = tmp
#
# cdef void evaluate(ind *x):
#     cdef int j, l, k, faisable
#     x.nombr = 0
#     x.nombr_nonpris = 0
#     for j in range(nf):
#         x.capa[j] = 0.0
#         x.f[j] = 0.0
#     for j in range(ni):
#         l = 0
#         faisable = 1
#         while l < nf and faisable == 1:
#             if x.capa[l] + weights[l][x.d[j]] > capacities[l]:
#                 faisable = 0
#             l += 1
#         if faisable == 1:
#             for k in range(nf):
#                 x.capa[k] += weights[k][x.d[j]]
#                 x.f[k] += profits[k][x.d[j]]
#             x.Items[x.d[j]] = 1
#             x.nombr += 1
#         else:
#             x.Items[x.d[j]] = 0
#             x.nombr_nonpris += 1
#
# cdef void P_init_pop(pop *SP, pop *Sarchive, int alpha):
#     cdef int i, x, tmp, t
#     t = max(alpha, Sarchive.size)
#     cdef int* shuffle = <int *>chk_malloc(t * sizeof(int))
#     for i in range(t):
#         shuffle[i] = i
#     for i in range(t):
#         x = irand(alpha)
#         tmp = shuffle[i]
#         shuffle[i] = shuffle[x]
#         shuffle[x] = tmp
#     SP.size = alpha
#     if Sarchive.size > alpha:
#         for i in range(alpha):
#             SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#     else:
#         for i in range(alpha):
#             if shuffle[i] < Sarchive.size:
#                 SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#             else:
#                 SP.ind_array[i] = create_ind(nf)
#                 random_init_ind(SP.ind_array[i])
#                 evaluate(SP.ind_array[i])
#     free(shuffle)
#
# cdef int extractPtoArchive(pop *P, pop *archive):
#     cdef int i, j, dom, t, convergence_rate
#     t = archive.size + P.size
#     archiveAndP = create_pop(t, nf)
#     convergence_rate = 0
#     for i in range(archive.size):
#         archiveAndP.ind_array[i] = archive.ind_array[i]
#     for i in range(P.size):
#         archiveAndP.ind_array[i + archive.size] = ind_copy(P.ind_array[i])
#     archiveAndP.size = t
#     archive.size = 0
#     for i in range(t):
#         for j in range(t):
#             if i != j:
#                 dom = non_dominated(archiveAndP.ind_array[i], archiveAndP.ind_array[j])
#                 if dom == -1 or (dom == 0 and i > j):
#                     break
#         else:
#             archive.ind_array[archive.size] = ind_copy(archiveAndP.ind_array[i])
#             archive.size += 1
#             if i >= t - P.size:
#                 convergence_rate += 1
#     complete_free_pop(archiveAndP)
#     return convergence_rate
#
# cdef double calcMaxbound(pop *SP, int size):
#     global max_bound
#     cdef int i, j
#     SP.size = size
#     cdef double max_b = SP.ind_array[0].v[0]
#     for i in range(SP.size):
#         for j in range(nf):
#             if max_b < SP.ind_array[i].v[j]:
#                 max_b = SP.ind_array[i].v[j]
#     if max_b == 0.0:
#         max_b = 1e-8
#     max_bound = max_b
#     return max_b
#
# cdef void calcul_weight(pop *SP, int size):
#     cdef int i, j
#     for i in range(SP.size):
#         for j in range(nf):
#             SP.ind_array[i].v[j] = SP.ind_array[i].f[j] * vector_weight[j]
#
# cdef int compute_fitness_and_select(pop *SP, ind *x, int size):
#     cdef int i, worst
#     cdef double worst_fit, fit_tmp
#     SP.size = size
#     x.fitness = 0
#     compute_ind_fitness(x, SP)
#     worst_fit = x.fitness
#     worst = -1
#     for i in range(SP.size):
#         fit_tmp = update_fitness_return(SP.ind_array[i].fitness, calcAddEpsIndicator(x, SP.ind_array[i]))
#         if fit_tmp > worst_fit:
#             worst = i
#             worst_fit = fit_tmp
#     fit_tmp = x.fitness
#     if worst == -1:
#         return -1
#     else:
#         for i in range(SP.size):
#             delete_fitness(SP.ind_array[i], calcAddEpsIndicator(SP.ind_array[worst], SP.ind_array[i]))
#             update_fitness(SP.ind_array[i], calcAddEpsIndicator(x, SP.ind_array[i]))
#         delete_fitness(x, calcAddEpsIndicator(SP.ind_array[worst], x))
#         free_ind(SP.ind_array[worst])
#         SP.ind_array[worst] = ind_copy(x)
#         if fit_tmp - worst_fit > smallValue:
#             return worst
#         else:
#             return -1
#
# cdef np.ndarray get_archive_objs(pop *archive):
#     cdef int i, j
#     arr = np.zeros((archive.size, nf), dtype=np.float64)
#     for i in range(archive.size):
#         for j in range(nf):
#             arr[i, j] = archive.ind_array[i].f[j]
#     return arr
#
# cdef np.ndarray get_items(ind *x):
#     arr = np.zeros(ni, dtype=np.int32)
#     for i in range(ni):
#         arr[i] = x.Items[i]
#     return arr
#
# cdef void Indicator_local_search1(pop *SP, pop *Sarchive, int size):
#     cdef ind *x
#     cdef ind *y
#     cdef int i, j, r, t, k, l, v, sol, mino, mp, maxp, consistant, pos, stop, convergence, ii, tmp_pris, tmp_nonpris, taille, feasible, tv, IM
#     cdef int* remplace = <int *>chk_malloc(L * sizeof(int))
#     SP.size = size
#     extractPtoArchive(SP, Sarchive)
#     while True:
#         convergence = 0
#         archive_objs = get_archive_objs(Sarchive) if Sarchive.size > 0 else None
#         for i in range(SP.size):
#             if not SP.ind_array[i].explored:
#                 x = ind_copy(SP.ind_array[i])
#                 j = 0
#                 while j < x.nombr:
#                     for l in range(L):
#                         remplace[l] = 0
#                     # -------- SMART AGENT INTEGRATION --------
#                     remove_idx = -1
#                     add_idx = -1
#                     agent_move_type = None
#                     agent_success = False
#                     if py_agent is not None:
#                         state = {
#                             "Items": [x.Items[ii] for ii in range(ni)],
#                             "capa": [x.capa[ii] for ii in range(nf)],
#                             "f": [x.f[ii] for ii in range(nf)],
#                         }
#                         context = {}
#                         if archive_objs is not None:
#                             context["archive_objs"] = archive_objs
#                         try:
#                             obs = py_agent.observe(state)
#                             remove_idx, add_idx = py_agent.act(obs, context)
#                         except Exception as e:
#                             print("Agent error:", e)
#                             remove_idx = -1
#                             add_idx = -1
#                     # Fallback to random if agent does not provide usable indices
#                     if remove_idx < 0 or remove_idx >= ni or x.Items[remove_idx] != 1:
#                         while True:
#                             mino = irand(ni)
#                             if x.Items[mino] == 1:
#                                 break
#                         remove_idx = mino
#                     if add_idx < 0 or add_idx >= ni or x.Items[add_idx] != 0 or add_idx == remove_idx:
#                         while True:
#                             maxp = irand(ni)
#                             if x.Items[maxp] == 0 and maxp != remove_idx:
#                                 break
#                         add_idx = maxp
#
#                     # Remove item
#                     x.Items[remove_idx] = 0
#                     x.nombr -= 1
#                     x.nombr_nonpris += 1
#                     for r in range(nf):
#                         x.capa[r] -= weights[r][remove_idx]
#                         x.f[r] -= profits[r][remove_idx]
#
#                     IM = 0
#                     taille = 0
#                     while IM < L:
#                         item_to_add = add_idx
#                         if item_to_add < 0 or item_to_add >= ni or x.Items[item_to_add] != 0 or item_to_add == remove_idx:
#                             while True:
#                                 item_to_add = irand(ni)
#                                 if x.Items[item_to_add] == 0 and item_to_add != remove_idx:
#                                     break
#                         consistant = 1
#                         r = 0
#                         while r < nf and consistant == 1:
#                             if x.capa[r] + weights[r][item_to_add] > capacities[r]:
#                                 consistant = 0
#                             r += 1
#                         if consistant == 1:
#                             feasible = 1
#                             r = 0
#                             while r < taille and feasible:
#                                 if item_to_add == remplace[r]:
#                                     feasible = 0
#                                 r += 1
#                             if feasible == 1:
#                                 remplace[taille] = item_to_add
#                                 taille += 1
#                                 x.Items[item_to_add] = 1
#                                 x.nombr_nonpris -= 1
#                                 x.nombr += 1
#                                 for r in range(nf):
#                                     x.capa[r] += weights[r][item_to_add]
#                                     x.f[r] += profits[r][item_to_add]
#                         IM += 1
#                     for tv in range(nf):
#                         x.v[tv] = x.f[tv] * vector_weight[tv]
#                     max_bound = calcMaxbound(SP, SP.size)
#                     sol = compute_fitness_and_select(SP, x, SP.size)
#                     agent_success = (sol != -1)
#                     if py_agent is not None:
#                         try:
#                             py_agent.report_move_result(None, agent_success)
#                         except Exception:
#                             pass
#                     if sol != -1:
#                         j = x.nombr + 1
#                         if sol > i and i + 1 < SP.size:
#                             y = SP.ind_array[i + 1]
#                             SP.ind_array[i + 1] = SP.ind_array[sol]
#                             SP.ind_array[sol] = y
#                             i += 1
#                         break
#                     elif sol == -1:
#                         x.Items[remove_idx] = 1
#                         x.nombr_nonpris -= 1
#                         x.nombr += 1
#                         for r in range(nf):
#                             x.capa[r] += weights[r][remove_idx]
#                             x.f[r] += profits[r][remove_idx]
#                         if taille >= 1:
#                             for r in range(taille):
#                                 x.Items[remplace[r]] = 0
#                                 x.nombr -= 1
#                                 x.nombr_nonpris += 1
#                                 for t in range(nf):
#                                     x.capa[t] -= weights[t][remplace[r]]
#                                     x.f[t] -= profits[t][remplace[r]]
#                                     x.v[t] = x.f[t] * vector_weight[t]
#                     j += 1
#                 tmp_pris = x.nombr
#                 tmp_nonpris = x.nombr_nonpris
#                 free_ind(x)
#                 if j == tmp_pris:
#                     SP.ind_array[i].explored = 1
#         convergence = extractPtoArchive(SP, Sarchive)
#         if not convergence:
#             break
#     free(remplace)
#
# def run_moacp(instance_file, weights_file, nbitems, num_objectives, output_file):
#     global nf, ni, NBITEMS, alpha, paretoIni, L, nombreLIGNE, nextLn, inv, vector_weight
#     global capacities, weights, profits, OBJ_Weights
#
#     alpha = 10
#     paretoIni = 28000
#
#     NBL = 100
#     NRUNS = 10
#
#     for run in range(1, NRUNS+1):
#         NBITEMS = nbitems
#         ni = nbitems
#         nf = num_objectives
#
#         print(f"RUN {run}/{NRUNS} -- {instance_file.decode()} nbitems={ni} nf={nf} => {output_file}")
#
#         nombreLIGNE = 0
#         nextLn = 0
#         inv = 0
#
#         seed(run)
#         loadMOKP(instance_file)
#         read_weights_file(weights_file)
#
#         vector_weight = <double *>chk_malloc(nf * sizeof(double))
#         P = create_pop(paretoIni, nf)
#
#         it = 0
#         while it < NBL:
#             solutions = create_pop(alpha, nf)
#             archive = create_pop(paretoIni, nf)
#             choose_weight()
#             P_init_pop(solutions, P, alpha)
#             extractPtoArchive(solutions, P)
#             calcul_weight(solutions, alpha)
#             calcMaxbound(solutions, alpha)
#             compute_all_fitness(solutions)
#             Indicator_local_search1(solutions, archive, alpha)
#             extractPtoArchive(archive, P)
#             # Update agent with best observation
#             if py_agent is not None and P.size > 0:
#                 best_idx = 0
#                 best_val = P.ind_array[0].fitness
#                 for i in range(1, P.size):
#                     if P.ind_array[i].fitness > best_val:
#                         best_idx = i
#                         best_val = P.ind_array[i].fitness
#                 best_items = get_items(P.ind_array[best_idx])
#                 try:
#                     py_agent.update_best(best_items)
#                 except Exception:
#                     pass
#             it += 1
#             complete_free_pop(solutions)
#             complete_free_pop(archive)
#
#         with open(output_file, "a") as fpareto:
#             fpareto.write("\n")
#             for i in range(P.size):
#                 for j in range(nf):
#                     fpareto.write(f"{P.ind_array[i].f[j]:.6f} ")
#                 fpareto.write("\n")
#
#         complete_free_pop(P)
#         cleanup_globals()

# %%
# ---- Run both reference and smart agent experiments ----

# Experiment parameters
nbitems = 250
num_objectives = 2
instance_file = b"250.2.txt"
weights_file = b"Weights_2obj_FQ200.txt"
output_file_agent = "output_agent1.txt"
output_file_ref = "output_ref.txt"

# Load data for agent
profits = load_profits_from_file("250.2.txt", num_objectives, nbitems)
weights = load_weights_from_file("250.2.txt", num_objectives, nbitems)
capacities = load_capacities_from_file("250.2.txt", num_objectives, nbitems)

# ---- Run reference (random) optimization ----
set_agent(None)  # Ensure agent is not set
run_moacp(instance_file, weights_file, nbitems, num_objectives, output_file_ref)
print("Reference optimization completed.")

# ---- Run agent optimization ----
agent = SmartAgent(nbitems, num_objectives, profits=profits, weights=weights, capacities=capacities)
set_agent(agent)
run_moacp(instance_file, weights_file, nbitems, num_objectives, output_file_agent)
print("Agent optimization completed.")
# Out:
# RUN 1/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 2/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 3/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 4/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 5/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 6/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 7/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 8/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 9/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 10/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# Reference optimization completed.
# RUN 1/10 -- 250.2.txt nbitems=250 nf=2 => output_agent1.txt
# RUN 2/10 -- 250.2.txt nbitems=250 nf=2 => output_agent1.txt
# RUN 3/10 -- 250.2.txt nbitems=250 nf=2 => output_agent1.txt
# RUN 4/10 -- 250.2.txt nbitems=250 nf=2 => output_agent1.txt
# RUN 5/10 -- 250.2.txt nbitems=250 nf=2 => output_agent1.txt
# RUN 6/10 -- 250.2.txt nbitems=250 nf=2 => output_agent1.txt
# RUN 7/10 -- 250.2.txt nbitems=250 nf=2 => output_agent1.txt
# RUN 8/10 -- 250.2.txt nbitems=250 nf=2 => output_agent1.txt
# RUN 9/10 -- 250.2.txt nbitems=250 nf=2 => output_agent1.txt
# RUN 10/10 -- 250.2.txt nbitems=250 nf=2 => output_agent1.txt
# Agent optimization completed.

# %%
import numpy as np
import matplotlib.pyplot as plt

def load_pareto_front(filename):
    points = []
    with open(filename) as f:
        for line in f:
            line = line.strip()
            if line:
                points.append([float(x) for x in line.split()])
    return np.array(points)

def is_dominated(point, others):
    return np.any(np.all(others >= point, axis=1) & np.any(others > point, axis=1))

def get_pareto_front(points):
    mask = np.ones(len(points), dtype=bool)
    for i, p in enumerate(points):
        others = np.delete(points, i, axis=0)
        if is_dominated(p, others):
            mask[i] = False
    return points[mask]

# Load and merge all runs' points for each result file
ref_points = load_pareto_front("output_ref.txt")
agent_points = load_pareto_front("output_agent.txt")

# Get the true Pareto front for each
ref_pareto = get_pareto_front(ref_points)
agent_pareto = get_pareto_front(agent_points)

# Plot
plt.figure(figsize=(8,6))
plt.scatter(ref_pareto[:,0], ref_pareto[:,1], label="Reference Pareto", alpha=0.7)
plt.scatter(agent_pareto[:,0], agent_pareto[:,1], label="Agent Pareto", alpha=0.7)
plt.xlabel("Objective 1")
plt.ylabel("Objective 2")
plt.legend()
plt.title("True Pareto Front: Reference vs. Smart Agent")
plt.show()

print(f"Reference Pareto size: {ref_pareto.shape[0]}")
print(f"Agent Pareto size: {agent_pareto.shape[0]}")
# Out:
# Reference Pareto size: 628
# Agent Pareto size: 211

# %%
import numpy as np
import matplotlib.pyplot as plt

def load_pareto_front(filename):
    points = []
    with open(filename) as f:
        for line in f:
            line = line.strip()
            if line:
                points.append([float(x) for x in line.split()])
    return np.array(points)

def is_dominated(point, others):
    return np.any(np.all(others >= point, axis=1) & np.any(others > point, axis=1))

def get_pareto_front(points):
    mask = np.ones(len(points), dtype=bool)
    for i, p in enumerate(points):
        others = np.delete(points, i, axis=0)
        if is_dominated(p, others):
            mask[i] = False
    return points[mask]

# Load and merge all runs' points for each result file
ref_points = load_pareto_front("output_ref.txt")
agent_points = load_pareto_front("output_agent1.txt")

# Get the true Pareto front for each
ref_pareto = get_pareto_front(ref_points)
agent_pareto = get_pareto_front(agent_points)

# Plot
plt.figure(figsize=(8,6))
plt.scatter(ref_pareto[:,0], ref_pareto[:,1], label="Reference Pareto", alpha=0.7)
plt.scatter(agent_pareto[:,0], agent_pareto[:,1], label="Agent Pareto", alpha=0.7)
plt.xlabel("Objective 1")
plt.ylabel("Objective 2")
plt.legend()
plt.title("True Pareto Front: Reference vs. Smart Agent")
plt.show()

print(f"Reference Pareto size: {ref_pareto.shape[0]}")
print(f"Agent Pareto size: {agent_pareto.shape[0]}")
# Out:
# Reference Pareto size: 785
# Agent Pareto size: 180

# %%
import numpy as np
import matplotlib.pyplot as plt

def load_pareto_front(filename):
    points = []
    with open(filename) as f:
        for line in f:
            line = line.strip()
            if line:
                points.append([float(x) for x in line.split()])
    return np.array(points)

def is_dominated(point, others):
    return np.any(np.all(others >= point, axis=1) & np.any(others > point, axis=1))

def get_pareto_front(points):
    mask = np.ones(len(points), dtype=bool)
    for i, p in enumerate(points):
        others = np.delete(points, i, axis=0)
        if is_dominated(p, others):
            mask[i] = False
    return points[mask]

# Load and merge all runs' points for each result file
ref_points = load_pareto_front("2502_Resulats.txt")
agent_points = load_pareto_front("output_agent1.txt")

# Get the true Pareto front for each
ref_pareto = get_pareto_front(ref_points)
agent_pareto = get_pareto_front(agent_points)

# Plot
plt.figure(figsize=(8,6))
plt.scatter(ref_pareto[:,0], ref_pareto[:,1], label="Reference Pareto", alpha=0.7)
plt.scatter(agent_pareto[:,0], agent_pareto[:,1], label="Agent Pareto", alpha=0.7)
plt.xlabel("Objective 1")
plt.ylabel("Objective 2")
plt.legend()
plt.title("True Pareto Front: Reference vs. Smart Agent")
plt.show()

print(f"Reference Pareto size: {ref_pareto.shape[0]}")
print(f"Agent Pareto size: {agent_pareto.shape[0]}")
# Out:
# Reference Pareto size: 848
# Agent Pareto size: 180

# %%
import numpy as np
from pymoo.indicators.hv import HV

def load_pareto_front(filename):
    points = []
    with open(filename) as f:
        for line in f:
            line = line.strip()
            if line:
                points.append([float(x) for x in line.split()])
    return np.array(points)

ref_pareto = load_pareto_front("output_ref.txt")   # reference (no agent)
new_pareto = load_pareto_front("output_agent1.txt") # agent (improved)

ref = ref_pareto
new = new_pareto

ref_point = np.max(np.vstack([ref, new]), axis=0) + 1

hv = HV(ref_point=ref_point)

print("Reference HV:", hv(ref))
print("Improved HV:", hv(new))
# Out:
# Reference HV: 1384385.0
# Improved HV: 1307985.0

# %%
############################################

# %%
import numpy as np

def load_profits_from_file(filename, num_objectives, num_items):
    profits = np.zeros((num_objectives, num_items))
    with open(filename, 'r') as f:
        lines = [line.strip() for line in f if line.strip()]
    idx = 1  # skip header
    for obj in range(num_objectives):
        idx += 1  # skip capacity line
        for item in range(num_items):
            idx += 1  # skip "n:" line
            idx += 1  # skip weight
            profit = int(lines[idx])
            profits[obj, item] = profit
            idx += 1
    return profits

def load_weights_from_file(filename, num_objectives, num_items):
    weights = np.zeros((num_objectives, num_items), dtype=int)
    with open(filename, 'r') as f:
        lines = [line.strip() for line in f if line.strip()]
    idx = 1  # skip header
    for obj in range(num_objectives):
        idx += 1  # skip capacity line
        for item in range(num_items):
            idx += 1  # skip "n:" line
            weight = int(lines[idx])
            weights[obj, item] = weight
            idx += 2  # skip profit
    return weights

def load_capacities_from_file(filename, num_objectives, num_items):
    with open(filename, 'r') as f:
        lines = [line.strip() for line in f if line.strip()]
    idx = 1  # skip header
    capacities = []
    for obj in range(num_objectives):
        cap = float(lines[idx])
        capacities.append(cap)
        idx += 1 + 3 * num_items
    return np.array(capacities)

# %%
import numpy as np

class SmartAgent:
    def __init__(self, nbitems, num_objectives, profits, weights, capacities,
                 move_probs=None, attempts_per_move=100, smoothing=0.2):
        self.nbitems = nbitems
        self.num_objectives = num_objectives
        self.profits = profits
        self.weights = weights
        self.capacities = capacities
        self.move_types = ["local_search", "global_search", "follow", "mutation", "diversity"]
        self.move_counts = {k: 1 for k in self.move_types}
        self.move_successes = {k: 1 for k in self.move_types}
        # TUNING: Change initial move probabilities below
        if move_probs is None:
            self.move_probs = np.array([0.25, 0.20, 0.15, 0.15, 0.25], dtype=np.float64)
        else:
            self.move_probs = move_probs
        self.attempts_per_move = attempts_per_move  # TUNING: More attempts may help
        self.smoothing = smoothing  # TUNING: Higher = slower adaptation, lower = faster
        self.best_observation = None
        self.last_move_type = None

    def observe(self, state):
        return np.array(state["Items"], dtype=np.int32)

    def act(self, observation, context=None):
        archive_objs = None
        if context is not None and "archive_objs" in context:
            archive_objs = context["archive_objs"]
        move_idx = np.random.choice(len(self.move_types), p=self.move_probs)
        move_type = self.move_types[move_idx]
        self.last_move_type = move_type

        # Diversity move logic
        if move_type == "diversity" and archive_objs is not None and self.profits is not None:
            move = self.diversity_move(observation, archive_objs)
            if move is not None:
                return move

        # Try move heuristics
        for _ in range(self.attempts_per_move):
            if move_type == "local_search":
                move = self.local_search_move(observation)
            elif move_type == "global_search":
                move = self.global_search_move(observation)
            elif move_type == "follow":
                move = self.follow_move(observation)
            elif move_type == "mutation":
                move = self.mutation_move(observation)
            else:
                continue  # If "diversity" move failed, skip

            if self._is_feasible(observation, move):
                return move

        # Fallback to feasible random mutation
        for _ in range(self.attempts_per_move * 2):
            move = self.mutation_move(observation)
            if self._is_feasible(observation, move):
                return move

        return (0, 0)

    def report_move_result(self, move_type=None, success=False):
        if move_type is None:
            move_type = self.last_move_type
        if move_type not in self.move_types:
            return
        self.move_counts[move_type] += 1
        if success:
            self.move_successes[move_type] += 1

        # Softmax update of move probabilities
        rates = np.array(
            [self.move_successes[k] / self.move_counts[k] for k in self.move_types],
            dtype=np.float64,
        )
        exp_rates = np.exp(rates / self.smoothing)
        new_probs = exp_rates / np.sum(exp_rates)
        self.move_probs = 0.5 * self.move_probs + 0.5 * new_probs
        self.move_probs = self.move_probs / np.sum(self.move_probs)
        print(f"Move: {move_type}, Success: {success}, Current Probs: {self.move_probs}")

    def update_best(self, observation):
        self.best_observation = observation.copy()

    def meta_adapt(self, meta_info: dict):
        pass

    # --- Heuristic Moves ---
    def local_search_move(self, observation):
        items_selected = np.where(observation == 1)[0]
        items_unselected = np.where(observation == 0)[0]
        if len(items_selected) == 0 or len(items_unselected) == 0 or self.profits is None:
            return 0, 0
        profs_selected = np.sum(self.profits[:, items_selected], axis=0)
        profs_unselected = np.sum(self.profits[:, items_unselected], axis=0)
        remove_idx = items_selected[np.argmin(profs_selected)]
        add_idx = items_unselected[np.argmax(profs_unselected)]
        return int(remove_idx), int(add_idx)

    def global_search_move(self, observation):
        items_selected = np.where(observation == 1)[0]
        items_unselected = np.where(observation == 0)[0]
        if len(items_selected) == 0 or len(items_unselected) == 0 or self.profits is None:
            return 0, 0
        profs_selected = np.sum(self.profits[:, items_selected], axis=0)
        profs_unselected = np.sum(self.profits[:, items_unselected], axis=0)
        ps = profs_selected + 1e-9
        pu = profs_unselected + 1e-9
        remove_idx = np.random.choice(items_selected, p=ps / np.sum(ps))
        add_idx = np.random.choice(items_unselected, p=pu / np.sum(pu))
        return int(remove_idx), int(add_idx)

    def follow_move(self, observation):
        if self.best_observation is None:
            return self.mutation_move(observation)
        diff = self.best_observation - observation
        add_candidates = np.where((diff == 1) & (observation == 0))[0]
        remove_candidates = np.where((diff == -1) & (observation == 1))[0]
        if len(add_candidates) == 0 or len(remove_candidates) == 0:
            return self.mutation_move(observation)
        add_idx = np.random.choice(add_candidates)
        remove_idx = np.random.choice(remove_candidates)
        return int(remove_idx), int(add_idx)

    def mutation_move(self, observation):
        items_selected = np.where(observation == 1)[0]
        items_unselected = np.where(observation == 0)[0]
        if len(items_selected) == 0 or len(items_unselected) == 0:
            return 0, 0
        remove_idx = int(np.random.choice(items_selected))
        add_idx = int(np.random.choice(items_unselected))
        return remove_idx, add_idx

    def diversity_move(self, observation, archive_objs):
        best_move = None
        best_min_dist = -np.inf
        items_selected = np.where(observation == 1)[0]
        items_unselected = np.where(observation == 0)[0]
        if len(items_selected) == 0 or len(items_unselected) == 0:
            return None

        for _ in range(self.attempts_per_move):
            remove_idx = int(np.random.choice(items_selected))
            add_idx = int(np.random.choice(items_unselected))
            if not self._is_feasible(observation, (remove_idx, add_idx)):
                continue
            candidate = observation.copy()
            candidate[remove_idx] = 0
            candidate[add_idx] = 1
            candidate_objs = np.sum(self.profits * candidate, axis=1)
            dists = np.linalg.norm(archive_objs - candidate_objs, axis=1)
            min_dist = np.min(dists)
            if min_dist > best_min_dist:
                best_min_dist = min_dist
                best_move = (remove_idx, add_idx)
        return best_move

    # --- Feasibility Checking ---
    def _is_feasible(self, observation, move):
        if self.weights is None or self.capacities is None:
            return True
        remove_idx, add_idx = move
        if remove_idx == add_idx:
            return False
        items = observation.copy()
        if items[remove_idx] == 0 or items[add_idx] == 1:
            return False
        items[remove_idx] = 0
        items[add_idx] = 1
        total_weights = np.sum(self.weights * items, axis=1)
        feasible = np.all(total_weights <= self.capacities)
        return feasible

# %%
# %%cython
# # Cython MOACP with agent integration (see usage of py_agent in Indicator_local_search1)
#
# from libc.stdlib cimport malloc, free, srand, rand
# from libc.string cimport memset
# from libc.math cimport exp
#
# import numpy as np
# cimport numpy as np
#
# cdef struct ind:
#     int nombr_nonpris
#     int nombr
#     int rank
#     float fitnessbest
#     float fitness
#     int explored
#     double *f
#     double *capa
#     double *v
#     int *d
#     int *Items
#
# cdef struct pop:
#     int size
#     int maxsize
#     ind **ind_array
#
# cdef int NBITEMS = 250
# cdef int ni = 250
# cdef int L = 5
# cdef double LARGE = 10e50
# cdef float smallValue = 0.0000001
# cdef double kappa = 0.05
# cdef int alpha = 10
# cdef int paretoIni = 28000
#
# cdef int nf = 2
# cdef double *capacities = NULL
# cdef int **weights = NULL
# cdef int **profits = NULL
# cdef double *vector_weight = NULL
# cdef double max_bound = 0.0
# cdef double **OBJ_Weights = NULL
# cdef int nombreLIGNE = 0
# cdef int nextLn = 0
# cdef int inv = 0
# cdef int OBJ_Weights_lines = 0
# cdef public object py_agent = None
#
# def set_agent(agent):
#     global py_agent
#     py_agent = agent
#
# def seed(int x):
#     srand(x)
#
# cdef int irand(int range_val):
#     return rand() % range_val
#
# cdef void *chk_malloc(size_t size):
#     cdef void *return_value = malloc(size)
#     if return_value == NULL:
#         raise MemoryError("Out of memory.")
#     memset(return_value, 0, size)
#     return return_value
#
# cdef pop *create_pop(int maxsize, int nf):
#     cdef int i
#     cdef pop *pp = <pop *>chk_malloc(sizeof(pop))
#     pp.size = 0
#     pp.maxsize = maxsize
#     pp.ind_array = <ind **>chk_malloc(maxsize * sizeof(void*))
#     for i in range(maxsize):
#         pp.ind_array[i] = NULL
#     return pp
#
# cdef ind *create_ind(int nf):
#     cdef int i
#     cdef ind *p_ind = <ind *>chk_malloc(sizeof(ind))
#     p_ind.nombr_nonpris = 0
#     p_ind.nombr = 0
#     p_ind.rank = 0
#     p_ind.fitnessbest = -1.0
#     p_ind.fitness = -1.0
#     p_ind.explored = 0
#     p_ind.f = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.capa = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.v = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.d = <int *>chk_malloc(ni * sizeof(int))
#     p_ind.Items = <int *>chk_malloc(ni * sizeof(int))
#     for i in range(ni):
#         p_ind.Items[i] = 0
#         p_ind.d[i] = 0
#     for i in range(nf):
#         p_ind.f[i] = 0.0
#         p_ind.capa[i] = 0.0
#         p_ind.v[i] = 0.0
#     return p_ind
#
# cdef ind *ind_copy(ind *i):
#     cdef ind *p_ind = create_ind(nf)
#     cdef int k
#     p_ind.nombr_nonpris = i.nombr_nonpris
#     p_ind.nombr = i.nombr
#     p_ind.rank = i.rank
#     p_ind.fitnessbest = i.fitnessbest
#     p_ind.fitness = i.fitness
#     p_ind.explored = i.explored
#     for k in range(nf):
#         p_ind.f[k] = i.f[k]
#         p_ind.v[k] = i.v[k]
#         p_ind.capa[k] = i.capa[k]
#     for k in range(ni):
#         p_ind.d[k] = i.d[k]
#         p_ind.Items[k] = i.Items[k]
#     return p_ind
#
# cdef void free_ind(ind *p_ind):
#     if p_ind != NULL:
#         free(p_ind.d)
#         free(p_ind.f)
#         free(p_ind.capa)
#         free(p_ind.v)
#         free(p_ind.Items)
#         free(p_ind)
#
# cdef void complete_free_pop(pop *pp):
#     cdef int i
#     if pp != NULL:
#         if pp.ind_array != NULL:
#             for i in range(pp.size):
#                 if pp.ind_array[i] != NULL:
#                     free_ind(pp.ind_array[i])
#                     pp.ind_array[i] = NULL
#             free(pp.ind_array)
#         free(pp)
#
# cdef void cleanup_globals():
#     global capacities, weights, profits, vector_weight, OBJ_Weights, OBJ_Weights_lines, nf, ni
#     if capacities != NULL:
#         free(capacities)
#         capacities = NULL
#     if weights != NULL:
#         for i in range(nf):
#             if weights[i] != NULL:
#                 free(weights[i])
#         free(weights)
#         weights = NULL
#     if profits != NULL:
#         for i in range(nf):
#             if profits[i] != NULL:
#                 free(profits[i])
#         free(profits)
#         profits = NULL
#     if vector_weight != NULL:
#         free(vector_weight)
#         vector_weight = NULL
#     if OBJ_Weights != NULL:
#         for i in range(nf):
#             if OBJ_Weights[i] != NULL:
#                 free(OBJ_Weights[i])
#         free(OBJ_Weights)
#         OBJ_Weights = NULL
#     OBJ_Weights_lines = 0
#     nf = 0
#     ni = 0
#
# cdef int non_dominated(ind *p_ind_a, ind *p_ind_b):
#     cdef int i
#     cdef int a_is_good = -1
#     cdef int equal = 1
#     for i in range(nf):
#         if p_ind_a.f[i] > p_ind_b.f[i]:
#             a_is_good = 1
#         if p_ind_a.f[i] != p_ind_b.f[i]:
#             equal = 0
#     if equal:
#         return 0
#     return a_is_good
#
# cdef double calcAddEpsIndicator(ind *p_ind_a, ind *p_ind_b):
#     global max_bound
#     cdef int i
#     cdef double eps
#     cdef double temp_eps
#     if max_bound == 0.0:
#         max_bound = 1e-8
#     eps = (p_ind_a.v[0]/max_bound)-(p_ind_b.v[0]/max_bound)
#     for i in range(1, nf):
#         temp_eps = (p_ind_a.v[i]/max_bound)-(p_ind_b.v[i]/max_bound)
#         if temp_eps > eps:
#             eps = temp_eps
#     return eps
#
# cdef void init_fitness(ind *x):
#     x.fitness = 0.0
#
# cdef void update_fitness(ind *x, double I):
#     x.fitness -= exp(-I / kappa)
#
# cdef double update_fitness_return(double f, double I):
#     return f - exp(-I / kappa)
#
# cdef int delete_fitness(ind *x, double I):
#     x.fitness += exp(-I / kappa)
#     return 0
#
# cdef void compute_ind_fitness(ind *x, pop *SP):
#     cdef int j
#     init_fitness(x)
#     for j in range(SP.size):
#         if SP.ind_array[j] != x:
#             update_fitness(x, calcAddEpsIndicator(SP.ind_array[j], x))
#
# cdef void compute_all_fitness(pop *SP):
#     cdef int i
#     for i in range(SP.size):
#         compute_ind_fitness(SP.ind_array[i], SP)
#
# cdef void loadMOKP(char *filename):
#     global nf, ni, capacities, weights, profits
#     cdef int i, f
#     with open(filename.decode(), "r") as source:
#         _nf, _ni = [int(x) for x in source.readline().split()]
#         nf = _nf
#         ni = _ni
#         capacities = <double *>chk_malloc(nf * sizeof(double))
#         weights = <int **>chk_malloc(nf * sizeof(void*))
#         profits = <int **>chk_malloc(nf * sizeof(void*))
#         for f in range(nf):
#             capacities[f] = float(source.readline().strip())
#             weights[f] = <int *>chk_malloc(ni * sizeof(int))
#             profits[f] = <int *>chk_malloc(ni * sizeof(int))
#             for i in range(ni):
#                 source.readline()
#                 weights[f][i] = int(source.readline().strip())
#                 profits[f][i] = int(source.readline().strip())
#
# cdef void read_weights_file(char *filename):
#     global OBJ_Weights, nombreLIGNE, nf, OBJ_Weights_lines
#     cdef int i, j, nlines
#     with open(filename.decode(), "r") as f:
#         lines = [line for line in f if line.strip()]
#     nlines = len(lines)
#     OBJ_Weights = <double **>chk_malloc(nf * sizeof(void*))
#     for i in range(nf):
#         OBJ_Weights[i] = <double *>chk_malloc(nlines * sizeof(double))
#     for i, line in enumerate(lines):
#         vals = line.strip().split()
#         for j in range(nf):
#             OBJ_Weights[j][i] = float(vals[j])
#     nombreLIGNE = nlines - 1
#     OBJ_Weights_lines = nlines
#
# cdef void dynamic_weight_allpop():
#     global vector_weight, OBJ_Weights, nombreLIGNE, nf, nextLn
#     cdef int i
#     if vector_weight == NULL:
#         vector_weight = <double *>chk_malloc(nf * sizeof(double))
#     for i in range(nf):
#         vector_weight[i] = OBJ_Weights[i][nextLn]
#     if nextLn == nombreLIGNE:
#         nextLn = 0
#     else:
#         nextLn += 1
#
# cdef void choose_weight():
#     dynamic_weight_allpop()
#
# cdef void random_init_ind(ind *x):
#     cdef int j, r, tmp
#     for j in range(ni):
#         x.d[j] = j
#     for j in range(ni):
#         r = irand(ni)
#         tmp = x.d[r]
#         x.d[r] = x.d[j]
#         x.d[j] = tmp
#
# cdef void evaluate(ind *x):
#     cdef int j, l, k, faisable
#     x.nombr = 0
#     x.nombr_nonpris = 0
#     for j in range(nf):
#         x.capa[j] = 0.0
#         x.f[j] = 0.0
#     for j in range(ni):
#         l = 0
#         faisable = 1
#         while l < nf and faisable == 1:
#             if x.capa[l] + weights[l][x.d[j]] > capacities[l]:
#                 faisable = 0
#             l += 1
#         if faisable == 1:
#             for k in range(nf):
#                 x.capa[k] += weights[k][x.d[j]]
#                 x.f[k] += profits[k][x.d[j]]
#             x.Items[x.d[j]] = 1
#             x.nombr += 1
#         else:
#             x.Items[x.d[j]] = 0
#             x.nombr_nonpris += 1
#
# cdef void P_init_pop(pop *SP, pop *Sarchive, int alpha):
#     cdef int i, x, tmp, t
#     t = max(alpha, Sarchive.size)
#     cdef int* shuffle = <int *>chk_malloc(t * sizeof(int))
#     for i in range(t):
#         shuffle[i] = i
#     for i in range(t):
#         x = irand(alpha)
#         tmp = shuffle[i]
#         shuffle[i] = shuffle[x]
#         shuffle[x] = tmp
#     SP.size = alpha
#     if Sarchive.size > alpha:
#         for i in range(alpha):
#             SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#     else:
#         for i in range(alpha):
#             if shuffle[i] < Sarchive.size:
#                 SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#             else:
#                 SP.ind_array[i] = create_ind(nf)
#                 random_init_ind(SP.ind_array[i])
#                 evaluate(SP.ind_array[i])
#     free(shuffle)
#
# cdef int extractPtoArchive(pop *P, pop *archive):
#     cdef int i, j, dom, t, convergence_rate
#     t = archive.size + P.size
#     archiveAndP = create_pop(t, nf)
#     convergence_rate = 0
#     for i in range(archive.size):
#         archiveAndP.ind_array[i] = archive.ind_array[i]
#     for i in range(P.size):
#         archiveAndP.ind_array[i + archive.size] = ind_copy(P.ind_array[i])
#     archiveAndP.size = t
#     archive.size = 0
#     for i in range(t):
#         for j in range(t):
#             if i != j:
#                 dom = non_dominated(archiveAndP.ind_array[i], archiveAndP.ind_array[j])
#                 if dom == -1 or (dom == 0 and i > j):
#                     break
#         else:
#             archive.ind_array[archive.size] = ind_copy(archiveAndP.ind_array[i])
#             archive.size += 1
#             if i >= t - P.size:
#                 convergence_rate += 1
#     complete_free_pop(archiveAndP)
#     return convergence_rate
#
# cdef double calcMaxbound(pop *SP, int size):
#     global max_bound
#     cdef int i, j
#     SP.size = size
#     cdef double max_b = SP.ind_array[0].v[0]
#     for i in range(SP.size):
#         for j in range(nf):
#             if max_b < SP.ind_array[i].v[j]:
#                 max_b = SP.ind_array[i].v[j]
#     if max_b == 0.0:
#         max_b = 1e-8
#     max_bound = max_b
#     return max_b
#
# cdef void calcul_weight(pop *SP, int size):
#     cdef int i, j
#     for i in range(SP.size):
#         for j in range(nf):
#             SP.ind_array[i].v[j] = SP.ind_array[i].f[j] * vector_weight[j]
#
# cdef int compute_fitness_and_select(pop *SP, ind *x, int size):
#     cdef int i, worst
#     cdef double worst_fit, fit_tmp
#     SP.size = size
#     x.fitness = 0
#     compute_ind_fitness(x, SP)
#     worst_fit = x.fitness
#     worst = -1
#     for i in range(SP.size):
#         fit_tmp = update_fitness_return(SP.ind_array[i].fitness, calcAddEpsIndicator(x, SP.ind_array[i]))
#         if fit_tmp > worst_fit:
#             worst = i
#             worst_fit = fit_tmp
#     fit_tmp = x.fitness
#     if worst == -1:
#         return -1
#     else:
#         for i in range(SP.size):
#             delete_fitness(SP.ind_array[i], calcAddEpsIndicator(SP.ind_array[worst], SP.ind_array[i]))
#             update_fitness(SP.ind_array[i], calcAddEpsIndicator(x, SP.ind_array[i]))
#         delete_fitness(x, calcAddEpsIndicator(SP.ind_array[worst], x))
#         free_ind(SP.ind_array[worst])
#         SP.ind_array[worst] = ind_copy(x)
#         if fit_tmp - worst_fit > smallValue:
#             return worst
#         else:
#             return -1
#
# cdef np.ndarray get_archive_objs(pop *archive):
#     cdef int i, j
#     arr = np.zeros((archive.size, nf), dtype=np.float64)
#     for i in range(archive.size):
#         for j in range(nf):
#             arr[i, j] = archive.ind_array[i].f[j]
#     return arr
#
# cdef np.ndarray get_items(ind *x):
#     arr = np.zeros(ni, dtype=np.int32)
#     for i in range(ni):
#         arr[i] = x.Items[i]
#     return arr
#
# cdef void Indicator_local_search1(pop *SP, pop *Sarchive, int size):
#     cdef ind *x
#     cdef ind *y
#     cdef int i, j, r, t, k, l, v, sol, mino, mp, maxp, consistant, pos, stop, convergence, ii, tmp_pris, tmp_nonpris, taille, feasible, tv, IM
#     cdef int* remplace = <int *>chk_malloc(L * sizeof(int))
#     SP.size = size
#     extractPtoArchive(SP, Sarchive)
#     while True:
#         convergence = 0
#         archive_objs = get_archive_objs(Sarchive) if Sarchive.size > 0 else None
#         for i in range(SP.size):
#             if not SP.ind_array[i].explored:
#                 x = ind_copy(SP.ind_array[i])
#                 j = 0
#                 while j < x.nombr:
#                     for l in range(L):
#                         remplace[l] = 0
#                     # -------- SMART AGENT INTEGRATION --------
#                     remove_idx = -1
#                     add_idx = -1
#                     agent_move_type = None
#                     agent_success = False
#                     if py_agent is not None:
#                         state = {
#                             "Items": [x.Items[ii] for ii in range(ni)],
#                             "capa": [x.capa[ii] for ii in range(nf)],
#                             "f": [x.f[ii] for ii in range(nf)],
#                         }
#                         context = {}
#                         if archive_objs is not None:
#                             context["archive_objs"] = archive_objs
#                         try:
#                             obs = py_agent.observe(state)
#                             remove_idx, add_idx = py_agent.act(obs, context)
#                         except Exception as e:
#                             print("Agent error:", e)
#                             remove_idx = -1
#                             add_idx = -1
#                     # Fallback to random if agent does not provide usable indices
#                     if remove_idx < 0 or remove_idx >= ni or x.Items[remove_idx] != 1:
#                         while True:
#                             mino = irand(ni)
#                             if x.Items[mino] == 1:
#                                 break
#                         remove_idx = mino
#                     if add_idx < 0 or add_idx >= ni or x.Items[add_idx] != 0 or add_idx == remove_idx:
#                         while True:
#                             maxp = irand(ni)
#                             if x.Items[maxp] == 0 and maxp != remove_idx:
#                                 break
#                         add_idx = maxp
#
#                     # Remove item
#                     x.Items[remove_idx] = 0
#                     x.nombr -= 1
#                     x.nombr_nonpris += 1
#                     for r in range(nf):
#                         x.capa[r] -= weights[r][remove_idx]
#                         x.f[r] -= profits[r][remove_idx]
#
#                     IM = 0
#                     taille = 0
#                     while IM < L:
#                         item_to_add = add_idx
#                         if item_to_add < 0 or item_to_add >= ni or x.Items[item_to_add] != 0 or item_to_add == remove_idx:
#                             while True:
#                                 item_to_add = irand(ni)
#                                 if x.Items[item_to_add] == 0 and item_to_add != remove_idx:
#                                     break
#                         consistant = 1
#                         r = 0
#                         while r < nf and consistant == 1:
#                             if x.capa[r] + weights[r][item_to_add] > capacities[r]:
#                                 consistant = 0
#                             r += 1
#                         if consistant == 1:
#                             feasible = 1
#                             r = 0
#                             while r < taille and feasible:
#                                 if item_to_add == remplace[r]:
#                                     feasible = 0
#                                 r += 1
#                             if feasible == 1:
#                                 remplace[taille] = item_to_add
#                                 taille += 1
#                                 x.Items[item_to_add] = 1
#                                 x.nombr_nonpris -= 1
#                                 x.nombr += 1
#                                 for r in range(nf):
#                                     x.capa[r] += weights[r][item_to_add]
#                                     x.f[r] += profits[r][item_to_add]
#                         IM += 1
#                     for tv in range(nf):
#                         x.v[tv] = x.f[tv] * vector_weight[tv]
#                     max_bound = calcMaxbound(SP, SP.size)
#                     sol = compute_fitness_and_select(SP, x, SP.size)
#                     agent_success = (sol != -1)
#                     if py_agent is not None:
#                         try:
#                             py_agent.report_move_result(None, agent_success)
#                         except Exception:
#                             pass
#                     if sol != -1:
#                         j = x.nombr + 1
#                         if sol > i and i + 1 < SP.size:
#                             y = SP.ind_array[i + 1]
#                             SP.ind_array[i + 1] = SP.ind_array[sol]
#                             SP.ind_array[sol] = y
#                             i += 1
#                         break
#                     elif sol == -1:
#                         x.Items[remove_idx] = 1
#                         x.nombr_nonpris -= 1
#                         x.nombr += 1
#                         for r in range(nf):
#                             x.capa[r] += weights[r][remove_idx]
#                             x.f[r] += profits[r][remove_idx]
#                         if taille >= 1:
#                             for r in range(taille):
#                                 x.Items[remplace[r]] = 0
#                                 x.nombr -= 1
#                                 x.nombr_nonpris += 1
#                                 for t in range(nf):
#                                     x.capa[t] -= weights[t][remplace[r]]
#                                     x.f[t] -= profits[t][remplace[r]]
#                                     x.v[t] = x.f[t] * vector_weight[t]
#                     j += 1
#                 tmp_pris = x.nombr
#                 tmp_nonpris = x.nombr_nonpris
#                 free_ind(x)
#                 if j == tmp_pris:
#                     SP.ind_array[i].explored = 1
#         convergence = extractPtoArchive(SP, Sarchive)
#         if not convergence:
#             break
#     free(remplace)
#
# def run_moacp(instance_file, weights_file, nbitems, num_objectives, output_file):
#     global nf, ni, NBITEMS, alpha, paretoIni, L, nombreLIGNE, nextLn, inv, vector_weight
#     global capacities, weights, profits, OBJ_Weights
#
#     alpha = 10
#     paretoIni = 28000
#
#     NBL = 100
#     NRUNS = 10
#
#     for run in range(1, NRUNS+1):
#         NBITEMS = nbitems
#         ni = nbitems
#         nf = num_objectives
#
#         print(f"RUN {run}/{NRUNS} -- {instance_file.decode()} nbitems={ni} nf={nf} => {output_file}")
#
#         nombreLIGNE = 0
#         nextLn = 0
#         inv = 0
#
#         seed(run)
#         loadMOKP(instance_file)
#         read_weights_file(weights_file)
#
#         vector_weight = <double *>chk_malloc(nf * sizeof(double))
#         P = create_pop(paretoIni, nf)
#
#         it = 0
#         while it < NBL:
#             solutions = create_pop(alpha, nf)
#             archive = create_pop(paretoIni, nf)
#             choose_weight()
#             P_init_pop(solutions, P, alpha)
#             extractPtoArchive(solutions, P)
#             calcul_weight(solutions, alpha)
#             calcMaxbound(solutions, alpha)
#             compute_all_fitness(solutions)
#             Indicator_local_search1(solutions, archive, alpha)
#             extractPtoArchive(archive, P)
#             # Update agent with best observation
#             if py_agent is not None and P.size > 0:
#                 best_idx = 0
#                 best_val = P.ind_array[0].fitness
#                 for i in range(1, P.size):
#                     if P.ind_array[i].fitness > best_val:
#                         best_idx = i
#                         best_val = P.ind_array[i].fitness
#                 best_items = get_items(P.ind_array[best_idx])
#                 try:
#                     py_agent.update_best(best_items)
#                 except Exception:
#                     pass
#             it += 1
#             complete_free_pop(solutions)
#             complete_free_pop(archive)
#
#         with open(output_file, "a") as fpareto:
#             fpareto.write("\n")
#             for i in range(P.size):
#                 for j in range(nf):
#                     fpareto.write(f"{P.ind_array[i].f[j]:.6f} ")
#                 fpareto.write("\n")
#
#         complete_free_pop(P)
#         cleanup_globals()

# %%
# ---- Run both reference and smart agent experiments ----

# Experiment parameters
nbitems = 250
num_objectives = 2
instance_file = b"250.2.txt"
weights_file = b"Weights_2obj_FQ200.txt"
output_file_agent = "output_agent.txt"
output_file_ref = "output_ref.txt"

# Load data for agent
profits = load_profits_from_file("250.2.txt", num_objectives, nbitems)
weights = load_weights_from_file("250.2.txt", num_objectives, nbitems)
capacities = load_capacities_from_file("250.2.txt", num_objectives, nbitems)

# ---- Run reference (random) optimization ----
set_agent(None)  # Ensure agent is not set
run_moacp(instance_file, weights_file, nbitems, num_objectives, output_file_ref)
print("Reference optimization completed.")

# ---- Run agent optimization ----
# Example of tuning agent for experiment
agent = SmartAgent(
    nbitems=250,
    num_objectives=2,
    profits=profits,
    weights=weights,
    capacities=capacities,
    move_probs=np.array([0.35, 0.25, 0.1, 0.1, 0.2]),   # example: favor local/global more
    attempts_per_move=120,       # try higher for more search
    smoothing=0.12               # try less for faster adaptation
)
set_agent(agent)
run_moacp(instance_file, weights_file, nbitems, num_objectives, output_file_agent)
print("Agent optimization completed.")
# Out:
# RUN 1/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 2/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 3/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 4/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 5/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 6/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 7/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 8/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 9/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# RUN 10/10 -- 250.2.txt nbitems=250 nf=2 => output_ref.txt
# Reference optimization completed.
# RUN 1/10 -- 250.2.txt nbitems=250 nf=2 => output_agent.txt
# Move: global_search, Success: False, Current Probs: [0.29951738 0.1269305  0.17451738 0.17451738 0.22451738]
# Move: follow, Success: False, Current Probs: [0.31472033 0.06602279 0.08981623 0.25222033 0.27722033]
# Move: diversity, Success: False, Current Probs: [0.40167835 0.03679927 0.04869599 0.37042835 0.14239804]
# Move: follow, Success: False, Current Probs: [0.44655468 0.02220917 0.02529791 0.43092968 0.07500856]
# Move: mutation, Success: False, Current Probs: [0.69929669 0.01848472 0.01448921 0.22284497 0.04488441]
# Move: local_search, Success: False, Current Probs: [0.46731334 0.12690735 0.03658463 0.22908748 0.1401072 ]
# Move: local_search, Success: False, Current Probs: [0.2692916  0.20636372 0.05392725 0.25745378 0.21296364]
# Move: global_search, Success: False, Current Probs: [0.18001463 0.14855069 0.07233245 0.31067365 0.28842858]
# Move: mutation, Success: False, Current Probs: [0.15242624 0.13669426 0.09858515 0.21775575 0.39453861]
# Move: local_search, Success: False, Current Probs: [0.10946005 0.1349273  0.11587274 0.17545804 0.46428186]
# Move: diversity, Success: False, Current Probs: [0.11022155 0.17859077 0.16906349 0.19885614 0.34326805]
# Move: follow, Success: False, Current Probs: [0.11754998 0.21433591 0.14697096 0.2244686  0.29667455]
# Move: diversity, Success: False, Current Probs: [0.13015062 0.25010452 0.1448611  0.25517086 0.2197129 ]
# Move: diversity, Success: False, Current Probs: [0.14010045 0.27529731 0.14745569 0.27783048 0.15931607]
# Move: global_search, Success: False, Current Probs: [0.15836079 0.22595922 0.16203841 0.31576564 0.13787595]
# Move: follow, Success: False, Current Probs: [0.17314632 0.20694554 0.14296536 0.34605864 0.13088413]
# Move: mutation, Success: False, Current Probs: [0.20235461 0.21925422 0.14781051 0.28881076 0.1417699 ]
# Move: global_search, Success: False, Current Probs: [0.22687739 0.19249371 0.15677186 0.27010547 0.15375156]
# Move: mutation, Success: False, Current Probs: [0.25091606 0.18687752 0.16901659 0.2256834  0.16750644]
# Move: diversity, Success: False, Current Probs: [0.26925711 0.18823696 0.17930649 0.2076399  0.15555955]
# Move: follow, Success: False, Current Probs: [0.28535877 0.19348596 0.16492065 0.20318743 0.15304718]
# Move: diversity, Success: False, Current Probs: [0.29760683 0.19887745 0.15982362 0.20372818 0.13996392]
# Move: local_search, Success: False, Current Probs: [0.2629949  0.21363021 0.16640788 0.21605557 0.14091145]
# Move: mutation, Success: False, Current Probs: [0.25238499 0.22770265 0.17477204 0.19959589 0.14554444]
# Move: local_search, Success: False, Current Probs: [0.22346452 0.24226915 0.18465804 0.19706997 0.15253833]
# Move: global_search, Success: False, Current Probs: [0.21546602 0.22486834 0.19606279 0.20226875 0.1613341 ]
# Move: mutation, Success: False, Current Probs: [0.21549018 0.22019133 0.20578856 0.18949863 0.16903131]
# Move: local_search, Success: False, Current Probs: [0.19967492 0.22220093 0.21499954 0.18667914 0.17644548]
# Move: diversity, Success: False, Current Probs: [0.19416526 0.22612996 0.22252927 0.18766737 0.16950814]
# Move: follow, Success: False, Current Probs: [0.1954846  0.2330628  0.20966661 0.19223566 0.16955032]
# Move: local_search, Success: False, Current Probs: [0.18491053 0.23988588 0.20598784 0.19727237 0.17194339]
# Move: global_search, Success: False, Current Probs: [0.18367357 0.2257974  0.20884838 0.20449064 0.17719   ]
# Move: mutation, Success: False, Current Probs: [0.18580578 0.2219452  0.2134707  0.19621432 0.182564  ]
# Move: follow, Success: False, Current Probs: [0.18979363 0.22340965 0.20362609 0.1949979  0.18817274]
# Move: diversity, Success: False, Current Probs: [0.19388402 0.22657471 0.20080024 0.19648615 0.18225487]
# Move: global_search, Success: False, Current Probs: [0.19917673 0.21552208 0.20263485 0.2004778  0.18218853]
# Move: local_search, Success: False, Current Probs: [0.19273094 0.21233266 0.20588904 0.20481052 0.18423684]
# Move: follow, Success: False, Current Probs: [0.19168691 0.21318417 0.19826596 0.20942309 0.18743986]
# Move: diversity, Success: False, Current Probs: [0.19279953 0.21544513 0.19608906 0.2135646  0.18210168]
# Move: global_search, Success: False, Current Probs: [0.19571904 0.20704184 0.1973638  0.21828852 0.18158679]
# Move: local_search, Success: False, Current Probs: [0.19001433 0.2046161  0.19977708 0.2226443  0.1829482 ]
# Move: global_search, Success: False, Current Probs: [0.18883976 0.19614065 0.20282428 0.2268886  0.1853067 ]
# Move: global_search, Success: False, Current Probs: [0.18955506 0.18626453 0.20577684 0.23061504 0.18778853]
# Move: follow, Success: False, Current Probs: [0.19170184 0.18298507 0.19981273 0.23468179 0.19081858]
# Move: mutation, Success: False, Current Probs: [0.19537211 0.18375275 0.19942755 0.22651711 0.19493048]
# Move: global_search, Success: False, Current Probs: [0.19834356 0.17948109 0.20037128 0.22368132 0.19812275]
# Move: local_search, Success: False, Current Probs: [0.19387641 0.17865116 0.20234362 0.22390946 0.20121935]
# Move: follow, Success: False, Current Probs: [0.19307593 0.17958161 0.19730953 0.22571939 0.20431354]
# Move: global_search, Success: False, Current Probs: [0.19358695 0.17616299 0.19570375 0.2277027  0.20684361]
# Move: mutation, Success: False, Current Probs: [0.19585462 0.17624448 0.19691302 0.22070871 0.21027917]
# Move: diversity, Success: False, Current Probs: [0.19855753 0.17768167 0.19908673 0.21890427 0.2057698 ]
# Move: global_search, Success: False, Current Probs: [0.2007222  0.17508339 0.2009868  0.21887928 0.20432834]
# Move: global_search, Success: False, Current Probs: [0.20248988 0.17098892 0.20262218 0.21960606 0.20429295]
# Move: mutation, Success: False, Current Probs: [0.2050423  0.17030504 0.20510845 0.21360039 0.20594383]
# Move: follow, Success: False, Current Probs: [0.20765375 0.1710541  0.20125483 0.2119328  0.20810452]
# Move: follow, Success: False, Current Probs: [0.2100502  0.17231984 0.19516464 0.21218973 0.21027559]
# Move: diversity, Success: False, Current Probs: [0.21264724 0.17409565 0.19336446 0.21371701 0.20617563]
# Move: global_search, Success: False, Current Probs: [0.2145956  0.17249548 0.19304272 0.21513048 0.20473573]
# Move: diversity, Success: False, Current Probs: [0.21672697 0.17260864 0.19391173 0.21699441 0.19975824]
# Move: diversity, Success: False, Current Probs: [0.21875499 0.17342469 0.1952027  0.21888871 0.19372891]
# Move: local_search, Success: False, Current Probs: [0.21443432 0.17502561 0.19719342 0.22134738 0.19199927]
# Move: follow, Success: False, Current Probs: [0.21321893 0.17662041 0.19458724 0.22358325 0.19199016]
# Move: global_search, Success: False, Current Probs: [0.21318432 0.17519641 0.1938031  0.22531161 0.19250456]
# Move: local_search, Success: False, Current Probs: [0.20875604 0.17545855 0.19449307 0.22744855 0.1938438 ]
# Move: follow, Success: False, Current Probs: [0.20732363 0.17626191 0.1917589  0.22939539 0.19526017]
# Move: mutation, Success: False, Current Probs: [0.20808538 0.17793462 0.19174871 0.22485112 0.19738016]
# Move: mutation, Success: False, Current Probs: [0.2096768  0.17981204 0.19285498 0.21805967 0.19959652]
# Move: global_search, Success: False, Current Probs: [0.21099066 0.17874378 0.19388382 0.21518209 0.20119966]
# Move: mutation, Success: False, Current Probs: [0.21266589 0.17906186 0.19533312 0.20996517 0.20297396]
# Move: diversity, Success: False, Current Probs: [0.21436406 0.17994109 0.19684784 0.20817876 0.20066825]
# Move: global_search, Success: False, Current Probs: [0.21568543 0.17859008 0.19803879 0.2077367  0.199949  ]
# Move: mutation, Success: False, Current Probs: [0.2172283  0.1786351  0.19944418 0.20429314 0.20039928]
# Move: diversity, Success: False, Current Probs: [0.21875467 0.1792742  0.20083996 0.20326444 0.19786673]
# Move: global_search, Success: False, Current Probs: [0.21994936 0.17798727 0.20193401 0.20314625 0.1969831 ]
# Move: follow, Success: False, Current Probs: [0.22131816 0.17796022 0.19970083 0.20379542 0.19722537]
# Move: global_search, Success: False, Current Probs: [0.22239314 0.17650484 0.19893058 0.20447858 0.19769285]
# Move: diversity, Success: False, Current Probs: [0.22360271 0.17630361 0.19914142 0.20543719 0.19551506]
# Move: diversity, Success: False, Current Probs: [0.2247944  0.17666273 0.19976728 0.20645532 0.19232027]
# Move: diversity, Success: False, Current Probs: [0.22590701 0.17724709 0.20053845 0.20743881 0.18886863]
# Move: mutation, Success: False, Current Probs: [0.22727646 0.17817623 0.20164509 0.20509527 0.18780694]
# Move: mutation, Success: False, Current Probs: [0.22866487 0.17919202 0.2028224  0.20146988 0.18785083]
# Move: local_search, Success: False, Current Probs: [0.22535413 0.18063728 0.20447218 0.20068629 0.18885012]
# Move: mutation, Success: False, Current Probs: [0.22429822 0.18185149 0.20585355 0.19813443 0.18986231]
# Move: global_search, Success: False, Current Probs: [0.22413674 0.18111751 0.20688443 0.19717957 0.19068175]
# Move: diversity, Success: False, Current Probs: [0.22452312 0.18112674 0.2078335  0.19711138 0.18940526]
# Move: follow, Success: False, Current Probs: [0.22542922 0.1817055  0.20580008 0.19770187 0.18936333]
# Move: follow, Success: False, Current Probs: [0.22650519 0.18249657 0.20259196 0.19854285 0.18986343]
# Move: follow, Success: False, Current Probs: [0.22759196 0.18333408 0.19905733 0.19944413 0.19057251]
# Move: follow, Success: False, Current Probs: [0.22862233 0.18414504 0.19557681 0.20032142 0.1913344 ]
# Move: local_search, Success: False, Current Probs: [0.22566506 0.18538424 0.19470245 0.201667   0.19258125]
# Move: follow, Success: False, Current Probs: [0.22461207 0.18636052 0.1927245  0.2027278  0.19357512]
# Move: follow, Success: False, Current Probs: [0.22446802 0.18716913 0.19035113 0.20360681 0.19440491]
# Move: mutation, Success: False, Current Probs: [0.22495083 0.18803838 0.18962938 0.20207873 0.19530269]
# Move: local_search, Success: False, Current Probs: [0.22218968 0.18920529 0.19000079 0.2020921  0.19651214]
# Move: mutation, Success: False, Current Probs: [0.2212922  0.19020787 0.19060562 0.20034215 0.19755216]
# Move: global_search, Success: False, Current Probs: [0.22118871 0.18944217 0.19120757 0.19977827 0.19838328]
# Move: mutation, Success: False, Current Probs: [0.2215713  0.18942999 0.19188536 0.19792315 0.1991902 ]
# Move: diversity, Success: False, Current Probs: [0.22220035 0.18979748 0.19260405 0.1973823  0.19801582]
# Move: mutation, Success: False, Current Probs: [0.2229083  0.19031698 0.19330472 0.19569384 0.19777617]
# Move: global_search, Success: False, Current Probs: [0.22358288 0.18941657 0.19393321 0.19512777 0.19793956]
# Move: follow, Success: False, Current Probs: [0.22427766 0.18926687 0.19296354 0.19515488 0.19833705]
# Move: diversity, Success: False, Current Probs: [0.22502608 0.18952914 0.19282095 0.19551637 0.19710745]
# Move: mutation, Success: False, Current Probs: [0.22576264 0.18996487 0.19305888 0.19440659 0.19680702]
# Move: follow, Success: False, Current Probs: [0.22645986 0.19045926 0.19200626 0.19413243 0.19694219]
# Move: global_search, Success: False, Current Probs: [0.22710841 0.1896382  0.19173208 0.19425131 0.19726999]
# Move: mutation, Success: False, Current Probs: [0.2277653  0.18950342 0.1918746  0.19313421 0.19772246]
# Move: follow, Success: False, Current Probs: [0.22839703 0.18968747 0.19087306 0.19283062 0.19821183]
# Move: follow, Success: False, Current Probs: [0.22899055 0.19000967 0.18939018 0.19291221 0.19869739]
# Move: local_search, Success: False, Current Probs: [0.22660029 0.1908346  0.18930411 0.19362613 0.19963487]
# Move: diversity, Success: False, Current Probs: [0.22577365 0.19156205 0.18957205 0.19430248 0.19878978]
# Move: global_search, Success: False, Current Probs: [0.22563651 0.1909341  0.1899391  0.19488004 0.19861026]
# Move: diversity, Success: False, Current Probs: [0.22590415 0.19090387 0.19040637 0.19546025 0.19732536]
# Move: mutation, Success: False, Current Probs: [0.22634459 0.19114751 0.19089876 0.19466047 0.19694867]
# Move: diversity, Success: False, Current Probs: [0.22687308 0.1915295  0.19140512 0.1945241  0.1956682 ]
# Move: diversity, Success: False, Current Probs: [0.22741958 0.19195869 0.1918965  0.19469719 0.19402804]
# Move: global_search, Success: False, Current Probs: [0.22795219 0.19125444 0.19236108 0.19500544 0.19342685]
# Move: local_search, Success: False, Current Probs: [0.22583594 0.19149076 0.19318884 0.19576273 0.19372173]
# Move: mutation, Success: False, Current Probs: [0.22505855 0.19184951 0.19384619 0.19513313 0.19411263]
# Move: mutation, Success: False, Current Probs: [0.22492784 0.19224998 0.19439859 0.19389178 0.19453181]
# Move: mutation, Success: False, Current Probs: [0.22510036 0.19265407 0.19488109 0.19241678 0.1949477 ]
# Move: global_search, Success: False, Current Probs: [0.22542551 0.19200041 0.19532951 0.19188176 0.19536281]
# Move: local_search, Success: False, Current Probs: [0.22347285 0.19219633 0.19608858 0.19213701 0.19610523]
# Move: diversity, Success: False, Current Probs: [0.22275441 0.19251827 0.19669728 0.19248861 0.19554143]
# Move: global_search, Success: False, Current Probs: [0.22261421 0.19188305 0.19719625 0.19285463 0.19545186]
# Move: diversity, Success: False, Current Probs: [0.22278285 0.19177067 0.19765789 0.19324499 0.19454361]
# Move: follow, Success: False, Current Probs: [0.2231284  0.19193904 0.19694914 0.19366706 0.19431636]
# Move: follow, Success: False, Current Probs: [0.22354207 0.19223032 0.19572835 0.19408731 0.19441196]
# Move: local_search, Success: False, Current Probs: [0.22185475 0.19284585 0.1955927  0.19477218 0.19493451]
# Move: diversity, Success: False, Current Probs: [0.22123122 0.19334705 0.1957203  0.19531004 0.19439138]
# Move: diversity, Success: False, Current Probs: [0.22112367 0.19377709 0.19596539 0.19576026 0.19337358]
# Move: diversity, Success: False, Current Probs: [0.22125984 0.19415902 0.19625657 0.196154   0.19217057]
# Move: local_search, Success: False, Current Probs: [0.21962726 0.19477491 0.19683147 0.19678018 0.19198618]
# Move: follow, Success: False, Current Probs: [0.21903111 0.19528016 0.19630844 0.19729262 0.19208767]
# Move: diversity, Success: False, Current Probs: [0.21890891 0.19569042 0.19620456 0.1977081  0.191488  ]
# Move: follow, Success: False, Current Probs: [0.21905269 0.1960792  0.19539982 0.19810137 0.19136692]
# Move: local_search, Success: False, Current Probs: [0.21758885 0.19666001 0.19538019 0.19868842 0.19168254]
# Move: global_search, Success: False, Current Probs: [0.21706049 0.19619429 0.19555438 0.19916964 0.19202119]
# Move: follow, Success: False, Current Probs: [0.21698568 0.19613261 0.19493812 0.19958485 0.19235874]
# Move: mutation, Success: False, Current Probs: [0.2171702  0.19630237 0.1948288  0.19897397 0.19272466]
# Move: local_search, Success: False, Current Probs: [0.21586819 0.19673726 0.19512103 0.19902191 0.19325161]
# Move: mutation, Success: False, Current Probs: [0.21542117 0.19714214 0.19545292 0.19828447 0.1936993 ]
# Move: follow, Success: False, Current Probs: [0.21537399 0.19750662 0.1949592  0.19807779 0.1940824 ]
# Move: mutation, Success: False, Current Probs: [0.21554077 0.19786381 0.19488428 0.19726527 0.19444588]
# Move: follow, Success: False, Current Probs: [0.21578957 0.1981944  0.19422939 0.19700965 0.194777  ]
# Move: follow, Success: False, Current Probs: [0.21606892 0.19850208 0.19332355 0.19702296 0.19508249]
# Move: local_search, Success: False, Current Probs: [0.21493432 0.1989792  0.19318352 0.19735001 0.19555296]
# Move: mutation, Success: False, Current Probs: [0.21454409 0.19938294 0.19327338 0.19684906 0.19595053]
# Move: global_search, Success: False, Current Probs: [0.21454014 0.19887047 0.19349093 0.19677386 0.1963246 ]
# Move: follow, Success: False, Current Probs: [0.21468337 0.19874848 0.193054   0.19686939 0.19664476]
# Move: follow, Success: False, Current Probs: [0.21489154 0.19881375 0.19232232 0.19704235 0.19693004]
# Move: follow, Success: False, Current Probs: [0.21512429 0.19896534 0.19147291 0.19724681 0.19719065]
# Move: global_search, Success: False, Current Probs: [0.21542032 0.19837302 0.19120723 0.19751375 0.19748567]
# Move: mutation, Success: False, Current Probs: [0.21573628 0.19823084 0.19122305 0.19702268 0.19778716]
# Move: global_search, Success: False, Current Probs: [0.21606272 0.19753446 0.19138007 0.19693038 0.19809236]
# Move: mutation, Success: False, Current Probs: [0.21638376 0.19732984 0.19159827 0.19629846 0.19838966]
# Move: global_search, Success: False, Current Probs: [0.21670257 0.1966411  0.19184748 0.19612542 0.19868343]
# Move: mutation, Success: False, Current Probs: [0.21701055 0.1964309  0.1921036  0.19548841 0.19896655]
# Move: global_search, Success: False, Current Probs: [0.21731353 0.19577473 0.19236354 0.19530349 0.19924471]
# Move: follow, Success: False, Current Probs: [0.21758902 0.19555783 0.19203347 0.19532221 0.19949747]
# Move: diversity, Success: False, Current Probs: [0.21789807 0.19560297 0.19201917 0.19548516 0.19899463]
# Move: mutation, Success: False, Current Probs: [0.21819349 0.19575187 0.19213599 0.19504728 0.19887137]
# Move: global_search, Success: False, Current Probs: [0.21848245 0.19530645 0.1923187  0.19495416 0.19893824]
# Move: mutation, Success: False, Current Probs: [0.21876003 0.1952023  0.19252717 0.19441776 0.19909274]
# Move: local_search, Success: False, Current Probs: [0.21771554 0.19544582 0.19292343 0.19444333 0.19947188]
# Move: mutation, Success: False, Current Probs: [0.21731794 0.19568016 0.19323276 0.19399272 0.19977642]
# Move: mutation, Success: False, Current Probs: [0.21723697 0.19590375 0.19349257 0.19332933 0.20003738]
# Move: mutation, Success: False, Current Probs: [0.21730805 0.19611631 0.19372201 0.19258287 0.20027076]
# Move: mutation, Success: False, Current Probs: [0.21744937 0.19631812 0.19393111 0.19181637 0.20048502]
# Move: follow, Success: False, Current Probs: [0.2176386  0.19652611 0.19359656 0.19153722 0.20070151]
# Move: global_search, Success: False, Current Probs: [0.21786701 0.19613671 0.19354799 0.19151512 0.20093317]
# Move: local_search, Success: False, Current Probs: [0.21689203 0.19621468 0.19379325 0.19177082 0.20132922]
# Move: local_search, Success: False, Current Probs: [0.21540308 0.19650438 0.19416372 0.19214393 0.20178489]
# Move: local_search, Success: False, Current Probs: [0.21373474 0.19688051 0.19457758 0.19255675 0.20225042]
# Move: global_search, Success: False, Current Probs: [0.21302432 0.19660016 0.19489829 0.19287576 0.20260147]
# Move: local_search, Success: False, Current Probs: [0.21181349 0.19667324 0.1952707  0.19324512 0.20299745]
# Move: follow, Success: False, Current Probs: [0.21131795 0.19681242 0.19503727 0.19353081 0.20330155]
# Move: diversity, Success: False, Current Probs: [0.21122923 0.1970306  0.19506753 0.19381988 0.20285276]
# Move: diversity, Success: False, Current Probs: [0.2113342  0.19727919 0.19522063 0.19410169 0.20206429]
# Move: diversity, Success: False, Current Probs: [0.21152713 0.1975347  0.19542697 0.19437172 0.20113948]
# Move: follow, Success: False, Current Probs: [0.21172867 0.19776061 0.19513095 0.19460333 0.20077644]
# Move: follow, Success: False, Current Probs: [0.21192921 0.19796676 0.19460392 0.19481085 0.20068926]
# Move: global_search, Success: False, Current Probs: [0.21214746 0.19762385 0.19444836 0.19502309 0.20075724]
# Move: follow, Success: False, Current Probs: [0.21235165 0.1975407  0.19400992 0.19521659 0.20088113]
# Move: follow, Success: False, Current Probs: [0.21254424 0.19758319 0.19344739 0.19539654 0.20102865]
# Move: diversity, Success: False, Current Probs: [0.21277415 0.19772856 0.19328728 0.19560936 0.20060064]
# Move: follow, Success: False, Current Probs: [0.21297557 0.19788157 0.19287973 0.19579525 0.20046789]
# Move: diversity, Success: False, Current Probs: [0.21320261 0.19807543 0.19279002 0.19600434 0.1999276 ]
# Move: follow, Success: False, Current Probs: [0.21339882 0.19824917 0.19243241 0.1961849  0.1997347 ]
# Move: follow, Success: False, Current Probs: [0.21357589 0.19840941 0.19195489 0.19634778 0.19971203]
# Move: follow, Success: False, Current Probs: [0.21373994 0.19855967 0.19143053 0.19649864 0.19977123]
# Move: diversity, Success: False, Current Probs: [0.21394193 0.19874625 0.19127542 0.19668436 0.19935203]
# Move: diversity, Success: False, Current Probs: [0.21415653 0.19894507 0.19129925 0.19688166 0.19871748]
# Move: local_search, Success: False, Current Probs: [0.21345945 0.19924838 0.19150706 0.1971821  0.19860302]
# Move: mutation, Success: False, Current Probs: [0.21321242 0.19949525 0.19170244 0.1969494  0.19864049]
# Move: follow, Success: False, Current Probs: [0.21316123 0.19968651 0.19152571 0.19689985 0.1987267 ]
# Move: diversity, Success: False, Current Probs: [0.21324311 0.19988295 0.19153385 0.19697436 0.19836573]
# Move: follow, Success: False, Current Probs: [0.21335347 0.20004628 0.19127484 0.19707573 0.19824968]
# Move: global_search, Success: False, Current Probs: [0.21352262 0.19970094 0.19124732 0.19723169 0.19829743]
# Move: mutation, Success: False, Current Probs: [0.21370437 0.19961893 0.19132052 0.19694467 0.19841151]
# Move: diversity, Success: False, Current Probs: [0.21389784 0.19967364 0.19144892 0.19689549 0.19808411]
# Move: follow, Success: False, Current Probs: [0.21406153 0.19976345 0.19126031 0.19693246 0.19798225]
# Move: global_search, Success: False, Current Probs: [0.21425198 0.1994027  0.19126288 0.1970508  0.19803164]
# Move: follow, Success: False, Current Probs: [0.21441158 0.19928207 0.19102137 0.19716917 0.19811581]
# Move: local_search, Success: False, Current Probs: [0.21373825 0.19941273 0.19108355 0.19741753 0.19834794]
# Move: mutation, Success: False, Current Probs: [0.21349421 0.19956481 0.19119774 0.19719291 0.19855033]
# Move: global_search, Success: False, Current Probs: [0.21347509 0.19925468 0.19134715 0.19717564 0.19874744]
# Move: mutation, Success: False, Current Probs: [0.21355399 0.19918205 0.1915012  0.19683434 0.19892843]
# Move: local_search, Success: False, Current Probs: [0.21288951 0.19932397 0.19174979 0.19683958 0.19919716]
# Move: mutation, Success: False, Current Probs: [0.21264126 0.19947386 0.19195007 0.19652436 0.19941046]
# Move: global_search, Success: False, Current Probs: [0.21261481 0.1991807  0.19213858 0.19645699 0.19960892]
# Move: local_search, Success: False, Current Probs: [0.2119426  0.19920057 0.19239379 0.19658766 0.19987537]
# Move: global_search, Success: False, Current Probs: [0.21169906 0.19885964 0.19260581 0.19673919 0.20009629]
# Move: mutation, Success: False, Current Probs: [0.21165744 0.19876442 0.1927849  0.19651057 0.20028267]
# Move: mutation, Success: False, Current Probs: [0.21171325 0.19878875 0.19294432 0.19610522 0.20044845]
# Move: global_search, Success: False, Current Probs: [0.21182965 0.19846614 0.19310472 0.19598432 0.20061517]
# Move: mutation, Success: False, Current Probs: [0.21196131 0.19837351 0.1932519  0.19564515 0.20076812]
# Move: global_search, Success: False, Current Probs: [0.21211169 0.19800761 0.19340259 0.19555342 0.20092469]
# Move: local_search, Success: False, Current Probs: [0.21156726 0.19798012 0.19363018 0.19566131 0.20116114]
# Move: follow, Success: False, Current Probs: [0.21135684 0.19802433 0.19350792 0.19577257 0.20133834]
# Move: diversity, Success: False, Current Probs: [0.21134966 0.1981384  0.19353658 0.19591915 0.20105621]
# Move: mutation, Success: False, Current Probs: [0.21141647 0.19826147 0.19361539 0.19572464 0.20098203]
# Move: local_search, Success: False, Current Probs: [0.21086716 0.19846961 0.19379793 0.19577189 0.20109341]
# Move: follow, Success: False, Current Probs: [0.21065185 0.19862974 0.19366177 0.19585076 0.20120587]
# Move: mutation, Success: False, Current Probs: [0.2106115  0.19877339 0.19365559 0.19563303 0.20132648]
# Move: diversity, Success: False, Current Probs: [0.21068462 0.19893334 0.1937383  0.19561075 0.20103299]
# Move: diversity, Success: False, Current Probs: [0.2108101  0.19909731 0.19386143 0.19568213 0.20054904]
# Move: mutation, Success: False, Current Probs: [0.21093765 0.19924052 0.19398259 0.1954707  0.20036853]
# Move: mutation, Success: False, Current Probs: [0.21106368 0.19937093 0.19410042 0.19512764 0.20033732]
# Move: mutation, Success: False, Current Probs: [0.21118653 0.19949266 0.19421437 0.19472798 0.20037847]
# Move: global_search, Success: False, Current Probs: [0.21132915 0.19924598 0.19434601 0.19460281 0.20047605]
# Move: diversity, Success: False, Current Probs: [0.21148573 0.19920288 0.19449025 0.19461866 0.20020248]
# Move: global_search, Success: False, Current Probs: [0.21164179 0.19888708 0.19463389 0.19469809 0.20013916]
# Move: diversity, Success: False, Current Probs: [0.21180139 0.19880566 0.19478072 0.19481282 0.1997994 ]
# Move: mutation, Success: False, Current Probs: [0.2119391  0.19881925 0.1949074  0.19465022 0.19968403]
# Move: mutation, Success: False, Current Probs: [0.21206371 0.19887831 0.19502201 0.19435716 0.1996788 ]
# Move: mutation, Success: False, Current Probs: [0.21217973 0.1989582  0.19512871 0.19400663 0.19972673]
# Move: global_search, Success: False, Current Probs: [0.21231251 0.19871602 0.19525083 0.19389958 0.19982106]
# Move: global_search, Success: False, Current Probs: [0.21245054 0.19832466 0.19537777 0.19391139 0.19993564]
# Move: diversity, Success: False, Current Probs: [0.21259801 0.19820203 0.19551339 0.19398888 0.19969769]
# Move: follow, Success: False, Current Probs: [0.21273009 0.19819504 0.19536061 0.19408084 0.19963342]
# Move: local_search, Success: False, Current Probs: [0.21224311 0.19833079 0.19542137 0.19426324 0.19974149]
# Move: global_search, Success: False, Current Probs: [0.21206823 0.19813898 0.19551508 0.19441743 0.19986028]
# Move: mutation, Success: False, Current Probs: [0.2120327  0.19809159 0.19560987 0.19429717 0.19996867]
# Move: follow, Success: False, Current Probs: [0.21207102 0.19812028 0.1954445  0.19428841 0.20007579]
# Move: global_search, Success: False, Current Probs: [0.21215615 0.19788523 0.19542255 0.19434445 0.20019162]
# Move: diversity, Success: False, Current Probs: [0.21227395 0.19783777 0.19548084 0.19444138 0.19996606]
# Move: diversity, Success: False, Current Probs: [0.21240493 0.19788115 0.19557634 0.19455587 0.19958171]
# Move: diversity, Success: False, Current Probs: [0.21253953 0.19796721 0.19568772 0.19467641 0.19912914]
# Move: global_search, Success: False, Current Probs: [0.21267045 0.19777033 0.19580198 0.19479495 0.1989623 ]
# Move: mutation, Success: False, Current Probs: [0.21278637 0.19771874 0.19590557 0.1946633  0.19892602]
# Move: follow, Success: False, Current Probs: [0.21289877 0.19774349 0.19575182 0.1946472  0.19895872]
# Move: local_search, Success: False, Current Probs: [0.21243151 0.1978874  0.19580505 0.19476861 0.19910743]
# Move: local_search, Success: False, Current Probs: [0.21170372 0.19808354 0.19595448 0.19495153 0.19930674]
# Move: global_search, Success: False, Current Probs: [0.21140068 0.19795038 0.19608575 0.19509926 0.19946393]
# Move: global_search, Success: False, Current Probs: [0.21130769 0.19766137 0.1962058  0.19522727 0.19959788]
# Move: local_search, Success: False, Current Probs: [0.21079355 0.19763387 0.19638221 0.1954071  0.19978327]
# Move: local_search, Success: False, Current Probs: [0.21009362 0.19773094 0.19658065 0.19560669 0.1999881 ]
# Move: local_search, Success: False, Current Probs: [0.20932368 0.19788456 0.1967844  0.1958105  0.20019686]
# Move: follow, Success: False, Current Probs: [0.20899045 0.1980105  0.19668706 0.19596103 0.20035096]
# Move: global_search, Success: False, Current Probs: [0.20887972 0.19785872 0.19669104 0.19608882 0.20048171]
# Move: local_search, Success: False, Current Probs: [0.20842522 0.19788256 0.19679225 0.19625169 0.20064828]
# Move: global_search, Success: False, Current Probs: [0.20825166 0.19768743 0.19689368 0.19638383 0.2007834 ]
# Move: diversity, Success: False, Current Probs: [0.2082305  0.19765215 0.19700653 0.19651188 0.20059895]
# Move: diversity, Success: False, Current Probs: [0.20828295 0.19769433 0.19712262 0.19663543 0.20026467]
# Move: follow, Success: False, Current Probs: [0.20835917 0.19776288 0.19698802 0.19674442 0.20014551]
# Move: diversity, Success: False, Current Probs: [0.20845793 0.19785471 0.19697799 0.19685619 0.19985318]
# Move: follow, Success: False, Current Probs: [0.20855562 0.19794648 0.19678694 0.19695771 0.19975324]
# Move: follow, Success: False, Current Probs: [0.20865114 0.19803666 0.19651173 0.19705254 0.19974793]
# Move: diversity, Success: False, Current Probs: [0.20875734 0.19813723 0.19642906 0.19715516 0.19952121]
# Move: global_search, Success: False, Current Probs: [0.20886259 0.19798734 0.19643675 0.19725571 0.19945761]
# Move: global_search, Success: False, Current Probs: [0.20896551 0.19771931 0.19648788 0.1973535  0.1994738 ]
# Move: follow, Success: False, Current Probs: [0.20906221 0.19762802 0.19633959 0.19744511 0.19952506]
# Move: diversity, Success: False, Current Probs: [0.20916699 0.19763567 0.19631837 0.19754421 0.19933477]
# Move: diversity, Success: False, Current Probs: [0.20927373 0.19769082 0.19635875 0.1976451  0.19903159]
# Move: global_search, Success: False, Current Probs: [0.2093758  0.19753181 0.19642462 0.19774153 0.19892623]
# Move: global_search, Success: False, Current Probs: [0.20947388 0.19727208 0.19650167 0.19783418 0.19891819]
# Move: diversity, Success: False, Current Probs: [0.20957541 0.19719157 0.19658945 0.19793008 0.1987135 ]
# Move: mutation, Success: False, Current Probs: [0.20967501 0.19719722 0.19667914 0.19779124 0.19865739]
# Move: local_search, Success: False, Current Probs: [0.20934288 0.19729536 0.19681909 0.19781735 0.19872532]
# Move: local_search, Success: False, Current Probs: [0.20881319 0.19743518 0.19697961 0.19792135 0.19885067]
# Move: follow, Success: False, Current Probs: [0.20859212 0.19754661 0.19689114 0.19801497 0.19895517]
# Move: local_search, Success: False, Current Probs: [0.20813488 0.19768889 0.1969331  0.19814854 0.19909459]
# Move: follow, Success: False, Current Probs: [0.20794852 0.19780027 0.19679072 0.19825566 0.19920483]
# Move: local_search, Success: False, Current Probs: [0.20752441 0.19793863 0.19680167 0.19839208 0.19934321]
# Move: mutation, Success: False, Current Probs: [0.20735913 0.19805255 0.1968516  0.19827927 0.19945745]
# Move: diversity, Success: False, Current Probs: [0.2073268  0.19815763 0.19692437 0.19827099 0.19932021]
# Move: diversity, Success: False, Current Probs: [0.2073592  0.19825661 0.19700691 0.1983133  0.19906398]
# Move: global_search, Success: False, Current Probs: [0.20742069 0.19813104 0.19709122 0.19837777 0.19897928]
# Move: mutation, Success: False, Current Probs: [0.20749677 0.19811151 0.19717646 0.19823488 0.19898038]
# Move: local_search, Success: False, Current Probs: [0.20721816 0.19818091 0.1972979  0.19824259 0.19906045]
# Move: global_search, Success: False, Current Probs: [0.20712259 0.19804616 0.19740034 0.19828834 0.19914257]
# Move: follow, Success: False, Current Probs: [0.20711574 0.19801791 0.19729291 0.19835043 0.19922301]
# Move: follow, Success: False, Current Probs: [0.20715195 0.19804168 0.19708553 0.19841945 0.19930138]
# Move: local_search, Success: False, Current Probs: [0.20686701 0.19812928 0.1970571  0.19852983 0.19941678]
# Move: diversity, Success: False, Current Probs: [0.20677143 0.19821807 0.19708761 0.19863012 0.19929277]
# Move: diversity, Success: False, Current Probs: [0.20676896 0.19830595 0.19714609 0.19872383 0.19905516]
# Move: global_search, Success: False, Current Probs: [0.20681009 0.19818565 0.19721574 0.19881143 0.19897709]
# Move: follow, Success: False, Current Probs: [0.20686909 0.1981623  0.19710142 0.19889218 0.19897501]
# Move: follow, Success: False, Current Probs: [0.20693584 0.1981863  0.19689968 0.19896838 0.1990098 ]
# Move: mutation, Success: False, Current Probs: [0.20701314 0.19824035 0.19684055 0.19883653 0.19906943]
# Move: global_search, Success: False, Current Probs: [0.2070929  0.19810825 0.19685004 0.19881004 0.19913877]
# Move: follow, Success: False, Current Probs: [0.20716898 0.19807679 0.19671446 0.19883153 0.19920824]
# Move: local_search, Success: False, Current Probs: [0.20691626 0.1981337  0.19671877 0.19891521 0.19931607]
# Move: diversity, Success: False, Current Probs: [0.20683384 0.19820428 0.19676274 0.19899935 0.19919978]
# Move: global_search, Success: False, Current Probs: [0.20683242 0.19808528 0.19682261 0.19907974 0.19917995]
# Move: follow, Success: False, Current Probs: [0.20686682 0.19805938 0.19671621 0.19915374 0.19920385]
# Move: global_search, Success: False, Current Probs: [0.20692261 0.19789687 0.19669967 0.1992279  0.19925295]
# Move: diversity, Success: False, Current Probs: [0.20699311 0.19785631 0.19673189 0.199306   0.19911269]
# Move: global_search, Success: False, Current Probs: [0.20706579 0.19769099 0.19678358 0.1993811  0.19907854]
# Move: global_search, Success: False, Current Probs: [0.20713845 0.19746764 0.19684393 0.19945362 0.19909636]
# Move: global_search, Success: False, Current Probs: [0.20721002 0.19721945 0.19690759 0.19952381 0.19913913]
# Move: mutation, Success: False, Current Probs: [0.20728853 0.19713595 0.19698002 0.19939391 0.19920158]
# Move: global_search, Success: False, Current Probs: [0.20736203 0.19696162 0.19704878 0.19936187 0.1992657 ]
# Move: mutation, Success: False, Current Probs: [0.20744016 0.19691372 0.19712248 0.19918609 0.19933754]
# Move: mutation, Success: False, Current Probs: [0.20751932 0.1969278  0.19719743 0.19894347 0.19941197]
# Move: local_search, Success: False, Current Probs: [0.20727941 0.19700431 0.19730448 0.19889224 0.19951955]
# Move: follow, Success: False, Current Probs: [0.20719371 0.19707516 0.19722525 0.19889952 0.19960636]
# Move: local_search, Success: False, Current Probs: [0.20688279 0.19717724 0.19725228 0.19897041 0.19971728]
# Move: mutation, Success: False, Current Probs: [0.20676605 0.19726526 0.19730278 0.19885572 0.1998102 ]
# Move: diversity, Success: False, Current Probs: [0.20674903 0.19734876 0.19736752 0.19883814 0.19969656]
# Move: diversity, Success: False, Current Probs: [0.20678057 0.19742875 0.19743814 0.19886787 0.19948467]
# Move: follow, Success: False, Current Probs: [0.20682962 0.19750053 0.19734432 0.19891474 0.19941079]
# Move: follow, Success: False, Current Probs: [0.20688648 0.1975673  0.19717195 0.19896927 0.199405  ]
# Move: diversity, Success: False, Current Probs: [0.20695376 0.1976378  0.19712275 0.19903391 0.19925177]
# Move: follow, Success: False, Current Probs: [0.20701886 0.19770309 0.19697616 0.19909648 0.19920541]
# Move: mutation, Success: False, Current Probs: [0.20708911 0.19777173 0.1969387  0.19898198 0.19921848]
# Move: mutation, Success: False, Current Probs: [0.2071608  0.19784097 0.19695472 0.19878332 0.19926019]
# Move: global_search, Success: False, Current Probs: [0.20723005 0.19774627 0.19699449 0.19871601 0.19931317]
# Move: follow, Success: False, Current Probs: [0.20729533 0.19772815 0.19689565 0.19871173 0.19936914]
# Move: local_search, Success: False, Current Probs: [0.20706997 0.19778344 0.19691029 0.19877426 0.19946204]
# Move: follow, Success: False, Current Probs: [0.20698706 0.19783955 0.19680205 0.19883414 0.1995372 ]
# Move: follow, Success: False, Current Probs: [0.20697456 0.19789531 0.19663548 0.19889192 0.19960272]
# Move: global_search, Success: False, Current Probs: [0.20700078 0.19779739 0.19658302 0.19895202 0.1996668 ]
# Move: global_search, Success: False, Current Probs: [0.20704544 0.19762614 0.19658674 0.1990124  0.19972929]
# Move: mutation, Success: False, Current Probs: [0.20710331 0.19757441 0.19662234 0.19890512 0.19979482]
# Move: mutation, Success: False, Current Probs: [0.20716676 0.19758145 0.1966729  0.19871801 0.19986088]
# Move: mutation, Success: False, Current Probs: [0.207232   0.19761692 0.19673    0.19849483 0.19992625]
# Move: follow, Success: False, Current Probs: [0.20729291 0.19766163 0.19664894 0.1984103  0.19998622]
# Move: global_search, Success: False, Current Probs: [0.20735413 0.19756496 0.19663757 0.19839745 0.20004589]
# Move: follow, Success: False, Current Probs: [0.2074123  0.19754287 0.19652512 0.1984174  0.20010231]
# Move: follow, Success: False, Current Probs: [0.20746825 0.19755739 0.19636488 0.19845305 0.20015644]
# Move: global_search, Success: False, Current Probs: [0.20752618 0.19744881 0.19631308 0.19849954 0.2002124 ]
# Move: diversity, Success: False, Current Probs: [0.20759314 0.19743064 0.19632311 0.19855912 0.20009399]
# Move: follow, Success: False, Current Probs: [0.20765283 0.19744647 0.1962267  0.19861398 0.20006002]
# Move: local_search, Success: False, Current Probs: [0.20743409 0.19751634 0.19624004 0.19870374 0.20010579]
# Move: diversity, Success: False, Current Probs: [0.20736153 0.19758638 0.19628157 0.19878394 0.19998659]
# Move: mutation, Success: False, Current Probs: [0.20735791 0.19765254 0.19633327 0.1986978  0.19995848]
# Move: local_search, Success: False, Current Probs: [0.20711703 0.19774526 0.19641835 0.19871463 0.20000473]
# Move: mutation, Success: False, Current Probs: [0.20702828 0.19782193 0.196491   0.19860029 0.2000585 ]
# Move: follow, Success: False, Current Probs: [0.20700941 0.19788466 0.19642829 0.19856758 0.20011006]
# Move: local_search, Success: False, Current Probs: [0.20676989 0.19797346 0.19645392 0.19860883 0.20019391]
# Move: diversity, Success: False, Current Probs: [0.20668579 0.19805206 0.19650066 0.19866376 0.20009774]
# Move: local_search, Success: False, Current Probs: [0.20642217 0.19814669 0.19657892 0.19874672 0.20010551]
# Move: follow, Success: False, Current Probs: [0.20631517 0.19821787 0.19652136 0.19881213 0.20013348]
# Move: global_search, Success: False, Current Probs: [0.20629077 0.19814031 0.19652031 0.1988729  0.20017571]
# Move: local_search, Success: False, Current Probs: [0.20606502 0.19815482 0.19657266 0.19895681 0.20025069]
# Move: global_search, Success: False, Current Probs: [0.20598043 0.19805189 0.19662585 0.19902611 0.20031571]
# Move: local_search, Success: False, Current Probs: [0.20573222 0.19805175 0.19670345 0.19911239 0.20040018]
# Move: local_search, Success: False, Current Probs: [0.20540947 0.1981012  0.19679145 0.19920534 0.20049254]
# Move: global_search, Success: False, Current Probs: [0.20527556 0.19801853 0.19686182 0.1992785  0.20056559]
# Move: diversity, Success: False, Current Probs: [0.2052431  0.19801047 0.19693011 0.1993486  0.20046772]
# Move: follow, Success: False, Current Probs: [0.20525102 0.19802975 0.19686975 0.19940712 0.20044236]
# Move: diversity, Success: False, Current Probs: [0.20528849 0.19807172 0.19687171 0.19946894 0.20029914]
# Move: follow, Success: False, Current Probs: [0.20533081 0.19811546 0.19678045 0.19952277 0.20025051]
# Move: mutation, Success: False, Current Probs: [0.20538273 0.19816701 0.19676427 0.19942981 0.20025618]
# Move: follow, Success: False, Current Probs: [0.20543172 0.198215   0.19666614 0.19940568 0.20028146]
# Move: global_search, Success: False, Current Probs: [0.20548306 0.19813425 0.19664275 0.19941966 0.20032028]
# Move: local_search, Success: False, Current Probs: [0.20531667 0.19814175 0.19667859 0.19947487 0.20038812]
# Move: follow, Success: False, Current Probs: [0.20525594 0.1981672  0.19660854 0.19952432 0.200444  ]
# Move: follow, Success: False, Current Probs: [0.20524751 0.19820112 0.19648761 0.19957039 0.20049337]
# Move: mutation, Success: False, Current Probs: [0.20527324 0.19824699 0.19645578 0.19947668 0.20054731]
# Move: global_search, Success: False, Current Probs: [0.20531226 0.19816774 0.1964649  0.19945524 0.20059985]
# Move: mutation, Success: False, Current Probs: [0.20536092 0.19815624 0.19649735 0.19933089 0.2006546 ]
# Move: diversity, Success: False, Current Probs: [0.20541792 0.198182   0.19654483 0.1993004  0.20055486]
# Move: follow, Success: False, Current Probs: [0.20546791 0.1982156  0.19648457 0.19930599 0.20052594]
# Move: diversity, Success: False, Current Probs: [0.20552466 0.19826305 0.1964848  0.19933959 0.2003879 ]
# Move: global_search, Success: False, Current Probs: [0.20557861 0.19818707 0.19650935 0.19938118 0.20034379]
# Move: global_search, Success: False, Current Probs: [0.20563051 0.19805187 0.19654545 0.19942616 0.20034601]
# Move: global_search, Success: False, Current Probs: [0.20568078 0.19788943 0.19658675 0.19947223 0.20037081]
# Move: local_search, Success: False, Current Probs: [0.20552002 0.19785448 0.19665342 0.19954197 0.20043012]
# Move: global_search, Success: False, Current Probs: [0.20546333 0.19774444 0.19670945 0.19959987 0.20048291]
# Move: local_search, Success: False, Current Probs: [0.20525529 0.19773412 0.19678197 0.19967397 0.20055465]
# Move: local_search, Success: False, Current Probs: [0.2049775  0.19777217 0.19686126 0.19975469 0.20063438]
# Move: global_search, Success: False, Current Probs: [0.20486168 0.19770079 0.1969231  0.19981757 0.20069687]
# Move: global_search, Success: False, Current Probs: [0.20482629 0.19757682 0.19697569 0.199871   0.2007502 ]
# Move: diversity, Success: False, Current Probs: [0.20483946 0.19754458 0.19703168 0.19992784 0.20065644]
# Move: global_search, Success: False, Current Probs: [0.20486805 0.19744223 0.19708085 0.19997775 0.20063111]
# Move: follow, Success: False, Current Probs: [0.20490336 0.19741129 0.19702313 0.20002321 0.20063901]
# Move: mutation, Success: False, Current Probs: [0.20494944 0.1974232  0.1970216  0.19993496 0.2006708 ]
# Move: diversity, Success: False, Current Probs: [0.20500254 0.19745811 0.19704973 0.19992014 0.20056947]
# Move: diversity, Success: False, Current Probs: [0.20505835 0.19750374 0.19709191 0.19994125 0.20040474]
# Move: local_search, Success: False, Current Probs: [0.20491787 0.19756841 0.19715476 0.19999417 0.20036479]
# Move: follow, Success: False, Current Probs: [0.20486817 0.19762056 0.19710566 0.20004069 0.20036491]
# Move: local_search, Success: False, Current Probs: [0.20468029 0.19768717 0.19712152 0.20010498 0.20040605]
# Move: mutation, Success: False, Current Probs: [0.20461401 0.19774722 0.19715612 0.2000289  0.20045374]
# Move: local_search, Success: False, Current Probs: [0.20442294 0.19781653 0.19721257 0.20003057 0.20051739]
# Move: diversity, Success: False, Current Probs: [0.20435581 0.19787871 0.19726823 0.20005923 0.20043803]
# Move: global_search, Success: False, Current Probs: [0.20434375 0.19782536 0.19731684 0.20009462 0.20041943]
# Move: mutation, Success: False, Current Probs: [0.20436467 0.19782477 0.19736717 0.20000682 0.20043657]
# Move: mutation, Success: False, Current Probs: [0.20440139 0.1978499  0.19741771 0.19986011 0.2004709 ]
# Move: local_search, Success: False, Current Probs: [0.20426659 0.19790056 0.19748099 0.1998252  0.20052666]
# Move: mutation, Success: False, Current Probs: [0.20422476 0.19795069 0.19753738 0.1997075  0.20057967]
# Move: diversity, Success: False, Current Probs: [0.20423153 0.1980026  0.19759238 0.19967571 0.20049778]
# Move: mutation, Success: False, Current Probs: [0.20425987 0.19805276 0.19764402 0.19956203 0.20048132]
# Move: local_search, Success: False, Current Probs: [0.20412546 0.19811483 0.19770676 0.19954243 0.20051052]
# Move: global_search, Success: False, Current Probs: [0.20407928 0.19806323 0.19775851 0.1995532  0.20054579]
# Move: local_search, Success: False, Current Probs: [0.20391204 0.19807329 0.19782021 0.19959472 0.20059974]
# Move: mutation, Success: False, Current Probs: [0.20385272 0.19810194 0.19787465 0.19952002 0.20065065]
# Move: diversity, Success: False, Current Probs: [0.20385002 0.19814248 0.19792806 0.19950906 0.20057039]
# Move: follow, Success: False, Current Probs: [0.20386875 0.19818227 0.19787576 0.19952322 0.20055   ]
# Move: mutation, Success: False, Current Probs: [0.20390184 0.19822523 0.19787264 0.19943713 0.20056315]
# Move: follow, Success: False, Current Probs: [0.20393804 0.19826582 0.1977938  0.19941329 0.20058905]
# Move: follow, Success: False, Current Probs: [0.20397535 0.19830479 0.19767881 0.19942015 0.2006209 ]
# Move: follow, Success: False, Current Probs: [0.20401281 0.19834256 0.19754736 0.19944196 0.20065531]
# Move: global_search, Success: False, Current Probs: [0.20405212 0.19828056 0.19750155 0.19947299 0.20069277]
# Move: follow, Success: False, Current Probs: [0.20409019 0.19826744 0.19740627 0.1995065  0.2007296 ]
# Move: mutation, Success: False, Current Probs: [0.20413243 0.19828342 0.19738106 0.19943224 0.20077084]
# Move: follow, Success: False, Current Probs: [0.20417158 0.19830892 0.1972976  0.19941272 0.20080919]
# Move: local_search, Success: False, Current Probs: [0.20405103 0.19835659 0.19729059 0.19943806 0.20086373]
# Move: follow, Success: False, Current Probs: [0.20400839 0.19839757 0.19721769 0.19946798 0.20090837]
# Move: local_search, Success: False, Current Probs: [0.20385101 0.19845198 0.19721494 0.19951703 0.20096504]
# Move: global_search, Success: False, Current Probs: [0.20379244 0.19840003 0.19723304 0.19956127 0.20101322]
# Move: diversity, Success: False, Current Probs: [0.20378949 0.19839968 0.19726758 0.19960918 0.20093407]
# Move: mutation, Success: False, Current Probs: [0.20381066 0.19842156 0.19730678 0.19954418 0.20091681]
# Move: follow, Success: False, Current Probs: [0.20383852 0.19844932 0.19725837 0.19952858 0.20092521]
# Move: mutation, Success: False, Current Probs: [0.20387458 0.19848474 0.19725557 0.19943389 0.20095122]
# Move: mutation, Success: False, Current Probs: [0.20391422 0.1985235  0.19727509 0.19930167 0.20098553]
# Move: local_search, Success: False, Current Probs: [0.20380178 0.19857587 0.19731762 0.19926865 0.20103609]
# Move: diversity, Success: False, Current Probs: [0.20377124 0.1986271  0.19736378 0.19927726 0.20096062]
# Move: mutation, Success: False, Current Probs: [0.20377709 0.1986733  0.19740732 0.19919859 0.20094371]
# Move: local_search, Success: False, Current Probs: [0.20365144 0.19872849 0.19746097 0.1991914  0.2009677 ]
# Move: global_search, Success: False, Current Probs: [0.20360832 0.19867855 0.19750691 0.19920708 0.20099914]
# Move: mutation, Success: False, Current Probs: [0.20360738 0.1986737  0.19754989 0.19913379 0.20103523]
# Move: follow, Success: False, Current Probs: [0.20362384 0.1986878  0.19750468 0.19911369 0.20107   ]
# Move: follow, Success: False, Current Probs: [0.20364865 0.19871103 0.19741671 0.19911986 0.20110376]
# Move: mutation, Success: False, Current Probs: [0.20368124 0.19874233 0.19739227 0.19904359 0.20114056]
# Move: diversity, Success: False, Current Probs: [0.20372261 0.19878246 0.19740435 0.19902996 0.20106062]
# Move: mutation, Success: False, Current Probs: [0.20376304 0.19882178 0.19742952 0.19894553 0.20104012]
# Move: mutation, Success: False, Current Probs: [0.20380257 0.19886029 0.19746082 0.19882741 0.20104892]
# Move: diversity, Success: False, Current Probs: [0.20384682 0.19890343 0.19750019 0.19879222 0.20095735]
# Move: local_search, Success: False, Current Probs: [0.2037438  0.19895628 0.19755092 0.19880586 0.20094314]
# Move: global_search, Success: False, Current Probs: [0.2037116  0.19890675 0.19759503 0.19883154 0.20095509]
# Move: global_search, Success: False, Current Probs: [0.20371439 0.19880767 0.19763541 0.19886282 0.20097971]
# Move: mutation, Success: False, Current Probs: [0.20373469 0.19877656 0.19767395 0.19880414 0.20101066]
# Move: diversity, Success: False, Current Probs: [0.20376873 0.19878432 0.1977164  0.19879811 0.20093244]
# Move: mutation, Success: False, Current Probs: [0.20380426 0.19880625 0.19775558 0.19872234 0.20091156]
# Move: diversity, Success: False, Current Probs: [0.20384536 0.19883997 0.19779782 0.1987072  0.20080966]
# Move: follow, Success: False, Current Probs: [0.20388221 0.19887274 0.19775476 0.19871552 0.20077476]
# ...
# Move: diversity, Success: False, Current Probs: [0.19999752 0.20001298 0.19999039 0.20000074 0.19999838]
# Move: local_search, Success: False, Current Probs: [0.19999748 0.200013   0.19999039 0.20000076 0.19999837]
# Move: global_search, Success: False, Current Probs: [0.19999748 0.20001296 0.1999904  0.20000078 0.19999838]
# Move: mutation, Success: False, Current Probs: [0.19999749 0.20001296 0.19999042 0.20000074 0.19999839]
# Move: global_search, Success: False, Current Probs: [0.1999975  0.2000129  0.19999044 0.20000074 0.19999841]
# Move: diversity, Success: False, Current Probs: [0.19999752 0.20001289 0.19999046 0.20000075 0.19999838]
# Move: mutation, Success: False, Current Probs: [0.19999755 0.20001289 0.19999048 0.20000071 0.19999837]
# Move: follow, Success: False, Current Probs: [0.19999757 0.20001291 0.19999045 0.2000007  0.19999838]
# Move: mutation, Success: False, Current Probs: [0.19999759 0.20001292 0.19999045 0.20000065 0.1999984 ]
# Move: diversity, Success: False, Current Probs: [0.19999761 0.20001294 0.19999046 0.20000063 0.19999836]
# Move: follow, Success: False, Current Probs: [0.19999763 0.20001297 0.19999042 0.20000063 0.19999835]
# Move: local_search, Success: False, Current Probs: [0.1999976  0.20001299 0.19999041 0.20000065 0.19999836]
# Move: mutation, Success: False, Current Probs: [0.19999759 0.20001301 0.19999041 0.20000061 0.19999837]
# Move: global_search, Success: False, Current Probs: [0.1999976  0.20001297 0.19999043 0.2000006  0.19999839]
# Move: global_search, Success: False, Current Probs: [0.19999762 0.20001291 0.19999045 0.20000061 0.19999841]
# Move: mutation, Success: False, Current Probs: [0.19999764 0.20001288 0.19999047 0.20000057 0.19999844]
# Move: mutation, Success: False, Current Probs: [0.19999766 0.20001288 0.19999049 0.2000005  0.19999846]
# Move: local_search, Success: False, Current Probs: [0.19999763 0.2000129  0.19999052 0.20000048 0.19999848]
# Move: follow, Success: False, Current Probs: [0.19999762 0.20001291 0.19999048 0.20000048 0.1999985 ]
# Move: global_search, Success: False, Current Probs: [0.19999763 0.20001287 0.19999048 0.20000049 0.19999853]
# Move: global_search, Success: False, Current Probs: [0.19999765 0.2000128  0.19999049 0.20000051 0.19999855]
# Move: mutation, Success: False, Current Probs: [0.19999767 0.20001278 0.19999051 0.20000047 0.19999858]
# Move: mutation, Success: False, Current Probs: [0.19999769 0.20001278 0.19999053 0.20000041 0.1999986 ]
# Move: mutation, Success: False, Current Probs: [0.19999771 0.20001279 0.19999055 0.20000033 0.19999862]
# Move: diversity, Success: False, Current Probs: [0.19999773 0.20001281 0.19999057 0.2000003  0.19999859]
# Move: local_search, Success: False, Current Probs: [0.1999977  0.20001283 0.19999059 0.2000003  0.19999858]
# Move: mutation, Success: False, Current Probs: [0.19999769 0.20001285 0.19999062 0.20000025 0.19999859]
# Move: mutation, Success: False, Current Probs: [0.1999977  0.20001287 0.19999064 0.20000018 0.19999861]
# Move: mutation, Success: False, Current Probs: [0.19999772 0.20001289 0.19999066 0.2000001  0.19999863]
# Move: mutation, Success: False, Current Probs: [0.19999774 0.20001292 0.19999068 0.20000001 0.19999865]
# Move: global_search, Success: False, Current Probs: [0.19999776 0.20001288 0.19999071 0.19999998 0.19999867]
# Move: global_search, Success: False, Current Probs: [0.19999778 0.20001281 0.19999073 0.19999998 0.19999869]
# Move: diversity, Success: False, Current Probs: [0.1999978  0.20001279 0.19999076 0.19999999 0.19999866]
# Move: mutation, Success: False, Current Probs: [0.19999783 0.20001279 0.19999078 0.19999995 0.19999865]
# Move: mutation, Success: False, Current Probs: [0.19999785 0.2000128  0.1999908  0.19999988 0.19999866]
# Move: local_search, Success: False, Current Probs: [0.19999782 0.20001282 0.19999082 0.19999986 0.19999868]
# Move: global_search, Success: False, Current Probs: [0.19999781 0.20001278 0.19999085 0.19999986 0.1999987 ]
# Move: local_search, Success: False, Current Probs: [0.19999776 0.20001277 0.19999087 0.19999987 0.19999872]
# Move: mutation, Success: False, Current Probs: [0.19999775 0.20001278 0.19999089 0.19999983 0.19999874]
# Move: follow, Success: False, Current Probs: [0.19999776 0.20001279 0.19999086 0.19999982 0.19999876]
# Move: global_search, Success: False, Current Probs: [0.19999777 0.20001275 0.19999086 0.19999983 0.19999879]
# Move: follow, Success: False, Current Probs: [0.19999779 0.20001274 0.19999081 0.19999985 0.19999881]
# Move: global_search, Success: False, Current Probs: [0.19999781 0.20001269 0.1999908  0.19999987 0.19999883]
# Move: follow, Success: False, Current Probs: [0.19999783 0.20001267 0.19999075 0.19999989 0.19999886]
# Move: diversity, Success: False, Current Probs: [0.19999785 0.20001268 0.19999074 0.19999991 0.19999882]
# Move: follow, Success: False, Current Probs: [0.19999788 0.20001269 0.19999069 0.19999993 0.19999882]
# Move: follow, Success: False, Current Probs: [0.1999979  0.20001271 0.19999062 0.19999995 0.19999882]
# Move: local_search, Success: False, Current Probs: [0.19999786 0.20001273 0.19999059 0.19999998 0.19999884]
# Move: global_search, Success: False, Current Probs: [0.19999786 0.20001269 0.1999906  0.2        0.19999886]
# Move: mutation, Success: False, Current Probs: [0.19999787 0.20001268 0.19999061 0.19999996 0.19999888]
# Move: follow, Success: False, Current Probs: [0.19999788 0.20001269 0.19999057 0.19999996 0.1999989 ]
# Move: global_search, Success: False, Current Probs: [0.1999979  0.20001264 0.19999056 0.19999997 0.19999892]
# Move: global_search, Success: False, Current Probs: [0.19999793 0.20001257 0.19999057 0.19999998 0.19999895]
# Move: follow, Success: False, Current Probs: [0.19999795 0.20001255 0.19999053 0.2        0.19999897]
# Move: mutation, Success: False, Current Probs: [0.19999797 0.20001255 0.19999052 0.19999997 0.19999899]
# Move: follow, Success: False, Current Probs: [0.19999799 0.20001256 0.19999048 0.19999996 0.19999902]
# Move: local_search, Success: False, Current Probs: [0.19999796 0.20001257 0.19999046 0.19999997 0.19999904]
# Move: mutation, Success: False, Current Probs: [0.19999795 0.20001259 0.19999047 0.19999993 0.19999906]
# Move: local_search, Success: False, Current Probs: [0.1999979  0.20001261 0.19999048 0.19999992 0.19999908]
# Move: diversity, Success: False, Current Probs: [0.19999789 0.20001264 0.1999905  0.19999992 0.19999905]
# Move: diversity, Success: False, Current Probs: [0.1999979  0.20001266 0.19999052 0.19999994 0.19999899]
# Move: global_search, Success: False, Current Probs: [0.19999791 0.20001262 0.19999054 0.19999996 0.19999897]
# Move: mutation, Success: False, Current Probs: [0.19999793 0.20001261 0.19999057 0.19999992 0.19999897]
# Move: global_search, Success: False, Current Probs: [0.19999795 0.20001256 0.19999059 0.19999992 0.19999898]
# Move: diversity, Success: False, Current Probs: [0.19999797 0.20001255 0.19999061 0.19999992 0.19999894]
# Move: global_search, Success: False, Current Probs: [0.199998   0.20001249 0.19999064 0.19999994 0.19999894]
# Move: local_search, Success: False, Current Probs: [0.19999796 0.20001247 0.19999066 0.19999996 0.19999894]
# Move: mutation, Success: False, Current Probs: [0.19999796 0.20001248 0.19999068 0.19999992 0.19999896]
# Move: global_search, Success: False, Current Probs: [0.19999797 0.20001243 0.19999071 0.19999992 0.19999898]
# Move: follow, Success: False, Current Probs: [0.19999798 0.20001242 0.19999067 0.19999993 0.199999  ]
# Move: mutation, Success: False, Current Probs: [0.199998   0.20001242 0.19999067 0.19999988 0.19999902]
# Move: mutation, Success: False, Current Probs: [0.19999802 0.20001244 0.19999068 0.19999982 0.19999904]
# Move: global_search, Success: False, Current Probs: [0.19999805 0.2000124  0.19999069 0.1999998  0.19999907]
# Move: global_search, Success: False, Current Probs: [0.19999807 0.20001233 0.19999072 0.1999998  0.19999909]
# Move: diversity, Success: False, Current Probs: [0.19999809 0.2000123  0.19999074 0.19999981 0.19999906]
# Move: follow, Success: False, Current Probs: [0.19999811 0.2000123  0.1999907  0.19999983 0.19999905]
# Move: global_search, Success: False, Current Probs: [0.19999814 0.20001226 0.1999907  0.19999985 0.19999906]
# Move: diversity, Success: False, Current Probs: [0.19999816 0.20001224 0.19999071 0.19999987 0.19999902]
# Move: follow, Success: False, Current Probs: [0.19999818 0.20001225 0.19999067 0.19999989 0.19999901]
# Move: mutation, Success: False, Current Probs: [0.19999821 0.20001226 0.19999066 0.19999986 0.19999902]
# Move: local_search, Success: False, Current Probs: [0.19999817 0.20001228 0.19999067 0.19999985 0.19999903]
# Move: local_search, Success: False, Current Probs: [0.19999811 0.2000123  0.19999068 0.19999986 0.19999905]
# Move: global_search, Success: False, Current Probs: [0.19999809 0.20001226 0.1999907  0.19999987 0.19999907]
# Move: diversity, Success: False, Current Probs: [0.19999809 0.20001225 0.19999072 0.19999989 0.19999904]
# Move: global_search, Success: False, Current Probs: [0.19999811 0.2000122  0.19999075 0.19999992 0.19999903]
# Move: diversity, Success: False, Current Probs: [0.19999812 0.20001219 0.19999077 0.19999994 0.19999898]
# Move: diversity, Success: False, Current Probs: [0.19999814 0.20001219 0.19999079 0.19999996 0.19999891]
# Move: mutation, Success: False, Current Probs: [0.19999816 0.2000122  0.19999081 0.19999993 0.19999889]
# Move: diversity, Success: False, Current Probs: [0.19999819 0.20001222 0.19999084 0.19999992 0.19999883]
# Move: follow, Success: False, Current Probs: [0.19999821 0.20001224 0.19999081 0.19999993 0.19999882]
# Move: global_search, Success: False, Current Probs: [0.19999823 0.2000122  0.1999908  0.19999994 0.19999882]
# Move: local_search, Success: False, Current Probs: [0.1999982  0.2000122  0.19999081 0.19999996 0.19999883]
# Move: diversity, Success: False, Current Probs: [0.19999819 0.2000122  0.19999083 0.19999998 0.19999879]
# Move: global_search, Success: False, Current Probs: [0.1999982  0.20001216 0.19999085 0.20000001 0.19999879]
# Move: diversity, Success: False, Current Probs: [0.19999822 0.20001215 0.19999087 0.20000003 0.19999874]
# Move: local_search, Success: False, Current Probs: [0.19999818 0.20001215 0.19999089 0.20000005 0.19999872]
# Move: mutation, Success: False, Current Probs: [0.19999817 0.20001217 0.19999091 0.20000002 0.19999873]
# Move: diversity, Success: False, Current Probs: [0.19999818 0.20001219 0.19999093 0.20000001 0.19999868]
# Move: diversity, Success: False, Current Probs: [0.1999982  0.20001221 0.19999096 0.20000002 0.19999862]
# Move: global_search, Success: False, Current Probs: [0.19999822 0.20001217 0.19999098 0.20000004 0.1999986 ]
# Move: follow, Success: False, Current Probs: [0.19999824 0.20001216 0.19999095 0.20000006 0.1999986 ]
# Move: follow, Success: False, Current Probs: [0.19999826 0.20001217 0.19999089 0.20000008 0.19999861]
# Move: follow, Success: False, Current Probs: [0.19999828 0.20001218 0.19999082 0.2000001  0.19999862]
# Move: local_search, Success: False, Current Probs: [0.19999825 0.2000122  0.19999079 0.20000012 0.19999864]
# Move: global_search, Success: False, Current Probs: [0.19999824 0.20001216 0.19999079 0.20000014 0.19999867]
# Move: mutation, Success: False, Current Probs: [0.19999825 0.20001215 0.1999908  0.20000011 0.19999869]
# Move: diversity, Success: False, Current Probs: [0.19999826 0.20001216 0.19999082 0.2000001  0.19999865]
# Move: global_search, Success: False, Current Probs: [0.19999828 0.20001212 0.19999084 0.20000011 0.19999865]
# Move: local_search, Success: False, Current Probs: [0.19999825 0.20001211 0.19999086 0.20000013 0.19999866]
# Move: global_search, Success: False, Current Probs: [0.19999824 0.20001205 0.19999088 0.20000015 0.19999867]
# Move: mutation, Success: False, Current Probs: [0.19999825 0.20001204 0.1999909  0.20000011 0.19999869]
# Move: mutation, Success: False, Current Probs: [0.19999827 0.20001204 0.19999093 0.20000005 0.19999872]
# Move: local_search, Success: False, Current Probs: [0.19999823 0.20001205 0.19999095 0.20000003 0.19999874]
# Move: mutation, Success: False, Current Probs: [0.19999822 0.20001207 0.19999097 0.19999997 0.19999876]
# Move: mutation, Success: False, Current Probs: [0.19999823 0.20001209 0.199991   0.1999999  0.19999878]
# Move: diversity, Success: False, Current Probs: [0.19999825 0.20001211 0.19999102 0.19999987 0.19999875]
# Move: global_search, Success: False, Current Probs: [0.19999827 0.20001208 0.19999104 0.19999987 0.19999874]
# Move: mutation, Success: False, Current Probs: [0.19999829 0.20001207 0.19999106 0.19999983 0.19999875]
# Move: global_search, Success: False, Current Probs: [0.19999831 0.20001202 0.19999109 0.19999982 0.19999877]
# Move: global_search, Success: False, Current Probs: [0.19999833 0.20001194 0.19999111 0.19999982 0.19999879]
# Move: local_search, Success: False, Current Probs: [0.1999983  0.20001192 0.19999114 0.19999984 0.19999881]
# Move: local_search, Success: False, Current Probs: [0.19999824 0.20001192 0.19999116 0.19999986 0.19999883]
# Move: local_search, Success: False, Current Probs: [0.19999816 0.20001193 0.19999118 0.19999988 0.19999885]
# Move: follow, Success: False, Current Probs: [0.19999813 0.20001194 0.19999115 0.1999999  0.19999888]
# Move: mutation, Success: False, Current Probs: [0.19999813 0.20001196 0.19999114 0.19999986 0.1999989 ]
# Move: global_search, Success: False, Current Probs: [0.19999814 0.20001192 0.19999115 0.19999986 0.19999892]
# Move: diversity, Success: False, Current Probs: [0.19999816 0.20001192 0.19999117 0.19999987 0.19999889]
# Move: follow, Success: False, Current Probs: [0.19999818 0.20001192 0.19999113 0.19999988 0.19999888]
# Move: mutation, Success: False, Current Probs: [0.1999982  0.20001194 0.19999113 0.19999984 0.19999889]
# Move: local_search, Success: False, Current Probs: [0.19999817 0.20001196 0.19999114 0.19999984 0.19999891]
# Move: diversity, Success: False, Current Probs: [0.19999816 0.20001198 0.19999115 0.19999984 0.19999887]
# Move: follow, Success: False, Current Probs: [0.19999817 0.200012   0.19999111 0.19999986 0.19999886]
# Move: global_search, Success: False, Current Probs: [0.19999818 0.20001196 0.19999111 0.19999988 0.19999887]
# Move: diversity, Success: False, Current Probs: [0.1999982  0.20001195 0.19999112 0.1999999  0.19999883]
# Move: mutation, Success: False, Current Probs: [0.19999822 0.20001196 0.19999113 0.19999986 0.19999882]
# Move: global_search, Success: False, Current Probs: [0.19999825 0.20001192 0.19999115 0.19999986 0.19999883]
# Move: follow, Success: False, Current Probs: [0.19999827 0.20001191 0.19999112 0.19999987 0.19999884]
# Move: local_search, Success: False, Current Probs: [0.19999823 0.20001191 0.19999111 0.19999988 0.19999886]
# Move: global_search, Success: False, Current Probs: [0.19999823 0.20001187 0.19999112 0.1999999  0.19999888]
# Move: diversity, Success: False, Current Probs: [0.19999824 0.20001186 0.19999114 0.19999992 0.19999885]
# Move: diversity, Success: False, Current Probs: [0.19999825 0.20001186 0.19999116 0.19999994 0.19999878]
# Move: diversity, Success: False, Current Probs: [0.19999827 0.20001188 0.19999118 0.19999997 0.19999871]
# Move: follow, Success: False, Current Probs: [0.19999829 0.20001189 0.19999115 0.19999999 0.19999868]
# Move: mutation, Success: False, Current Probs: [0.19999832 0.20001191 0.19999114 0.19999995 0.19999868]
# Move: mutation, Success: False, Current Probs: [0.19999834 0.20001193 0.19999115 0.19999989 0.19999869]
# Move: follow, Success: False, Current Probs: [0.19999836 0.20001196 0.19999111 0.19999987 0.1999987 ]
# Move: global_search, Success: False, Current Probs: [0.19999838 0.20001192 0.1999911  0.19999987 0.19999872]
# Move: local_search, Success: False, Current Probs: [0.19999835 0.20001191 0.19999111 0.19999989 0.19999874]
# Move: global_search, Success: False, Current Probs: [0.19999834 0.20001186 0.19999112 0.1999999  0.19999877]
# Move: global_search, Success: False, Current Probs: [0.19999835 0.20001179 0.19999114 0.19999992 0.19999879]
# Move: local_search, Success: False, Current Probs: [0.19999831 0.20001176 0.19999117 0.19999995 0.19999881]

# %%
import numpy as np
import matplotlib.pyplot as plt

def load_pareto_front(filename):
    points = []
    with open(filename) as f:
        for line in f:
            line = line.strip()
            if line:
                points.append([float(x) for x in line.split()])
    return np.array(points)

def is_dominated(point, others):
    return np.any(np.all(others >= point, axis=1) & np.any(others > point, axis=1))

def get_pareto_front(points):
    mask = np.ones(len(points), dtype=bool)
    for i, p in enumerate(points):
        others = np.delete(points, i, axis=0)
        if is_dominated(p, others):
            mask[i] = False
    return points[mask]

# Load and merge all runs' points for each result file
ref_points = load_pareto_front("output_ref.txt")
agent_points = load_pareto_front("output_agent.txt")

# Get the true Pareto front for each
ref_pareto = get_pareto_front(ref_points)
agent_pareto = get_pareto_front(agent_points)

# Plot
plt.figure(figsize=(8,6))
plt.scatter(ref_pareto[:,0], ref_pareto[:,1], label="Reference Pareto", alpha=0.7)
plt.scatter(agent_pareto[:,0], agent_pareto[:,1], label="Agent Pareto", alpha=0.7)
plt.xlabel("Objective 1")
plt.ylabel("Objective 2")
plt.legend()
plt.title("True Pareto Front: Reference vs. Smart Agent")
plt.show()

print(f"Reference Pareto size: {ref_pareto.shape[0]}")
print(f"Agent Pareto size: {agent_pareto.shape[0]}")
# Out:
# Reference Pareto size: 628
# Agent Pareto size: 211

# %%
from pymoo.indicators.hv import HV

ref_point = np.max(np.vstack([ref_pareto, agent_pareto]), axis=0) + 1
hv = HV(ref_point=ref_point)

print("Reference HV:", hv(ref_pareto))
print("Agent HV:", hv(agent_pareto))

# %%
# !conda install -c conda-forge pymoo
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... failed
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==2022.10=py39_0
#   - defaults/win-64::anaconda-client==1.11.0=py39haa95532_0
#   - defaults/win-64::anaconda-navigator==2.3.1=py39haa95532_0
#   - defaults/win-64::anaconda-project==0.11.1=py39haa95532_0
#   - defaults/win-64::argon2-cffi-bindings==21.2.0=py39h2bbff1b_0
#   - defaults/win-64::astropy==5.1=py39h080aedc_0
#   - defaults/noarch::automat==20.2.0=py_0
#   - defaults/noarch::backports.functools_lru_cache==1.6.4=pyhd3eb1b0_0
#   - defaults/win-64::bcrypt==3.2.0=py39h2bbff1b_1
#   - defaults/win-64::bkcharts==0.2=py39haa95532_1
#   - defaults/win-64::bokeh==2.4.3=py39haa95532_0
#   - defaults/win-64::boto3==1.24.28=py39haa95532_0
#   - defaults/win-64::botocore==1.27.28=py39haa95532_0
#   - defaults/win-64::bottleneck==1.3.5=py39h080aedc_0
#   - defaults/win-64::brotlipy==0.7.0=py39h2bbff1b_1003
#   - defaults/win-64::clyent==1.2.2=py39haa95532_1
#   - defaults/win-64::colorcet==3.0.0=py39haa95532_0
#   - defaults/win-64::conda==22.9.0=py39haa95532_0
#   - defaults/win-64::conda-build==3.22.0=py39haa95532_0
#   - defaults/win-64::conda-content-trust==0.1.3=py39haa95532_0
#   - defaults/win-64::conda-pack==0.7.1=py39haa95532_0
#   - defaults/win-64::conda-package-handling==1.9.0=py39h8cc25b3_0
#   - defaults/win-64::conda-repo-cli==1.0.20=py39haa95532_0
#   - defaults/noarch::conda-token==0.4.0=pyhd3eb1b0_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/noarch::cookiecutter==1.7.3=pyhd3eb1b0_0
#   - defaults/win-64::daal4py==2021.6.0=py39h757b272_1
#   - defaults/win-64::dask==2022.7.0=py39haa95532_0
#   - defaults/win-64::dask-core==2022.7.0=py39haa95532_0
#   - defaults/win-64::datashader==0.14.1=py39haa95532_0
#   - defaults/win-64::datashape==0.5.4=py39haa95532_1
#   - defaults/win-64::distributed==2022.7.0=py39haa95532_0
#   - defaults/win-64::gensim==4.1.2=py39hd77b12b_0
#   - defaults/win-64::holoviews==1.15.0=py39haa95532_0
#   - defaults/win-64::hvplot==0.8.0=py39haa95532_0
#   - defaults/noarch::hyperlink==21.0.0=pyhd3eb1b0_0
#   - defaults/win-64::imagecodecs==2021.8.26=py39hc0a7faf_1
#   - defaults/win-64::imageio==2.19.3=py39haa95532_0
#   - defaults/noarch::importlib_metadata==4.11.3=hd3eb1b0_0
#   - defaults/noarch::intake==0.6.5=pyhd3eb1b0_0
#   - defaults/noarch::itemloaders==1.0.4=pyhd3eb1b0_1
#   - defaults/noarch::jinja2-time==0.2.0=pyhd3eb1b0_3
#   - defaults/win-64::keyring==23.4.0=py39haa95532_0
#   - defaults/win-64::markdown==3.3.4=py39haa95532_0
#   - defaults/win-64::matplotlib==3.5.2=py39haa95532_0
#   - defaults/win-64::matplotlib-base==3.5.2=py39hd77b12b_0
#   - defaults/win-64::mkl-service==2.4.0=py39h2bbff1b_0
#   - defaults/win-64::mkl_fft==1.3.1=py39h277e83a_0
#   - defaults/win-64::mkl_random==1.2.2=py39hf11a4ad_0
#   - defaults/win-64::multipledispatch==0.6.0=py39haa95532_0
#   - defaults/win-64::navigator-updater==0.3.0=py39haa95532_0
#   - defaults/noarch::nbclassic==0.3.5=pyhd3eb1b0_0
#   - defaults/noarch::nltk==3.7=pyhd3eb1b0_0
#   - defaults/win-64::numba==0.55.1=py39hf11a4ad_0
#   - defaults/win-64::numexpr==2.8.3=py39hb80d3ca_0
#   - defaults/win-64::numpy==1.21.5=py39h7a0a035_3
#   - defaults/win-64::numpydoc==1.4.0=py39haa95532_0
#   - defaults/win-64::pandas==1.4.4=py39hd77b12b_0
#   - defaults/win-64::panel==0.13.1=py39haa95532_0
#   - defaults/noarch::paramiko==2.8.1=pyhd3eb1b0_0
#   - defaults/win-64::parsel==1.6.0=py39haa95532_0
#   - defaults/win-64::patsy==0.5.2=py39haa95532_1
#   - defaults/noarch::prompt_toolkit==3.0.20=hd3eb1b0_0
#   - defaults/noarch::protego==0.1.16=py_0
#   - defaults/win-64::pyct==0.4.8=py39haa95532_1
#   - defaults/win-64::pyerfa==2.0.0=py39h2bbff1b_0
#   - defaults/noarch::pyhamcrest==2.0.2=pyhd3eb1b0_2
#   - defaults/noarch::pyls-spyder==0.4.0=pyhd3eb1b0_0
#   - defaults/win-64::pynacl==1.5.0=py39h8cc25b3_0
#   - defaults/noarch::pyopenssl==22.0.0=pyhd3eb1b0_0
#   - defaults/win-64::pytables==3.6.1=py39h56d22b6_1
#   - defaults/win-64::pytest==7.1.2=py39haa95532_0
#   - defaults/win-64::pywavelets==1.3.0=py39h2bbff1b_0
#   - defaults/noarch::requests-file==1.5.1=pyhd3eb1b0_0
#   - defaults/win-64::s3transfer==0.6.0=py39haa95532_0
#   - defaults/win-64::scikit-image==0.19.2=py39hf11a4ad_0
#   - defaults/win-64::scikit-learn==1.0.2=py39hf11a4ad_1
#   - defaults/win-64::scikit-learn-intelex==2021.6.0=py39haa95532_0
#   - defaults/win-64::scipy==1.9.1=py39he11b74f_0
#   - defaults/win-64::scrapy==2.6.2=py39haa95532_0
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/noarch::service_identity==18.1.0=pyhd3eb1b0_1
#   - defaults/win-64::sphinx==5.0.2=py39haa95532_0
#   - defaults/win-64::statsmodels==0.13.2=py39h2bbff1b_0
#   - defaults/noarch::tifffile==2021.7.2=pyhd3eb1b0_2
#   - defaults/noarch::tldextract==3.2.0=pyhd3eb1b0_0
#   - defaults/win-64::tqdm==4.64.1=py39haa95532_0
#   - defaults/win-64::twisted==22.2.0=py39h2bbff1b_1
#   - defaults/win-64::typing-extensions==4.3.0=py39haa95532_0
#   - defaults/noarch::w3lib==1.21.0=pyhd3eb1b0_0
#   - defaults/win-64::watchdog==2.1.6=py39haa95532_0
#   - defaults/noarch::xarray==0.20.1=pyhd3eb1b0_1
#   - defaults/win-64::xlwings==0.27.15=py39haa95532_0
#   - defaults/win-64::zope.interface==5.4.0=py39h2bbff1b_0
#   - defaults/win-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39haa95532_0
#
# CondaMemoryError: The conda process ran out of memory. Increase system memory and/or try again.

# %%
from pymoo.indicators.hv import HV

# %%
import numpy as np
from pymoo.indicators.hv import HV

# Use your previously calculated Pareto fronts
ref = ref_pareto
new = new_pareto

# Calculate the reference point (must be worse than any point in both sets)
ref_point = np.max(np.vstack([ref, new]), axis=0) + 1

# Instantiate HV indicator
hv = HV(ref_point=ref_point)

# Compute and print hypervolumes
print("Reference HV:", hv(ref))
print("Improved HV:", hv(new))
# Out:
# Reference HV: 1224742.0
# Improved HV: 1159322.0

# %%
from pymoo.performance_indicator.hv import HV
# Out:
# 0.6.1.5

# %%
import numpy as np
from pymoo.indicators.hv import HV

def load_pareto_front(filename):
    points = []
    with open(filename) as f:
        for line in f:
            line = line.strip()
            if line:
                points.append([float(x) for x in line.split()])
    return np.array(points)

ref_pareto = load_pareto_front("output_ref.txt")   # reference (no agent)
new_pareto = load_pareto_front("output_agent.txt") # agent (improved)

ref = ref_pareto
new = new_pareto

ref_point = np.max(np.vstack([ref, new]), axis=0) + 1

hv = HV(ref_point=ref_point)

print("Reference HV:", hv(ref))
print("Improved HV:", hv(new))
# Out:
# Reference HV: 1384385.0
# Improved HV: 1286563.0

# %%
import numpy as np
from pymoo.indicators.hv import HV

def load_pareto_front(filename):
    points = []
    with open(filename) as f:
        for line in f:
            line = line.strip()
            if line:
                points.append([float(x) for x in line.split()])
    return np.array(points)

ref_pareto = load_pareto_front("2502_Resulats.txt")   # reference (no agent)
new_pareto = load_pareto_front("output_agent.txt") # agent (improved)

ref = ref_pareto
new = new_pareto

ref_point = np.max(np.vstack([ref, new]), axis=0) + 1

hv = HV(ref_point=ref_point)

print("Reference HV:", hv(ref))
print("Improved HV:", hv(new))
# Out:
# Reference HV: 3614987.0
# Improved HV: 1245628.0

# %%
# %load_ext cython

# %%
# Python imports
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import requests
import json

print("=== PYTHON IMPORTS AND CONFIGURATION ===")

# --- Configuration ---
# Set a single, good set of parameters to avoid LLM parameter tuning overhead
DEFAULT_PARAMS = {
    'alpha': 40,
    'kappa': 0.15,
    'L': 6,
    'smallValue': 1e-7
}

# --- Simplified LLM Interface for Solution Generation ---
def call_llm_for_solution(prompt, model="llama3:latest", timeout=50):
    """
    Makes a fast call to the local LLM to generate a solution string.
    This is the core of the LLM's role in the new architecture.
    """
    try:
        response = requests.post(
            'http://localhost:11434/api/generate',
            json={
                'model': model,
                'prompt': prompt,
                'stream': False,
                'options': {
                    'temperature': 0.8,       # Higher temp for more creativity
                    'num_predict': 100,      # Short response for speed
                    'timeout': timeout
                }
            },
            timeout=timeout
        )
        if response.status_code == 200:
            return response.json()['response'].strip()
        else:
            print(f"⚠️ LLM API Error: {response.status_code}")
            return None
    except requests.exceptions.RequestException as e:
        print(f"⚠️ Could not connect to LLM: {e}")
        return None

print("✅ Imports and simplified LLM interface ready!")
# Out:
# === PYTHON IMPORTS AND CONFIGURATION ===
# ✅ Imports and simplified LLM interface ready!

# %%
# %%cython
# """
# Hybrid MOACP Implementation: Cython Local Search + LLM Solution Generation
# """
# import numpy as np
# import time
# from libc.stdlib cimport malloc, free, srand, rand
# from libc.string cimport memset
# from libc.math cimport exp
#
# # Structs
# cdef struct ind:
#     int nombr_nonpris
#     int nombr
#     int rank
#     float fitnessbest
#     float fitness
#     int explored
#     double *f
#     double *capa
#     double *v
#     int *d
#     int *Items
#
# cdef struct pop:
#     int size
#     int maxsize
#     ind **ind_array
#
# # Globals
# cdef int NBITEMS = 250
# cdef int ni = 250
# cdef int L = 5
# cdef double LARGE = 10e50
# cdef float smallValue = 0.0000001
# cdef double kappa = 0.05
# cdef int alpha = 10
# cdef int paretoIni = 28000
# cdef int nf = 2
# cdef double *capacities = NULL
# cdef int **weights = NULL
# cdef int **profits = NULL
# cdef double *vector_weight = NULL
# cdef double max_bound = 0.0
# cdef double **OBJ_Weights = NULL
# cdef int nombreLIGNE = 0
# cdef int nextLn = 0
# cdef int inv = 0
# cdef int OBJ_Weights_lines = 0
#
# # --- Helper Functions ---
# def seed(int x):
#     srand(x)
#
# cdef int irand(int range_val):
#     return rand() % range_val
#
# cdef void *chk_malloc(size_t size):
#     cdef void *return_value = malloc(size)
#     if return_value == NULL:
#         raise MemoryError("Out of memory.")
#     memset(return_value, 0, size)
#     return return_value
#
# cdef pop *create_pop(int maxsize, int nf):
#     cdef int i
#     cdef pop *pp = <pop *>chk_malloc(sizeof(pop))
#     pp.size = 0
#     pp.maxsize = maxsize
#     pp.ind_array = <ind **>chk_malloc(maxsize * sizeof(void*))
#     for i in range(maxsize):
#         pp.ind_array[i] = NULL
#     return pp
#
# cdef ind *create_ind(int nf):
#     cdef int i
#     cdef ind *p_ind = <ind *>chk_malloc(sizeof(ind))
#     p_ind.nombr_nonpris = 0
#     p_ind.nombr = 0
#     p_ind.rank = 0
#     p_ind.fitnessbest = -1.0
#     p_ind.fitness = -1.0
#     p_ind.explored = 0
#     p_ind.f = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.capa = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.v = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.d = <int *>chk_malloc(ni * sizeof(int))
#     p_ind.Items = <int *>chk_malloc(ni * sizeof(int))
#     for i in range(ni):
#         p_ind.Items[i] = 0
#         p_ind.d[i] = 0
#     for i in range(nf):
#         p_ind.f[i] = 0.0
#         p_ind.capa[i] = 0.0
#         p_ind.v[i] = 0.0
#     return p_ind
#
# cdef ind *ind_copy(ind *i):
#     cdef ind *p_ind = create_ind(nf)
#     cdef int k
#     p_ind.nombr_nonpris = i.nombr_nonpris
#     p_ind.nombr = i.nombr
#     p_ind.rank = i.rank
#     p_ind.fitnessbest = i.fitnessbest
#     p_ind.fitness = i.fitness
#     p_ind.explored = i.explored
#     for k in range(nf):
#         p_ind.f[k] = i.f[k]
#         p_ind.v[k] = i.v[k]
#         p_ind.capa[k] = i.capa[k]
#     for k in range(ni):
#         p_ind.d[k] = i.d[k]
#         p_ind.Items[k] = i.Items[k]
#     return p_ind
#
# cdef void free_ind(ind *p_ind):
#     if p_ind != NULL:
#         free(p_ind.d)
#         free(p_ind.f)
#         free(p_ind.capa)
#         free(p_ind.v)
#         free(p_ind.Items)
#         free(p_ind)
#
# cdef void complete_free_pop(pop *pp):
#     cdef int i
#     if pp != NULL:
#         if pp.ind_array != NULL:
#             for i in range(pp.size):
#                 if pp.ind_array[i] != NULL:
#                     free_ind(pp.ind_array[i])
#                     pp.ind_array[i] = NULL
#             free(pp.ind_array)
#         free(pp)
#
# cdef void cleanup_globals():
#     global capacities, weights, profits, vector_weight, OBJ_Weights, OBJ_Weights_lines, nf, ni
#     if capacities != NULL:
#         free(capacities)
#         capacities = NULL
#     if weights != NULL:
#         for i in range(nf):
#             if weights[i] != NULL:
#                 free(weights[i])
#         free(weights)
#         weights = NULL
#     if profits != NULL:
#         for i in range(nf):
#             if profits[i] != NULL:
#                 free(profits[i])
#         free(profits)
#         profits = NULL
#     if vector_weight != NULL:
#         free(vector_weight)
#         vector_weight = NULL
#     if OBJ_Weights != NULL:
#         for i in range(nf):
#             if OBJ_Weights[i] != NULL:
#                 free(OBJ_Weights[i])
#         free(OBJ_Weights)
#         OBJ_Weights = NULL
#     OBJ_Weights_lines = 0
#     nf = 0
#     ni = 0
#
# cdef int non_dominated(ind *p_ind_a, ind *p_ind_b):
#     cdef int i
#     cdef int a_is_good = -1
#     cdef int equal = 1
#     for i in range(nf):
#         if p_ind_a.f[i] > p_ind_b.f[i]:
#             a_is_good = 1
#         if p_ind_a.f[i] != p_ind_b.f[i]:
#             equal = 0
#     if equal:
#         return 0
#     return a_is_good
#
# cdef double calcAddEpsIndicator(ind *p_ind_a, ind *p_ind_b):
#     global max_bound
#     cdef int i
#     cdef double eps
#     cdef double temp_eps
#     if max_bound == 0.0:
#         max_bound = 1e-8
#     eps = (p_ind_a.v[0]/max_bound)-(p_ind_b.v[0]/max_bound)
#     for i in range(1, nf):
#         temp_eps = (p_ind_a.v[i]/max_bound)-(p_ind_b.v[i]/max_bound)
#         if temp_eps > eps:
#             eps = temp_eps
#     return eps
#
# cdef void init_fitness(ind *x):
#     x.fitness = 0.0
#
# cdef void update_fitness(ind *x, double I):
#     x.fitness -= exp(-I / kappa)
#
# cdef double update_fitness_return(double f, double I):
#     return f - exp(-I / kappa)
#
# cdef int delete_fitness(ind *x, double I):
#     x.fitness += exp(-I / kappa)
#     return 0
#
# cdef void compute_ind_fitness(ind *x, pop *SP):
#     cdef int j
#     init_fitness(x)
#     for j in range(SP.size):
#         if SP.ind_array[j] != x:
#             update_fitness(x, calcAddEpsIndicator(SP.ind_array[j], x))
#
# cdef void compute_all_fitness(pop *SP):
#     cdef int i
#     for i in range(SP.size):
#         compute_ind_fitness(SP.ind_array[i], SP)
#
# cdef void loadMOKP(char *filename):
#     global nf, ni, capacities, weights, profits
#     cdef int i, f
#     with open(filename.decode(), "r") as source:
#         _nf, _ni = [int(x) for x in source.readline().split()]
#         nf = _nf
#         ni = _ni
#         capacities = <double *>chk_malloc(nf * sizeof(double))
#         weights = <int **>chk_malloc(nf * sizeof(void*))
#         profits = <int **>chk_malloc(nf * sizeof(void*))
#         for f in range(nf):
#             capacities[f] = float(source.readline().strip())
#             weights[f] = <int *>chk_malloc(ni * sizeof(int))
#             profits[f] = <int *>chk_malloc(ni * sizeof(int))
#             for i in range(ni):
#                 source.readline()  # item index (ignore)
#                 weights[f][i] = int(source.readline().strip())
#                 profits[f][i] = int(source.readline().strip())
#
# cdef void read_weights_file(char *filename):
#     global OBJ_Weights, nombreLIGNE, nf, OBJ_Weights_lines
#     cdef int i, j, nlines
#     with open(filename.decode(), "r") as f:
#         lines = [line for line in f if line.strip()]
#     nlines = len(lines)
#     OBJ_Weights = <double **>chk_malloc(nf * sizeof(void*))
#     for i in range(nf):
#         OBJ_Weights[i] = <double *>chk_malloc(nlines * sizeof(double))
#     for i, line in enumerate(lines):
#         vals = line.strip().split()
#         for j in range(nf):
#             OBJ_Weights[j][i] = float(vals[j])
#     nombreLIGNE = nlines - 1
#     OBJ_Weights_lines = nlines
#
# cdef void dynamic_weight_allpop():
#     global vector_weight, OBJ_Weights, nombreLIGNE, nf, nextLn
#     cdef int i
#     if vector_weight == NULL:
#         vector_weight = <double *>chk_malloc(nf * sizeof(double))
#     for i in range(nf):
#         vector_weight[i] = OBJ_Weights[i][nextLn]
#     if nextLn == nombreLIGNE:
#         nextLn = 0
#     else:
#         nextLn += 1
#
# cdef void choose_weight():
#     dynamic_weight_allpop()
#
# cdef void random_init_ind(ind *x):
#     cdef int j, r, tmp
#     for j in range(ni):
#         x.d[j] = j
#     for j in range(ni):
#         r = irand(ni)
#         tmp = x.d[r]
#         x.d[r] = x.d[j]
#         x.d[j] = tmp
#
# cdef void evaluate(ind *x):
#     cdef int j, l, k, faisable
#     x.nombr = 0
#     x.nombr_nonpris = 0
#     for j in range(nf):
#         x.capa[j] = 0.0
#         x.f[j] = 0.0
#     for j in range(ni):
#         l = 0
#         faisable = 1
#         while l < nf and faisable == 1:
#             if x.capa[l] + weights[l][x.d[j]] > capacities[l]:
#                 faisable = 0
#             l += 1
#         if faisable == 1:
#             for k in range(nf):
#                 x.capa[k] += weights[k][x.d[j]]
#                 x.f[k] += profits[k][x.d[j]]
#             x.Items[x.d[j]] = 1
#             x.nombr += 1
#         else:
#             x.Items[x.d[j]] = 0
#             x.nombr_nonpris += 1
#
# cdef void P_init_pop(pop *SP, pop *Sarchive, int alpha):
#     cdef int i, x, tmp, t
#     t = max(alpha, Sarchive.size)
#     cdef int* shuffle = <int *>chk_malloc(t * sizeof(int))
#     for i in range(t):
#         shuffle[i] = i
#     for i in range(t):
#         x = irand(alpha)
#         tmp = shuffle[i]
#         shuffle[i] = shuffle[x]
#         shuffle[x] = tmp
#     SP.size = alpha
#     if Sarchive.size > alpha:
#         for i in range(alpha):
#             SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#     else:
#         for i in range(alpha):
#             if shuffle[i] < Sarchive.size:
#                 SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#             else:
#                 SP.ind_array[i] = create_ind(nf)
#                 random_init_ind(SP.ind_array[i])
#                 evaluate(SP.ind_array[i])
#     free(shuffle)
#
# cdef int extractPtoArchive(pop *P, pop *archive):
#     cdef int i, j, dom, t, convergence_rate
#     t = archive.size + P.size
#     archiveAndP = create_pop(t, nf)
#     convergence_rate = 0
#     for i in range(archive.size):
#         archiveAndP.ind_array[i] = archive.ind_array[i]
#     for i in range(P.size):
#         archiveAndP.ind_array[i + archive.size] = ind_copy(P.ind_array[i])
#     archiveAndP.size = t
#     archive.size = 0
#     for i in range(t):
#         for j in range(t):
#             if i != j:
#                 dom = non_dominated(archiveAndP.ind_array[i], archiveAndP.ind_array[j])
#                 if dom == -1 or (dom == 0 and i > j):
#                     break
#         else:
#             archive.ind_array[archive.size] = ind_copy(archiveAndP.ind_array[i])
#             archive.size += 1
#             if i >= t - P.size:
#                 convergence_rate += 1
#     complete_free_pop(archiveAndP)
#     return convergence_rate
#
# cdef double calcMaxbound(pop *SP, int size):
#     global max_bound
#     cdef int i, j
#     SP.size = size
#     cdef double max_b = SP.ind_array[0].v[0]
#     for i in range(SP.size):
#         for j in range(nf):
#             if max_b < SP.ind_array[i].v[j]:
#                 max_b = SP.ind_array[i].v[j]
#     if max_b == 0.0:
#         max_b = 1e-8
#     max_bound = max_b
#     return max_bound
#
# cdef void calcul_weight(pop *SP, int size):
#     cdef int i, j
#     for i in range(SP.size):
#         for j in range(nf):
#             SP.ind_array[i].v[j] = SP.ind_array[i].f[j] * vector_weight[j]
#
# cdef int compute_fitness_and_select(pop *SP, ind *x, int size):
#     cdef int i, worst
#     cdef double worst_fit, fit_tmp
#     SP.size = size
#     x.fitness = 0
#     compute_ind_fitness(x, SP)
#     worst_fit = x.fitness
#     worst = -1
#     for i in range(SP.size):
#         fit_tmp = update_fitness_return(SP.ind_array[i].fitness, calcAddEpsIndicator(x, SP.ind_array[i]))
#         if fit_tmp > worst_fit:
#             worst = i
#             worst_fit = fit_tmp
#     fit_tmp = x.fitness
#     if worst == -1:
#         return -1
#     else:
#         for i in range(SP.size):
#             delete_fitness(SP.ind_array[i], calcAddEpsIndicator(SP.ind_array[worst], SP.ind_array[i]))
#             update_fitness(SP.ind_array[i], calcAddEpsIndicator(x, SP.ind_array[i]))
#         delete_fitness(x, calcAddEpsIndicator(SP.ind_array[worst], x))
#         free_ind(SP.ind_array[worst])
#         SP.ind_array[worst] = ind_copy(x)
#         if fit_tmp - worst_fit > smallValue:
#             return worst
#         else:
#             return -1
#
# # --- NEW: Function to create an individual from LLM output ---
# cdef ind *create_ind_from_indices(list item_indices, int n_items):
#     """Creates a valid 'ind' struct from a list of item indices."""
#     cdef ind *p_ind = create_ind(nf)
#     cdef int i, idx
#
#     # Initialize all items as not taken
#     for i in range(ni):
#         p_ind.Items[i] = 0
#         p_ind.d[i] = i # Default order
#
#     # Mark the items provided by the LLM as taken
#     for idx in item_indices:
#         if 0 <= idx < n_items:
#             p_ind.Items[idx] = 1
#
#     # Evaluate the solution to calculate fitness, capacity, etc.
#     evaluate(p_ind)
#     return p_ind
#
# # --- Simplified Local Search Operators ---
# cdef ind *apply_swap(ind *x):
#     """Apply swap operator: exchange two items"""
#     cdef int idx1, idx2, tmp
#     idx1 = irand(ni)
#     idx2 = irand(ni)
#     while idx2 == idx1:
#         idx2 = irand(ni)
#
#     tmp = x.d[idx1]
#     x.d[idx1] = x.d[idx2]
#     x.d[idx2] = tmp
#
#     return x
#
# cdef ind *apply_greedy_add(ind *x, pop *SP):
#     """Apply greedy add operator: add best feasible items"""
#     cdef int i, j, best_idx
#     cdef double best_ratio, current_ratio, total_profit, total_weight
#     cdef bint feasible
#
#     best_idx = -1
#     best_ratio = -1.0
#
#     for i in range(ni):
#         if x.Items[i] == 0:
#             feasible = 1
#             for j in range(nf):
#                 if x.capa[j] + weights[j][i] > capacities[j]:
#                     feasible = 0
#                     break
#
#             if feasible:
#                 total_profit = 0.0
#                 total_weight = 0.0
#                 for j in range(nf):
#                     total_profit += profits[j][i]
#                     total_weight += weights[j][i]
#
#                 current_ratio = total_profit / total_weight if total_weight > 0 else 0.0
#                 if current_ratio > best_ratio:
#                     best_ratio = current_ratio
#                     best_idx = i
#
#     if best_idx != -1:
#         x.Items[best_idx] = 1
#         x.nombr += 1
#         x.nombr_nonpris -= 1
#         for j in range(nf):
#             x.capa[j] += weights[j][best_idx]
#             x.f[j] += profits[j][best_idx]
#
#     return x
#
# cdef ind *apply_local_search(ind *x, pop *SP):
#     """Apply local search operator: neighborhood exploration"""
#     cdef int i, j, k, best_neighbor
#     cdef double best_improvement, current_improvement
#
#     best_neighbor = -1
#     best_improvement = 0.0
#
#     for i in range(ni):
#         if x.Items[i] == 1:
#             x.Items[i] = 0
#             x.nombr -= 1
#             x.nombr_nonpris += 1
#             for j in range(nf):
#                 x.capa[j] -= weights[j][i]
#                 x.f[j] -= profits[j][i]
#
#             for k in range(ni):
#                 if k != i and x.Items[k] == 0:
#                     feasible = 1
#                     for j in range(nf):
#                         if x.capa[j] + weights[j][k] > capacities[j]:
#                             feasible = 0
#                             break
#
#                     if feasible:
#                         current_improvement = 0.0
#                         for j in range(nf):
#                             current_improvement += profits[j][k] - profits[j][i]
#
#                         if current_improvement > best_improvement:
#                             best_improvement = current_improvement
#                             best_neighbor = k
#
#             if best_neighbor == -1:
#                 x.Items[i] = 1
#                 x.nombr += 1
#                 x.nombr_nonpris -= 1
#                 for j in range(nf):
#                     x.capa[j] += weights[j][i]
#                     x.f[j] += profits[j][i]
#             else:
#                 x.Items[best_neighbor] = 1
#                 x.nombr += 1
#                 x.nombr_nonpris -= 1
#                 for j in range(nf):
#                     x.capa[j] += weights[j][best_neighbor]
#                     x.f[j] += profits[j][best_neighbor]
#                 break
#
#     return x
#
# cdef ind *apply_mutation(ind *x):
#     """Apply mutation operator: random modifications"""
#     cdef int num_mutations, i, mutation_idx, new_pos
#
#     num_mutations = max(1, ni // 10)
#     for i in range(num_mutations):
#         mutation_idx = irand(ni)
#         new_pos = irand(ni)
#         x.d[mutation_idx] = new_pos
#
#     return x
#
# cdef ind *apply_repair(ind *x):
#     """Apply repair operator: fix infeasible solutions"""
#     cdef int i, j, worst_idx
#     cdef bint is_feasible
#     cdef double worst_ratio, current_ratio
#
#     is_feasible = 1
#     for j in range(nf):
#         if x.capa[j] > capacities[j]:
#             is_feasible = 0
#             break
#
#     if is_feasible:
#         return x
#
#     while not is_feasible:
#         is_feasible = 1
#         worst_idx = -1
#         worst_ratio = 1e10
#
#         for i in range(ni):
#             if x.Items[i] == 1:
#                 current_ratio = 0.0
#                 for j in range(nf):
#                     if weights[j][i] > 0:
#                         current_ratio += profits[j][i] / weights[j][i]
#
#                 if current_ratio < worst_ratio:
#                     worst_ratio = current_ratio
#                     worst_idx = i
#
#         if worst_idx != -1:
#             x.Items[worst_idx] = 0
#             x.nombr -= 1
#             x.nombr_nonpris += 1
#             for j in range(nf):
#                 x.capa[j] -= weights[j][worst_idx]
#                 x.f[j] -= profits[j][worst_idx]
#
#         for j in range(nf):
#             if x.capa[j] > capacities[j]:
#                 is_feasible = 0
#                 break
#
#     return x
#
# # --- NEW, ROBUST Main Hybrid Optimization Function ---
# def run_hybrid_moacp(
#     object llm_caller_func,
#     instance_file,
#     weights_file,
#     nbitems,
#     num_objectives,
#     time_limit=200.0,
#     llm_interval=25.0  # Increased interval to give local search more time
# ):
#     """
#     Robust Hybrid MOACP runner using LLM to guide local search strategy.
#     """
#     global nf, ni, NBITEMS, alpha, paretoIni, L, nombreLIGNE, nextLn, inv, vector_weight
#     global capacities, weights, profits, OBJ_Weights
#
#     alpha = 40
#     kappa = 0.15
#     L = 6
#     smallValue = 1e-7
#
#     NBITEMS = nbitems
#     ni = nbitems
#     nf = num_objectives
#     paretoIni = 28000
#
#     print(f"\n🚀 Starting ROBUST Hybrid MOACP: {nbitems} items, {num_objectives} objectives")
#     print(f"   Time Limit: {time_limit}s | LLM Interval: {llm_interval}s")
#
#     # --- Initialization ---
#     seed(42)
#     loadMOKP(instance_file.encode())
#     read_weights_file(weights_file.encode())
#     vector_weight = <double *>chk_malloc(nf * sizeof(double))
#
#     P = create_pop(paretoIni, nf)
#
#     # Create an initial population using standard methods
#     solutions = create_pop(alpha, nf)
#     archive = create_pop(paretoIni, nf)
#     choose_weight()
#     P_init_pop(solutions, P, alpha)
#     extractPtoArchive(solutions, P)
#     calcul_weight(solutions, alpha)
#     calcMaxbound(solutions, alpha)
#     compute_all_fitness(solutions)
#     extractPtoArchive(archive, P)
#     complete_free_pop(solutions)
#     complete_free_pop(archive)
#
#     # --- Hybrid Optimization Loop ---
#     start_time = time.time()
#     next_llm_call_time = start_time + llm_interval
#     last_pareto_size = 0
#
#     while (time.time() - start_time) < time_limit:
#         current_time = time.time()
#
#         # --- Phase 1: Intensive Local Search Burst ---
#         # This is our primary workhorse. We run it for longer.
#         solutions = create_pop(alpha, nf)
#         P_init_pop(solutions, P, alpha)
#         calcul_weight(solutions, alpha)
#         compute_all_fitness(solutions)
#
#         # Apply a mix of local search operators to the entire population
#         for i in range(solutions.size):
#             op_choice = irand(4)
#             if op_choice == 0:
#                 apply_local_search(solutions.ind_array[i], solutions)
#             elif op_choice == 1:
#                 apply_greedy_add(solutions.ind_array[i], solutions)
#             elif op_choice == 2:
#                 apply_swap(solutions.ind_array[i])
#             else:
#                 apply_mutation(solutions.ind_array[i])
#             # Always repair to ensure feasibility
#             apply_repair(solutions.ind_array[i])
#
#         extractPtoArchive(solutions, P)
#         complete_free_pop(solutions)
#
#         # --- Phase 2: LLM-Guided Strategy Injection ---
#         if current_time >= next_llm_call_time:
#             print(f"   [{current_time - start_time:.1f}s] Calling LLM for strategy guidance...", end="")
#
#             # Get the best solution to use as context
#             best_ind = P.ind_array[0] # Assuming archive is sorted by fitness
#             current_solution_str = ",".join([str(i) for i in range(ni) if best_ind.Items[i] == 1])
#
#             # --- NEW PROMPT: Ask for a strategy, not direct changes ---
#             prompt = f"""
# I am optimizing a {nbitems}-item knapsack problem. My current best solution is: [{current_solution_str}].
# The objectives are to maximize profits for two criteria.
# Suggest ONE specific local search strategy to improve this solution.
# Choose from these strategies: 'swap', 'greedy_add', 'local_search', 'mutation'.
# Respond with only the strategy name.
# """
#             llm_response = llm_caller_func(prompt)
#
#             if llm_response:
#                 strategy = llm_response.strip().lower()
#                 print(f" LLM suggests strategy: '{strategy}'")
#
#                 # Apply the suggested strategy to a copy of the best solution
#                 new_ind = ind_copy(best_ind)
#
#                 if strategy == 'swap':
#                     apply_swap(new_ind)
#                 elif strategy == 'greedy_add':
#                     apply_greedy_add(new_ind, P)
#                 elif strategy == 'local_search':
#                     apply_local_search(new_ind, P)
#                 elif strategy == 'mutation':
#                     apply_mutation(new_ind)
#
#                 # Always repair to ensure feasibility
#                 apply_repair(new_ind)
#
#                 # Add to population if it's a good solution
#                 is_dominated = False
#                 for i in range(P.size):
#                     if non_dominated(P.ind_array[i], new_ind) == 1:
#                         is_dominated = True
#                         break
#
#                 if not is_dominated:
#                     P.ind_array[P.size] = new_ind
#                     P.size += 1
#                     print(f" Success! Added new solution.")
#                 else:
#                     free_ind(new_ind)
#             else:
#                 print(" LLM call failed.")
#
#             next_llm_call_time = time.time() + llm_interval
#
#         if P.size == last_pareto_size and (current_time - start_time) > (time_limit * 0.8):
#             print("   Search stagnated, ending early.")
#             break
#         last_pareto_size = P.size
#
#     # --- Finalization ---
#     total_time = time.time() - start_time
#     print(f"✅ Robust Hybrid MOACP Complete in {total_time:.2f}s. Found {P.size} solutions.")
#
#     # Extract Pareto front for this run
#     final_pareto = []
#     for i in range(P.size):
#         if P.ind_array[i] != NULL:
#             obj1 = P.ind_array[i].f[0]
#             obj2 = P.ind_array[i].f[1] if nf > 1 else 0
#             final_pareto.append([obj1, obj2])
#
#     complete_free_pop(P)
#     cleanup_globals()
#
#     return {
#         'pareto_solutions': np.array(final_pareto) if final_pareto else np.array([]),
#         'total_time': total_time,
#         'num_solutions': len(final_pareto)
#     }
#
# print("✅ Robust Hybrid Cython implementation ready!")
# Out:
# Content of stdout:
# _cython_magic_1dbca78b3a9b86a225c0c24e5e26ee7da5f17e46b631ed5e2cef9cb7ecd1a6e2.c
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_1dbca78b3a9b86a225c0c24e5e26ee7da5f17e46b631ed5e2cef9cb7ecd1a6e2.c(4762): warning C4244: '='ÿ: conversion de 'double' en 'float', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_1dbca78b3a9b86a225c0c24e5e26ee7da5f17e46b631ed5e2cef9cb7ecd1a6e2.c(4852): warning C4244: '='ÿ: conversion de 'double' en 'float', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_1dbca78b3a9b86a225c0c24e5e26ee7da5f17e46b631ed5e2cef9cb7ecd1a6e2.c(5862): warning C4244: '='ÿ: conversion de 'Py_ssize_t' en 'int', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_1dbca78b3a9b86a225c0c24e5e26ee7da5f17e46b631ed5e2cef9cb7ecd1a6e2.c(11620): warning C4305: '='ÿ: troncation de 'double' … 'float'
#    Cr‚ation de la bibliothŠque C:\Users\Aziz il patal\.ipython\cython\Users\Aziz il patal\.ipython\cython\_cython_magic_1dbca78b3a9b86a225c0c24e5e26ee7da5f17e46b631ed5e2cef9cb7ecd1a6e2.cp39-win_amd64.lib et de l'objet C:\Users\Aziz il patal\.ipython\cython\Users\Aziz il patal\.ipython\cython\_cython_magic_1dbca78b3a9b86a225c0c24e5e26ee7da5f17e46b631ed5e2cef9cb7ecd1a6e2.cp39-win_amd64.exp
# G‚n‚ration de code en cours
# ✅ Robust Hybrid Cython implementation ready!

# %%
# Utility functions for hypervolume calculation and visualization
import numpy as np
import matplotlib.pyplot as plt
import os

def calculate_hypervolume_2d(pareto_points, reference_point=None):
    """Calculate hypervolume for 2D Pareto front (maximization)"""
    if len(pareto_points) == 0:
        return 0.0
    
    # Sort points by first objective (ascending for maximization)
    sorted_points = pareto_points[np.argsort(pareto_points[:, 0])]
    
    # Set reference point if not provided
    if reference_point is None:
        # Use origin as reference point for maximization
        reference_point = np.zeros(2)
    
    # Calculate hypervolume
    hypervolume = 0.0
    prev_x = reference_point[0]
    
    for point in sorted_points:
        # For maximization, we calculate area above the point
        width = point[0] - prev_x
        height = point[1] - reference_point[1]
        hypervolume += width * height
        prev_x = point[0]
    
    return hypervolume

def calculate_reference_hv_for_instance(result_file):
    """Calculate reference hypervolume for a specific instance result file"""
    try:
        # Load the results
        data = np.loadtxt(result_file)
        if data.ndim == 1:
            data = data.reshape(1, -1)
        
        # Remove duplicates
        data_unique = np.unique(data, axis=0)
        
        # Extract Pareto front (maximization)
        def is_pareto_efficient(points):
            is_efficient = np.ones(points.shape[0], dtype=bool)
            for i, c in enumerate(points):
                if is_efficient[i]:
                    is_efficient[is_efficient] = np.any(points[is_efficient]>=c, axis=1)
                    is_efficient[i] = True
            return is_efficient
        
        pareto_mask = is_pareto_efficient(data_unique)
        pareto_points = data_unique[pareto_mask]
        
        # Calculate hypervolume
        hv = calculate_hypervolume_2d(pareto_points)
        
        return {
            'all_solutions': data,
            'unique_solutions': data_unique,
            'pareto_solutions': pareto_points,
            'num_pareto': len(pareto_points),
            'hypervolume': hv
        }
    except Exception as e:
        print(f"Error loading result file {result_file}: {e}")
        return None

def visualize_pareto_comparison(reference_file, optimized_file, title="Pareto Front Comparison"):
    """Visualize comparison between reference and optimized Pareto fronts"""
    # Load reference data
    ref_data = calculate_reference_hv_for_instance(reference_file)
    if not ref_data:
        print(f"Error loading reference file {reference_file}")
        return
    
    # Load optimized data
    opt_data = calculate_reference_hv_for_instance(optimized_file)
    if not opt_data:
        print(f"Error loading optimized file {optimized_file}")
        return
    
    # Create plot
    plt.figure(figsize=(12, 8))
    
    # Plot reference Pareto front
    ref_pareto = ref_data['pareto_solutions']
    plt.scatter(ref_pareto[:, 0], ref_pareto[:, 1], 
                c='blue', alpha=0.7, label=f'Reference (HV: {ref_data["hypervolume"]:,.0f})')
    
    # Plot optimized Pareto front
    opt_pareto = opt_data['pareto_solutions']
    plt.scatter(opt_pareto[:, 0], opt_pareto[:, 1], 
                c='red', alpha=0.7, label=f'Optimized (HV: {opt_data["hypervolume"]:,.0f})')
    
    # Calculate improvement
    improvement = ((opt_data['hypervolume'] - ref_data['hypervolume']) / ref_data['hypervolume']) * 100
    
    plt.title(f"{title}\nImprovement: {improvement:.2f}%")
    plt.xlabel('Objective 1')
    plt.ylabel('Objective 2')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    
    # Save plot
    filename = f"hybrid_pareto_comparison_{os.path.basename(reference_file).replace('.txt', '')}.png"
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    print(f"✅ Comparison plot saved: {filename}")
    plt.show()
    
    return improvement

print("✅ Utility functions ready!")
# Out:
# ✅ Utility functions ready!

# %%
# Main execution script
if __name__ == "__main__":
    
    # --- Check LLM Connection ---
    try:
        # A quick test call to ensure Llama 3 is running
        print("Testing LLM connection...")
        test_response = call_llm_for_solution("Respond with only the number 1.", timeout=50)
        if test_response and "1" in test_response:
            print("✅ LLaMA-3 is connected and responding!")
            llm_working = True
        else:
            print("⚠️ LLaMA-3 is not responding correctly. The hybrid method will run without LLM calls.")
            llm_working = False
    except Exception as e:
        print(f"❌ Failed to connect to LLaMA-3: {e}")
        llm_working = False

    # --- Define Instances to Optimize ---
    instances_to_optimize = [
        ("./multiobjectives/250.2.txt", "./multiobjectives/Weights_2obj_FQ200.txt", 250, 2, "2502_Resulats.txt"),
        ("./multiobjectives/500.2.txt", "./multiobjectives/Weights_2obj_FQ200.txt", 500, 2, "5002_Resulats.txt"),
        ("./multiobjectives/750.2.txt", "./multiobjectives/Weights_2obj_FQ200.txt", 750, 2, "7502_Resulats.txt")
    ]

    results_summary = {}

    # --- Run Optimization for Each Instance ---
    for instance_file, weights_file, nbitems, num_objectives, reference_result_file in instances_to_optimize:
        print(f"\n{'='*70}")
        print(f"🧬 HYBRID OPTIMIZATION FOR {nbitems}x{num_objectives} INSTANCE")
        print(f"{'='*70}")
        
        # Check if files exist
        if not os.path.exists(instance_file):
            print(f"❌ Skipping: Instance file not found at {instance_file}")
            continue
        if not os.path.exists(weights_file):
            print(f"❌ Skipping: Weights file not found at {weights_file}")
            continue

        # Get reference data for comparison
        reference_data = calculate_reference_hv_for_instance(reference_result_file)
        if not reference_data:
            print(f"❌ Skipping: Could not load reference data from {reference_result_file}")
            continue
        
        reference_hv = reference_data['hypervolume']
        print(f"Reference Hypervolume: {reference_hv:,.0f}")

        # --- Run the Hybrid Algorithm ---
        # Set time limits. 200s for the first, more for larger ones.
        time_limit = 200 if nbitems == 250 else 400 if nbitems == 500 else 600
        
        result = run_hybrid_moacp(
            llm_caller_func=call_llm_for_solution,  # Pass the Python function to Cython
            instance_file=instance_file,
            weights_file=weights_file,
            nbitems=nbitems,
            num_objectives=num_objectives,
            time_limit=time_limit,
            llm_interval=20.0  # Call LLM every 20 seconds
        )
        
        # --- Analyze and Report Results ---
        final_hv = calculate_hypervolume_2d(result['pareto_solutions'])
        improvement = ((final_hv - reference_hv) / reference_hv) * 100
        
        # Store results
        instance_sig = f"{nbitems}_{num_objectives}"
        results_summary[instance_sig] = {
            'result': result,
            'hv': final_hv,
            'reference_hv': reference_hv,
            'improvement': improvement,
            'total_time': result['total_time']
        }
        
        # Save results
        output_file = f"hybrid_optimized_{instance_sig}.txt"
        np.savetxt(output_file, result['pareto_solutions'])
        print(f"Results saved to {output_file}")
        
        # Visualize comparison
        visualize_pareto_comparison(reference_result_file, output_file, f"Hybrid LLM+Local Search - {instance_sig}")
        
        print(f"\n🏆 OPTIMIZATION COMPLETE FOR {instance_sig}")
        print(f"  Final HV: {final_hv:,.0f}")
        print(f"  Reference HV: {reference_hv:,.0f}")
        print(f"  Improvement: {improvement:.2f}%")
        print(f"  Total Time: {result['total_time']:.2f}s (Target: {time_limit}s)")

    # --- Print Overall Summary ---
    print(f"\n{'='*70}")
    print("📊 OVERALL HYBRID OPTIMIZATION SUMMARY")
    print(f"{'='*70}")

    if results_summary:
        for instance_sig, results in results_summary.items():
            print(f"\n{instance_sig}:")
            print(f"  Final HV: {results['hv']:,.0f}")
            print(f"  Reference HV: {results['reference_hv']:,.0f}")
            print(f"  Improvement: {results['improvement']:.2f}%")
            print(f"  Total Time: {results['total_time']:.2f}s")

        avg_improvement = np.mean([results['improvement'] for results in results_summary.values()])
        avg_time = np.mean([results['total_time'] for results in results_summary.values()])
        
        print(f"\n📈 AVERAGE RESULTS:")
        print(f"  Average Improvement: {avg_improvement:.2f}%")
        print(f"  Average Time: {avg_time:.2f}s")
        if avg_improvement > 0:
            print("🎉 SUCCESS: The hybrid approach achieved a positive improvement!")
        else:
            print("🤔 The hybrid approach needs further tuning. Consider the LLM prompt or interval.")
    else:
        print("No results to summarize.")
# Out:
# Testing LLM connection...
# ✅ LLaMA-3 is connected and responding!
#
# ======================================================================
# 🧬 HYBRID OPTIMIZATION FOR 250x2 INSTANCE
# ======================================================================
# Reference Hypervolume: 97,640,877
#
# 🚀 Starting ROBUST Hybrid MOACP: 250 items, 2 objectives
#    Time Limit: 200s | LLM Interval: 20.0s
#    [20.0s] Calling LLM for strategy guidance... LLM suggests strategy: ''local_search''
#  LLM suggests strategy: 'swap'ategy guidance...
#  LLM suggests strategy: ''local_search''ance...
#  LLM suggests strategy: 'swap'ategy guidance...
#  LLM suggests strategy: 'greedy_add' guidance...
#  LLM suggests strategy: 'swap'rategy guidance...
#    Search stagnated, ending early.
# ✅ Robust Hybrid MOACP Complete in 160.00s. Found 3 solutions.
# Results saved to hybrid_optimized_250_2.txt
# ✅ Comparison plot saved: hybrid_pareto_comparison_2502_Resulats.png
# 🏆 OPTIMIZATION COMPLETE FOR 250_2
#   Final HV: 85,267,704
#   Reference HV: 97,640,877
#   Improvement: -12.67%
#   Total Time: 160.00s (Target: 200s)
#
# ======================================================================
# 🧬 HYBRID OPTIMIZATION FOR 500x2 INSTANCE
# ======================================================================
# Reference Hypervolume: 405,521,824
#
# 🚀 Starting ROBUST Hybrid MOACP: 500 items, 2 objectives
#    Time Limit: 400s | LLM Interval: 20.0s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 55
#      51 # --- Run the Hybrid Algorithm ---
#      52 # Set time limits. 200s for the first, more for larger ones.
#      53 time_limit = 200 if nbitems == 250 else 400 if nbitems == 500 else 600
# ---> 55 result = run_hybrid_moacp(
#      56     llm_caller_func=call_llm_for_solution,  # Pass the Python function to Cython
#      57     instance_file=instance_file,
#      58     weights_file=weights_file,
#      59     nbitems=nbitems,
#      60     num_objectives=num_objectives,
#      61     time_limit=time_limit,
#      62     llm_interval=20.0  # Call LLM every 20 seconds
#      63 )
#      65 # --- Analyze and Report Results ---
#      66 final_hv = calculate_hypervolume_2d(result['pareto_solutions'])
#
# File _cython_magic_1dbca78b3a9b86a225c0c24e5e26ee7da5f17e46b631ed5e2cef9cb7ecd1a6e2.pyx:667, in _cython_magic_1dbca78b3a9b86a225c0c24e5e26ee7da5f17e46b631ed5e2cef9cb7ecd1a6e2.run_hybrid_moacp()
#
# File A:\conda\envs\ibmols\lib\site-packages\ipykernel\iostream.py:664, in OutStream.write(self, string)
#     655 def write(self, string: str) -> Optional[int]:  # type:ignore[override]
#     656     """Write to current stream after encoding if necessary
#     657
#     658     Returns
#    (...)
#     662
#     663     """
# --> 664     parent = self.parent_header
#     666     if not isinstance(string, str):
#     667         msg = f"write() argument must be str, not {type(string)}"  # type:ignore[unreachable]
#
# File A:\conda\envs\ibmols\lib\site-packages\ipykernel\iostream.py:507, in OutStream.parent_header(self)
#     505 @property
#     506 def parent_header(self):
# --> 507     try:
#     508         # asyncio-specific
#     509         return self._parent_header.get()
#     510     except LookupError:
#
# KeyboardInterrupt:

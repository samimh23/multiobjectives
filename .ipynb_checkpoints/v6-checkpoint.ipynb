# %%
# %load_ext cython
# Out:
# The cython extension is already loaded. To reload it, use:
#   %reload_ext cython

# %%
# %%cython
#
# # =========================================================================
# # PART 1: C LIBRARY IMPORTS AND GLOBAL DEFINITIONS
# # =========================================================================
#
# from libc.stdlib cimport malloc, free, srand, rand
# from libc.string cimport memset
# from libc.math cimport exp
#
# # Import Python libraries needed for the LLM part
# import time
# import json
# import ollama
# import numpy as np
# import hashlib
# from collections import defaultdict
#
# # Constants for the enhanced algorithm
# cdef int NBITEMS = 250
# cdef int ni = 250
# cdef int L = 5  # This will be adjusted by the LLM
# cdef double LARGE = 10e50
# cdef float smallValue = 0.0000001
# cdef double kappa = 0.05  # This will be adjusted by the LLM
# cdef int alpha = 10
# cdef int paretoIni = 28000
#
# # Data structures (MODIFIED to track more info)
# cdef struct ind:
#     int nombr_nonpris
#     int nombr
#     int rank
#     float fitnessbest
#     float fitness
#     int explored
#     double *f
#     double *capa
#     double *v
#     int *d
#     int *Items
#     int age
#     int improvement_count
#     int llm_enhanced
#     int last_improvement_iteration # NEW: Track when it was last improved
#
# cdef struct pop:
#     int size
#     int maxsize
#     ind **ind_array
#
# # Global variables for the problem instance (unchanged)
# cdef int nf = 2
# cdef double *capacities = NULL
# cdef int **weights = NULL
# cdef int **profits = NULL
# cdef double *vector_weight = NULL
# cdef double max_bound = 0.0
# cdef double **OBJ_Weights = NULL
# cdef int nombreLIGNE = 0
# cdef int nextLn = 0
# cdef int inv = 0
# cdef int OBJ_Weights_lines = 0
#
# # =========================================================================
# # PART 2: CORE CYTHON HELPER FUNCTIONS
# # =========================================================================
#
# def seed(int x):
#     srand(x)
#
# cdef int irand(int range_val):
#     return rand() % range_val
#
# cdef void *chk_malloc(size_t size):
#     cdef void *return_value = malloc(size)
#     if return_value == NULL:
#         raise MemoryError("Out of memory.")
#     memset(return_value, 0, size)
#     return return_value
#
# cdef pop *create_pop(int maxsize, int nf):
#     cdef int i
#     cdef pop *pp = <pop *>chk_malloc(sizeof(pop))
#     pp.size = 0
#     pp.maxsize = maxsize
#     pp.ind_array = <ind **>chk_malloc(maxsize * sizeof(void*))
#     for i in range(maxsize):
#         pp.ind_array[i] = NULL
#     return pp
#
# cdef ind *create_ind(int nf):
#     cdef int i
#     cdef ind *p_ind = <ind *>chk_malloc(sizeof(ind))
#     p_ind.nombr_nonpris = 0
#     p_ind.nombr = 0
#     p_ind.rank = 0
#     p_ind.fitnessbest = -1.0
#     p_ind.fitness = -1.0
#     p_ind.explored = 0
#     p_ind.age = 0
#     p_ind.improvement_count = 0
#     p_ind.llm_enhanced = 0
#     p_ind.last_improvement_iteration = 0 # NEW
#     p_ind.f = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.capa = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.v = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.d = <int *>chk_malloc(ni * sizeof(int))
#     p_ind.Items = <int *>chk_malloc(ni * sizeof(int))
#     for i in range(ni):
#         p_ind.Items[i] = 0
#         p_ind.d[i] = 0
#     for i in range(nf):
#         p_ind.f[i] = 0.0
#         p_ind.capa[i] = 0.0
#         p_ind.v[i] = 0.0
#     return p_ind
#
# cdef ind *ind_copy(ind *i):
#     cdef ind *p_ind = create_ind(nf)
#     cdef int k
#     p_ind.nombr_nonpris = i.nombr_nonpris
#     p_ind.nombr = i.nombr
#     p_ind.rank = i.rank
#     p_ind.fitnessbest = i.fitnessbest
#     p_ind.fitness = i.fitness
#     p_ind.explored = i.explored
#     p_ind.age = i.age
#     p_ind.improvement_count = i.improvement_count
#     p_ind.llm_enhanced = i.llm_enhanced
#     p_ind.last_improvement_iteration = i.last_improvement_iteration # NEW
#     for k in range(nf):
#         p_ind.f[k] = i.f[k]
#         p_ind.v[k] = i.v[k]
#         p_ind.capa[k] = i.capa[k]
#     for k in range(ni):
#         p_ind.d[k] = i.d[k]
#         p_ind.Items[k] = i.Items[k]
#     return p_ind
#
# cdef void free_ind(ind *p_ind):
#     if p_ind != NULL:
#         free(p_ind.d)
#         free(p_ind.f)
#         free(p_ind.capa)
#         free(p_ind.v)
#         free(p_ind.Items)
#         free(p_ind)
#
# cdef void complete_free_pop(pop *pp):
#     cdef int i
#     if pp != NULL:
#         if pp.ind_array != NULL:
#             for i in range(pp.size):
#                 if pp.ind_array[i] != NULL:
#                     free_ind(pp.ind_array[i])
#                     pp.ind_array[i] = NULL
#             free(pp.ind_array)
#         free(pp)
#
# cdef void cleanup_globals():
#     global capacities, weights, profits, vector_weight, OBJ_Weights, OBJ_Weights_lines, nf, ni
#     if capacities != NULL:
#         free(capacities)
#         capacities = NULL
#     if weights != NULL:
#         for i in range(nf):
#             if weights[i] != NULL:
#                 free(weights[i])
#         free(weights)
#         weights = NULL
#     if profits != NULL:
#         for i in range(nf):
#             if profits[i] != NULL:
#                 free(profits[i])
#         free(profits)
#         profits = NULL
#     if vector_weight != NULL:
#         free(vector_weight)
#         vector_weight = NULL
#     if OBJ_Weights != NULL:
#         for i in range(nf):
#             if OBJ_Weights[i] != NULL:
#                 free(OBJ_Weights[i])
#         free(OBJ_Weights)
#         OBJ_Weights = NULL
#     OBJ_Weights_lines = 0
#     nf = 0
#     ni = 0
#
# cdef int non_dominated(ind *p_ind_a, ind *p_ind_b):
#     cdef int i
#     cdef int a_is_good = -1
#     cdef int equal = 1
#     for i in range(nf):
#         if p_ind_a.f[i] > p_ind_b.f[i]:
#             a_is_good = 1
#         if p_ind_a.f[i] != p_ind_b.f[i]:
#             equal = 0
#     if equal:
#         return 0
#     return a_is_good
#
# cdef double calcAddEpsIndicator(ind *p_ind_a, ind *p_ind_b):
#     global max_bound
#     cdef int i
#     cdef double eps
#     cdef double temp_eps
#     if max_bound == 0.0:
#         max_bound = 1e-8
#     eps = (p_ind_a.v[0]/max_bound)-(p_ind_b.v[0]/max_bound)
#     for i in range(1, nf):
#         temp_eps = (p_ind_a.v[i]/max_bound)-(p_ind_b.v[i]/max_bound)
#         if temp_eps > eps:
#             eps = temp_eps
#     return eps
#
# cdef void init_fitness(ind *x):
#     x.fitness = 0.0
#
# cdef void update_fitness(ind *x, double I):
#     x.fitness -= exp(-I / kappa)
#
# cdef double update_fitness_return(double f, double I):
#     return f - exp(-I / kappa)
#
# cdef int delete_fitness(ind *x, double I):
#     x.fitness += exp(-I / kappa)
#     return 0
#
# cdef void compute_ind_fitness(ind *x, pop *SP):
#     cdef int j
#     init_fitness(x)
#     for j in range(SP.size):
#         if SP.ind_array[j] != x:
#             update_fitness(x, calcAddEpsIndicator(SP.ind_array[j], x))
#
# cdef void compute_all_fitness(pop *SP):
#     cdef int i
#     for i in range(SP.size):
#         compute_ind_fitness(SP.ind_array[i], SP)
#
# # =========================================================================
# # PART 3: PROBLEM LOADING AND EVALUATION FUNCTIONS
# # =========================================================================
#
# def loadMOKP(char *filename):
#     global nf, ni, capacities, weights, profits
#     cdef int i, f
#     with open(filename.decode(), "r") as source:
#         _nf, _ni = [int(x) for x in source.readline().split()]
#         nf = _nf
#         ni = _ni
#         capacities = <double *>chk_malloc(nf * sizeof(double))
#         weights = <int **>chk_malloc(nf * sizeof(void*))
#         profits = <int **>chk_malloc(nf * sizeof(void*))
#         for f in range(nf):
#             capacities[f] = float(source.readline().strip())
#             weights[f] = <int *>chk_malloc(ni * sizeof(int))
#             profits[f] = <int *>chk_malloc(ni * sizeof(int))
#             for i in range(ni):
#                 source.readline()  # item index (ignore)
#                 weights[f][i] = int(source.readline().strip())
#                 profits[f][i] = int(source.readline().strip())
#
# def read_weights_file(char *filename):
#     global OBJ_Weights, nombreLIGNE, nf, OBJ_Weights_lines
#     cdef int i, j, nlines
#     with open(filename.decode(), "r") as f:
#         lines = [line for line in f if line.strip()]
#     nlines = len(lines)
#     OBJ_Weights = <double **>chk_malloc(nf * sizeof(void*))
#     for i in range(nf):
#         OBJ_Weights[i] = <double *>chk_malloc(nlines * sizeof(double))
#     for i, line in enumerate(lines):
#         vals = line.strip().split()
#         for j in range(nf):
#             OBJ_Weights[j][i] = float(vals[j])
#     nombreLIGNE = nlines - 1
#     OBJ_Weights_lines = nlines
#
# cdef void dynamic_weight_allpop():
#     global vector_weight, OBJ_Weights, nombreLIGNE, nf, nextLn
#     cdef int i
#     if vector_weight == NULL:
#         vector_weight = <double *>chk_malloc(nf * sizeof(double))
#     for i in range(nf):
#         vector_weight[i] = OBJ_Weights[i][nextLn]
#     if nextLn == nombreLIGNE:
#         nextLn = 0
#     else:
#         nextLn += 1
#
# cdef void choose_weight():
#     dynamic_weight_allpop()
#
# cdef void random_init_ind(ind *x):
#     cdef int j, r, tmp
#     for j in range(ni):
#         x.d[j] = j
#     for j in range(ni):
#         r = irand(ni)
#         tmp = x.d[r]
#         x.d[r] = x.d[j]
#         x.d[j] = tmp
#
# cdef void evaluate(ind *x):
#     cdef int j, l, k, faisable
#     x.nombr = 0
#     x.nombr_nonpris = 0
#     for j in range(nf):
#         x.capa[j] = 0.0
#         x.f[j] = 0.0
#     for j in range(ni):
#         l = 0
#         faisable = 1
#         while l < nf and faisable == 1:
#             if x.capa[l] + weights[l][x.d[j]] > capacities[l]:
#                 faisable = 0
#             l += 1
#         if faisable == 1:
#             for k in range(nf):
#                 x.capa[k] += weights[k][x.d[j]]
#                 x.f[k] += profits[k][x.d[j]]
#             x.Items[x.d[j]] = 1
#             x.nombr += 1
#         else:
#             x.Items[x.d[j]] = 0
#             x.nombr_nonpris += 1
#
# cdef void P_init_pop(pop *SP, pop *Sarchive, int alpha):
#     cdef int i, x, tmp, t
#     t = max(alpha, Sarchive.size)
#     cdef int* shuffle = <int *>chk_malloc(t * sizeof(int))
#     for i in range(t):
#         shuffle[i] = i
#     for i in range(t):
#         x = irand(alpha)
#         tmp = shuffle[i]
#         shuffle[i] = shuffle[x]
#         shuffle[x] = tmp
#     SP.size = alpha
#     if Sarchive.size > alpha:
#         for i in range(alpha):
#             SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#     else:
#         for i in range(alpha):
#             if shuffle[i] < Sarchive.size:
#                 SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#             else:
#                 SP.ind_array[i] = create_ind(nf)
#                 random_init_ind(SP.ind_array[i])
#                 evaluate(SP.ind_array[i])
#     free(shuffle)
#
# cdef int extractPtoArchive(pop *P, pop *archive):
#     cdef int i, j, dom, t, convergence_rate
#     t = archive.size + P.size
#     archiveAndP = create_pop(t, nf)
#     convergence_rate = 0
#     for i in range(archive.size):
#         archiveAndP.ind_array[i] = archive.ind_array[i]
#     for i in range(P.size):
#         archiveAndP.ind_array[i + archive.size] = ind_copy(P.ind_array[i])
#     archiveAndP.size = t
#     archive.size = 0
#     for i in range(t):
#         for j in range(t):
#             if i != j:
#                 dom = non_dominated(archiveAndP.ind_array[i], archiveAndP.ind_array[j])
#                 if dom == -1 or (dom == 0 and i > j):
#                     break
#         else:
#             archive.ind_array[archive.size] = ind_copy(archiveAndP.ind_array[i])
#             archive.size += 1
#             if i >= t - P.size:
#                 convergence_rate += 1
#     complete_free_pop(archiveAndP)
#     return convergence_rate
#
# cdef double calcMaxbound(pop *SP, int size):
#     global max_bound
#     cdef int i, j
#     SP.size = size
#     cdef double max_b = SP.ind_array[0].v[0]
#     for i in range(SP.size):
#         for j in range(nf):
#             if max_b < SP.ind_array[i].v[j]:
#                 max_b = SP.ind_array[i].v[j]
#     if max_b == 0.0:
#         max_b = 1e-8
#     max_bound = max_b
#     return max_b
#
# cdef void calcul_weight(pop *SP, int size):
#     cdef int i, j
#     for i in range(SP.size):
#         for j in range(nf):
#             SP.ind_array[i].v[j] = SP.ind_array[i].f[j] * vector_weight[j]
#
# cdef int compute_fitness_and_select(pop *SP, ind *x, int size):
#     cdef int i, worst
#     cdef double worst_fit, fit_tmp
#     SP.size = size
#     x.fitness = 0
#     compute_ind_fitness(x, SP)
#     worst_fit = x.fitness
#     worst = -1
#     for i in range(SP.size):
#         fit_tmp = update_fitness_return(SP.ind_array[i].fitness, calcAddEpsIndicator(x, SP.ind_array[i]))
#         if fit_tmp > worst_fit:
#             worst = i
#             worst_fit = fit_tmp
#     fit_tmp = x.fitness
#     if worst == -1:
#         return -1
#     else:
#         for i in range(SP.size):
#             delete_fitness(SP.ind_array[i], calcAddEpsIndicator(SP.ind_array[worst], SP.ind_array[i]))
#             update_fitness(SP.ind_array[i], calcAddEpsIndicator(x, SP.ind_array[i]))
#         delete_fitness(x, calcAddEpsIndicator(SP.ind_array[worst], x))
#         free_ind(SP.ind_array[worst])
#         SP.ind_array[worst] = ind_copy(x)
#         if fit_tmp - worst_fit > smallValue:
#             return worst
#         else:
#             return -1
#
# # =========================================================================
# # PART 4: ENHANCED LOCAL SEARCH
# # =========================================================================
#
# cdef void Indicator_local_search1(pop *SP, pop *Sarchive, int size):
#     cdef ind *x
#     cdef ind *y
#     cdef int i, j, r, t, k, l, v, sol, mino, mp, maxp, consistant, pos, stop, convergence, ii, tmp_pris, tmp_nonpris, taille, feasible, tv, IM
#     cdef int* remplace = <int *>chk_malloc(L * sizeof(int))
#     SP.size = size
#     extractPtoArchive(SP, Sarchive)
#     while True:
#         convergence = 0
#         for i in range(SP.size):
#             if not SP.ind_array[i].explored:
#                 x = ind_copy(SP.ind_array[i])
#                 j = 0
#                 while j < x.nombr:
#                     for l in range(L):
#                         remplace[l] = 0
#                     while True:
#                         mino = irand(ni)
#                         if x.Items[mino] == 1:
#                             break
#                     x.Items[mino] = 0
#                     x.nombr -= 1
#                     x.nombr_nonpris += 1
#                     for r in range(nf):
#                         x.capa[r] -= weights[r][mino]
#                         x.f[r] -= profits[r][mino]
#                     IM = 0
#                     taille = 0
#                     while IM < L:
#                         while True:
#                             maxp = irand(ni)
#                             if x.Items[maxp] == 0:
#                                 break
#                         if maxp != mino:
#                             consistant = 1
#                             r = 0
#                             while r < nf and consistant == 1:
#                                 if x.capa[r] + weights[r][maxp] > capacities[r]:
#                                     consistant = 0
#                                 r += 1
#                             if consistant == 1:
#                                 feasible = 1
#                                 r = 0
#                                 while r < taille and feasible:
#                                     if maxp == remplace[r]:
#                                         feasible = 0
#                                     r += 1
#                                 if feasible == 1:
#                                     remplace[taille] = maxp
#                                     taille += 1
#                                     x.Items[maxp] = 1
#                                     x.nombr_nonpris -= 1
#                                     x.nombr += 1
#                                     for r in range(nf):
#                                         x.capa[r] += weights[r][maxp]
#                                         x.f[r] += profits[r][maxp]
#                         IM += 1
#                     for tv in range(nf):
#                         x.v[tv] = x.f[tv] * vector_weight[tv]
#                     max_bound = calcMaxbound(SP, SP.size)
#                     sol = compute_fitness_and_select(SP, x, SP.size)
#                     if sol != -1:
#                         j = x.nombr + 1
#                         if sol > i and i + 1 < SP.size:
#                             y = SP.ind_array[i + 1]
#                             SP.ind_array[i + 1] = SP.ind_array[sol]
#                             SP.ind_array[sol] = y
#                             i += 1
#                         break
#                     elif sol == -1:
#                         x.Items[mino] = 1
#                         x.nombr_nonpris -= 1
#                         x.nombr += 1
#                         for r in range(nf):
#                             x.capa[r] += weights[r][mino]
#                             x.f[r] += profits[r][mino]
#                         if taille >= 1:
#                             for r in range(taille):
#                                 x.Items[remplace[r]] = 0
#                                 x.nombr -= 1
#                                 x.nombr_nonpris += 1
#                                 for t in range(nf):
#                                     x.capa[t] -= weights[t][remplace[r]]
#                                     x.f[t] -= profits[t][remplace[r]]
#                                     x.v[t] = x.f[t] * vector_weight[t]
#                     j += 1
#                 tmp_pris = x.nombr
#                 tmp_nonpris = x.nombr_nonpris
#                 free_ind(x)
#                 if j == tmp_pris:
#                     SP.ind_array[i].explored = 1
#         convergence = extractPtoArchive(SP, Sarchive)
#         if not convergence:
#             break
#     free(remplace)
#
# # =========================================================================
# # PART 4.5: HELPER FUNCTION FOR ADAPTIVE STRATEGY
# # =========================================================================
#
# cdef double calculate_archive_hypervolume(pop *archive):
#     """
#     Calculate hypervolume for the current archive. Used by the LLM agent.
#     NOTE: This is a simplified 2D hypervolume calculation.
#     """
#     if archive == NULL or archive.size == 0:
#         return 0.0
#
#     # Create a list of points from the archive
#     points = []
#     cdef int i
#     for i in range(archive.size):
#         points.append((archive.ind_array[i].f[0], archive.ind_array[i].f[1]))
#
#     if not points:
#         return 0.0
#
#     # Find a reference point
#     ref_x = max(p[0] for p in points) * 1.1
#     ref_y = max(p[1] for p in points) * 1.1
#
#     # Sort points by the first objective
#     points.sort(key=lambda p: p[0])
#
#     cdef double hv = 0.0
#     cdef int j
#     for j in range(len(points) - 1):
#         x1, y1 = points[j]
#         x2, y2 = points[j + 1]
#         hv += (x2 - x1) * (ref_y - y1)
#
#     if points:
#         x_last, y_last = points[-1]
#         hv += (ref_x - x_last) * (ref_y - y_last)
#
#     return hv
#
#
# # =========================================================================
# # PART 5: ROBUST LLM AGENT AND MAIN EXECUTION FUNCTION (V5 - REFINED)
# # =========================================================================
#
# def extract_problem_features_for_llm():
#     """
#     NEW: Extract meaningful statistical features from the problem instance.
#     This is the core of the "Strategist" model.
#     """
#     if capacities == NULL or weights == NULL or profits == NULL:
#         return None
#
#     # Calculate overall capacity tightness
#     total_capacity = sum(capacities[i] for i in range(nf))
#     total_avg_weight = sum(sum(weights[obj][i] for i in range(ni)) for obj in range(nf)) / nf
#     capacity_tightness = total_avg_weight / total_capacity if total_capacity > 0 else 0
#
#     # Calculate profit and weight variance for each objective
#     profit_variances = []
#     weight_variances = []
#     for obj in range(nf):
#         profits_list = [profits[obj][i] for i in range(ni)]
#         weights_list = [weights[obj][i] for i in range(ni)]
#         profit_variances.append(np.var(profits_list))
#         weight_variances.append(np.var(weights_list))
#
#     features = {
#         "num_items": ni,
#         "num_objectives": nf,
#         "capacity_tightness": round(capacity_tightness, 4),
#         "avg_profit_variance": round(np.mean(profit_variances), 2),
#         "avg_weight_variance": round(np.mean(weight_variances), 2),
#     }
#     return features
#
# cdef void write_results_to_file(pop *P, output_file, str log_message=""):
#     """Write the Pareto front results and a log message to a file."""
#     cdef int i, j
#
#     with open(output_file if isinstance(output_file, str) else output_file.decode(), "a") as fpareto:
#         if log_message:
#             fpareto.write(f"# LOG: {log_message}\n")
#         fpareto.write("\n")
#         for i in range(P.size):
#             for j in range(nf):
#                 fpareto.write(f"{P.ind_array[i].f[j]:.6f} ")
#             fpareto.write("\n")
#
# def run_efficient_llm_moacp_v5(instance_file, weights_file, nbitems, num_objectives, output_file):
#     """
#     REFINED: Run MOACP with a focused LLM "Strategist" Agent (V5).
#     This version uses detailed problem features and structured JSON prompts.
#     """
#     # All cdef variables must be declared at the top of the function
#     cdef pop *P
#     cdef pop *solutions
#     cdef pop *archive
#     cdef int it
#     cdef double last_hv = 0.0  # <-- ADD THIS LINE HERE
#
#
#     global nf, ni, NBITEMS, alpha, paretoIni, L, kappa, nombreLIGNE, nextLn, inv, vector_weight
#     global capacities, weights, profits, OBJ_Weights
#
#     # --- REFINED LLM Agent Definition (V5 - The Strategist) ---
#     class LLMStrategistV5:
#         def __init__(self, model_name="llama3:latest"):
#             self.model_name = model_name
#             self.cache = {}
#
#         def _call_llm_with_json(self, prompt, cache_key):
#             """Helper to call LLM and robustly parse JSON."""
#             if cache_key in self.cache:
#                 print(f"  [LLM Cache Hit] Using cached response.")
#                 return self.cache[cache_key]
#
#             print(f"  [LLM Call] Sending prompt to {self.model_name}...")
#             try:
#                 response = ollama.generate(model=self.model_name, prompt=prompt, format='json')
#                 response_text = response.get('response', '').strip()
#
#                 if not response_text:
#                     print("  [LLM Error] Empty response. Using default strategy.")
#                     return None
#
#                 result = json.loads(response_text)
#                 self.cache[cache_key] = result
#                 print(f"  [LLM Success] Received valid JSON.")
#                 return result
#
#             except json.JSONDecodeError as e:
#                 print(f"  [LLM Error] Failed to decode JSON: {e}. Response was: '{response_text[:100]}...'")
#                 return None
#             except Exception as e:
#                 print(f"  [LLM Error] An unexpected error occurred: {e}. Using default strategy.")
#                 return None
#
#         def get_initial_strategy(self, problem_features):
#             """Get one initial strategy based on detailed problem features."""
#             cache_key = f"init_{hash(str(problem_features))}"
#
#             prompt = f"""
# You are an expert strategist for the Multi-Objective Knapsack Problem. Your task is to analyze the features of a problem instance and recommend the best initial search strategy.
#
# The key parameter you control is 'L', which determines the number of items to try swapping during the local search. A higher L means a more aggressive, explorative search. A lower L means a more focused, exploitative search.
#
# Here are the problem features:
# {json.dumps(problem_features, indent=2)}
#
# Based on these features, choose the best strategy.
# - If the problem is 'tight' (high capacity_tightness) or has high variance, a more explorative approach might be better.
# - If the problem is 'loose' or has low variance, a more focused approach might be better.
#
# Respond with a JSON object containing 'strategy_name', 'L_value', and 'reasoning'.
# Example: {{"strategy_name": "AGGRESSIVE", "L_value": 8, "reasoning": "High capacity tightness requires broad exploration."}}
# """
#             result = self._call_llm_with_json(prompt, cache_key)
#
#             if result and 'L_value' in result:
#                 print(f"  [LLM Decision] Strategy: {result.get('strategy_name')}, L: {result['L_value']}")
#                 print(f"  [LLM Reasoning] {result.get('reasoning')}")
#                 return result['L_value']
#             return 5 # Default L value
#
#         def get_adaptive_strategy(self, current_iteration, last_hv, current_hv, current_L):
#             """Get a new L value based on the current state of the search."""
#             hv_change = current_hv - last_hv
#             cache_key = f"adaptive_{current_iteration}_{current_hv:.2f}_{current_L}"
#
#             prompt = f"""
# You are an expert strategist for the Multi-Objective Knapsack Problem. You are monitoring an ongoing search.
#
# The search is currently at iteration {current_iteration}.
# The search parameter 'L' (local search intensity) is currently set to {current_L}.
# The hypervolume of the Pareto front was {last_hv:.2f} at the last check.
# The hypervolume is now {current_hv:.2f}.
# The change in hypervolume since the last check is {hv_change:.2f}.
#
# Your task is to decide whether to keep, increase, or decrease the parameter 'L' for the next phase of the search.
# - If the hypervolume improvement is small or negative, the search might be stagnating. Consider increasing 'L' to explore more.
# - If the hypervolume improvement is very large, the current strategy is working well. You can keep 'L' the same or even decrease it slightly to focus on exploiting the good region.
# - A moderate change might suggest keeping the strategy.
#
# Respond with a JSON object containing 'new_L_value' and 'reasoning'.
# Example: {{"new_L_value": 6, "reasoning": "Hypervolume has stagnated, increasing L will encourage more exploration."}}
# """
#             result = self._call_llm_with_json(prompt, cache_key)
#
#             if result and 'new_L_value' in result:
#                 print(f"  [LLM Adaptive Decision] Iteration {current_iteration}: New L={result['new_L_value']}")
#                 print(f"  [LLM Reasoning] {result.get('reasoning')}")
#                 return result['new_L_value']
#
#             print(f"  [LLM Adaptive Decision] Iteration {current_iteration}: No change, keeping L={current_L}")
#             return current_L # Default to no change
#
#
#     # --- Main Execution Loop ---
#     alpha = 10
#     paretoIni = 28000
#     NBL = 100
#     NRUNS = 10
#
#     total_time = 0
#     start_time = time.time()
#
#     for run in range(1, NRUNS+1):
#         NBITEMS = nbitems
#         ni = nbitems
#         nf = num_objectives
#         print(f"\n--- RUN {run}/{NRUNS} ---")
#         print(f"Instance: {instance_file.decode()}, Items: {ni}, Objectives: {nf}")
#
#         nombreLIGNE = 0
#         nextLn = 0
#         inv = 0
#
#         seed(run)
#         loadMOKP(instance_file)
#         read_weights_file(weights_file)
#
#         # --- LLM Integration ---
#         llm_strategist = LLMStrategistV5()
#         problem_features = extract_problem_features_for_llm()
#
#         print(f"  [Problem Features] {json.dumps(problem_features, indent=4)}")
#
#         # --- LLM Call 1: Initial Strategy ---
#         L = llm_strategist.get_initial_strategy(problem_features)
#         # We will keep kappa fixed for now to isolate the effect of L.
#         kappa = 0.05
#
#         print(f"  [Final Parameters] L={L}, kappa={kappa}")
#
#         vector_weight = <double *>chk_malloc(nf * sizeof(double))
#         P = create_pop(paretoIni, nf)
#
#         current_log = f"Run {run}: Initial LLM strategy set L={L} based on features."
#
#             # --- NEW: Configuration for Adaptive Strategy ---
#         INTERVENTION_INTERVAL = 25  # Check every 25 iterations
#         it = 0
#         while it < NBL:
#             # --- NEW: Periodic LLM Intervention ---
#             if it > 0 and it % INTERVENTION_INTERVAL == 0:
#                 print(f"  [Intervention] Pausing at iteration {it} to consult LLM...")
#
#                 # 1. Calculate current hypervolume
#                 current_hv = calculate_archive_hypervolume(P) # This is OK because it's inside the loop
#
#                 # 2. Ask LLM for a new strategy
#                 L = llm_strategist.get_adaptive_strategy(it, last_hv, current_hv, L)
#
#                 # 3. Update for next interval
#                 last_hv = current_hv
#
#             # --- Existing Cython Code (this part is unchanged) ---
#             solutions = create_pop(alpha, nf)
#             archive = create_pop(paretoIni, nf)
#
#             choose_weight()
#             P_init_pop(solutions, P, alpha)
#             extractPtoArchive(solutions, P)
#             calcul_weight(solutions, alpha)
#             calcMaxbound(solutions, alpha)
#             compute_all_fitness(solutions)
#
#             Indicator_local_search1(solutions, archive, alpha)
#
#             extractPtoArchive(archive, P)
#             it += 1
#             complete_free_pop(solutions)
#             complete_free_pop(archive)
#
#         write_results_to_file(P, output_file, current_log)
#         print(f"  [Run Summary] LLM calls this run: 1")
#         complete_free_pop(P)
#         cleanup_globals()
#
#     total_time = time.time() - start_time
#     print(f"\nTotal execution time: {total_time:.2f} seconds")
#     print(f"Average time per run: {total_time/NRUNS:.2f} seconds")
# Out:
# Content of stdout:
# _cython_magic_e88879c4a5429e470de09474d9b5f2ad6914c40c0da36f831ef3de4d44a560ab.c
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_e88879c4a5429e470de09474d9b5f2ad6914c40c0da36f831ef3de4d44a560ab.c(5497): warning C4244: '='ÿ: conversion de 'double' en 'float', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_e88879c4a5429e470de09474d9b5f2ad6914c40c0da36f831ef3de4d44a560ab.c(5587): warning C4244: '='ÿ: conversion de 'double' en 'float', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_e88879c4a5429e470de09474d9b5f2ad6914c40c0da36f831ef3de4d44a560ab.c(6773): warning C4244: '='ÿ: conversion de 'Py_ssize_t' en 'int', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_e88879c4a5429e470de09474d9b5f2ad6914c40c0da36f831ef3de4d44a560ab.c(16368): warning C4305: '='ÿ: troncation de 'double' … 'float'
#    Cr‚ation de la bibliothŠque C:\Users\Aziz il patal\.ipython\cython\Users\Aziz il patal\.ipython\cython\_cython_magic_e88879c4a5429e470de09474d9b5f2ad6914c40c0da36f831ef3de4d44a560ab.cp39-win_amd64.lib et de l'objet C:\Users\Aziz il patal\.ipython\cython\Users\Aziz il patal\.ipython\cython\_cython_magic_e88879c4a5429e470de09474d9b5f2ad6914c40c0da36f831ef3de4d44a560ab.cp39-win_amd64.exp
# G‚n‚ration de code en cours
# Fin de la g‚n‚ration du code

# %%
# =========================================================================
# PART 6: RUN THE EFFICIENT EXPERIMENTS (V4)
# =========================================================================

print("Running Efficient LLM-MOACP V4 on test instances...")
print("This version is optimized for efficiency with minimal LLM calls.")

# Test with 250 items, 2 objectives
print("\n======================================================")
print("Starting experiment for 250 items...")
run_efficient_llm_moacp_v5(b"250.2.txt", b"Weights_2obj_FQ200.txt", 250, 2, "2502_Results_Strategist_v6.txt")
print("Finished experiment for 250 items.")
print("======================================================")


# Test with 500 items, 2 objectives
print("\n======================================================")
print("Starting experiment for 500 items...")
run_efficient_llm_moacp_v5(b"500.2.txt", b"Weights_2obj_FQ200.txt", 500, 2, "5002_Results_Strategist_v6.txt")
print("Finished experiment for 500 items.")
print("======================================================")


# Test with 750 items, 2 objectives
print("\n======================================================")
print("Starting experiment for 750 items...")
run_efficient_llm_moacp_v5(b"750.2.txt", b"Weights_2obj_FQ200.txt", 750, 2, "7502_Results_Strategist_v6.txt")
print("Finished experiment for 750 items.")
print("======================================================")


print("\n\nAll efficient experiments finished.")
print("The following result files have been created:")
print("- 2502_Results_Strategist_v5.txt")
print("- 5002_Results_Strategist_v5.txt")
print("- 7502_Results_Strategist_v5.txt")
print("\nYou can now run the analysis cells to compare the new results.")
# Out:
# Running Efficient LLM-MOACP V4 on test instances...
# This version is optimized for efficiency with minimal LLM calls.
#
# ======================================================
# Starting experiment for 250 items...
#
# --- RUN 1/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: EXPLOITATIVE, L: 2
#   [LLM Reasoning] Low capacity tightness and low variance suggest a more focused search is needed to efficiently explore the solution space.
#   [Final Parameters] L=2, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=3
#   [LLM Reasoning] The hypervolume improvement is quite large, indicating that the current strategy is working well. To exploit this region further and potentially find even better solutions, I'll decrease 'L' slightly to focus on local optimization.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=4
#   [LLM Reasoning] The hypervolume improvement is moderate, but the overall value has increased significantly. Since the current strategy seems to be working well, I'll slightly decrease 'L' to focus on exploiting this good region and potentially finding even better solutions.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=5
#   [LLM Reasoning] The hypervolume improvement is small and negative, indicating that the search might be stagnating. Increasing 'L' to 5 from its current value of 4 could help encourage more exploration and potentially escape local optima.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 2/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: BALANCED, L: 4
#   [LLM Reasoning] Medium number of items and moderate variance suggest a balanced approach between exploration and exploitation.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=5
#   [LLM Reasoning] The hypervolume change is negative, suggesting the search might be stagnating. Increasing 'L' by one unit could help explore new regions of the Pareto front and improve convergence.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=8
#   [LLM Reasoning] The hypervolume improvement is substantial, indicating the current strategy is working well. Since the improvement is not extreme, I'll slightly increase L to maintain momentum and potentially find even better solutions while still exploring the region effectively.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=10
#   [LLM Reasoning] The hypervolume improvement is moderate (4112.00), suggesting that the current strategy is still exploring new regions. Given that 'L' is currently set to 8, a slight increase to 10 might help maintain this momentum and continue to explore the search space.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 3/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: FOCUSED, L: 3
#   [LLM Reasoning] Low capacity tightness and low variance in profit and weight indicate a relatively loose problem instance. A focused approach with a smaller L value is more suitable to exploit the existing good solutions and avoid wasting time on unproductive explorations.
#   [Final Parameters] L=3, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=4
#   [LLM Reasoning] Hypervolume improvement is negative, indicating stagnation. Increasing L to 4 might help escape local optima and explore new regions of the Pareto front.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=8
#   [LLM Reasoning] The hypervolume improvement is quite large, indicating that the current strategy is working well. However, since it's not extremely large, I'll slightly increase 'L' to balance exploration and exploitation, hoping to maintain the good region while still allowing for some exploration.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=10
#   [LLM Reasoning] The hypervolume improvement is moderate, indicating that the search is still making progress. However, considering the small increase in hypervolume since the last check, I think it's reasonable to increase 'L' slightly to encourage more exploration and potentially discover new areas of the Pareto front.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 4/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MODERATE, L: 4
#   [LLM Reasoning] The problem has an average number of items (250) and a moderate level of variance in both profit and weight. The capacity tightness is relatively high (1.0), but not extremely so. Given these factors, a moderately explorative approach with L=4 seems suitable to strike a balance between exploration and exploitation.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=5
#   [LLM Reasoning] Hypervolume improvement is negative, indicating stagnation. Increasing L by a small amount to explore further and potentially escape local optima.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=7
#   [LLM Reasoning] The hypervolume improvement is significant (1858525.22), but we're still exploring and the search hasn't stalled yet. Considering that 'L' was previously set to 5, I'll increase it slightly to continue exploiting this good region while also encouraging further exploration.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=8
#   [LLM Reasoning] The hypervolume improvement is significant (382531.00), indicating that the current strategy is working well. Since the change is large, I'm choosing to keep 'L' the same or slightly increase it to focus on exploiting this good region further.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 5/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: EXPLORE, L: 12
#   [LLM Reasoning] High variance in both profit and weight suggests a need to explore the solution space more aggressively to avoid local optima.
#   [Final Parameters] L=12, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=15
#   [LLM Reasoning] The hypervolume improvement is negative, indicating that the search might be stagnating. Given the current L value of 12, I recommend increasing it to 15 to encourage more exploration and potentially escape local optima.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=20
#   [LLM Reasoning] The large hypervolume improvement suggests that the current strategy is effective. However, since the previous iteration, there was a moderate change in hypervolume. Considering this and the fact that the search has not stagnated yet, I decide to slightly increase 'L' to maintain momentum and continue exploring new regions.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=25
#   [LLM Reasoning] Although the hypervolume increase is moderate, the overall trend suggests that the search is still making progress. Increasing 'L' to 25 will allow the algorithm to continue exploring new regions and potentially find better solutions.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 6/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: FOCUSED, L: 3
#   [LLM Reasoning] Low capacity tightness and relatively low variance in both profit and weight suggest a more focused search to exploit the existing solution space.
#   [Final Parameters] L=3, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=4
#   [LLM Reasoning] The hypervolume improvement is negative, indicating stagnation. Increasing L slightly to 4 may help the search explore new regions and improve convergence.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=5
#   [LLM Reasoning] The hypervolume change is small and the search seems to be stagnating. A slight increase in L might help to encourage some new discoveries.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=10
#   [LLM Reasoning] Hypervolume has remained constant since the last check. Increasing L to a higher value (5 -> 10) will allow for more intense local search and potentially lead to new Pareto front discoveries, as stagnation is likely.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 7/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MODERATE, L: 5
#   [LLM Reasoning] Average variance and moderate problem size suggest a balanced approach that balances exploration and exploitation.
#   [Final Parameters] L=5, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=7
#   [LLM Reasoning] The hypervolume improvement is quite large, indicating that the current strategy is working well. However, to avoid overfitting and ensure continued progress, I'll slightly increase 'L' to maintain a balance between exploration and exploitation.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=9
#   [LLM Reasoning] The hypervolume improvement is significant, indicating the current strategy is working well. Increasing L slightly will allow us to further exploit this good region and potentially identify even better solutions.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=12
#   [LLM Reasoning] The hypervolume improvement is moderate (157584.57), which suggests that the search is not stagnating nor overfitting. Increasing L to 12 will allow the algorithm to explore new regions and potentially improve the Pareto front further.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 8/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: EXPLORE, L: 5
#   [LLM Reasoning] The problem has high average profit and weight variances, indicating that the objectives are highly correlated. This suggests that a more explorative approach is necessary to find a good trade-off between the two objectives.
#   [Final Parameters] L=5, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=7
#   [LLM Reasoning] The hypervolume improvement is small and negative, indicating potential stagnation. Increasing the local search intensity (L) to 7 might encourage the search to explore new regions and improve the solution quality.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=9
#   [LLM Reasoning] The hypervolume improvement is very large, indicating that the current strategy is working well. Given this, it's reasonable to slightly decrease 'L' to focus on exploiting the good region and refine the search around the optimal solutions.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=12
#   [LLM Reasoning] The hypervolume improvement is small and negative. This suggests that the search might be stagnating, so I recommend increasing 'L' to explore more possibilities and potentially escape local optima.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 9/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: FOCUSED, L: 2
#   [LLM Reasoning] Low variance in both profit and weight suggests a well-structured problem that can be solved efficiently with a more focused approach.
#   [Final Parameters] L=2, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=4
#   [LLM Reasoning] The hypervolume improvement is small (-1222643.25), indicating potential stagnation in the search. Increasing 'L' to 4 may help encourage more exploration and avoid getting stuck in a local optimum.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=8
#   [LLM Reasoning] The hypervolume improvement is moderate, but considering the significant change since the last check, I think it's wise to keep the momentum going. Increasing L by a small amount (to 8) should allow the search to continue exploring new regions without getting too aggressive.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=10
#   [LLM Reasoning] The hypervolume improvement is small (-11755.00) and negative, indicating potential stagnation in the search. Given this, I recommend increasing 'L' to intensify local search and encourage further exploration of the solution space.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 10/10 ---
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: FOCUSED, L: 4
#   [LLM Reasoning] Low average weight and profit variances suggest a more focused search strategy is suitable for this problem instance.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=5
#   [LLM Reasoning] The hypervolume improvement is moderate (-2890888.53), suggesting that the search might be stuck in a local optimum. Increasing 'L' to 5 will provide a gentle nudge to explore new regions and potentially escape this stagnation.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=7
#   [LLM Reasoning] The hypervolume improvement is large, indicating that the current strategy is working well. A moderate increase in L can help to further exploit this good region and potentially find even better solutions.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=9
#   [LLM Reasoning] The hypervolume improvement is moderate (235388.60), which suggests keeping the strategy. However, considering the search might be stagnating slightly, I'm choosing to increase 'L' to explore more and potentially find better solutions.
#   [Run Summary] LLM calls this run: 1
#
# Total execution time: 636.02 seconds
# Average time per run: 63.60 seconds
# Finished experiment for 250 items.
# ======================================================
#
# ======================================================
# Starting experiment for 500 items...
#
# --- RUN 1/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: EXPLORE, L: 5
#   [LLM Reasoning] Average weight variance is high and capacity tightness is high, suggesting a balance between exploration and exploitation is needed.
#   [Final Parameters] L=5, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=7
#   [LLM Reasoning] The hypervolume improvement is large, indicating the current strategy is working well. However, considering the search is still in its early stages (iteration 25), I'll increase 'L' slightly to encourage further exploration and potentially find even better solutions.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=9
#   [LLM Reasoning] Although the hypervolume hasn't changed, it's still relatively high. However, considering the stagnation, I think increasing 'L' will help to explore new regions and potentially improve the search further.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=11
#   [LLM Reasoning] The hypervolume has not changed since the last check, indicating stagnation. Increasing 'L' to 11 will introduce more randomness in the search, potentially leading to new and better solutions.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 2/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: AGGRESSIVE, L: 10
#   [LLM Reasoning] High average profit and weight variances indicate that the problem is challenging, requiring a more explorative approach to effectively navigate the solution space.
#   [Final Parameters] L=10, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=20
#   [LLM Reasoning] The hypervolume has increased significantly, indicating that the current strategy is working well. However, the improvement is still moderate, suggesting that there might be some room for further exploration. Therefore, I recommend increasing L to maintain the momentum and keep exploring the promising region.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=25
#   [LLM Reasoning] The hypervolume improvement is significant, indicating the search is currently effective. To balance exploration and exploitation, we'll increase the local search intensity (L) to 25, hoping to maintain momentum and potentially discover new promising regions.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=35
#   [LLM Reasoning] The hypervolume improvement is small and negative. This suggests that the search might be stagnating. Increasing L to 35 can help explore more and potentially escape local optima.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 3/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MODERATE, L: 3
#   [LLM Reasoning] The problem has a high number of items (500), which suggests that the search space is large and complex. The average profit and weight variances are also quite high. However, the capacity tightness is relatively low, indicating that there may be some flexibility in the item selection. Given these features, a moderate level of exploration (L=3) seems reasonable to strike a balance between exploring new regions of the search space and focusing on improving the current solution.
#   [Final Parameters] L=3, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=4
#   [LLM Reasoning] The hypervolume decrease is quite significant (-6794046.78). This suggests that the search might be stagnating. Increasing L to 4 could help explore new regions and potentially improve the hypervolume gain in the next iteration.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=5
#   [LLM Reasoning] The hypervolume improvement is significant (8940405.32), but the previous value of L was quite high (4). Considering that the hypervolume has increased significantly, it's likely that the current strategy is still effective. Therefore, I'll keep L at its current level and slightly reduce it to 5 to focus on exploiting the good region rather than over-exploring.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=7
#   [LLM Reasoning] The hypervolume improvement is small and negative. This suggests the search might be stagnating. Increasing L to a higher value (7) will allow for more exploration and potentially escape local optima.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 4/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: BALANCED, L: 4
#   [LLM Reasoning] The problem has a moderate number of items (500) and two objectives. The capacity tightness is high, indicating that the problem is relatively tight, but the variance in profit and weight is also moderately high. This suggests a balanced approach, neither too aggressive nor too focused. A medium value for L (4) strikes a good balance between exploration and exploitation.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=5
#   [LLM Reasoning] The hypervolume improvement is negative, which suggests that the search might be stagnating. Increasing L to 5 will provide a moderate boost to exploration and help escape local optima without drastically changing the strategy.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=7
#   [LLM Reasoning] The hypervolume improvement is moderate, suggesting a balance between exploitation and exploration. Given the increase in hypervolume, it's reasonable to keep exploring with a slightly higher intensity.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=8
#   [LLM Reasoning] The hypervolume improvement is small (-11342.00), suggesting that the search might be stagnating. Increasing 'L' to 8 could help explore new regions and potentially improve the hypervolume further.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 5/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: EXPLORE, L: 5
#   [LLM Reasoning] The high variance in both profit and weight suggests that the problem is 'loose' or has high uncertainty. A more explorative approach with a moderate L value (5) allows for a balance between exploration and exploitation, taking into account the high variance in the problem features.
#   [Final Parameters] L=5, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=7
#   [LLM Reasoning] The hypervolume improvement is quite small and negative, indicating that the search might be stagnating. Increasing L to 7 will give the search a boost to explore new regions of the Pareto front.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=9
#   [LLM Reasoning] The large hypervolume improvement suggests that the current strategy is working well. However, considering the search is still relatively early (iteration 50), I want to maintain some level of exploration to avoid stagnation in the future. Therefore, I will increase 'L' slightly to keep the search trajectory dynamic and encourage continued discovery.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=12
#   [LLM Reasoning] The hypervolume improvement is moderate (158406.06), which suggests that the current strategy is working reasonably well. To balance exploitation and exploration, I recommend increasing 'L' to a higher value than the current 9, aiming for a more diverse search.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 6/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: AGGRESSIVE, L: 6
#   [LLM Reasoning] The problem has a high capacity tightness (1.0) and significant variance in both profit and weight, indicating a challenging and complex environment. A more explorative approach with L=6 is recommended to effectively navigate this landscape.
#   [Final Parameters] L=6, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=8
#   [LLM Reasoning] The hypervolume improvement is negative (-8445796.22), which suggests that the search might be stagnating. Given this, I recommend increasing 'L' to 8 to encourage more exploration and potentially discover new Pareto-optimal solutions.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=10
#   [LLM Reasoning] The hypervolume improvement is large, but not extremely so. Since the search is still making progress, I'll keep the strategy going by keeping 'L' at its current value. A slight increase might even help to further improve the search.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=15
#   [LLM Reasoning] Hypervolume improvement is small (-8113.00), suggesting stagnation. Increasing the local search intensity (L) to 15 might help to explore new regions and improve the overall performance.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 7/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: EXPLORE_MID, L: 4
#   [LLM Reasoning] The problem has high variance in both profit and weight, but the capacity tightness is moderate. This suggests a balance between exploration and exploitation. A mid-range value for L (4) allows for some exploration while still maintaining a degree of focus.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=8
#   [LLM Reasoning] The hypervolume improvement is negative, indicating a possible stagnation of the search. Increasing L to 8 can help to explore new regions and potentially escape the local optima, leading to a more diverse Pareto front.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=12
#   [LLM Reasoning] The hypervolume improvement is moderate to large, indicating that the current strategy is working well. To further exploit this region, I suggest keeping 'L' relatively high at 12, as this should allow us to continue finding good solutions without sacrificing too much exploration.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=15
#   [LLM Reasoning] The hypervolume improvement is small (-95627.00), suggesting that the search might be stagnating. Since 'L' (local search intensity) is currently set to 12, I recommend increasing it to 15 to encourage more exploration and potentially jump out of the local minimum.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 8/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MODERATE, L: 5
#   [LLM Reasoning] The problem has a moderate level of complexity and variance. The number of items is relatively high (500), but the capacity tightness is not extremely high. This suggests that a balanced approach is suitable. A moderate value for L (5) allows for some exploration while still being focused enough to make progress in the search space.
#   [Final Parameters] L=5, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=7
#   [LLM Reasoning] The hypervolume improvement is small (-7703053.05), indicating potential stagnation in the search. Increasing 'L' to 7 might help revitalize the search by exploring new regions of the Pareto front.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=8
#   [LLM Reasoning] The large hypervolume improvement suggests that the current strategy is working well. However, considering the search is at iteration 50 and the improvement is still significant, I believe it's a good idea to keep the momentum going by increasing L slightly. This will allow the search to continue exploring the promising region without getting stuck in local optima.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=10
#   [LLM Reasoning] The hypervolume change is negative, indicating stagnation. Increasing 'L' to 10 will allow the search to explore more and potentially find better solutions, as the current strategy is not leading to significant improvements.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 9/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MODERATE, L: 4
#   [LLM Reasoning] The problem has a moderate number of items (500) and average profit/weight variances that are not extremely high. The capacity tightness is also not very tight. A more moderate approach with L=4 provides a good balance between exploration and exploitation, allowing the algorithm to make progress while still being able to focus on promising areas.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=5
#   [LLM Reasoning] The hypervolume improvement is relatively small, suggesting the search might be stagnating. Increasing L by a small amount (1) could help explore new regions and potentially improve the hypervolume further.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=7
#   [LLM Reasoning] The hypervolume improvement is significant, indicating that the current strategy is working well. Increasing 'L' slightly will allow the search to further exploit this good region while still encouraging some exploration.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=9
#   [LLM Reasoning] The hypervolume change is negative, indicating potential stagnation. Increasing L to 9 will provide more intensity for the local search, which may help escape local optima and explore new regions of the Pareto front.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 10/10 ---
# Instance: 500.2.txt, Items: 500, Objectives: 2
#   [Problem Features] {
#     "num_items": 500,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 681.29,
#     "avg_weight_variance": 672.18
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MIXED, L: 4
#   [LLM Reasoning] The problem has a moderate number of items (500) and two objectives. The capacity tightness is high (1.0), indicating a relatively tight knapsack, but the average profit and weight variances are also quite high (681.29 and 672.18 respectively). This suggests that while some exploration is needed to escape local optima, too much randomness could lead to poor performance. A moderate value of L=4 provides a good balance between exploration and exploitation.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=5
#   [LLM Reasoning] The hypervolume improvement is moderate, suggesting the search might be stuck in a local optimum. Increasing L slightly to 5 should help explore new regions without drastically changing the strategy, as the current intensity of 4 has already yielded some promising results.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=7
#   [LLM Reasoning] The hypervolume improvement is significant (8941637.70), indicating the current strategy is working well. However, considering the large change, I recommend keeping 'L' slightly lower than its current value to continue exploiting the good region while still allowing some exploration.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=8
#   [LLM Reasoning] The hypervolume improvement is moderate (250.00), which suggests that the current strategy is not too far off from optimal. Since the change is positive but not extremely large, I think it's a good idea to keep the momentum going by increasing 'L' slightly, which will encourage more exploration and potentially lead to further improvements.
#   [Run Summary] LLM calls this run: 1
#
# Total execution time: 754.66 seconds
# Average time per run: 75.47 seconds
# Finished experiment for 500 items.
# ======================================================
#
# ======================================================
# Starting experiment for 750 items...
#
# --- RUN 1/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: BALANCED, L: 4
#   [LLM Reasoning] The moderate capacity tightness and variance suggest a balanced approach. The problem is not extremely tight or loose, and the variance is neither very high nor very low.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=5
#   [LLM Reasoning] The hypervolume improvement is significant, indicating that the current strategy is working well. To maintain this momentum and avoid over-exploitation, I recommend decreasing 'L' slightly to focus on refining the existing good region.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=7
#   [LLM Reasoning] The hypervolume improvement is substantial (21181639.81) and the strategy seems to be working well. I'll slightly increase 'L' to keep exploring the promising region without overwhelming the search space.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=8
#   [LLM Reasoning] The hypervolume improvement is moderate. Since the change in hypervolume since the last check is not very large, but still positive, I think it's a good idea to increase 'L' slightly to keep exploring and avoid stagnation.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 2/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MODERATE, L: 4
#   [LLM Reasoning] Average variance and capacity tightness suggest a balanced approach. A moderate L value allows for some exploration while still focusing on promising areas.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=5
#   [LLM Reasoning] The hypervolume improvement is moderate (-23.3M), suggesting the current strategy is not working as well as it could be. Given that the change is neither small nor very large, I recommend keeping 'L' at its current value but decreasing it slightly to focus on exploiting the good region and refining the search.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=7
#   [LLM Reasoning] The hypervolume improvement is substantial (23124200.80), indicating that the current strategy is working well. To further exploit this good region, I'll increase 'L' slightly to 7, keeping the momentum going while still allowing for some exploration.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=8
#   [LLM Reasoning] The hypervolume improvement is relatively small (-17964.00), suggesting that the search might be stagnating. Since 'L' is currently set to 7, I recommend increasing it to 8 to encourage more exploration and potentially escape local optima.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 3/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: FOCUSED, L: 2
#   [LLM Reasoning] Low variance in both profit and weight suggests a problem with a relatively small number of optimal solutions. A more focused approach will help to narrow down the search space and find the best solution.
#   [Final Parameters] L=2, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=3
#   [LLM Reasoning] The hypervolume improvement is moderate but decreasing. This suggests that the search might be stuck in a local optimum. Increasing L slightly to 3 could help to escape this local optimum and explore new regions of the Pareto front.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=4
#   [LLM Reasoning] The hypervolume improvement is moderate, not extremely large. This suggests that the current strategy is still yielding good results but could benefit from a slight increase in intensity to keep exploring and potentially find better solutions.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=5
#   [LLM Reasoning] The hypervolume improvement is moderate, suggesting that the current strategy is working well. To maintain momentum and avoid stagnation, I'll increase 'L' slightly to keep exploring new regions of the Pareto front.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 4/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: BALANCED, L: 4
#   [LLM Reasoning] Average capacity tightness and variance suggest a balanced approach with moderate exploration.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=8
#   [LLM Reasoning] The hypervolume improvement is relatively small (-27740614.04), indicating possible stagnation of the search. Increasing L to a value of 8 might help in exploring new regions and reviving the search process.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=10
#   [LLM Reasoning] The hypervolume improvement is substantial (23176358.05), suggesting the current strategy is effective. However, I'll slightly increase 'L' to keep exploring and potentially further improve the results.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=12
#   [LLM Reasoning] The hypervolume improvement is moderate (282741.70), but the hypervolume itself has increased significantly (54626057.85). This suggests that the current strategy is still effective, and a slight increase in 'L' will allow for more exploration without risking stagnation.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 5/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: FOCUSED, L: 3
#   [LLM Reasoning] Low capacity tightness and low variance indicate a relatively easy problem. A focused approach with smaller L-value is likely to be more effective in exploiting the solution space.
#   [Final Parameters] L=3, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=4
#   [LLM Reasoning] The hypervolume has decreased significantly, indicating stagnation. Increasing L to 4 might help the search explore new regions and escape local optima.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=6
#   [LLM Reasoning] The hypervolume improvement is very large, suggesting the current strategy is working well. To focus on exploiting this good region, I'll keep the 'L' value the same for now.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=8
#   [LLM Reasoning] The hypervolume improvement is small and negative, suggesting the search might be stagnating. Increasing L to 8 will allow for more exploration and potentially escape local optima.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 6/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MODERATE, L: 4
#   [LLM Reasoning] The problem has a moderate number of items (750) and average profit/weight variances. The capacity tightness is high, but not extremely so. Considering these features, a moderately aggressive strategy with L = 4 seems suitable for this problem instance.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=5
#   [LLM Reasoning] The hypervolume change is significant (-46984642.38), indicating that the search might be stuck in a local optimum. Despite this being a negative change, I'm choosing to increase 'L' slightly from 4 to 5, as increasing exploration intensity can help escape stagnation.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=7
#   [LLM Reasoning] The hypervolume change is small (0.00), indicating possible stagnation. To encourage more exploration and potentially escape local optima, I recommend increasing the local search intensity by one unit to L = 6.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=8
#   [LLM Reasoning] Although the hypervolume is stagnant, the change in hypervolume since the last check is still zero. This suggests that the search might be stuck in a local optimum. Increasing 'L' to 8 will allow for more exploration and potentially help the search escape this stagnation.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 7/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: MODERATE, L: 4
#   [LLM Reasoning] The problem has a moderate number of items (750) and relatively high variance in both profit and weight, indicating a mix of exploration and exploitation is needed. A moderately aggressive search with L = 4 seems suitable for this instance.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=8
#   [LLM Reasoning] The hypervolume improvement is substantial, indicating that the current strategy is working well. Since the change in hypervolume is quite large, it's reasonable to keep 'L' at its current value or even decrease it slightly to focus on exploiting the good region and avoid over-exploration.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=10
#   [LLM Reasoning] The hypervolume improvement is significant (25067288.73), suggesting that the current strategy is working well. However, to further exploit this good region and potentially find even better solutions, I'll slightly increase L to maintain momentum and avoid stagnation.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=12
#   [LLM Reasoning] The hypervolume improvement is small and negative, suggesting that the search might be stagnating. Increasing 'L' to 12 will allow for more exploration and potentially discover new regions of the Pareto front.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 8/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: BALANCED, L: 4
#   [LLM Reasoning] The problem has a moderate number of items (750) and two objectives. The average profit variance is high (703.64), but the average weight variance is also relatively high (687.3). Given these factors, a balanced approach with moderate exploration is recommended to strike a balance between exploration and exploitation.
#   [Final Parameters] L=4, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=5
#   [LLM Reasoning] The hypervolume improvement is relatively small (-23.4 million), suggesting that the search might be stagnating. Increasing L to 5 would allow for more exploration and potentially escape local optima.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=7
#   [LLM Reasoning] The hypervolume improvement is significant (24729917.33), indicating that the current strategy is working well. However, I'm not seeing any signs of stagnation, so I'll increase 'L' slightly to 7 to maintain momentum and keep exploring the promising region.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=8
#   [LLM Reasoning] The hypervolume improvement is small and negative. This suggests that the search might be stagnating. Increasing 'L' to 8 will provide a boost in local search intensity, allowing the algorithm to explore new regions of the Pareto front.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 9/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: EXPLORE, L: 12
#   [LLM Reasoning] The high capacity tightness and variance in both profit and weight suggest that the problem is challenging. A more explorative approach with a higher L value will help to find better solutions by trying more combinations of items.
#   [Final Parameters] L=12, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=15
#   [LLM Reasoning] The hypervolume improvement is negative, indicating that the search might be stagnating. Increasing L to a higher value (12 -> 15) will provide a stronger push for exploration and potentially lead to new discoveries.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=20
#   [LLM Reasoning] The hypervolume improvement is significant (18523941.38), but the current value of 'L' (15) might not be taking full advantage of the good region. A slight increase in 'L' could help further exploit this region and potentially lead to even more improvements.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=25
#   [LLM Reasoning] Hypervolume improvement is small and negative. This suggests the search might be stagnating, so I recommend increasing the local search intensity 'L' to 25 to encourage more exploration and potentially escape the current local optimum.
#   [Run Summary] LLM calls this run: 1
#
# --- RUN 10/10 ---
# Instance: 750.2.txt, Items: 750, Objectives: 2
#   [Problem Features] {
#     "num_items": 750,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 703.64,
#     "avg_weight_variance": 687.3
# }
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Decision] Strategy: AGGRESSIVE, L: 6
#   [LLM Reasoning] High capacity tightness and high variance in both profit and weight suggest a need for broader exploration to avoid local optima. A moderate L value of 6 provides a good balance between exploration and exploitation.
#   [Final Parameters] L=6, kappa=0.05
#   [Intervention] Pausing at iteration 25 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 25: New L=8
#   [LLM Reasoning] The hypervolume improvement is small and negative, indicating that the search might be stagnating. Increasing 'L' to 8 will encourage more exploration and potentially escape local optima.
#   [Intervention] Pausing at iteration 50 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 50: New L=12
#   [LLM Reasoning] The hypervolume improvement is very large, which suggests that the current strategy is working well. However, considering the moderate size of the previous hypervolume (30058094.60), it's likely that there is still some exploration needed to fully exploit this region. Therefore, I recommend increasing L slightly to 12 to maintain momentum.
#   [Intervention] Pausing at iteration 75 to consult LLM...
#   [LLM Call] Sending prompt to llama3:latest...
#   [LLM Success] Received valid JSON.
#   [LLM Adaptive Decision] Iteration 75: New L=15
#   [LLM Reasoning] The hypervolume improvement is moderate, suggesting that the current strategy is working reasonably well. However, a small decrease in the improvement since the last check might indicate some stagnation. Increasing 'L' to 15 will allow for more exploration and potentially uncover new regions of the Pareto front.
#   [Run Summary] LLM calls this run: 1
#
# Total execution time: 708.58 seconds
# Average time per run: 70.86 seconds
# Finished experiment for 750 items.
# ======================================================
#
#
# All efficient experiments finished.
# The following result files have been created:
# - 2502_Results_Strategist_v5.txt
# - 5002_Results_Strategist_v5.txt
# - 7502_Results_Strategist_v5.txt
#
# You can now run the analysis cells to compare the new results.

# %%
# =========================================================================
# PART 7: RESULTS COMPARISON AND ANALYSIS (Fixed for V6)
# =========================================================================

import matplotlib.pyplot as plt
import numpy as np

def dominates(a, b):
    """Returns True if a dominates b (maximization for both objectives)."""
    return all(x >= y for x, y in zip(a, b)) and any(x > y for x, y in zip(a, b))

def get_true_pareto_front(points):
    """Extract the true Pareto front from a set of points."""
    pareto = []
    for i, p in enumerate(points):
        dominated = False
        for j, q in enumerate(points):
            if i != j and dominates(q, p):
                dominated = True
                break
        if not dominated:
            pareto.append(p)
    return pareto

def calculate_hypervolume(points):
    """Calculate a simplified hypervolume metric for comparison."""
    if not points:
        return 0.0
    
    # Find a reference point that is slightly worse than the worst point in all objectives
    ref_x = max(p[0] for p in points) * 1.1
    ref_y = max(p[1] for p in points) * 1.1
    
    # Sort points by the first objective to calculate the area under the curve
    sorted_points = sorted(points, key=lambda p: p[0])
    
    hv = 0.0
    for i in range(len(sorted_points) - 1):
        x1, y1 = sorted_points[i]
        x2, y2 = sorted_points[i + 1]
        # Area of the rectangle between two points on the front
        hv += (x2 - x1) * (ref_y - y1)
    
    # Add the area of the last rectangle to the reference point
    if sorted_points:
        x_last, y_last = sorted_points[-1]
        hv += (ref_x - x_last) * (ref_y - y_last)
    
    return hv

def compare_baseline_vs_strategist(original_file, strategist_v6_file, title):
    """
    Compare the original baseline results with the new LLM-Strategist V6 results.
    """
    print(f"\n--- Analyzing {title} ---")
    
    # --- Load and Process Original Results ---
    original_points = []
    try:
        with open(original_file, "r") as f:
            for line in f:
                line = line.strip()
                if line and not line.startswith("#"):
                    try:
                        original_points.append([float(x) for x in line.split()])
                    except ValueError:
                        pass # Skip malformed lines
    except FileNotFoundError:
        print(f"  [ERROR] Original file not found: {original_file}")
        return None

    # --- Load and Process Strategist V6 Results ---
    strategist_v6_points = []
    try:
        with open(strategist_v6_file, "r") as f:
            for line in f:
                line = line.strip()
                if line and not line.startswith("#"):
                    try:
                        strategist_v6_points.append([float(x) for x in line.split()])
                    except ValueError:
                        pass # Skip malformed lines
    except FileNotFoundError:
        print(f"  [ERROR] Strategist V6 file not found: {strategist_v6_file}")
        return None

    # --- Calculate Pareto Fronts and Metrics ---
    original_pareto = get_true_pareto_front(original_points)
    strategist_v6_pareto = get_true_pareto_front(strategist_v6_points)
    
    original_size = len(original_pareto)
    strategist_v6_size = len(strategist_v6_pareto)
    
    original_hv = calculate_hypervolume(original_pareto)
    strategist_v6_hv = calculate_hypervolume(strategist_v6_pareto)
    
    # --- Calculate Percentage Improvements ---
    size_improvement = (strategist_v6_size - original_size) / original_size * 100 if original_size > 0 else 0
    hv_improvement = (strategist_v6_hv - original_hv) / original_hv * 100 if original_hv > 0 else 0
    
    # --- Print Results ---
    print(f"  Original Algorithm:")
    print(f"    Pareto Front Size: {original_size}")
    print(f"    Hypervolume: {original_hv:.2f}")
    print(f"  LLM-Strategist V6 (Adaptive):")
    print(f"    Pareto Front Size: {strategist_v6_size} ({size_improvement:+.2f}%)")
    print(f"    Hypervolume: {strategist_v6_hv:.2f} ({hv_improvement:+.2f}%)")
    
    # --- Plotting ---
    plt.figure(figsize=(10, 8))
    
    if original_pareto:
        ox, oy = zip(*original_pareto)
        plt.scatter(ox, oy, color='blue', alpha=0.6, s=50, label="Original Baseline")
    if strategist_v6_pareto:
        sx, sy = zip(*strategist_v6_pareto)
        plt.scatter(sx, sy, color='red', marker='x', s=50, alpha=0.8, label="LLM-Strategist V6 (Adaptive)")

    plt.xlabel("Objective 1 (Profit 1)", fontsize=12)
    plt.ylabel("Objective 2 (Profit 2)", fontsize=12)
    plt.title(f"{title} - Pareto Front Comparison", fontsize=16)
    plt.legend(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()
    
    return {
        "title": title,
        "original_size": original_size,
        "strategist_v6_size": strategist_v6_size,
        "size_improvement": size_improvement,
        "original_hv": original_hv,
        "strategist_v6_hv": strategist_v6_hv,
        "hv_improvement": hv_improvement
    }

# --- MAIN EXECUTION ---
print("Starting results analysis: Original Baseline vs. LLM-Strategist V6 (Adaptive)...")

# Define the file names for comparison
files_to_compare = [
    {
        "original": "2502_ResultsMD.txt",
        "strategist": "2502_Results_Strategist_v6.txt",
        "title": "250-Item Problem"
    },
    {
        "original": "5002_ResultsMD.txt",
        "strategist": "5002_Results_Strategist_v6.txt",
        "title": "500-Item Problem"
    },
    {
        "original": "7502_ResultsMD.txt",
        "strategist": "7502_Results_Strategist_v6.txt",
        "title": "750-Item Problem"
    }
]

all_results = []
for files in files_to_compare:
    result = compare_baseline_vs_strategist(
        files["original"], 
        files["strategist"], 
        files["title"]
    )
    if result:
        all_results.append(result)

# --- Summary of Improvements ---
print("\n" + "="*50)
print("              SUMMARY OF IMPROVEMENTS (V6)")
print("="*50)

if all_results:
    total_hv_improvement = 0
    for res in all_results:
        print(f"\n{res['title']}:")
        print(f"  Hypervolume Improvement: {res['hv_improvement']:+.2f}%")
        total_hv_improvement += res['hv_improvement']

    avg_hv_improvement = total_hv_improvement / len(all_results)
    
    print("\n" + "-"*50)
    print(f"  AVERAGE HV IMPROVEMENT: {avg_hv_improvement:+.2f}%")
    print("-"*50)
else:
    print("\nCould not generate a summary as no results were successfully analyzed.")

print("\nAnalysis complete.")
# Out:
# Starting results analysis: Original Baseline vs. LLM-Strategist V6 (Adaptive)...
#
# --- Analyzing 250-Item Problem ---
#   Original Algorithm:
#     Pareto Front Size: 212
#     Hypervolume: 6614986.88
#   LLM-Strategist V6 (Adaptive):
#     Pareto Front Size: 207 (-2.36%)
#     Hypervolume: 6714067.12 (+1.50%)
# --- Analyzing 500-Item Problem ---
#   Original Algorithm:
#     Pareto Front Size: 369
#     Hypervolume: 23044962.94
#   LLM-Strategist V6 (Adaptive):
#     Pareto Front Size: 364 (-1.36%)
#     Hypervolume: 23245692.48 (+0.87%)
# --- Analyzing 750-Item Problem ---
#   Original Algorithm:
#     Pareto Front Size: 552
#     Hypervolume: 56877706.67
#   LLM-Strategist V6 (Adaptive):
#     Pareto Front Size: 526 (-4.71%)
#     Hypervolume: 57153720.25 (+0.49%)
# ==================================================
#               SUMMARY OF IMPROVEMENTS (V6)
# ==================================================
#
# 250-Item Problem:
#   Hypervolume Improvement: +1.50%
#
# 500-Item Problem:
#   Hypervolume Improvement: +0.87%
#
# 750-Item Problem:
#   Hypervolume Improvement: +0.49%
#
# --------------------------------------------------
#   AVERAGE HV IMPROVEMENT: +0.95%
# --------------------------------------------------
#
# Analysis complete.

# %%
# Simple test to see if the module exists and can be imported
try:
    import optimized_moacp_cython
    print("✅ Module imported successfully.")
    print("Functions available:", dir(optimized_moacp_cython))
except ImportError as e:
    print(f"❌ ImportError: {e}")
except Exception as e:
    print(f"❌ Other error: {e}")
# Out:
# ✅ Module imported successfully.
# Functions available: ['__builtins__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '__test__', 'get_L', 'get_alpha', 'get_kappa', 'np', 'run_optimized_cython_moacp', 'seed', 'set_L', 'set_alpha', 'set_kappa', 'set_smallValue', 'time']

# %%
import optimized_moacp_cython as omc
print(dir(omc))
# Out:
# ['__builtins__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '__test__', 'get_L', 'get_alpha', 'get_kappa', 'np', 'run_optimized_cython_moacp', 'seed', 'set_L', 'set_alpha', 'set_kappa', 'set_smallValue', 'time']

# %%
import optimized_moacp_cython as omc

for fn in [
    "set_alpha", "set_kappa", "set_L", "set_smallValue",
    "set_mutation_rate", "set_local_search_intensity",
    "set_greedy_bias", "set_repair_aggressiveness"
]:
    print(fn, hasattr(omc, fn))
# Out:
# set_alpha True
# set_kappa True
# set_L True
# set_smallValue True
# set_mutation_rate False
# set_local_search_intensity False
# set_greedy_bias False
# set_repair_aggressiveness False

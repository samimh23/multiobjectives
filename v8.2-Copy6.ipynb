# %%
# %load_ext cython

# %%
# %%cython
#
# # =========================================================================
# # PART 1: C LIBRARY IMPORTS AND GLOBAL DEFINITIONS
# # =========================================================================
#
# from libc.stdlib cimport malloc, free, srand, rand
# from libc.string cimport memset
# from libc.math cimport exp
#
# # Import Python libraries needed for the LLM part
# import time
# import json
# import ollama
# import numpy as np
# import hashlib
# from collections import defaultdict
#
# # Constants for the enhanced algorithm
# cdef int NBITEMS = 250
# cdef int ni = 250
# cdef int L = 5
# cdef double LARGE = 10e50
# cdef float smallValue = 0.0000001
# cdef double kappa = 0.05
# cdef int alpha = 10
# cdef int paretoIni = 28000
#
# # Data structures (MODIFIED to track more info)
# cdef struct ind:
#     int nombr_nonpris
#     int nombr
#     int rank
#     float fitnessbest
#     float fitness
#     int explored
#     double *f
#     double *capa
#     double *v
#     int *d
#     int *Items
#     # V13: Added fields for tracking agent intervention
#     int age
#     int improvement_count
#     int llm_enhanced
#     int last_improvement_iteration
#
# cdef struct pop:
#     int size
#     int maxsize
#     ind **ind_array
#
# # Global variables for the problem instance (RENAMED to avoid name collision)
# cdef int nf = 2
# cdef double *capacities = NULL
# cdef int **g_weights = NULL  # RENAMED from 'weights'
# cdef int **g_profits = NULL  # RENAMED from 'profits'
# cdef double *vector_weight = NULL
# cdef double max_bound = 0.0
# cdef double **OBJ_Weights = NULL
# cdef int nombreLIGNE = 0
# cdef int nextLn = 0
# cdef int inv = 0
# cdef int OBJ_Weights_lines = 0
#
# # =========================================================================
# # PART 2: CORE CYTHON HELPER FUNCTIONS (Unchanged, but with renamed vars)
# # =========================================================================
#
# def seed(int x):
#     srand(x)
#
# cdef int irand(int range_val):
#     return rand() % range_val
#
# cdef void *chk_malloc(size_t size):
#     cdef void *return_value = malloc(size)
#     if return_value == NULL:
#         raise MemoryError("Out of memory.")
#     memset(return_value, 0, size)
#     return return_value
#
# cdef pop *create_pop(int maxsize, int nf):
#     cdef int i
#     cdef pop *pp = <pop *>chk_malloc(sizeof(pop))
#     pp.size = 0
#     pp.maxsize = maxsize
#     pp.ind_array = <ind **>chk_malloc(maxsize * sizeof(void*))
#     for i in range(maxsize):
#         pp.ind_array[i] = NULL
#     return pp
#
# cdef ind *create_ind(int nf):
#     cdef int i
#     cdef ind *p_ind = <ind *>chk_malloc(sizeof(ind))
#     p_ind.nombr_nonpris = 0
#     p_ind.nombr = 0
#     p_ind.rank = 0
#     p_ind.fitnessbest = -1.0
#     p_ind.fitness = -1.0
#     p_ind.explored = 0
#     # V13: Initialize new tracking fields
#     p_ind.age = 0
#     p_ind.improvement_count = 0
#     p_ind.llm_enhanced = 0
#     p_ind.last_improvement_iteration = 0
#     p_ind.f = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.capa = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.v = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.d = <int *>chk_malloc(ni * sizeof(int))
#     p_ind.Items = <int *>chk_malloc(ni * sizeof(int))
#     for i in range(ni):
#         p_ind.Items[i] = 0
#         p_ind.d[i] = 0
#     for i in range(nf):
#         p_ind.f[i] = 0.0
#         p_ind.capa[i] = 0.0
#         p_ind.v[i] = 0.0
#     return p_ind
#
# cdef ind *ind_copy(ind *i):
#     cdef ind *p_ind = create_ind(nf)
#     cdef int k
#     p_ind.nombr_nonpris = i.nombr_nonpris
#     p_ind.nombr = i.nombr
#     p_ind.rank = i.rank
#     p_ind.fitnessbest = i.fitnessbest
#     p_ind.fitness = i.fitness
#     p_ind.explored = i.explored
#     # V13: Copy new tracking fields
#     p_ind.age = i.age
#     p_ind.improvement_count = i.improvement_count
#     p_ind.llm_enhanced = i.llm_enhanced
#     p_ind.last_improvement_iteration = i.last_improvement_iteration
#     for k in range(nf):
#         p_ind.f[k] = i.f[k]
#         p_ind.v[k] = i.v[k]
#         p_ind.capa[k] = i.capa[k]
#     for k in range(ni):
#         p_ind.d[k] = i.d[k]
#         p_ind.Items[k] = i.Items[k]
#     return p_ind
#
# cdef void free_ind(ind *p_ind):
#     if p_ind != NULL:
#         free(p_ind.d)
#         free(p_ind.f)
#         free(p_ind.capa)
#         free(p_ind.v)
#         free(p_ind.Items)
#         free(p_ind)
#
# cdef void complete_free_pop(pop *pp):
#     cdef int i
#     if pp != NULL:
#         if pp.ind_array != NULL:
#             for i in range(pp.size):
#                 if pp.ind_array[i] != NULL:
#                     free_ind(pp.ind_array[i])
#                     pp.ind_array[i] = NULL
#             free(pp.ind_array)
#         free(pp)
#
# cdef void cleanup_globals():
#     global capacities, g_weights, g_profits, vector_weight, OBJ_Weights, OBJ_Weights_lines, nf, ni
#     if capacities != NULL:
#         free(capacities)
#         capacities = NULL
#     if g_weights != NULL:
#         for i in range(nf):
#             if g_weights[i] != NULL:
#                 free(g_weights[i])
#         free(g_weights)
#         g_weights = NULL
#     if g_profits != NULL:
#         for i in range(nf):
#             if g_profits[i] != NULL:
#                 free(g_profits[i])
#         free(g_profits)
#         g_profits = NULL
#     if vector_weight != NULL:
#         free(vector_weight)
#         vector_weight = NULL
#     if OBJ_Weights != NULL:
#         for i in range(nf):
#             if OBJ_Weights[i] != NULL:
#                 free(OBJ_Weights[i])
#         free(OBJ_Weights)
#         OBJ_Weights = NULL
#     OBJ_Weights_lines = 0
#     nf = 0
#     ni = 0
#
# cdef int non_dominated(ind *p_ind_a, ind *p_ind_b):
#     cdef int i
#     cdef int a_is_good = -1
#     cdef int equal = 1
#     for i in range(nf):
#         if p_ind_a.f[i] > p_ind_b.f[i]:
#             a_is_good = 1
#         if p_ind_a.f[i] != p_ind_b.f[i]:
#             equal = 0
#     if equal:
#         return 0
#     return a_is_good
#
# cdef double calcAddEpsIndicator(ind *p_ind_a, ind *p_ind_b):
#     global max_bound
#     cdef int i
#     cdef double eps
#     cdef double temp_eps
#     if max_bound == 0.0:
#         max_bound = 1e-8
#     eps = (p_ind_a.v[0]/max_bound)-(p_ind_b.v[0]/max_bound)
#     for i in range(1, nf):
#         temp_eps = (p_ind_a.v[i]/max_bound)-(p_ind_b.v[i]/max_bound)
#         if temp_eps > eps:
#             eps = temp_eps
#     return eps
#
# cdef void init_fitness(ind *x):
#     x.fitness = 0.0
#
# cdef void update_fitness(ind *x, double I):
#     x.fitness -= exp(-I / kappa)
#
# cdef double update_fitness_return(double f, double I):
#     return f - exp(-I / kappa)
#
# cdef int delete_fitness(ind *x, double I):
#     x.fitness += exp(-I / kappa)
#     return 0
#
# cdef void compute_ind_fitness(ind *x, pop *SP):
#     cdef int j
#     init_fitness(x)
#     for j in range(SP.size):
#         if SP.ind_array[j] != x:
#             update_fitness(x, calcAddEpsIndicator(SP.ind_array[j], x))
#
# cdef void compute_all_fitness(pop *SP):
#     cdef int i
#     for i in range(SP.size):
#         compute_ind_fitness(SP.ind_array[i], SP)
#
# # =========================================================================
# # PART 3: PROBLEM LOADING AND EVALUATION FUNCTIONS (Unchanged, but with renamed vars)
# # =========================================================================
#
# def loadMOKP(char *filename):
#     global nf, ni, capacities, g_weights, g_profits
#     cdef int i, f
#     with open(filename.decode(), "r") as source:
#         _nf, _ni = [int(x) for x in source.readline().split()]
#         nf = _nf
#         ni = _ni
#         capacities = <double *>chk_malloc(nf * sizeof(double))
#         g_weights = <int **>chk_malloc(nf * sizeof(void*))
#         g_profits = <int **>chk_malloc(nf * sizeof(void*))
#         for f in range(nf):
#             capacities[f] = float(source.readline().strip())
#             g_weights[f] = <int *>chk_malloc(ni * sizeof(int))
#             g_profits[f] = <int *>chk_malloc(ni * sizeof(int))
#             for i in range(ni):
#                 source.readline()
#                 g_weights[f][i] = int(source.readline().strip())
#                 g_profits[f][i] = int(source.readline().strip())
#
# def read_weights_file(char *filename):
#     global OBJ_Weights, nombreLIGNE, nf, OBJ_Weights_lines
#     cdef int i, j, nlines
#     with open(filename.decode(), "r") as f:
#         lines = [line for line in f if line.strip()]
#     nlines = len(lines)
#     OBJ_Weights = <double **>chk_malloc(nf * sizeof(void*))
#     for i in range(nf):
#         OBJ_Weights[i] = <double *>chk_malloc(nlines * sizeof(double))
#     for i, line in enumerate(lines):
#         vals = line.strip().split()
#         for j in range(nf):
#             OBJ_Weights[j][i] = float(vals[j])
#     nombreLIGNE = nlines - 1
#     OBJ_Weights_lines = nlines
#
# cdef void dynamic_weight_allpop():
#     global vector_weight, OBJ_Weights, nombreLIGNE, nf, nextLn
#     cdef int i
#     if vector_weight == NULL:
#         vector_weight = <double *>chk_malloc(nf * sizeof(double))
#     for i in range(nf):
#         vector_weight[i] = OBJ_Weights[i][nextLn]
#     if nextLn == nombreLIGNE:
#         nextLn = 0
#     else:
#         nextLn += 1
#
# cdef void choose_weight():
#     dynamic_weight_allpop()
#
# cdef void random_init_ind(ind *x):
#     cdef int j, r, tmp
#     for j in range(ni):
#         x.d[j] = j
#     for j in range(ni):
#         r = irand(ni)
#         tmp = x.d[r]
#         x.d[r] = x.d[j]
#         x.d[j] = tmp
#
# cdef void evaluate(ind *x):
#     cdef int j, l, k, faisable
#     x.nombr = 0
#     x.nombr_nonpris = 0
#     for j in range(nf):
#         x.capa[j] = 0.0
#         x.f[j] = 0.0
#     for j in range(ni):
#         l = 0
#         faisable = 1
#         while l < nf and faisable == 1:
#             if x.capa[l] + g_weights[l][x.d[j]] > capacities[l]:
#                 faisable = 0
#             l += 1
#         if faisable == 1:
#             for k in range(nf):
#                 x.capa[k] += g_weights[k][x.d[j]]
#                 x.f[k] += g_profits[k][x.d[j]]
#             x.Items[x.d[j]] = 1
#             x.nombr += 1
#         else:
#             x.Items[x.d[j]] = 0
#             x.nombr_nonpris += 1
#
# cdef void P_init_pop(pop *SP, pop *Sarchive, int alpha):
#     cdef int i, x, tmp, t
#     t = max(alpha, Sarchive.size)
#     cdef int* shuffle = <int *>chk_malloc(t * sizeof(int))
#     for i in range(t):
#         shuffle[i] = i
#     for i in range(t):
#         x = irand(alpha)
#         tmp = shuffle[i]
#         shuffle[i] = shuffle[x]
#         shuffle[x] = tmp
#     SP.size = alpha
#     if Sarchive.size > alpha:
#         for i in range(alpha):
#             SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#     else:
#         for i in range(alpha):
#             if shuffle[i] < Sarchive.size:
#                 SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#             else:
#                 SP.ind_array[i] = create_ind(nf)
#                 random_init_ind(SP.ind_array[i])
#                 evaluate(SP.ind_array[i])
#     free(shuffle)
#
# cdef int extractPtoArchive(pop *P, pop *archive):
#     cdef int i, j, dom, t, convergence_rate
#     t = archive.size + P.size
#     archiveAndP = create_pop(t, nf)
#     convergence_rate = 0
#     for i in range(archive.size):
#         archiveAndP.ind_array[i] = archive.ind_array[i]
#     for i in range(P.size):
#         archiveAndP.ind_array[i + archive.size] = ind_copy(P.ind_array[i])
#     archiveAndP.size = t
#     archive.size = 0
#     for i in range(t):
#         for j in range(t):
#             if i != j:
#                 dom = non_dominated(archiveAndP.ind_array[i], archiveAndP.ind_array[j])
#                 if dom == -1 or (dom == 0 and i > j):
#                     break
#         else:
#             archive.ind_array[archive.size] = ind_copy(archiveAndP.ind_array[i])
#             archive.size += 1
#             if i >= t - P.size:
#                 convergence_rate += 1
#     complete_free_pop(archiveAndP)
#     return convergence_rate
#
# cdef double calcMaxbound(pop *SP, int size):
#     global max_bound
#     cdef int i, j
#     SP.size = size
#     cdef double max_b = SP.ind_array[0].v[0]
#     for i in range(SP.size):
#         for j in range(nf):
#             if max_b < SP.ind_array[i].v[j]:
#                 max_b = SP.ind_array[i].v[j]
#     if max_b == 0.0:
#         max_b = 1e-8
#     max_bound = max_b
#     return max_b
#
# cdef void calcul_weight(pop *SP, int size):
#     cdef int i, j
#     for i in range(SP.size):
#         for j in range(nf):
#             SP.ind_array[i].v[j] = SP.ind_array[i].f[j] * vector_weight[j]
#
# cdef int compute_fitness_and_select(pop *SP, ind *x, int size):
#     cdef int i, worst
#     cdef double worst_fit, fit_tmp
#     SP.size = size
#     x.fitness = 0
#     compute_ind_fitness(x, SP)
#     worst_fit = x.fitness
#     worst = -1
#     for i in range(SP.size):
#         fit_tmp = update_fitness_return(SP.ind_array[i].fitness, calcAddEpsIndicator(x, SP.ind_array[i]))
#         if fit_tmp > worst_fit:
#             worst = i
#             worst_fit = fit_tmp
#     fit_tmp = x.fitness
#     if worst == -1:
#         return -1
#     else:
#         for i in range(SP.size):
#             delete_fitness(SP.ind_array[i], calcAddEpsIndicator(SP.ind_array[worst], SP.ind_array[i]))
#             update_fitness(SP.ind_array[i], calcAddEpsIndicator(x, SP.ind_array[i]))
#         delete_fitness(x, calcAddEpsIndicator(SP.ind_array[worst], x))
#         free_ind(SP.ind_array[worst])
#         SP.ind_array[worst] = ind_copy(x)
#         if fit_tmp - worst_fit > smallValue:
#             return worst
#         else:
#             return -1
#
# # =========================================================================
# # PART 4: MODULAR LOCAL SEARCH & EVALUATION HELPERS (Unchanged, but with renamed vars)
# # =========================================================================
#
# cdef void original_swap_heuristic(pop *SP, pop *Sarchive, int size, int L_val, double kappa_val):
#     """The original logic from Indicator_local_search1, now modular."""
#     cdef ind *x
#     cdef ind *y
#     cdef int i, j, r, t, k, l, v, sol, mino, mp, maxp, consistant, pos, stop, convergence, ii, tmp_pris, tmp_nonpris, taille, feasible, tv, IM
#     cdef int* remplace = <int *>chk_malloc(L_val * sizeof(int))
#     SP.size = size
#     extractPtoArchive(SP, Sarchive)
#     while True:
#         convergence = 0
#         for i in range(SP.size):
#             if not SP.ind_array[i].explored:
#                 x = ind_copy(SP.ind_array[i])
#                 j = 0
#                 while j < x.nombr:
#                     for l in range(L_val):
#                         remplace[l] = 0
#                     while True:
#                         mino = irand(ni)
#                         if x.Items[mino] == 1:
#                             break
#                     x.Items[mino] = 0
#                     x.nombr -= 1
#                     x.nombr_nonpris += 1
#                     for r in range(nf):
#                         x.capa[r] -= g_weights[r][mino]
#                         x.f[r] -= g_profits[r][mino]
#                     IM = 0
#                     taille = 0
#                     while IM < L_val:
#                         while True:
#                             maxp = irand(ni)
#                             if x.Items[maxp] == 0:
#                                 break
#                         if maxp != mino:
#                             consistant = 1
#                             r = 0
#                             while r < nf and consistant == 1:
#                                 if x.capa[r] + g_weights[r][maxp] > capacities[r]:
#                                     consistant = 0
#                                 r += 1
#                             if consistant == 1:
#                                 feasible = 1
#                                 r = 0
#                                 while r < taille and feasible:
#                                     if maxp == remplace[r]:
#                                         feasible = 0
#                                     r += 1
#                                 if feasible == 1:
#                                     remplace[taille] = maxp
#                                     taille += 1
#                                     x.Items[maxp] = 1
#                                     x.nombr_nonpris -= 1
#                                     x.nombr += 1
#                                     for r in range(nf):
#                                         x.capa[r] += g_weights[r][maxp]
#                                         x.f[r] += g_profits[r][maxp]
#                         IM += 1
#                     for tv in range(nf):
#                         x.v[tv] = x.f[tv] * vector_weight[tv]
#                     max_bound = calcMaxbound(SP, SP.size)
#                     sol = compute_fitness_and_select(SP, x, SP.size)
#                     if sol != -1:
#                         j = x.nombr + 1
#                         if sol > i and i + 1 < SP.size:
#                             y = SP.ind_array[i + 1]
#                             SP.ind_array[i + 1] = SP.ind_array[sol]
#                             SP.ind_array[sol] = y
#                             i += 1
#                         break
#                     elif sol == -1:
#                         x.Items[mino] = 1
#                         x.nombr_nonpris -= 1
#                         x.nombr += 1
#                         for r in range(nf):
#                             x.capa[r] += g_weights[r][mino]
#                             x.f[r] += g_profits[r][mino]
#                         if taille >= 1:
#                             for r in range(taille):
#                                 x.Items[remplace[r]] = 0
#                                 x.nombr -= 1
#                                 x.nombr_nonpris += 1
#                                 for t in range(nf):
#                                     x.capa[t] -= g_weights[t][remplace[r]]
#                                     x.f[t] -= g_profits[t][remplace[r]]
#                                     x.v[t] = x.f[t] * vector_weight[tv]
#                     j += 1
#                 tmp_pris = x.nombr
#                 tmp_nonpris = x.nombr_nonpris
#                 free_ind(x)
#                 if j == tmp_pris:
#                     SP.ind_array[i].explored = 1
#         convergence = extractPtoArchive(SP, Sarchive)
#         if not convergence:
#             break
#     free(remplace)
#
# cdef void adaptive_local_search(pop *SP, pop *Sarchive, int size, str heuristic_name, int L_val, double kappa_val):
#     """Dispatches to the correct local search heuristic."""
#     if heuristic_name == "original_swap":
#         original_swap_heuristic(SP, Sarchive, size, L_val, kappa_val)
#     else:
#         # Fallback to original
#         original_swap_heuristic(SP, Sarchive, size, L_val, kappa_val)
#
# cdef dict extract_solution_data_for_python(ind *solution_ind):
#     cdef int i
#     data = {
#         'f': [solution_ind.f[i] for i in range(nf)],
#         'capa': [solution_ind.capa[i] for i in range(nf)],
#         'fitness': solution_ind.fitness,
#         'nombr': solution_ind.nombr,
#         'Items': [solution_ind.Items[i] for i in range(ni)]
#     }
#     return data
#
# def extract_problem_features_for_llm():
#     if capacities == NULL or g_weights == NULL or g_profits == NULL:
#         return None
#     total_capacity = sum(capacities[i] for i in range(nf))
#     total_avg_weight = sum(sum(g_weights[obj][i] for i in range(ni)) for obj in range(nf)) / nf
#     capacity_tightness = total_avg_weight / total_capacity if total_capacity > 0 else 0
#     profit_variances = []
#     weight_variances = []
#     for obj in range(nf):
#         profits_list = [g_profits[obj][i] for i in range(ni)]
#         weights_list = [g_weights[obj][i] for i in range(ni)]
#         profit_variances.append(np.var(profits_list))
#         weight_variances.append(np.var(weights_list))
#     features = {
#         "num_items": ni, "num_objectives": nf, "capacity_tightness": round(capacity_tightness, 4),
#         "avg_profit_variance": round(np.mean(profit_variances), 2),
#         "avg_weight_variance": round(np.mean(weight_variances), 2),
#     }
#     return features
#
# # =========================================================================
# # PART 5: THE GUIDED AGENT (V17 - FINAL)
# # =========================================================================
#
# class GuidedAgent:
#     """
#     V17: The Guided Agent.
#     Evaluates a pre-computed list of the best possible swaps using LLM reasoning.
#     """
#     def __init__(self, model_name="llama3:latest"):
#         self.model_name = model_name
#         self.cache = {}
#
#     def _call_llm(self, prompt, cache_key):
#         if cache_key in self.cache:
#             print(f"  [LLM Cache Hit] Using cached response.")
#             return self.cache[cache_key]
#         print(f"  [LLM Agent Call] Requesting evaluation of top swaps...")
#
#         try:
#             response = ollama.generate(model=self.model_name, prompt=prompt, format='json')
#             response_text = response.get('response', '').strip()
#
#             if not response_text:
#                 print("  [LLM Error] Empty response.")
#                 return None
#             result = json.loads(response_text)
#             self.cache[cache_key] = result
#             print(f"  [LLM Agent Success] Received evaluation.")
#             return result
#         except (json.JSONDecodeError, Exception) as e:
#             print(f"  [LLM Agent Error] {e}.")
#             return None
#
#     def evaluate_best_swaps(self, solution_data, problem_data):
#         """
#         V17: Asks the LLM to evaluate the top 5 best swaps based on a combined score.
#         """
#         weakest_obj_idx = 0 if solution_data['f'][0] < solution_data['f'][1] else 1
#
#         candidates = []
#         items_in_knapsack_indices = [i for i, val in enumerate(solution_data['Items']) if val == 1]
#         items_not_in_knapsack_indices = [i for i, val in enumerate(solution_data['Items']) if val == 0]
#
#         # Generate a larger list of candidates
#         worst_items_in_knapsack = sorted(
#             items_in_knapsack_indices,
#             key=lambda i: g_profits[weakest_obj_idx][i]
#         )[:10]
#
#         best_items_not_in_knapsack = sorted(
#             items_not_in_knapsack_indices,
#             key=lambda i: g_profits[weakest_obj_idx][i],
#             reverse=True
#         )[:10]
#
#         for remove_idx in worst_items_in_knapsack:
#             for add_idx in best_items_not_in_knapsack:
#                 if remove_idx == add_idx: continue
#                 new_capa_obj1 = solution_data['capa'][0] - g_weights[0][remove_idx] + g_weights[0][add_idx]
#                 new_capa_obj2 = solution_data['capa'][1] - g_weights[1][remove_idx] + g_weights[1][add_idx]
#
#                 if new_capa_obj1 <= capacities[0] and new_capa_obj2 <= capacities[1]:
#                     delta_f1 = g_profits[0][add_idx] - g_profits[0][remove_idx]
#                     delta_f2 = g_profits[1][add_idx] - g_profits[1][remove_idx]
#                     combined_score = delta_f1 + delta_f2
#                     candidates.append({
#                         "remove": remove_idx, "add": add_idx, "delta_f1": delta_f1, "delta_f2": delta_f2, "combined_score": combined_score
#                     })
#
#         if not candidates:
#             return {"item_to_remove": -1, "item_to_add": -1, "state": None}
#
#         # Sort candidates by combined score and take the top 5
#         top_candidates = sorted(candidates, key=lambda x: x['combined_score'], reverse=True)[:5]
#
#         prompt = f"""
# You are an expert evaluator for a multi-objective knapsack problem. Your task is to choose the best swap from a pre-selected list of top candidates.
#
# PROBLEM FEATURES:
# {json.dumps(problem_data, indent=2)}
#
# CURRENT SOLUTION:
# - Profits (Objective 1, Objective 2): {solution_data['f']}
# - Fitness: {solution_data['fitness']:.4f}
#
# TOP 5 CANDIDATE SWAPS:
# These are the 5 best swaps based on a simple combined profit score. 'delta_f1' and 'delta_f2' are the changes in profit.
# {json.dumps(top_candidates, indent=2)}
#
# YOUR TASK:
# Analyze these 5 candidates. Some might look good based on profit but could be bad for the overall population fitness.
# Choose the single swap that you believe is the most promising for improving the solution's overall quality and fitness.
# Consider the trade-offs between the two objectives.
#
# Respond ONLY with a JSON object containing 'item_to_remove' and 'item_to_add'.
# Example: {{"item_to_remove": 123, "item_to_add": 45}}
# """
#
#         cache_key = f"guided_{hash(str(top_candidates))}"
#         result = self._call_llm(prompt, cache_key)
#
#         if result:
#             result['state'] = solution_data
#         return result
#
# # V17: The agent function that works on a population snapshot
# cdef bint perform_agent_refinement_on_snapshot(pop *P_snapshot, pop *P_main, int item_to_remove, int item_to_add):
#     """
#     V17: Performs the LLM-suggested swap on a population snapshot and integrates the result back into the main population.
#     Returns True on success, False on failure.
#     """
#     if P_snapshot == NULL or P_snapshot.size == 0 or P_main == NULL or P_main.size == 0:
#         return False
#
#     cdef ind *modified_solution = NULL
#     cdef bint is_feasible
#     cdef int sol_idx
#     cdef int i
#     cdef double old_fitness, new_fitness
#
#     cdef ind *original_solution = P_snapshot.ind_array[0]
#
#     if original_solution.Items[item_to_remove] != 1 or original_solution.Items[item_to_add] != 0:
#         print(f"  [Agent Fail] Invalid swap suggestion (remove not in knapsack or add already in).")
#         return False
#
#     modified_solution = ind_copy(original_solution)
#
#     for i in range(nf):
#         modified_solution.capa[i] -= g_weights[i][item_to_remove]
#         modified_solution.f[i] -= g_profits[i][item_to_remove]
#     modified_solution.Items[item_to_remove] = 0
#     modified_solution.nombr -= 1
#
#     is_feasible = 1
#     for i in range(nf):
#         if modified_solution.capa[i] + g_weights[i][item_to_add] > capacities[i]:
#             is_feasible = 0
#             break
#
#     if not is_feasible:
#         free_ind(modified_solution)
#         print(f"  [Agent Fail] Swap {item_to_remove} for {item_to_add} was not feasible.")
#         return False
#
#     for i in range(nf):
#         modified_solution.capa[i] += g_weights[i][item_to_add]
#         modified_solution.f[i] += g_profits[i][item_to_add]
#     modified_solution.Items[item_to_add] = 1
#     modified_solution.nombr += 1
#     modified_solution.llm_enhanced = 1
#
#     calcul_weight(P_snapshot, P_snapshot.size)
#     sol_idx = compute_fitness_and_select(P_snapshot, modified_solution, P_snapshot.size)
#
#     old_fitness = original_solution.fitness
#     new_fitness = modified_solution.fitness
#
#     if sol_idx != -1:
#         print(f"  [Agent Success] Swap {item_to_remove} for {item_to_add} improved fitness from {old_fitness:.4f} to {new_fitness:.4f} in snapshot.")
#
#         calcul_weight(P_main, P_main.size)
#         main_sol_idx = compute_fitness_and_select(P_main, modified_solution, P_main.size)
#
#         free_ind(modified_solution)
#
#         if main_sol_idx != -1:
#             print(f"  [Agent Success] Improved solution successfully integrated into main population.")
#             return True
#         else:
#             print(f"  [Agent Fail] Improved solution could not be integrated into main population (context mismatch).")
#             return False
#     else:
#         free_ind(modified_solution)
#         print(f"  [Agent Fail] Swap {item_to_remove} for {item_to_add} did NOT improve fitness in snapshot. Old: {old_fitness:.4f}, New: {new_fitness:.4f}.")
#         return False
#
# # =========================================================================
# # PART 6: MAIN EXECUTION FUNCTION (V17 - GUIDED)
# # =========================================================================
# def load_baseline_pareto_front(filename):
#     """A pure Python function to load the baseline data."""
#     baseline_pareto_front = []
#     try:
#         with open(filename, "r") as f:
#             for line in f:
#                 if line.strip() and not line.startswith("#"):
#                     baseline_pareto_front.append([float(x) for x in line.split()])
#     except FileNotFoundError:
#         print(f"Warning: Baseline file {filename} not found. Dominance will be 0%.")
#     return baseline_pareto_front
#
# def run_guided_moacp_v17(instance_file, weights_file, nbitems, num_objectives, output_file_base, baseline_pareto_front):
#     """
#     V17: The "Guided Agent" with a more reliable LLM evaluation process.
#     """
#     cdef int i, j, item_to_remove, item_to_add
#     cdef pop *P
#     cdef pop *solutions
#     cdef pop *archive
#     cdef pop *P_snapshot
#     cdef ind *x
#     cdef int it
#
#     NBL = 150
#     NRUNS = 10
#     METRIC_INTERVAL = 10
#     STAGNATION_WINDOW = 5
#     HV_IMPROVEMENT_THRESHOLD = 100.0
#     TIME_BUDGET_SECONDS = 600
#
#     total_time = 0
#     start_time = time.time()
#
#     for run in range(1, NRUNS + 1):
#         print(f"\n--- RUN {run}/{NRUNS} --- V17 Guided Agent")
#         print(f"Instance: {instance_file.decode()}, Items: {nbitems}, Objectives: {num_objectives}")
#
#         global nf, ni, NBITEMS, alpha, paretoIni, L, kappa, nombreLIGNE, nextLn, inv, vector_weight
#         global capacities, g_weights, g_profits, OBJ_Weights
#         NBITEMS = nbitems
#         ni = nbitems
#         nf = num_objectives
#         alpha = 10
#         paretoIni = 28000
#         L = 5
#         kappa = 0.05
#
#         seed(run)
#         loadMOKP(instance_file)
#         read_weights_file(weights_file)
#
#         agent = GuidedAgent()
#         problem_features = extract_problem_features_for_llm()
#         print(f"  [Problem Features] {json.dumps(problem_features, indent=4)}")
#
#         run_log = {"iterations": [], "hypervolumes": [], "dominance_percentages": []}
#         last_hv = 0.0
#         stagnation_counter = 0
#         consecutive_agent_failures = 0
#
#         P = create_pop(paretoIni, nf)
#         it = 0
#         while it < NBL and (time.time() - start_time) < TIME_BUDGET_SECONDS:
#             solutions = create_pop(alpha, nf)
#             archive = create_pop(paretoIni, nf)
#             choose_weight()
#             P_init_pop(solutions, P, alpha)
#             extractPtoArchive(solutions, P)
#             calcul_weight(solutions, alpha)
#             calcMaxbound(solutions, alpha)
#             compute_all_fitness(solutions)
#
#             adaptive_local_search(solutions, archive, alpha, "original_swap", L, kappa)
#
#             extractPtoArchive(archive, P)
#             complete_free_pop(solutions)
#             complete_free_pop(archive)
#
#             if it % METRIC_INTERVAL == 0:
#                 current_pareto = []
#                 for i in range(P.size):
#                     current_pareto.append([P.ind_array[i].f[0], P.ind_array[i].f[1]])
#
#                 current_hv = calculate_hypervolume(current_pareto)
#                 dominance = calculate_dominance_percentage(current_pareto, baseline_pareto_front)
#
#                 run_log["iterations"].append(it)
#                 run_log["hypervolumes"].append(current_hv)
#                 run_log["dominance_percentages"].append(dominance)
#
#                 print(f"  [Metrics] Iter {it:3d}: HV={current_hv:10.2f}, Dominates Baseline={dominance:5.2f}%")
#
#                 hv_change = current_hv - last_hv
#                 if hv_change < HV_IMPROVEMENT_THRESHOLD:
#                     stagnation_counter += 1
#                     print(f"  [Stagnation] Counter: {stagnation_counter}/{STAGNATION_WINDOW}")
#                 else:
#                     stagnation_counter = 0
#                     consecutive_agent_failures = 0
#
#                 last_hv = current_hv
#
#                 # --- THE GUIDED AGENT INTERVENTION (V17) ---
#                 if stagnation_counter >= STAGNATION_WINDOW:
#                     print("\n!!! STAGNATION DETECTED. Calling Guided Agent. !!!")
#
#                     P_snapshot = create_pop(P.size, nf)
#                     for i in range(P.size):
#                         P_snapshot.ind_array[i] = ind_copy(P.ind_array[i])
#                     P_snapshot.size = P.size
#
#                     population_snapshot_data = [extract_solution_data_for_python(P_snapshot.ind_array[i]) for i in range(P_snapshot.size)]
#
#                     agent_response = agent.evaluate_best_swaps(population_snapshot_data[0], problem_features)
#
#                     if agent_response and 'state' in agent_response and agent_response['state'] is not None:
#                         item_to_remove = agent_response.get('item_to_remove', -1)
#                         item_to_add = agent_response.get('item_to_add', -1)
#
#                         if 0 <= item_to_remove < ni and 0 <= item_to_add < ni and item_to_remove != item_to_add:
#                             success = perform_agent_refinement_on_snapshot(
#                                 P_snapshot,
#                                 P,
#                                 item_to_remove,
#                                 item_to_add
#                             )
#
#                             if success:
#                                 stagnation_counter = 0
#                                 consecutive_agent_failures = 0
#                                 L = 8
#                                 kappa = 0.08
#                             else:
#                                 consecutive_agent_failures += 1
#                         else:
#                             print("  [Agent Fail] Received invalid item indices from LLM.")
#                             consecutive_agent_failures += 1
#                     else:
#                         print("  [Agent Fail] Could not parse a valid response from LLM.")
#                         consecutive_agent_failures += 1
#
#                     complete_free_pop(P_snapshot)
#
#                     if consecutive_agent_failures >= 2 or stagnation_counter >= STAGNATION_WINDOW:
#                         print("  [Fallback] Agent is struggling. Applying random parameter reset.")
#                         L = 15
#                         kappa = 0.2
#                         stagnation_counter = 0
#                         consecutive_agent_failures = 0
#
#             it += 1
#
#         with open(f"{output_file_base}_V17_pareto.txt", "a") as f:
#             f.write(f"\n# RUN {run}\n")
#             for i in range(P.size):
#                 for j in range(nf):
#                     f.write(f"{P.ind_array[i].f[j]:.6f} ")
#                 f.write("\n")
#
#         with open(f"{output_file_base}_V17_log.json", "w") as f:
#             json.dump(run_log, f, indent=2)
#
#         complete_free_pop(P)
#         cleanup_globals()
#
#     total_time = time.time() - start_time
#     print(f"\nTotal execution time: {total_time:.2f} seconds")
#     print(f"Average time per run: {total_time/NRUNS:.2f} seconds")
#     with open(f"{output_file_base}_V17_pareto.txt", "a") as f:
#         f.write(f"# RUNTIME: {total_time:.2f}\n")
#
# # Python helper functions for metrics (Unchanged)
# def calculate_hypervolume(pareto_points, ref_point=None):
#     if not pareto_points: return 0.0
#     if ref_point is None:
#         max_f1 = max(p[0] for p in pareto_points)
#         max_f2 = max(p[1] for p in pareto_points)
#         ref_point = (max_f1 * 1.1, max_f2 * 1.1)
#     points = sorted(pareto_points, key=lambda p: p[0])
#     hv = 0.0
#     for i in range(len(points) - 1):
#         x1, y1 = points[i]
#         x2, y2 = points[i + 1]
#         hv += (x2 - x1) * (ref_point[1] - y1)
#     if points:
#         x_last, y_last = points[-1]
#         hv += (ref_point[0] - x_last) * (ref_point[1] - y_last)
#     return hv
#
# def calculate_dominance_percentage(new_pareto, reference_pareto):
#     if not reference_pareto: return 100.0
#     if not new_pareto: return 0.0
#     dominated_count = 0
#     for ref_point in reference_pareto:
#         is_dominated = any(new_p[0] >= ref_point[0] and new_p[1] >= ref_point[1] and (new_p[0] > ref_point[0] or new_p[1] > ref_point[1]) for new_p in new_pareto)
#         if is_dominated: dominated_count += 1
#     return (dominated_count / len(reference_pareto)) * 100
# Out:
# Content of stdout:
# _cython_magic_a364ed58c0bb2e1cbbd371dc36a49529829ac825706a1d7c0a812a9e9f5cc75e.c
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_a364ed58c0bb2e1cbbd371dc36a49529829ac825706a1d7c0a812a9e9f5cc75e.c(5730): warning C4244: '='ÿ: conversion de 'double' en 'float', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_a364ed58c0bb2e1cbbd371dc36a49529829ac825706a1d7c0a812a9e9f5cc75e.c(5820): warning C4244: '='ÿ: conversion de 'double' en 'float', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_a364ed58c0bb2e1cbbd371dc36a49529829ac825706a1d7c0a812a9e9f5cc75e.c(7006): warning C4244: '='ÿ: conversion de 'Py_ssize_t' en 'int', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_a364ed58c0bb2e1cbbd371dc36a49529829ac825706a1d7c0a812a9e9f5cc75e.c(20885): warning C4305: '='ÿ: troncation de 'double' … 'float'
#    Cr‚ation de la bibliothŠque C:\Users\Aziz il patal\.ipython\cython\Users\Aziz il patal\.ipython\cython\_cython_magic_a364ed58c0bb2e1cbbd371dc36a49529829ac825706a1d7c0a812a9e9f5cc75e.cp39-win_amd64.lib et de l'objet C:\Users\Aziz il patal\.ipython\cython\Users\Aziz il patal\.ipython\cython\_cython_magic_a364ed58c0bb2e1cbbd371dc36a49529829ac825706a1d7c0a812a9e9f5cc75e.cp39-win_amd64.exp
# G‚n‚ration de code en cours
# Fin de la g‚n‚ration du code

# %%
# Cell 2
import matplotlib.pyplot as plt

# Ensure the baseline file exists for comparison
# !copy 2502_ResultsMD.txt 2502_ResultsMD_baseline.txt
baseline_data = load_baseline_pareto_front("2502_ResultsMD_baseline.txt")

# --- Run the new V17 Guided Agent ---
run_guided_moacp_v17(b"250.2.txt", b"Weights_2obj_FQ200.txt", 250, 2, "2502_ResultsMD", baseline_data)

# --- Final Comparison and Visualization ---
def plot_pareto_comparison(baseline_file, new_file, title):
    """Generates a final comparison plot of the Pareto fronts."""
    baseline_points = []
    with open(baseline_file, "r") as f:
        for line in f:
            if line.strip() and not line.startswith("#"):
                baseline_points.append([float(x) for x in line.split()])

    new_points = []
    with open(new_file, "r") as f:
        for line in f:
            if line.strip() and not line.startswith("#"):
                new_points.append([float(x) for x in line.split()])
    
    if not baseline_points or not new_points:
        print("Could not load data for plotting.")
        return

    base_x, base_y = zip(*baseline_points)
    new_x, new_y = zip(*new_points)

    plt.figure(figsize=(10, 8))
    plt.scatter(base_x, base_y, color='red', label='Original Baseline', alpha=0.6, s=30)
    plt.scatter(new_x, new_y, color='blue', label='V17 Guided Agent', alpha=0.8, s=40, marker='x')
    
    plt.xlabel("Objective 1 (Profit)")
    plt.ylabel("Objective 2 (Profit)")
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    
    # Save the plot
    plot_filename = new_file.replace(".txt", "_comparison.png")
    plt.savefig(plot_filename)
    print(f"Comparison plot saved to {plot_filename}")
    plt.show()

# Run the comparison
print("\nGenerating final comparison plot...")
plot_pareto_comparison(
    "2502_ResultsMD_baseline.txt", 
    "2502_ResultsMD_V17_pareto.txt", 
    "Pareto Front Comparison: Original Baseline vs. V17 Guided Agent"
)
# Out:
#         1 fichier(s) copi‚(s).
#
# --- RUN 1/10 --- V16 Context-Aware Strategist Agent
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV= 927946.72, Dominates Baseline= 0.28%
#   [Metrics] Iter  10: HV=1250476.69, Dominates Baseline= 7.36%
#   [Metrics] Iter  20: HV=3431437.82, Dominates Baseline=11.54%
#   [Metrics] Iter  30: HV=4719855.45, Dominates Baseline=24.13%
#   [Metrics] Iter  40: HV=5179601.92, Dominates Baseline=29.44%
#   [Metrics] Iter  50: HV=6018937.88, Dominates Baseline=31.14%
#   [Metrics] Iter  60: HV=6015402.88, Dominates Baseline=31.14%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  70: HV=6008069.88, Dominates Baseline=32.91%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  80: HV=6002310.88, Dominates Baseline=37.79%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  90: HV=5998982.88, Dominates Baseline=40.91%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 100: HV=5993729.88, Dominates Baseline=41.83%
#   [Stagnation] Counter: 5/5
#
# !!! STAGNATION DETECTED. Calling Context-Aware Strategist Agent. !!!
#   [LLM Agent Call] Requesting strategic analysis...
#   [LLM Agent Success] Received strategic advice.
#   [Analyst] Strategy chosen: AGGRESSIVE
#   [LLM Agent Call] Requesting strategic analysis...
#   [LLM Agent Success] Received strategic advice.
#   [Agent Fail] Swap 188 for 32 did NOT improve fitness in snapshot. Old: -8.9007, New: -0.0001.
#   [Fallback] Agent is struggling. Applying random parameter reset.
#   [Metrics] Iter 110: HV=5988878.88, Dominates Baseline=42.53%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 120: HV=5977043.88, Dominates Baseline=50.18%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 130: HV=5976683.88, Dominates Baseline=51.66%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 140: HV=5976683.88, Dominates Baseline=51.66%
#   [Stagnation] Counter: 4/5
#
# --- RUN 2/10 --- V16 Context-Aware Strategist Agent
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV=1049680.76, Dominates Baseline= 0.00%
#   [Metrics] Iter  10: HV=6480222.30, Dominates Baseline= 5.73%
#   [Metrics] Iter  20: HV=5881139.30, Dominates Baseline=20.67%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  30: HV=5815079.30, Dominates Baseline=38.00%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  40: HV=5855482.30, Dominates Baseline=43.88%
#   [Metrics] Iter  50: HV=5754755.04, Dominates Baseline=49.89%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  60: HV=5806684.12, Dominates Baseline=52.02%
#   [Metrics] Iter  70: HV=5799334.12, Dominates Baseline=60.08%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  80: HV=5794778.12, Dominates Baseline=62.77%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  90: HV=5791254.12, Dominates Baseline=68.08%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 100: HV=5789582.12, Dominates Baseline=69.43%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 110: HV=5790057.12, Dominates Baseline=69.71%
#   [Metrics] Iter 120: HV=5789817.12, Dominates Baseline=71.69%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 130: HV=5788756.12, Dominates Baseline=72.12%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 140: HV=5786176.12, Dominates Baseline=72.97%
#   [Stagnation] Counter: 3/5
#
# --- RUN 3/10 --- V16 Context-Aware Strategist Agent
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV= 940763.63, Dominates Baseline= 0.00%
#   [Metrics] Iter  10: HV=7074539.52, Dominates Baseline= 2.41%
#   [Metrics] Iter  20: HV=6918704.52, Dominates Baseline= 7.43%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  30: HV=6617489.52, Dominates Baseline=20.88%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  40: HV=6430558.52, Dominates Baseline=28.17%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  50: HV=6444445.52, Dominates Baseline=35.03%
#   [Metrics] Iter  60: HV=6404763.02, Dominates Baseline=35.74%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  70: HV=6395286.02, Dominates Baseline=40.62%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  80: HV=6383838.02, Dominates Baseline=46.99%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  90: HV=6377054.02, Dominates Baseline=58.03%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 100: HV=6375319.02, Dominates Baseline=59.59%
#   [Stagnation] Counter: 5/5
#
# !!! STAGNATION DETECTED. Calling Context-Aware Strategist Agent. !!!
#   [LLM Agent Call] Requesting strategic analysis...
#   [LLM Agent Success] Received strategic advice.
#   [Analyst] Strategy chosen: AGGRESSIVE
#   [LLM Agent Call] Requesting strategic analysis...
#   [LLM Agent Success] Received strategic advice.
#   [Agent Fail] Swap 188 for 191 did NOT improve fitness in snapshot. Old: -8.9569, New: -0.0000.
#   [Fallback] Agent is struggling. Applying random parameter reset.
#   [Metrics] Iter 110: HV=6375319.02, Dominates Baseline=59.59%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 120: HV=6370606.02, Dominates Baseline=62.28%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 130: HV=6368783.02, Dominates Baseline=63.55%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 140: HV=6367337.02, Dominates Baseline=64.33%
#   [Stagnation] Counter: 4/5
#
# --- RUN 4/10 --- V16 Context-Aware Strategist Agent
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV=1499135.28, Dominates Baseline= 0.00%
#   [Metrics] Iter  10: HV=7389967.36, Dominates Baseline= 1.42%
#   [Metrics] Iter  20: HV=7187117.36, Dominates Baseline= 3.18%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  30: HV=6793649.36, Dominates Baseline= 5.59%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  40: HV=6513996.36, Dominates Baseline= 6.44%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  50: HV=6540892.36, Dominates Baseline= 9.48%
#   [Metrics] Iter  60: HV=6566527.36, Dominates Baseline=11.75%
#   [Metrics] Iter  70: HV=6581779.36, Dominates Baseline=13.02%
#   [Metrics] Iter  80: HV=6562281.36, Dominates Baseline=17.55%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  90: HV=6547876.36, Dominates Baseline=27.03%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 100: HV=6546811.36, Dominates Baseline=27.81%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 110: HV=6547812.36, Dominates Baseline=27.81%
#   [Metrics] Iter 120: HV=6460160.88, Dominates Baseline=30.15%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 130: HV=6456428.88, Dominates Baseline=33.47%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 140: HV=6457670.88, Dominates Baseline=35.74%
#
# --- RUN 5/10 --- V16 Context-Aware Strategist Agent
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV= 952131.42, Dominates Baseline= 0.00%
#   [Metrics] Iter  10: HV=1152828.50, Dominates Baseline= 1.77%
#   [Metrics] Iter  20: HV=6957532.70, Dominates Baseline= 8.49%
#   [Metrics] Iter  30: HV=6678517.70, Dominates Baseline=27.25%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  40: HV=6571376.70, Dominates Baseline=33.55%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  50: HV=6537656.70, Dominates Baseline=36.31%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  60: HV=6543993.70, Dominates Baseline=37.79%
#   [Metrics] Iter  70: HV=6544038.70, Dominates Baseline=37.86%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  80: HV=6539965.70, Dominates Baseline=39.07%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  90: HV=6537014.70, Dominates Baseline=41.05%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 100: HV=6536976.70, Dominates Baseline=41.05%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 110: HV=6531353.70, Dominates Baseline=42.11%
#   [Stagnation] Counter: 5/5
#
# !!! STAGNATION DETECTED. Calling Context-Aware Strategist Agent. !!!
#   [LLM Agent Call] Requesting strategic analysis...
#   [LLM Agent Success] Received strategic advice.
#   [Analyst] Strategy chosen: BALANCED
#   [LLM Agent Call] Requesting strategic analysis...
#   [LLM Agent Success] Received strategic advice.
#   [Agent Fail] Swap 228 for 58 did NOT improve fitness in snapshot. Old: -8.3586, New: -191.4779.
#   [Fallback] Agent is struggling. Applying random parameter reset.
#   [Metrics] Iter 120: HV=6531137.70, Dominates Baseline=43.24%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 130: HV=6528588.70, Dominates Baseline=45.93%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 140: HV=6518807.70, Dominates Baseline=55.56%
#   [Stagnation] Counter: 3/5
#
# --- RUN 6/10 --- V16 Context-Aware Strategist Agent
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV= 810822.87, Dominates Baseline= 2.19%
#   [Metrics] Iter  10: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  20: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  30: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  40: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter  50: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 5/5
#
# !!! STAGNATION DETECTED. Calling Context-Aware Strategist Agent. !!!
#   [LLM Agent Call] Requesting strategic analysis...
#   [LLM Agent Success] Received strategic advice.
#   [Analyst] Strategy chosen: AGGRESSIVE
#   [LLM Agent Call] Requesting strategic analysis...
#   [LLM Agent Success] Received strategic advice.
#   [Agent Fail] Swap 228 for 66 did NOT improve fitness in snapshot. Old: -9.1212, New: -0.8042.
#   [Fallback] Agent is struggling. Applying random parameter reset.
#   [Metrics] Iter  60: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  70: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  80: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  90: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 100: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 5/5
#
# !!! STAGNATION DETECTED. Calling Context-Aware Strategist Agent. !!!
#   [LLM Cache Hit] Using cached response.
#   [Analyst] Strategy chosen: AGGRESSIVE
#   [LLM Cache Hit] Using cached response.
#   [Agent Fail] Swap 228 for 66 did NOT improve fitness in snapshot. Old: -9.1212, New: -0.8941.
#   [Fallback] Agent is struggling. Applying random parameter reset.
#   [Metrics] Iter 110: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 120: HV=4383500.45, Dominates Baseline= 2.48%
#   [Metrics] Iter 130: HV=4383500.45, Dominates Baseline= 2.48%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 140: HV=4383500.45, Dominates Baseline= 2.48%
#   [Stagnation] Counter: 2/5
#
# --- RUN 7/10 --- V16 Context-Aware Strategist Agent
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV=1126483.34, Dominates Baseline= 0.00%
#   [Metrics] Iter  10: HV=1439688.32, Dominates Baseline= 3.18%
#   [Metrics] Iter  20: HV=6639126.52, Dominates Baseline= 5.17%
#   [Metrics] Iter  30: HV=6452113.52, Dominates Baseline=15.57%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  40: HV=6286224.52, Dominates Baseline=30.08%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  50: HV=6143033.52, Dominates Baseline=34.04%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  60: HV=6138183.52, Dominates Baseline=41.54%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter  70: HV=6302489.02, Dominates Baseline=43.03%
#   [Metrics] Iter  80: HV=6301645.02, Dominates Baseline=43.38%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  90: HV=6297917.02, Dominates Baseline=44.80%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 100: HV=6291654.02, Dominates Baseline=50.25%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 110: HV=6290706.02, Dominates Baseline=51.45%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 120: HV=6290984.02, Dominates Baseline=51.52%
#   [Metrics] Iter 130: HV=6291080.02, Dominates Baseline=51.73%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 140: HV=6286434.02, Dominates Baseline=54.99%
#   [Stagnation] Counter: 2/5
#
# --- RUN 8/10 --- V16 Context-Aware Strategist Agent
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV=1058631.28, Dominates Baseline= 0.00%
#   [Metrics] Iter  10: HV=1365757.41, Dominates Baseline= 1.91%
#   [Metrics] Iter  20: HV=1476100.85, Dominates Baseline= 2.55%
#   [Metrics] Iter  30: HV=5913150.00, Dominates Baseline=11.96%
#   [Metrics] Iter  40: HV=5778829.00, Dominates Baseline=26.96%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  50: HV=5715752.00, Dominates Baseline=34.04%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  60: HV=5703573.00, Dominates Baseline=39.84%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  70: HV=6330773.98, Dominates Baseline=44.66%
#   [Metrics] Iter  80: HV=6330124.98, Dominates Baseline=45.36%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  90: HV=6315625.98, Dominates Baseline=52.30%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 100: HV=6297147.98, Dominates Baseline=61.43%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 110: HV=6289266.98, Dominates Baseline=67.02%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 120: HV=6289365.98, Dominates Baseline=67.80%
#   [Stagnation] Counter: 5/5
#
# !!! STAGNATION DETECTED. Calling Context-Aware Strategist Agent. !!!
#   [LLM Agent Call] Requesting strategic analysis...
#   [LLM Agent Success] Received strategic advice.
#   [Analyst] Strategy chosen: AGGRESSIVE
#   [LLM Agent Call] Requesting strategic analysis...
#   [LLM Agent Success] Received strategic advice.
#   [Agent Fail] Swap 188 for 32 did NOT improve fitness in snapshot. Old: -9.0227, New: -0.0000.
#   [Fallback] Agent is struggling. Applying random parameter reset.
#   [Metrics] Iter 130: HV=6289872.98, Dominates Baseline=68.51%
#   [Metrics] Iter 140: HV=6290800.98, Dominates Baseline=70.13%
#
# --- RUN 9/10 --- V16 Context-Aware Strategist Agent
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV= 960346.20, Dominates Baseline= 0.00%
#   [Metrics] Iter  10: HV=1343951.75, Dominates Baseline= 5.10%
#   [Metrics] Iter  20: HV=1934420.00, Dominates Baseline=10.54%
#   [Metrics] Iter  30: HV=6103517.40, Dominates Baseline=14.51%
#   [Metrics] Iter  40: HV=5659041.30, Dominates Baseline=25.05%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  50: HV=5790694.30, Dominates Baseline=43.67%
#   [Metrics] Iter  60: HV=5808100.30, Dominates Baseline=45.15%
#   [Metrics] Iter  70: HV=5807658.30, Dominates Baseline=45.15%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  80: HV=6092600.30, Dominates Baseline=48.97%
#   [Metrics] Iter  90: HV=6092611.30, Dominates Baseline=49.75%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 100: HV=6090804.30, Dominates Baseline=50.81%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 110: HV=6085043.30, Dominates Baseline=55.13%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 120: HV=6084901.30, Dominates Baseline=55.34%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 130: HV=6084747.30, Dominates Baseline=55.63%
#   [Stagnation] Counter: 5/5
#
# !!! STAGNATION DETECTED. Calling Context-Aware Strategist Agent. !!!
#   [LLM Agent Call] Requesting strategic analysis...
#   [LLM Agent Success] Received strategic advice.
#   [Analyst] Strategy chosen: BALANCED
#   [LLM Agent Call] Requesting strategic analysis...
#   [LLM Agent Success] Received strategic advice.
#   [Agent Fail] Swap 228 for 58 did NOT improve fitness in snapshot. Old: -8.9347, New: -0.0002.
#   [Fallback] Agent is struggling. Applying random parameter reset.
#   [Metrics] Iter 140: HV=6080785.30, Dominates Baseline=57.96%
#   [Stagnation] Counter: 1/5
#
# --- RUN 10/10 --- V16 Context-Aware Strategist Agent
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV= 911714.70, Dominates Baseline= 0.00%
#   [Metrics] Iter  10: HV=1526198.08, Dominates Baseline= 9.98%
#   [Metrics] Iter  20: HV=2292455.44, Dominates Baseline=14.93%
#   [Metrics] Iter  30: HV=6572079.96, Dominates Baseline=16.99%
#   [Metrics] Iter  40: HV=6360681.96, Dominates Baseline=23.92%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  50: HV=6158110.96, Dominates Baseline=31.00%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  60: HV=6217260.96, Dominates Baseline=33.05%
#   [Metrics] Iter  70: HV=6214244.96, Dominates Baseline=35.03%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  80: HV=6226418.96, Dominates Baseline=35.39%
#   [Metrics] Iter  90: HV=6209421.96, Dominates Baseline=39.63%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 100: HV=6201020.96, Dominates Baseline=48.97%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 110: HV=6198470.96, Dominates Baseline=52.80%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 120: HV=6197986.96, Dominates Baseline=53.01%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 130: HV=6559386.24, Dominates Baseline=54.21%
#   [Metrics] Iter 140: HV=6530184.24, Dominates Baseline=59.52%
#   [Stagnation] Counter: 1/5
#
# Total execution time: 209.49 seconds
# Average time per run: 20.95 seconds
#
# Generating final comparison plot...
# Comparison plot saved to 2502_ResultsMD_V16_pareto_comparison.png

# %%
import matplotlib.pyplot as plt
import json
import os

def load_pareto_front(filename):
    pareto_front = []
    try:
        with open(filename, "r") as f:
            for line in f:
                line = line.strip()
                if line and not line.startswith("#"):
                    pareto_front.append([float(x) for x in line.split()])
    except FileNotFoundError:
        print(f"Warning: {filename} not found.")
    return pareto_front

def plot_run_results(log_file, pareto_file, baseline_file):
    """Generates plots to compare V13 performance against the baseline."""
    # Load data
    with open(log_file, 'r') as f:
        run_log = json.load(f)
    
    v13_pareto = load_pareto_front(pareto_file)
    baseline_pareto = load_pareto_front(baseline_file)
    
    # Calculate baseline hypervolume for reference line
    baseline_hv = calculate_hypervolume(baseline_pareto)

    # Create plots
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10), sharex=True)
    fig.suptitle(f"V13 Critic-Author Agent Performance vs. Baseline\n({log_file.split('_')[0]})", fontsize=16)

    # Plot 1: Hypervolume over Time
    ax1.plot(run_log["iterations"], run_log["hypervolumes"], marker='o', linestyle='-', label='V13 Hypervolume', color='blue')
    ax1.axhline(y=baseline_hv, color='red', linestyle='--', label=f'Baseline Final HV ({baseline_hv:.2f})')
    ax1.set_ylabel("Hypervolume")
    ax1.set_title("Hypervolume Progression")
    ax1.legend()
    ax1.grid(True)

    # Plot 2: Dominance Percentage over Time
    ax2.plot(run_log["iterations"], run_log["dominance_percentages"], marker='s', linestyle='-', color='green', label='V13 Dominance %')
    ax2.set_xlabel("Iteration")
    ax2.set_ylabel("Dominance over Baseline (%)")
    ax2.set_title("Percentage of Baseline Pareto Front Dominated")
    ax2.legend()
    ax2.grid(True)
    ax2.set_ylim(0, 105)

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# --- Main execution for plotting ---
if __name__ == "__main__":
    # Define the files for the 250-item instance
    log_file = "2502_ResultsMD_V13_log.json"
    pareto_file = "2502_ResultsMD.txt"
    baseline_file = "2502_ResultsMD_baseline.txt"

    # Check if the V13 log file exists before plotting
    if os.path.exists(log_file):
        plot_run_results(log_file, pareto_file, baseline_file)
    else:
        print(f"Error: Log file '{log_file}' not found.")
        print("Please run the execution cell first to generate the results.")

# %%
# =========================================================================
# PART 7: COMPREHENSIVE RESULTS ANALYSIS (V10 vs. Baseline)
# =========================================================================

import matplotlib.pyplot as plt
import numpy as np

def dominates(a, b):
    """Returns True if a dominates b (maximization for both objectives)."""
    return all(x >= y for x, y in zip(a, b)) and any(x > y for x, y in zip(a, b))

def get_true_pareto_front(points):
    """Extract the true Pareto front from a set of points."""
    pareto = []
    for i, p in enumerate(points):
        dominated = False
        for j, q in enumerate(points):
            if i != j and dominates(q, p):
                dominated = True
                break
        if not dominated:
            pareto.append(p)
    return pareto

def calculate_hypervolume(points):
    """Calculate a simplified hypervolume metric for comparison."""
    if not points:
        return 0.0
    ref_x = max(p[0] for p in points) * 1.1
    ref_y = max(p[1] for p in points) * 1.1
    sorted_points = sorted(points, key=lambda p: p[0])
    hv = 0.0
    for i in range(len(sorted_points) - 1):
        x1, y1 = sorted_points[i]
        x2, y2 = sorted_points[i + 1]
        hv += (x2 - x1) * (ref_y - y1)
    if sorted_points:
        x_last, y_last = sorted_points[-1]
        hv += (ref_x - x_last) * (ref_y - y_last)
    return hv

def analyze_dominance(baseline_pareto, v10_pareto):
    """Calculate dominance metrics between two Pareto fronts."""
    dominated_baseline_count = 0
    dominated_v10_count = 0
    
    for b_point in baseline_pareto:
        for v_point in v10_pareto:
            if dominates(v_point, b_point):
                dominated_baseline_count += 1
                break
                
    for v_point in v10_pareto:
        for b_point in baseline_pareto:
            if dominates(b_point, v_point):
                dominated_v10_count += 1
                break

    percent_baseline_dominated = (dominated_baseline_count / len(baseline_pareto)) * 100 if baseline_pareto else 0
    percent_v10_dominated = (dominated_v10_count / len(v10_pareto)) * 100 if v10_pareto else 0
    
    return {
        "dominated_baseline_count": dominated_baseline_count,
        "percent_baseline_dominated": percent_baseline_dominated,
        "dominated_v10_count": dominated_v10_count,
        "percent_v10_dominated": percent_v10_dominated
    }

def load_results_and_runtime(filename):
    """Load points and parse runtime from a results file."""
    points = []
    runtime = -1.0
    with open(filename, "r") as f:
        for line in f:
            line = line.strip()
            if line.startswith("# RUNTIME:"):
                try:
                    runtime = float(line.split(":")[1].strip())
                except (IndexError, ValueError):
                    pass
            elif line and not line.startswith("#"):
                try:
                    points.append([float(x) for x in line.split()])
                except ValueError:
                    pass
    return points, runtime

def compare_baseline_vs_v10(original_file, v10_file, title):
    """
    Compare the original baseline results with the new LLM-Strategist V10 results.
    """
    print(f"\n--- Analyzing {title} ---")
    
    # --- Load and Process Results ---
    original_points, _ = load_results_and_runtime(original_file)
    v10_points, v10_runtime = load_results_and_runtime(v10_file)

    if not original_points:
        print(f"  [ERROR] Original file not found or empty: {original_file}")
        return None
    if not v10_points:
        print(f"  [ERROR] V10 file not found or empty: {v10_file}")
        return None

    # --- Calculate Pareto Fronts and Metrics ---
    original_pareto = get_true_pareto_front(original_points)
    v10_pareto = get_true_pareto_front(v10_points)
    
    original_size = len(original_pareto)
    v10_size = len(v10_pareto)
    
    original_hv = calculate_hypervolume(original_pareto)
    v10_hv = calculate_hypervolume(v10_pareto)
    
    # --- Calculate Percentage Improvements ---
    size_improvement = (v10_size - original_size) / original_size * 100 if original_size > 0 else 0
    hv_improvement = (v10_hv - original_hv) / original_hv * 100 if original_hv > 0 else 0
    
    # --- Calculate Dominance ---
    dominance_stats = analyze_dominance(original_pareto, v10_pareto)

    # --- Print Results ---
    print(f"  Original Algorithm:")
    print(f"    Pareto Front Size: {original_size}")
    print(f"    Hypervolume: {original_hv:.2f}")
    print(f"  LLM-Strategist V10 (Intelligent Explorer):")
    print(f"    Pareto Front Size: {v10_size} ({size_improvement:+.2f}%)")
    print(f"    Hypervolume: {v10_hv:.2f} ({hv_improvement:+.2f}%)")
    if v10_runtime > 0:
        print(f"    Total Runtime: {v10_runtime:.2f} seconds")
    print(f"  -------------------------------------------------")
    print(f"  Dominance Analysis:")
    print(f"    Baseline points dominated by V10: {dominance_stats['dominated_baseline_count']} / {original_size} ({dominance_stats['percent_baseline_dominated']:.2f}%)")
    print(f"    V10 points dominated by Baseline: {dominance_stats['dominated_v10_count']} / {v10_size} ({dominance_stats['percent_v10_dominated']:.2f}%)")
    print(f"  -------------------------------------------------")

    # --- Plotting ---
    plt.figure(figsize=(12, 10))
    
    if original_pareto:
        ox, oy = zip(*original_pareto)
        plt.scatter(ox, oy, color='blue', alpha=0.6, s=50, label="Original Baseline")
    if v10_pareto:
        sx, sy = zip(*v10_pareto)
        plt.scatter(sx, sy, color='red', marker='x', s=50, alpha=0.8, label="LLM-Strategist V10")

    plt.xlabel("Objective 1 (Profit 1)", fontsize=12)
    plt.ylabel("Objective 2 (Profit 2)", fontsize=12)
    plt.title(f"{title} - Pareto Front Comparison (V10)", fontsize=16)
    plt.legend(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()
    
    return {
        "title": title,
        "original_size": original_size,
        "v10_size": v10_size,
        "size_improvement": size_improvement,
        "original_hv": original_hv,
        "v10_hv": v10_hv,
        "hv_improvement": hv_improvement,
        "v10_runtime": v10_runtime,
        "dominance_stats": dominance_stats
    }

# --- MAIN EXECUTION ---
print("Starting comprehensive results analysis: Original Baseline vs. LLM-Strategist V10...")

# Define the file names for comparison
files_to_compare = [
    {
        "original": "2502_ResultsMD.txt",
        "v10": "2502_ResultsMD_V16_pareto.txt",
        "title": "250-Item Problem"
    },
    {
        "original": "5002_ResultsMD.txt",
        "v10": "5002_Results_Strategist_v10.txt",
        "title": "500-Item Problem"
    },
    {
        "original": "7502_ResultsMD.txt",
        "v10": "7502_Results_Strategist_v10.txt",
        "title": "750-Item Problem"
    }
]

all_results = []
for files in files_to_compare:
    result = compare_baseline_vs_v10(
        files["original"], 
        files["v10"], 
        files["title"]
    )
    if result:
        all_results.append(result)

# --- Summary of Improvements ---
print("\n" + "="*60)
print("              SUMMARY OF IMPROVEMENTS (V10)")
print("="*60)

if all_results:
    total_hv_improvement = 0
    total_domination_advantage = 0
    for res in all_results:
        print(f"\n{res['title']}:")
        print(f"  Hypervolume Improvement: {res['hv_improvement']:+.2f}%")
        print(f"  Dominance Advantage: {res['dominance_stats']['percent_baseline_dominated'] - res['dominance_stats']['percent_v10_dominated']:+.2f}%")
        if res['v10_runtime'] > 0:
            print(f"  V10 Runtime: {res['v10_runtime']:.2f}s")
        total_hv_improvement += res['hv_improvement']
        total_domination_advantage += (res['dominance_stats']['percent_baseline_dominated'] - res['dominance_stats']['percent_v10_dominated'])

    avg_hv_improvement = total_hv_improvement / len(all_results)
    avg_domination_advantage = total_domination_advantage / len(all_results)
    
    print("\n" + "-"*60)
    print(f"  AVERAGE HV IMPROVEMENT: {avg_hv_improvement:+.2f}%")
    print(f"  AVERAGE DOMINANCE ADVANTAGE: {avg_domination_advantage:+.2f}%")
    print("-"*60)
else:
    print("\nCould not generate a summary as no results were successfully analyzed.")

print("\nAnalysis complete.")
# Out:
# Starting comprehensive results analysis: Original Baseline vs. LLM-Strategist V10...
#
# --- Analyzing 250-Item Problem ---
#   Original Algorithm:
#     Pareto Front Size: 212
#     Hypervolume: 6614986.88
#   LLM-Strategist V10 (Intelligent Explorer):
#     Pareto Front Size: 269 (+26.89%)
#     Hypervolume: 6553339.36 (-0.93%)
#     Total Runtime: 209.49 seconds
#   -------------------------------------------------
#   Dominance Analysis:
#     Baseline points dominated by V10: 156 / 212 (73.58%)
#     V10 points dominated by Baseline: 46 / 269 (17.10%)
#   -------------------------------------------------
# --- Analyzing 500-Item Problem ---
#   Original Algorithm:
#     Pareto Front Size: 369
#     Hypervolume: 23044962.94
#   LLM-Strategist V10 (Intelligent Explorer):
#     Pareto Front Size: 334 (-9.49%)
#     Hypervolume: 22392900.94 (-2.83%)
#     Total Runtime: 888.23 seconds
#   -------------------------------------------------
#   Dominance Analysis:
#     Baseline points dominated by V10: 191 / 369 (51.76%)
#     V10 points dominated by Baseline: 141 / 334 (42.22%)
#   -------------------------------------------------
# --- Analyzing 750-Item Problem ---
#   Original Algorithm:
#     Pareto Front Size: 552
#     Hypervolume: 56877706.67
#   LLM-Strategist V10 (Intelligent Explorer):
#     Pareto Front Size: 561 (+1.63%)
#     Hypervolume: 55318411.65 (-2.74%)
#     Total Runtime: 925.25 seconds
#   -------------------------------------------------
#   Dominance Analysis:
#     Baseline points dominated by V10: 222 / 552 (40.22%)
#     V10 points dominated by Baseline: 294 / 561 (52.41%)
#   -------------------------------------------------
# ============================================================
#               SUMMARY OF IMPROVEMENTS (V10)
# ============================================================
#
# 250-Item Problem:
#   Hypervolume Improvement: -0.93%
#   Dominance Advantage: +56.48%
#   V10 Runtime: 209.49s
#
# 500-Item Problem:
#   Hypervolume Improvement: -2.83%
#   Dominance Advantage: +9.55%
#   V10 Runtime: 888.23s
#
# 750-Item Problem:
#   Hypervolume Improvement: -2.74%
#   Dominance Advantage: -12.19%
#   V10 Runtime: 925.25s
#
# ------------------------------------------------------------
#   AVERAGE HV IMPROVEMENT: -2.17%
#   AVERAGE DOMINANCE ADVANTAGE: +17.95%
# ------------------------------------------------------------
#
# Analysis complete.

# %%
# %%cython
#
# # =========================================================================
# # PART 1: C LIBRARY IMPORTS AND GLOBAL DEFINITIONS
# # =========================================================================
#
# from libc.stdlib cimport malloc, free, srand, rand
# from libc.string cimport memset
# from libc.math cimport exp
#
# # Import Python libraries needed for the LLM part
# import time
# import json
# import ollama
# import numpy as np
# import hashlib
# from collections import defaultdict
#
# # Constants for the enhanced algorithm
# cdef int NBITEMS = 250
# cdef int ni = 250
# cdef int L = 5
# cdef double LARGE = 10e50
# cdef float smallValue = 0.0000001
# cdef double kappa = 0.05
# cdef int alpha = 10
# cdef int paretoIni = 28000
#
# # Data structures (MODIFIED to track more info)
# cdef struct ind:
#     int nombr_nonpris
#     int nombr
#     int rank
#     float fitnessbest
#     float fitness
#     int explored
#     double *f
#     double *capa
#     double *v
#     int *d
#     int *Items
#     # V13: Added fields for tracking agent intervention
#     int age
#     int improvement_count
#     int llm_enhanced
#     int last_improvement_iteration
#
# cdef struct pop:
#     int size
#     int maxsize
#     ind **ind_array
#
# # Global variables for the problem instance (RENAMED to avoid name collision)
# cdef int nf = 2
# cdef double *capacities = NULL
# cdef int **g_weights = NULL  # RENAMED from 'weights'
# cdef int **g_profits = NULL  # RENAMED from 'profits'
# cdef double *vector_weight = NULL
# cdef double max_bound = 0.0
# cdef double **OBJ_Weights = NULL
# cdef int nombreLIGNE = 0
# cdef int nextLn = 0
# cdef int inv = 0
# cdef int OBJ_Weights_lines = 0
#
# # =========================================================================
# # PART 2: CORE CYTHON HELPER FUNCTIONS (Unchanged, but with renamed vars)
# # =========================================================================
#
# def seed(int x):
#     srand(x)
#
# cdef int irand(int range_val):
#     return rand() % range_val
#
# cdef void *chk_malloc(size_t size):
#     cdef void *return_value = malloc(size)
#     if return_value == NULL:
#         raise MemoryError("Out of memory.")
#     memset(return_value, 0, size)
#     return return_value
#
# cdef pop *create_pop(int maxsize, int nf):
#     cdef int i
#     cdef pop *pp = <pop *>chk_malloc(sizeof(pop))
#     pp.size = 0
#     pp.maxsize = maxsize
#     pp.ind_array = <ind **>chk_malloc(maxsize * sizeof(void*))
#     for i in range(maxsize):
#         pp.ind_array[i] = NULL
#     return pp
#
# cdef ind *create_ind(int nf):
#     cdef int i
#     cdef ind *p_ind = <ind *>chk_malloc(sizeof(ind))
#     p_ind.nombr_nonpris = 0
#     p_ind.nombr = 0
#     p_ind.rank = 0
#     p_ind.fitnessbest = -1.0
#     p_ind.fitness = -1.0
#     p_ind.explored = 0
#     # V13: Initialize new tracking fields
#     p_ind.age = 0
#     p_ind.improvement_count = 0
#     p_ind.llm_enhanced = 0
#     p_ind.last_improvement_iteration = 0
#     p_ind.f = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.capa = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.v = <double *>chk_malloc(nf * sizeof(double))
#     p_ind.d = <int *>chk_malloc(ni * sizeof(int))
#     p_ind.Items = <int *>chk_malloc(ni * sizeof(int))
#     for i in range(ni):
#         p_ind.Items[i] = 0
#         p_ind.d[i] = 0
#     for i in range(nf):
#         p_ind.f[i] = 0.0
#         p_ind.capa[i] = 0.0
#         p_ind.v[i] = 0.0
#     return p_ind
#
# cdef ind *ind_copy(ind *i):
#     cdef ind *p_ind = create_ind(nf)
#     cdef int k
#     p_ind.nombr_nonpris = i.nombr_nonpris
#     p_ind.nombr = i.nombr
#     p_ind.rank = i.rank
#     p_ind.fitnessbest = i.fitnessbest
#     p_ind.fitness = i.fitness
#     p_ind.explored = i.explored
#     # V13: Copy new tracking fields
#     p_ind.age = i.age
#     p_ind.improvement_count = i.improvement_count
#     p_ind.llm_enhanced = i.llm_enhanced
#     p_ind.last_improvement_iteration = i.last_improvement_iteration
#     for k in range(nf):
#         p_ind.f[k] = i.f[k]
#         p_ind.v[k] = i.v[k]
#         p_ind.capa[k] = i.capa[k]
#     for k in range(ni):
#         p_ind.d[k] = i.d[k]
#         p_ind.Items[k] = i.Items[k]
#     return p_ind
#
# cdef void free_ind(ind *p_ind):
#     if p_ind != NULL:
#         free(p_ind.d)
#         free(p_ind.f)
#         free(p_ind.capa)
#         free(p_ind.v)
#         free(p_ind.Items)
#         free(p_ind)
#
# cdef void complete_free_pop(pop *pp):
#     cdef int i
#     if pp != NULL:
#         if pp.ind_array != NULL:
#             for i in range(pp.size):
#                 if pp.ind_array[i] != NULL:
#                     free_ind(pp.ind_array[i])
#                     pp.ind_array[i] = NULL
#             free(pp.ind_array)
#         free(pp)
#
# cdef void cleanup_globals():
#     global capacities, g_weights, g_profits, vector_weight, OBJ_Weights, OBJ_Weights_lines, nf, ni
#     if capacities != NULL:
#         free(capacities)
#         capacities = NULL
#     if g_weights != NULL:
#         for i in range(nf):
#             if g_weights[i] != NULL:
#                 free(g_weights[i])
#         free(g_weights)
#         g_weights = NULL
#     if g_profits != NULL:
#         for i in range(nf):
#             if g_profits[i] != NULL:
#                 free(g_profits[i])
#         free(g_profits)
#         g_profits = NULL
#     if vector_weight != NULL:
#         free(vector_weight)
#         vector_weight = NULL
#     if OBJ_Weights != NULL:
#         for i in range(nf):
#             if OBJ_Weights[i] != NULL:
#                 free(OBJ_Weights[i])
#         free(OBJ_Weights)
#         OBJ_Weights = NULL
#     OBJ_Weights_lines = 0
#     nf = 0
#     ni = 0
#
# cdef int non_dominated(ind *p_ind_a, ind *p_ind_b):
#     cdef int i
#     cdef int a_is_good = -1
#     cdef int equal = 1
#     for i in range(nf):
#         if p_ind_a.f[i] > p_ind_b.f[i]:
#             a_is_good = 1
#         if p_ind_a.f[i] != p_ind_b.f[i]:
#             equal = 0
#     if equal:
#         return 0
#     return a_is_good
#
# cdef double calcAddEpsIndicator(ind *p_ind_a, ind *p_ind_b):
#     global max_bound
#     cdef int i
#     cdef double eps
#     cdef double temp_eps
#     if max_bound == 0.0:
#         max_bound = 1e-8
#     eps = (p_ind_a.v[0]/max_bound)-(p_ind_b.v[0]/max_bound)
#     for i in range(1, nf):
#         temp_eps = (p_ind_a.v[i]/max_bound)-(p_ind_b.v[i]/max_bound)
#         if temp_eps > eps:
#             eps = temp_eps
#     return eps
#
# cdef void init_fitness(ind *x):
#     x.fitness = 0.0
#
# cdef void update_fitness(ind *x, double I):
#     x.fitness -= exp(-I / kappa)
#
# cdef double update_fitness_return(double f, double I):
#     return f - exp(-I / kappa)
#
# cdef int delete_fitness(ind *x, double I):
#     x.fitness += exp(-I / kappa)
#     return 0
#
# cdef void compute_ind_fitness(ind *x, pop *SP):
#     cdef int j
#     init_fitness(x)
#     for j in range(SP.size):
#         if SP.ind_array[j] != x:
#             update_fitness(x, calcAddEpsIndicator(SP.ind_array[j], x))
#
# cdef void compute_all_fitness(pop *SP):
#     cdef int i
#     for i in range(SP.size):
#         compute_ind_fitness(SP.ind_array[i], SP)
#
# # =========================================================================
# # PART 3: PROBLEM LOADING AND EVALUATION FUNCTIONS (Unchanged, but with renamed vars)
# # =========================================================================
#
# def loadMOKP(char *filename):
#     global nf, ni, capacities, g_weights, g_profits
#     cdef int i, f
#     with open(filename.decode(), "r") as source:
#         _nf, _ni = [int(x) for x in source.readline().split()]
#         nf = _nf
#         ni = _ni
#         capacities = <double *>chk_malloc(nf * sizeof(double))
#         g_weights = <int **>chk_malloc(nf * sizeof(void*))
#         g_profits = <int **>chk_malloc(nf * sizeof(void*))
#         for f in range(nf):
#             capacities[f] = float(source.readline().strip())
#             g_weights[f] = <int *>chk_malloc(ni * sizeof(int))
#             g_profits[f] = <int *>chk_malloc(ni * sizeof(int))
#             for i in range(ni):
#                 source.readline()
#                 g_weights[f][i] = int(source.readline().strip())
#                 g_profits[f][i] = int(source.readline().strip())
#
# def read_weights_file(char *filename):
#     global OBJ_Weights, nombreLIGNE, nf, OBJ_Weights_lines
#     cdef int i, j, nlines
#     with open(filename.decode(), "r") as f:
#         lines = [line for line in f if line.strip()]
#     nlines = len(lines)
#     OBJ_Weights = <double **>chk_malloc(nf * sizeof(void*))
#     for i in range(nf):
#         OBJ_Weights[i] = <double *>chk_malloc(nlines * sizeof(double))
#     for i, line in enumerate(lines):
#         vals = line.strip().split()
#         for j in range(nf):
#             OBJ_Weights[j][i] = float(vals[j])
#     nombreLIGNE = nlines - 1
#     OBJ_Weights_lines = nlines
#
# cdef void dynamic_weight_allpop():
#     global vector_weight, OBJ_Weights, nombreLIGNE, nf, nextLn
#     cdef int i
#     if vector_weight == NULL:
#         vector_weight = <double *>chk_malloc(nf * sizeof(double))
#     for i in range(nf):
#         vector_weight[i] = OBJ_Weights[i][nextLn]
#     if nextLn == nombreLIGNE:
#         nextLn = 0
#     else:
#         nextLn += 1
#
# cdef void choose_weight():
#     dynamic_weight_allpop()
#
# cdef void random_init_ind(ind *x):
#     cdef int j, r, tmp
#     for j in range(ni):
#         x.d[j] = j
#     for j in range(ni):
#         r = irand(ni)
#         tmp = x.d[r]
#         x.d[r] = x.d[j]
#         x.d[j] = tmp
#
# cdef void evaluate(ind *x):
#     cdef int j, l, k, faisable
#     x.nombr = 0
#     x.nombr_nonpris = 0
#     for j in range(nf):
#         x.capa[j] = 0.0
#         x.f[j] = 0.0
#     for j in range(ni):
#         l = 0
#         faisable = 1
#         while l < nf and faisable == 1:
#             if x.capa[l] + g_weights[l][x.d[j]] > capacities[l]:
#                 faisable = 0
#             l += 1
#         if faisable == 1:
#             for k in range(nf):
#                 x.capa[k] += g_weights[k][x.d[j]]
#                 x.f[k] += g_profits[k][x.d[j]]
#             x.Items[x.d[j]] = 1
#             x.nombr += 1
#         else:
#             x.Items[x.d[j]] = 0
#             x.nombr_nonpris += 1
#
# cdef void P_init_pop(pop *SP, pop *Sarchive, int alpha):
#     cdef int i, x, tmp, t
#     t = max(alpha, Sarchive.size)
#     cdef int* shuffle = <int *>chk_malloc(t * sizeof(int))
#     for i in range(t):
#         shuffle[i] = i
#     for i in range(t):
#         x = irand(alpha)
#         tmp = shuffle[i]
#         shuffle[i] = shuffle[x]
#         shuffle[x] = tmp
#     SP.size = alpha
#     if Sarchive.size > alpha:
#         for i in range(alpha):
#             SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#     else:
#         for i in range(alpha):
#             if shuffle[i] < Sarchive.size:
#                 SP.ind_array[i] = ind_copy(Sarchive.ind_array[shuffle[i]])
#             else:
#                 SP.ind_array[i] = create_ind(nf)
#                 random_init_ind(SP.ind_array[i])
#                 evaluate(SP.ind_array[i])
#     free(shuffle)
#
# cdef int extractPtoArchive(pop *P, pop *archive):
#     cdef int i, j, dom, t, convergence_rate
#     t = archive.size + P.size
#     archiveAndP = create_pop(t, nf)
#     convergence_rate = 0
#     for i in range(archive.size):
#         archiveAndP.ind_array[i] = archive.ind_array[i]
#     for i in range(P.size):
#         archiveAndP.ind_array[i + archive.size] = ind_copy(P.ind_array[i])
#     archiveAndP.size = t
#     archive.size = 0
#     for i in range(t):
#         for j in range(t):
#             if i != j:
#                 dom = non_dominated(archiveAndP.ind_array[i], archiveAndP.ind_array[j])
#                 if dom == -1 or (dom == 0 and i > j):
#                     break
#         else:
#             archive.ind_array[archive.size] = ind_copy(archiveAndP.ind_array[i])
#             archive.size += 1
#             if i >= t - P.size:
#                 convergence_rate += 1
#     complete_free_pop(archiveAndP)
#     return convergence_rate
#
# cdef double calcMaxbound(pop *SP, int size):
#     global max_bound
#     cdef int i, j
#     SP.size = size
#     cdef double max_b = SP.ind_array[0].v[0]
#     for i in range(SP.size):
#         for j in range(nf):
#             if max_b < SP.ind_array[i].v[j]:
#                 max_b = SP.ind_array[i].v[j]
#     if max_b == 0.0:
#         max_b = 1e-8
#     max_bound = max_b
#     return max_b
#
# cdef void calcul_weight(pop *SP, int size):
#     cdef int i, j
#     for i in range(SP.size):
#         for j in range(nf):
#             SP.ind_array[i].v[j] = SP.ind_array[i].f[j] * vector_weight[j]
#
# cdef int compute_fitness_and_select(pop *SP, ind *x, int size):
#     cdef int i, worst
#     cdef double worst_fit, fit_tmp
#     SP.size = size
#     x.fitness = 0
#     compute_ind_fitness(x, SP)
#     worst_fit = x.fitness
#     worst = -1
#     for i in range(SP.size):
#         fit_tmp = update_fitness_return(SP.ind_array[i].fitness, calcAddEpsIndicator(x, SP.ind_array[i]))
#         if fit_tmp > worst_fit:
#             worst = i
#             worst_fit = fit_tmp
#     fit_tmp = x.fitness
#     if worst == -1:
#         return -1
#     else:
#         for i in range(SP.size):
#             delete_fitness(SP.ind_array[i], calcAddEpsIndicator(SP.ind_array[worst], SP.ind_array[i]))
#             update_fitness(SP.ind_array[i], calcAddEpsIndicator(x, SP.ind_array[i]))
#         delete_fitness(x, calcAddEpsIndicator(SP.ind_array[worst], x))
#         free_ind(SP.ind_array[worst])
#         SP.ind_array[worst] = ind_copy(x)
#         if fit_tmp - worst_fit > smallValue:
#             return worst
#         else:
#             return -1
#
# # =========================================================================
# # PART 4: MODULAR LOCAL SEARCH & EVALUATION HELPERS (Unchanged, but with renamed vars)
# # =========================================================================
#
# cdef void original_swap_heuristic(pop *SP, pop *Sarchive, int size, int L_val, double kappa_val):
#     """The original logic from Indicator_local_search1, now modular."""
#     cdef ind *x
#     cdef ind *y
#     cdef int i, j, r, t, k, l, v, sol, mino, mp, maxp, consistant, pos, stop, convergence, ii, tmp_pris, tmp_nonpris, taille, feasible, tv, IM
#     cdef int* remplace = <int *>chk_malloc(L_val * sizeof(int))
#     SP.size = size
#     extractPtoArchive(SP, Sarchive)
#     while True:
#         convergence = 0
#         for i in range(SP.size):
#             if not SP.ind_array[i].explored:
#                 x = ind_copy(SP.ind_array[i])
#                 j = 0
#                 while j < x.nombr:
#                     for l in range(L_val):
#                         remplace[l] = 0
#                     while True:
#                         mino = irand(ni)
#                         if x.Items[mino] == 1:
#                             break
#                     x.Items[mino] = 0
#                     x.nombr -= 1
#                     x.nombr_nonpris += 1
#                     for r in range(nf):
#                         x.capa[r] -= g_weights[r][mino]
#                         x.f[r] -= g_profits[r][mino]
#                     IM = 0
#                     taille = 0
#                     while IM < L_val:
#                         while True:
#                             maxp = irand(ni)
#                             if x.Items[maxp] == 0:
#                                 break
#                         if maxp != mino:
#                             consistant = 1
#                             r = 0
#                             while r < nf and consistant == 1:
#                                 if x.capa[r] + g_weights[r][maxp] > capacities[r]:
#                                     consistant = 0
#                                 r += 1
#                             if consistant == 1:
#                                 feasible = 1
#                                 r = 0
#                                 while r < taille and feasible:
#                                     if maxp == remplace[r]:
#                                         feasible = 0
#                                     r += 1
#                                 if feasible == 1:
#                                     remplace[taille] = maxp
#                                     taille += 1
#                                     x.Items[maxp] = 1
#                                     x.nombr_nonpris -= 1
#                                     x.nombr += 1
#                                     for r in range(nf):
#                                         x.capa[r] += g_weights[r][maxp]
#                                         x.f[r] += g_profits[r][maxp]
#                         IM += 1
#                     for tv in range(nf):
#                         x.v[tv] = x.f[tv] * vector_weight[tv]
#                     max_bound = calcMaxbound(SP, SP.size)
#                     sol = compute_fitness_and_select(SP, x, SP.size)
#                     if sol != -1:
#                         j = x.nombr + 1
#                         if sol > i and i + 1 < SP.size:
#                             y = SP.ind_array[i + 1]
#                             SP.ind_array[i + 1] = SP.ind_array[sol]
#                             SP.ind_array[sol] = y
#                             i += 1
#                         break
#                     elif sol == -1:
#                         x.Items[mino] = 1
#                         x.nombr_nonpris -= 1
#                         x.nombr += 1
#                         for r in range(nf):
#                             x.capa[r] += g_weights[r][mino]
#                             x.f[r] += g_profits[r][mino]
#                         if taille >= 1:
#                             for r in range(taille):
#                                 x.Items[remplace[r]] = 0
#                                 x.nombr -= 1
#                                 x.nombr_nonpris += 1
#                                 for t in range(nf):
#                                     x.capa[t] -= g_weights[t][remplace[r]]
#                                     x.f[t] -= g_profits[t][remplace[r]]
#                                     x.v[t] = x.f[t] * vector_weight[tv]
#                     j += 1
#                 tmp_pris = x.nombr
#                 tmp_nonpris = x.nombr_nonpris
#                 free_ind(x)
#                 if j == tmp_pris:
#                     SP.ind_array[i].explored = 1
#         convergence = extractPtoArchive(SP, Sarchive)
#         if not convergence:
#             break
#     free(remplace)
#
# cdef void adaptive_local_search(pop *SP, pop *Sarchive, int size, str heuristic_name, int L_val, double kappa_val):
#     """Dispatches to the correct local search heuristic."""
#     if heuristic_name == "original_swap":
#         original_swap_heuristic(SP, Sarchive, size, L_val, kappa_val)
#     else:
#         # Fallback to original
#         original_swap_heuristic(SP, Sarchive, size, L_val, kappa_val)
#
# cdef dict extract_solution_data_for_python(ind *solution_ind):
#     cdef int i
#     data = {
#         'f': [solution_ind.f[i] for i in range(nf)],
#         'capa': [solution_ind.capa[i] for i in range(nf)],
#         'nombr': solution_ind.nombr,
#         'Items': [solution_ind.Items[i] for i in range(ni)]
#     }
#     return data
#
# def extract_problem_features_for_llm():
#     if capacities == NULL or g_weights == NULL or g_profits == NULL:
#         return None
#     total_capacity = sum(capacities[i] for i in range(nf))
#     total_avg_weight = sum(sum(g_weights[obj][i] for i in range(ni)) for obj in range(nf)) / nf
#     capacity_tightness = total_avg_weight / total_capacity if total_capacity > 0 else 0
#     profit_variances = []
#     weight_variances = []
#     for obj in range(nf):
#         profits_list = [g_profits[obj][i] for i in range(ni)]
#         weights_list = [g_weights[obj][i] for i in range(ni)]
#         profit_variances.append(np.var(profits_list))
#         weight_variances.append(np.var(weights_list))
#     features = {
#         "num_items": ni, "num_objectives": nf, "capacity_tightness": round(capacity_tightness, 4),
#         "avg_profit_variance": round(np.mean(profit_variances), 2),
#         "avg_weight_variance": round(np.mean(weight_variances), 2),
#     }
#     return features
#
# # =========================================================================
# # PART 5: THE LLM CRITIC-AUTHOR AGENT (V15 - ENHANCED PROMPT)
# # =========================================================================
#
# class CriticAuthorAgent:
#     """
#     V15: The Critic-Author Agent with enhanced multi-objective prompting.
#     """
#     def __init__(self, model_name="llama3:latest"):
#         self.model_name = model_name
#         self.cache = {}
#
#     def _call_llm(self, prompt, cache_key):
#         if cache_key in self.cache:
#             print(f"  [LLM Cache Hit] Using cached response.")
#             return self.cache[cache_key]
#         print(f"  [LLM Agent Call] Requesting a move suggestion...")
#
#         try:
#             response = ollama.generate(model=self.model_name, prompt=prompt, format='json')
#             response_text = response.get('response', '').strip()
#
#             if not response_text:
#                 print("  [LLM Error] Empty response.")
#                 return None
#             result = json.loads(response_text)
#             self.cache[cache_key] = result
#             print(f"  [LLM Agent Success] Received a suggestion.")
#             return result
#         except (json.JSONDecodeError, Exception) as e:
#             print(f"  [LLM Agent Error] {e}.")
#             return None
#
#     def suggest_move_and_state_v2(self, solution_data, problem_data):
#         """
#         V15: Asks the LLM to choose the best swap with enhanced multi-objective context.
#         """
#         cache_key = f"move_v15_{hash(str(solution_data['Items']) + str(problem_data))}"
#
#         weakest_obj_idx = 0
#         if solution_data['f'][1] < solution_data['f'][0]:
#             weakest_obj_idx = 1
#
#         candidates = []
#         items_in_knapsack_indices = [i for i, val in enumerate(solution_data['Items']) if val == 1]
#         items_not_in_knapsack_indices = [i for i, val in enumerate(solution_data['Items']) if val == 0]
#
#         worst_items_in_knapsack = sorted(
#             items_in_knapsack_indices,
#             key=lambda i: g_profits[weakest_obj_idx][i]
#         )[:5]
#
#         best_items_not_in_knapsack = sorted(
#             items_not_in_knapsack_indices,
#             key=lambda i: g_profits[weakest_obj_idx][i],
#             reverse=True
#         )[:5]
#
#         for remove_idx in worst_items_in_knapsack:
#             for add_idx in best_items_not_in_knapsack:
#                 new_capa_obj1 = solution_data['capa'][0] - g_weights[0][remove_idx] + g_weights[0][add_idx]
#                 new_capa_obj2 = solution_data['capa'][1] - g_weights[1][remove_idx] + g_weights[1][add_idx]
#
#                 is_feasible = (new_capa_obj1 <= capacities[0] and new_capa_obj2 <= capacities[1])
#
#                 if is_feasible:
#                     delta_f1 = g_profits[0][add_idx] - g_profits[0][remove_idx]
#                     delta_f2 = g_profits[1][add_idx] - g_profits[1][remove_idx]
#
#                     candidates.append({
#                         "remove": remove_idx,
#                         "add": add_idx,
#                         "delta_f1": delta_f1,
#                         "delta_f2": delta_f2,
#                     })
#
#         if not candidates:
#             return {"item_to_remove": -1, "item_to_add": -1, "state": None}
#
#         prompt = f"""
# You are an expert analyst for a multi-objective knapsack problem. Your goal is to choose the best swap from a list of candidates.
#
# PROBLEM CONTEXT:
# - The current solution is weak on Objective {weakest_obj_idx + 1}.
# - You must improve this objective, but WITHOUT SIGNIFICANTLY HARMING the other objective.
#
# CANDIDATE SWAPS:
# Here is a list of feasible swaps. 'delta_f1' and 'delta_f2' represent the change in profit for Objective 1 and 2, respectively. A positive number is an improvement.
# {json.dumps(candidates, indent=2)}
#
# YOUR TASK:
# Analyze the trade-offs. Choose the swap that provides the best improvement for Objective {weakest_obj_idx + 1}.
# Crucially, if multiple swaps improve Objective {weakest_obj_idx + 1}, choose the one that has the LEAST NEGATIVE (or most positive) impact on the other objective.
#
# Prioritize swaps that are beneficial for both objectives, or have a large gain for the weak objective and a small loss for the strong one.
#
# Respond ONLY with a JSON object containing 'item_to_remove' and 'item_to_add'.
# Example: {{"item_to_remove": 123, "item_to_add": 45}}
# """
#         result = self._call_llm(prompt, cache_key)
#
#         if result:
#             result['state'] = solution_data
#         return result
#
# cdef bint perform_llm_suggested_swap_with_state(pop *P, int *items_snapshot, double *f_snapshot, double *capa_snapshot, int nombr_snapshot, int item_to_remove, int item_to_add):
#     """
#     V14: Performs the LLM-suggested swap on a fresh copy created from a snapshot.
#     Returns True on success, False on failure.
#     """
#     if P == NULL or P.size == 0:
#         return False
#
#     cdef ind *modified_solution = NULL
#     cdef bint is_feasible
#     cdef int sol_idx
#     cdef int i
#
#     if items_snapshot[item_to_remove] != 1 or items_snapshot[item_to_add] != 0:
#         print(f"  [Agent Fail] Invalid swap suggestion (remove not in knapsack or add already in) based on snapshot.")
#         return False
#
#     modified_solution = create_ind(nf)
#
#     for i in range(ni):
#         modified_solution.Items[i] = items_snapshot[i]
#     for i in range(nf):
#         modified_solution.f[i] = f_snapshot[i]
#         modified_solution.capa[i] = capa_snapshot[i]
#     modified_solution.nombr = nombr_snapshot
#
#     for i in range(nf):
#         modified_solution.capa[i] -= g_weights[i][item_to_remove]
#         modified_solution.f[i] -= g_profits[i][item_to_remove]
#     modified_solution.Items[item_to_remove] = 0
#     modified_solution.nombr -= 1
#
#     is_feasible = 1
#     for i in range(nf):
#         if modified_solution.capa[i] + g_weights[i][item_to_add] > capacities[i]:
#             is_feasible = 0
#             break
#
#     if not is_feasible:
#         free_ind(modified_solution)
#         print(f"  [Agent Fail] Swap {item_to_remove} for {item_to_add} was not feasible based on snapshot.")
#         return False
#
#     for i in range(nf):
#         modified_solution.capa[i] += g_weights[i][item_to_add]
#         modified_solution.f[i] += g_profits[i][item_to_add]
#     modified_solution.Items[item_to_add] = 1
#     modified_solution.nombr += 1
#     modified_solution.llm_enhanced = 1
#
#     calcul_weight(P, P.size)
#     sol_idx = compute_fitness_and_select(P, modified_solution, P.size)
#
#     free_ind(modified_solution)
#
#     if sol_idx != -1:
#         print(f"  [Agent Success] Swapped item {item_to_remove} for {item_to_add} based on snapshot. Solution improved.")
#         return True
#     else:
#         print(f"  [Agent Fail] Swap {item_to_remove} for {item_to_add} based on snapshot did not improve solution.")
#         return False
#
# # =========================================================================
# # PART 6: MAIN EXECUTION FUNCTION (V15 - FINAL)
# # =========================================================================
# def load_baseline_pareto_front(filename):
#     """A pure Python function to load the baseline data."""
#     baseline_pareto_front = []
#     try:
#         with open(filename, "r") as f:
#             for line in f:
#                 if line.strip() and not line.startswith("#"):
#                     baseline_pareto_front.append([float(x) for x in line.split()])
#     except FileNotFoundError:
#         print(f"Warning: Baseline file {filename} not found. Dominance will be 0%.")
#     return baseline_pareto_front
#
# def run_critic_author_moacp_v15(instance_file, weights_file, nbitems, num_objectives, output_file_base, baseline_pareto_front):
#     """
#     V15: The "Critic-Author Agent" with enhanced multi-objective prompting.
#     """
#     cdef int i, j, item_to_remove, item_to_add
#     cdef pop *P
#     cdef pop *solutions
#     cdef pop *archive
#     cdef ind *x
#     cdef int it
#     cdef int *items_c_array
#     cdef double *f_c_array
#     cdef double *capa_c_array
#
#     NBL = 150
#     NRUNS = 10
#     METRIC_INTERVAL = 10
#     STAGNATION_WINDOW = 5
#     HV_IMPROVEMENT_THRESHOLD = 100.0
#     TIME_BUDGET_SECONDS = 600
#
#     total_time = 0
#     start_time = time.time()
#
#     for run in range(1, NRUNS + 1):
#         print(f"\n--- RUN {run}/{NRUNS} --- V15 Critic-Author Agent (Final)")
#         print(f"Instance: {instance_file.decode()}, Items: {nbitems}, Objectives: {num_objectives}")
#
#         global nf, ni, NBITEMS, alpha, paretoIni, L, kappa, nombreLIGNE, nextLn, inv, vector_weight
#         global capacities, g_weights, g_profits, OBJ_Weights
#         NBITEMS = nbitems
#         ni = nbitems
#         nf = num_objectives
#         alpha = 10
#         paretoIni = 28000
#         L = 5
#         kappa = 0.05
#
#         seed(run)
#         loadMOKP(instance_file)
#         read_weights_file(weights_file)
#
#         agent = CriticAuthorAgent()
#         problem_features = extract_problem_features_for_llm()
#         print(f"  [Problem Features] {json.dumps(problem_features, indent=4)}")
#
#         run_log = {"iterations": [], "hypervolumes": [], "dominance_percentages": []}
#         last_hv = 0.0
#         stagnation_counter = 0
#
#         P = create_pop(paretoIni, nf)
#         it = 0
#         while it < NBL and (time.time() - start_time) < TIME_BUDGET_SECONDS:
#             solutions = create_pop(alpha, nf)
#             archive = create_pop(paretoIni, nf)
#             choose_weight()
#             P_init_pop(solutions, P, alpha)
#             extractPtoArchive(solutions, P)
#             calcul_weight(solutions, alpha)
#             calcMaxbound(solutions, alpha)
#             compute_all_fitness(solutions)
#
#             adaptive_local_search(solutions, archive, alpha, "original_swap", L, kappa)
#
#             extractPtoArchive(archive, P)
#             complete_free_pop(solutions)
#             complete_free_pop(archive)
#
#             if it % METRIC_INTERVAL == 0:
#                 current_pareto = []
#                 for i in range(P.size):
#                     current_pareto.append([P.ind_array[i].f[0], P.ind_array[i].f[1]])
#
#                 current_hv = calculate_hypervolume(current_pareto)
#                 dominance = calculate_dominance_percentage(current_pareto, baseline_pareto_front)
#
#                 run_log["iterations"].append(it)
#                 run_log["hypervolumes"].append(current_hv)
#                 run_log["dominance_percentages"].append(dominance)
#
#                 print(f"  [Metrics] Iter {it:3d}: HV={current_hv:10.2f}, Dominates Baseline={dominance:5.2f}%")
#
#                 hv_change = current_hv - last_hv
#                 if hv_change < HV_IMPROVEMENT_THRESHOLD:
#                     stagnation_counter += 1
#                     print(f"  [Stagnation] Counter: {stagnation_counter}/{STAGNATION_WINDOW}")
#                 else:
#                     stagnation_counter = 0
#
#                 last_hv = current_hv
#
#                 # --- THE CRITIC-AUTHOR INTERVENTION (V15 - FINAL) ---
#                 if stagnation_counter >= STAGNATION_WINDOW:
#                     print("\n!!! STAGNATION DETECTED. Calling Critic-Author Agent (V15) for targeted refinement. !!!")
#
#                     agent_response = agent.suggest_move_and_state_v2(extract_solution_data_for_python(P.ind_array[0]), problem_features)
#
#                     if agent_response and 'state' in agent_response and agent_response['state'] is not None:
#                         item_to_remove = agent_response.get('item_to_remove', -1)
#                         item_to_add = agent_response.get('item_to_add', -1)
#                         solution_state = agent_response['state']
#
#                         if 0 <= item_to_remove < ni and 0 <= item_to_add < ni and item_to_remove != item_to_add:
#                             items_c_array = <int *>chk_malloc(ni * sizeof(int))
#                             f_c_array = <double *>chk_malloc(nf * sizeof(double))
#                             capa_c_array = <double *>chk_malloc(nf * sizeof(double))
#
#                             for i in range(ni):
#                                 items_c_array[i] = solution_state['Items'][i]
#                             for i in range(nf):
#                                 f_c_array[i] = solution_state['f'][i]
#                                 capa_c_array[i] = solution_state['capa'][i]
#
#                             success = perform_llm_suggested_swap_with_state(
#                                 P,
#                                 items_c_array,
#                                 f_c_array,
#                                 capa_c_array,
#                                 solution_state['nombr'],
#                                 item_to_remove,
#                                 item_to_add
#                             )
#
#                             free(items_c_array)
#                             free(f_c_array)
#                             free(capa_c_array)
#
#                             if success:
#                                 stagnation_counter = 0
#                                 L = 8
#                                 kappa = 0.08
#                             else:
#                                 pass
#                         else:
#                             print("  [Agent Fail] Received invalid item indices from LLM.")
#                     else:
#                         print("  [Agent Fail] Could not parse a valid response from LLM.")
#
#                     if stagnation_counter >= STAGNATION_WINDOW:
#                         print("  [Fallback] Applying random parameter reset.")
#                         L = 15
#                         kappa = 0.2
#                         stagnation_counter = 0
#
#             it += 1
#
#         with open(f"{output_file_base}_V15_pareto.txt", "a") as f:
#             f.write(f"\n# RUN {run}\n")
#             for i in range(P.size):
#                 for j in range(nf):
#                     f.write(f"{P.ind_array[i].f[j]:.6f} ")
#                 f.write("\n")
#
#         with open(f"{output_file_base}_V15_log.json", "w") as f:
#             json.dump(run_log, f, indent=2)
#
#         complete_free_pop(P)
#         cleanup_globals()
#
#     total_time = time.time() - start_time
#     print(f"\nTotal execution time: {total_time:.2f} seconds")
#     print(f"Average time per run: {total_time/NRUNS:.2f} seconds")
#     with open(f"{output_file_base}_V15_pareto.txt", "a") as f:
#         f.write(f"# RUNTIME: {total_time:.2f}\n")
#
# # Python helper functions for metrics (Unchanged)
# def calculate_hypervolume(pareto_points, ref_point=None):
#     if not pareto_points: return 0.0
#     if ref_point is None:
#         max_f1 = max(p[0] for p in pareto_points)
#         max_f2 = max(p[1] for p in pareto_points)
#         ref_point = (max_f1 * 1.1, max_f2 * 1.1)
#     points = sorted(pareto_points, key=lambda p: p[0])
#     hv = 0.0
#     for i in range(len(points) - 1):
#         x1, y1 = points[i]
#         x2, y2 = points[i + 1]
#         hv += (x2 - x1) * (ref_point[1] - y1)
#     if points:
#         x_last, y_last = points[-1]
#         hv += (ref_point[0] - x_last) * (ref_point[1] - y_last)
#     return hv
#
# def calculate_dominance_percentage(new_pareto, reference_pareto):
#     if not reference_pareto: return 100.0
#     if not new_pareto: return 0.0
#     dominated_count = 0
#     for ref_point in reference_pareto:
#         is_dominated = any(new_p[0] >= ref_point[0] and new_p[1] >= ref_point[1] and (new_p[0] > ref_point[0] or new_p[1] > ref_point[1]) for new_p in new_pareto)
#         if is_dominated: dominated_count += 1
#     return (dominated_count / len(reference_pareto)) * 100
# Out:
# Content of stdout:
# _cython_magic_f2b672d2f53c8b7909bd0dbae94dbd59ba054bd115516ed24460a055ce1769f8.c
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_f2b672d2f53c8b7909bd0dbae94dbd59ba054bd115516ed24460a055ce1769f8.c(5713): warning C4244: '='ÿ: conversion de 'double' en 'float', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_f2b672d2f53c8b7909bd0dbae94dbd59ba054bd115516ed24460a055ce1769f8.c(5803): warning C4244: '='ÿ: conversion de 'double' en 'float', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_f2b672d2f53c8b7909bd0dbae94dbd59ba054bd115516ed24460a055ce1769f8.c(6989): warning C4244: '='ÿ: conversion de 'Py_ssize_t' en 'int', perte possible de donn‚es
# C:\Users\Aziz il patal\.ipython\cython\_cython_magic_f2b672d2f53c8b7909bd0dbae94dbd59ba054bd115516ed24460a055ce1769f8.c(20639): warning C4305: '='ÿ: troncation de 'double' … 'float'
#    Cr‚ation de la bibliothŠque C:\Users\Aziz il patal\.ipython\cython\Users\Aziz il patal\.ipython\cython\_cython_magic_f2b672d2f53c8b7909bd0dbae94dbd59ba054bd115516ed24460a055ce1769f8.cp39-win_amd64.lib et de l'objet C:\Users\Aziz il patal\.ipython\cython\Users\Aziz il patal\.ipython\cython\_cython_magic_f2b672d2f53c8b7909bd0dbae94dbd59ba054bd115516ed24460a055ce1769f8.cp39-win_amd64.exp
# G‚n‚ration de code en cours
# Fin de la g‚n‚ration du code

# %%
# Cell 2
# !copy 2502_ResultsMD.txt 2502_ResultsMD_baseline.txt
baseline_data = load_baseline_pareto_front("2502_ResultsMD_baseline.txt")

# Use the V15 function
run_critic_author_moacp_v15(b"250.2.txt", b"Weights_2obj_FQ200.txt", 250, 2, "2502_ResultsMD", baseline_data)
# Out:
#         1 fichier(s) copi‚(s).
#
# --- RUN 1/10 --- V15 Critic-Author Agent (Final)
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV= 927946.72, Dominates Baseline= 0.28%
#   [Metrics] Iter  10: HV=1250476.69, Dominates Baseline= 7.36%
#   [Metrics] Iter  20: HV=3431437.82, Dominates Baseline=11.54%
#   [Metrics] Iter  30: HV=4719855.45, Dominates Baseline=24.13%
#   [Metrics] Iter  40: HV=5179601.92, Dominates Baseline=29.44%
#   [Metrics] Iter  50: HV=6018937.88, Dominates Baseline=31.14%
#   [Metrics] Iter  60: HV=6015402.88, Dominates Baseline=31.14%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  70: HV=6008069.88, Dominates Baseline=32.91%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  80: HV=6002310.88, Dominates Baseline=37.79%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  90: HV=5998982.88, Dominates Baseline=40.91%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 100: HV=5993729.88, Dominates Baseline=41.83%
#   [Stagnation] Counter: 5/5
#
# !!! STAGNATION DETECTED. Calling Critic-Author Agent (V15) for targeted refinement. !!!
#   [LLM Agent Call] Requesting a move suggestion...
#   [LLM Agent Success] Received a suggestion.
#   [Agent Fail] Swap 188 for 32 based on snapshot did not improve solution.
#   [Fallback] Applying random parameter reset.
#   [Metrics] Iter 110: HV=5988878.88, Dominates Baseline=42.53%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 120: HV=5977043.88, Dominates Baseline=50.18%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 130: HV=5976683.88, Dominates Baseline=51.66%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 140: HV=5976683.88, Dominates Baseline=51.66%
#   [Stagnation] Counter: 4/5
#
# --- RUN 2/10 --- V15 Critic-Author Agent (Final)
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV=1049680.76, Dominates Baseline= 0.00%
#   [Metrics] Iter  10: HV=6480222.30, Dominates Baseline= 5.73%
#   [Metrics] Iter  20: HV=5881139.30, Dominates Baseline=20.67%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  30: HV=5815079.30, Dominates Baseline=38.00%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  40: HV=5855482.30, Dominates Baseline=43.88%
#   [Metrics] Iter  50: HV=5754755.04, Dominates Baseline=49.89%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  60: HV=5806684.12, Dominates Baseline=52.02%
#   [Metrics] Iter  70: HV=5799334.12, Dominates Baseline=60.08%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  80: HV=5794778.12, Dominates Baseline=62.77%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  90: HV=5791254.12, Dominates Baseline=68.08%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 100: HV=5789582.12, Dominates Baseline=69.43%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 110: HV=5790057.12, Dominates Baseline=69.71%
#   [Metrics] Iter 120: HV=5789817.12, Dominates Baseline=71.69%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 130: HV=5788756.12, Dominates Baseline=72.12%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 140: HV=5786176.12, Dominates Baseline=72.97%
#   [Stagnation] Counter: 3/5
#
# --- RUN 3/10 --- V15 Critic-Author Agent (Final)
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV= 940763.63, Dominates Baseline= 0.00%
#   [Metrics] Iter  10: HV=7074539.52, Dominates Baseline= 2.41%
#   [Metrics] Iter  20: HV=6918704.52, Dominates Baseline= 7.43%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  30: HV=6617489.52, Dominates Baseline=20.88%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  40: HV=6430558.52, Dominates Baseline=28.17%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  50: HV=6444445.52, Dominates Baseline=35.03%
#   [Metrics] Iter  60: HV=6404763.02, Dominates Baseline=35.74%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  70: HV=6395286.02, Dominates Baseline=40.62%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  80: HV=6383838.02, Dominates Baseline=46.99%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  90: HV=6377054.02, Dominates Baseline=58.03%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 100: HV=6375319.02, Dominates Baseline=59.59%
#   [Stagnation] Counter: 5/5
#
# !!! STAGNATION DETECTED. Calling Critic-Author Agent (V15) for targeted refinement. !!!
#   [LLM Agent Call] Requesting a move suggestion...
#   [LLM Agent Success] Received a suggestion.
#   [Agent Fail] Swap 188 for 191 based on snapshot did not improve solution.
#   [Fallback] Applying random parameter reset.
#   [Metrics] Iter 110: HV=6375319.02, Dominates Baseline=59.59%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 120: HV=6370606.02, Dominates Baseline=62.28%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 130: HV=6368783.02, Dominates Baseline=63.55%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 140: HV=6367337.02, Dominates Baseline=64.33%
#   [Stagnation] Counter: 4/5
#
# --- RUN 4/10 --- V15 Critic-Author Agent (Final)
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV=1499135.28, Dominates Baseline= 0.00%
#   [Metrics] Iter  10: HV=7389967.36, Dominates Baseline= 1.42%
#   [Metrics] Iter  20: HV=7187117.36, Dominates Baseline= 3.18%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  30: HV=6793649.36, Dominates Baseline= 5.59%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  40: HV=6513996.36, Dominates Baseline= 6.44%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  50: HV=6540892.36, Dominates Baseline= 9.48%
#   [Metrics] Iter  60: HV=6566527.36, Dominates Baseline=11.75%
#   [Metrics] Iter  70: HV=6581779.36, Dominates Baseline=13.02%
#   [Metrics] Iter  80: HV=6562281.36, Dominates Baseline=17.55%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  90: HV=6547876.36, Dominates Baseline=27.03%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 100: HV=6546811.36, Dominates Baseline=27.81%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 110: HV=6547812.36, Dominates Baseline=27.81%
#   [Metrics] Iter 120: HV=6460160.88, Dominates Baseline=30.15%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 130: HV=6456428.88, Dominates Baseline=33.47%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 140: HV=6457670.88, Dominates Baseline=35.74%
#
# --- RUN 5/10 --- V15 Critic-Author Agent (Final)
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV= 952131.42, Dominates Baseline= 0.00%
#   [Metrics] Iter  10: HV=1152828.50, Dominates Baseline= 1.77%
#   [Metrics] Iter  20: HV=6957532.70, Dominates Baseline= 8.49%
#   [Metrics] Iter  30: HV=6678517.70, Dominates Baseline=27.25%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  40: HV=6571376.70, Dominates Baseline=33.55%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  50: HV=6537656.70, Dominates Baseline=36.31%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  60: HV=6543993.70, Dominates Baseline=37.79%
#   [Metrics] Iter  70: HV=6544038.70, Dominates Baseline=37.86%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  80: HV=6539965.70, Dominates Baseline=39.07%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  90: HV=6537014.70, Dominates Baseline=41.05%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 100: HV=6536976.70, Dominates Baseline=41.05%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 110: HV=6531353.70, Dominates Baseline=42.11%
#   [Stagnation] Counter: 5/5
#
# !!! STAGNATION DETECTED. Calling Critic-Author Agent (V15) for targeted refinement. !!!
#   [LLM Agent Call] Requesting a move suggestion...
#   [LLM Agent Success] Received a suggestion.
#   [Agent Fail] Swap 228 for 58 based on snapshot did not improve solution.
#   [Fallback] Applying random parameter reset.
#   [Metrics] Iter 120: HV=6531137.70, Dominates Baseline=43.24%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 130: HV=6528588.70, Dominates Baseline=45.93%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 140: HV=6518807.70, Dominates Baseline=55.56%
#   [Stagnation] Counter: 3/5
#
# --- RUN 6/10 --- V15 Critic-Author Agent (Final)
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV= 810822.87, Dominates Baseline= 2.19%
#   [Metrics] Iter  10: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  20: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  30: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  40: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter  50: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 5/5
#
# !!! STAGNATION DETECTED. Calling Critic-Author Agent (V15) for targeted refinement. !!!
#   [LLM Agent Call] Requesting a move suggestion...
#   [LLM Agent Success] Received a suggestion.
#   [Agent Fail] Swap 228 for 66 based on snapshot did not improve solution.
#   [Fallback] Applying random parameter reset.
#   [Metrics] Iter  60: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  70: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  80: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  90: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 100: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 5/5
#
# !!! STAGNATION DETECTED. Calling Critic-Author Agent (V15) for targeted refinement. !!!
#   [LLM Cache Hit] Using cached response.
#   [Agent Fail] Swap 228 for 66 based on snapshot did not improve solution.
#   [Fallback] Applying random parameter reset.
#   [Metrics] Iter 110: HV= 810822.87, Dominates Baseline= 2.19%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 120: HV=4383500.45, Dominates Baseline= 2.48%
#   [Metrics] Iter 130: HV=4383500.45, Dominates Baseline= 2.48%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 140: HV=4383500.45, Dominates Baseline= 2.48%
#   [Stagnation] Counter: 2/5
#
# --- RUN 7/10 --- V15 Critic-Author Agent (Final)
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV=1126483.34, Dominates Baseline= 0.00%
#   [Metrics] Iter  10: HV=1439688.32, Dominates Baseline= 3.18%
#   [Metrics] Iter  20: HV=6639126.52, Dominates Baseline= 5.17%
#   [Metrics] Iter  30: HV=6452113.52, Dominates Baseline=15.57%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  40: HV=6286224.52, Dominates Baseline=30.08%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  50: HV=6143033.52, Dominates Baseline=34.04%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  60: HV=6138183.52, Dominates Baseline=41.54%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter  70: HV=6302489.02, Dominates Baseline=43.03%
#   [Metrics] Iter  80: HV=6301645.02, Dominates Baseline=43.38%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  90: HV=6297917.02, Dominates Baseline=44.80%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 100: HV=6291654.02, Dominates Baseline=50.25%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 110: HV=6290706.02, Dominates Baseline=51.45%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 120: HV=6290984.02, Dominates Baseline=51.52%
#   [Metrics] Iter 130: HV=6291080.02, Dominates Baseline=51.73%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 140: HV=6286434.02, Dominates Baseline=54.99%
#   [Stagnation] Counter: 2/5
#
# --- RUN 8/10 --- V15 Critic-Author Agent (Final)
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV=1058631.28, Dominates Baseline= 0.00%
#   [Metrics] Iter  10: HV=1365757.41, Dominates Baseline= 1.91%
#   [Metrics] Iter  20: HV=1476100.85, Dominates Baseline= 2.55%
#   [Metrics] Iter  30: HV=5913150.00, Dominates Baseline=11.96%
#   [Metrics] Iter  40: HV=5778829.00, Dominates Baseline=26.96%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  50: HV=5715752.00, Dominates Baseline=34.04%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  60: HV=5703573.00, Dominates Baseline=39.84%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter  70: HV=6330773.98, Dominates Baseline=44.66%
#   [Metrics] Iter  80: HV=6330124.98, Dominates Baseline=45.36%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  90: HV=6315625.98, Dominates Baseline=52.30%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 100: HV=6297147.98, Dominates Baseline=61.43%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 110: HV=6289266.98, Dominates Baseline=67.02%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 120: HV=6289365.98, Dominates Baseline=67.80%
#   [Stagnation] Counter: 5/5
#
# !!! STAGNATION DETECTED. Calling Critic-Author Agent (V15) for targeted refinement. !!!
#   [LLM Agent Call] Requesting a move suggestion...
#   [LLM Agent Success] Received a suggestion.
#   [Agent Fail] Swap 188 for 191 based on snapshot did not improve solution.
#   [Fallback] Applying random parameter reset.
#   [Metrics] Iter 130: HV=6289872.98, Dominates Baseline=68.51%
#   [Metrics] Iter 140: HV=6290800.98, Dominates Baseline=70.13%
#
# --- RUN 9/10 --- V15 Critic-Author Agent (Final)
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV= 960346.20, Dominates Baseline= 0.00%
#   [Metrics] Iter  10: HV=1343951.75, Dominates Baseline= 5.10%
#   [Metrics] Iter  20: HV=1934420.00, Dominates Baseline=10.54%
#   [Metrics] Iter  30: HV=6103517.40, Dominates Baseline=14.51%
#   [Metrics] Iter  40: HV=5659041.30, Dominates Baseline=25.05%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  50: HV=5790694.30, Dominates Baseline=43.67%
#   [Metrics] Iter  60: HV=5808100.30, Dominates Baseline=45.15%
#   [Metrics] Iter  70: HV=5807658.30, Dominates Baseline=45.15%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  80: HV=6092600.30, Dominates Baseline=48.97%
#   [Metrics] Iter  90: HV=6092611.30, Dominates Baseline=49.75%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 100: HV=6090804.30, Dominates Baseline=50.81%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 110: HV=6085043.30, Dominates Baseline=55.13%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 120: HV=6084901.30, Dominates Baseline=55.34%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 130: HV=6084747.30, Dominates Baseline=55.63%
#   [Stagnation] Counter: 5/5
#
# !!! STAGNATION DETECTED. Calling Critic-Author Agent (V15) for targeted refinement. !!!
#   [LLM Agent Call] Requesting a move suggestion...
#   [LLM Agent Success] Received a suggestion.
#   [Agent Fail] Swap 228 for 58 based on snapshot did not improve solution.
#   [Fallback] Applying random parameter reset.
#   [Metrics] Iter 140: HV=6080785.30, Dominates Baseline=57.96%
#   [Stagnation] Counter: 1/5
#
# --- RUN 10/10 --- V15 Critic-Author Agent (Final)
# Instance: 250.2.txt, Items: 250, Objectives: 2
#   [Problem Features] {
#     "num_items": 250,
#     "num_objectives": 2,
#     "capacity_tightness": 1.0,
#     "avg_profit_variance": 745.59,
#     "avg_weight_variance": 693.31
# }
#   [Metrics] Iter   0: HV= 911714.70, Dominates Baseline= 0.00%
#   [Metrics] Iter  10: HV=1526198.08, Dominates Baseline= 9.98%
#   [Metrics] Iter  20: HV=2292455.44, Dominates Baseline=14.93%
#   [Metrics] Iter  30: HV=6572079.96, Dominates Baseline=16.99%
#   [Metrics] Iter  40: HV=6360681.96, Dominates Baseline=23.92%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  50: HV=6158110.96, Dominates Baseline=31.00%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter  60: HV=6217260.96, Dominates Baseline=33.05%
#   [Metrics] Iter  70: HV=6214244.96, Dominates Baseline=35.03%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter  80: HV=6226418.96, Dominates Baseline=35.39%
#   [Metrics] Iter  90: HV=6209421.96, Dominates Baseline=39.63%
#   [Stagnation] Counter: 1/5
#   [Metrics] Iter 100: HV=6201020.96, Dominates Baseline=48.97%
#   [Stagnation] Counter: 2/5
#   [Metrics] Iter 110: HV=6198470.96, Dominates Baseline=52.80%
#   [Stagnation] Counter: 3/5
#   [Metrics] Iter 120: HV=6197986.96, Dominates Baseline=53.01%
#   [Stagnation] Counter: 4/5
#   [Metrics] Iter 130: HV=6559386.24, Dominates Baseline=54.21%
#   [Metrics] Iter 140: HV=6530184.24, Dominates Baseline=59.52%
#   [Stagnation] Counter: 1/5
#
# Total execution time: 53.92 seconds
# Average time per run: 5.39 seconds
